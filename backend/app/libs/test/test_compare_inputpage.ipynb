# %%
import sys
import os

# 現在の作業ディレクトリを取得
current_dir = os.getcwd()

# utilsディレクトリへのパスを構築
utils_path = os.path.join(current_dir, '../../utils')

# utilsディレクトリをシステムパスに追加
sys.path.append(utils_path)
sys.path.append('../')

# モジュールをインポート
from html_to_df import input_html_to_df_rsa, result_html_to_df_rsa
from compare_inputpage import compare_inputpage

# %%
input_html_str = """
<!DOCTYPE html>
<html>

<head>
                        <script src="/js/jquery.js?1580433509"></script>    
    <title>
        人生掌握【ゆめの心々渾身】あなたの全運命を霊視◆1年⇒10年後/晩年 | cocoloni占い館 Moon    </title>
            <meta name="viewport" content="width=device-width, initial-scale=1.0">
    
            <!-- Google Tag Manager -->
        <script>
            (function(w, d, s, l, i) {
                w[l] = w[l] || [];
                w[l].push({
                    'gtm.start': new Date().getTime(),
                    event: 'gtm.js'
                });
                var f = d.getElementsByTagName(s)[0],
                    j = d.createElement(s),
                    dl = l != 'dataLayer' ? '&l=' + l : '';
                j.async = true;
                j.src = 'https://www.googletagmanager.com/gtm.js?id=' + i + dl;
                f.parentNode.insertBefore(j, f);
            })(window, document, 'script', 'dataLayer', 'GTM-MV3KXWG');
        </script>
        <!-- End Google Tag Manager -->
            
    
    <meta charset="utf-8"/>
            <meta name="description" content="チャクラ占い｜目には見えない人の運命。しかし、人の体にあるチャクラとそこから流れるエネルギーを視れば、その詳細を知ることができるのです。あなたのチャクラのエネルギーから、あなただけに与えられた運命、歩んでいく人生の詳細を明らかにしていきましょう。" />            <meta name="Keywords" content="[%keyword%]" />                        <meta property="og:type" content="article" />                    <meta property="og:image" content="https://web-img.rensa.jp.net/rensa/images/web/Cocoloni/Yumecakra/1200_630.jpg" />                    <meta property="og:title" content="人生掌握【ゆめの心々渾身】あなたの全運命を霊視◆1年⇒10年後/晩年 | cocoloni占い館 Moon" />                    <meta property="og:description" content="チャクラ占い｜目には見えない人の運命。しかし、人の体にあるチャクラとそこから流れるエネルギーを視れば、その詳細を知ることができるのです。あなたのチャクラのエネルギーから、あなただけに与えられた運命、歩んでいく人生の詳細を明らかにしていきましょう。" />                    <meta property="og:url" content="https://honkaku-uranai.jp/cp_rsa/yumecakra_rsa/pre/life001/">        <meta property="og:locale" content="ja_JP" />
                
        </head>

<body>
    
            <!-- Google Tag Manager (noscript) -->
        <noscript><iframe src="https://www.googletagmanager.com/ns.html?id=GTM-MV3KXWG" height="0" width="0" style="display:none;visibility:hidden"></iframe></noscript>
        <!-- End Google Tag Manager (noscript) -->
                                    <!-- <script><//?php echo mb_convert_encoding( file_get_contents('https://630hso4ag2.user-space.cdn.idcfcloud.net/js/'.$cocoloniJsFailName ) , 'utf-8', 'euc-jp') ?></script> -->
                <script type="text/javascript" src="https://630hso4ag2.user-space.cdn.idcfcloud.net/js/honkaku_common.js" charset="EUC-JP" ;></script>
                            <!-- cocoloni header tag start -->
        <div id="honkaku_header" style="display:none;">
                            <input type="hidden" name="contents_name" value="yumecakra_rsa">
                                    <input type="hidden" name="zp_channel_id" value="105_yc0004a">
                                    </div>
        <!-- cocoloni header tag start -->
        <!-- contents_headerCopy start -->
        <p class="contents_headerCopy">
                            人生掌握【ゆめの心々渾身】あなたの全運命を霊視◆1年⇒10年後/晩年                    </p>
        <!-- contents_headerCopy end -->
        <noscript>
            <!-- cocoloni sp javascript not working -->
            <style>
                .js-error-section {
                    margin: 1vw;
                    padding: 1vw;
                    background: #fff;
                    border: 2px solid #dc0000;
                    text-align: center;
                    font-size: 2vw;
                }
            </style>
            <div class="js-error-section">
                <p>お客様が現在お使いのブラウザでは、JavaScriptの設定が無効となっています。<br />
                    当サイトはJavaScriptを使用致しますので、設定をオンにご変更下さい。</p>
            </div>
        </noscript>
        <div id="cocoloniAttention"></div>
        <!-- cocoloniAttention -->
    
    
        
        <div class="container clearfix">

        <!-- CSS -->
<style>
@import url('https://fonts.googleapis.com/css2?family=Noto+Sans+JP&display=swap');
body , main , h1 , h2 , h3 , h4 , h5 , p , img , div {
  margin: 0px;
  font-family: 'Noto Sans JP', sans-serif;
}
html {
  font-size: 16px;
}
a {
  transition: all 0.25s 0s ease;
  text-underline-offset: 0.25em;
}
a:hover {
  text-decoration: none;
}
button {
  cursor: pointer;
  background-color: transparent;
  border: none;
}

/********************************************************************/
/* use common background and common font size and color adjustment */
/******************************************************************/
.content_main {
  background: url("https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/common/main_background.jpg") no-repeat center top;
  background-size: 1800px 1600px;
  min-width: 990px;
  background-color: #131120;
  background-attachment: fixed;
  color: white;
  display: block;
  overflow: hidden;
}

.main_shadow {
  max-width: 1800px;
  margin: 0 auto;
  box-shadow: 100px 0 50px -50px #131120 inset, -100px 0px 50px -50px #131120 inset;
}

/**********************************/
/* use common  section adjustment */
/*********************************/
.section_container {
  width: 990px;
  margin: 0 auto;
}
.section_background {
  background: url('https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/common/section_background.jpg') repeat-y;
  background-size: 100%;
}

/* cocoloniのおすすめリンク先のスタイル */
  .content-main {
    background: url("https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/common/main_background.jpg") no-repeat center top;
    background-size: 1800px 1600px;
    min-width: 990px;
    background-color: #131120;
    background-attachment: fixed;
    color: white;
    display: block;
    overflow: hidden;
  }
  .section-container {
    width: 990px;
    margin: 0 auto;
  }
  .section-background {
    background: url('https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/common/section_background.jpg') repeat-y;
    background-size: 100%;
  }

/* つなぎ込み部分 */
.balloon_connect_background {
  background: url('https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/result_background.jpg') repeat-y;
  background-position: center;
  background-size: 100%;
  min-height: 100px;
  padding: 3% 5% 2%;
}
.balloon_connect {
  background-color: #00000080;
  width: 100%;
  min-height: 100px;
  text-align: left;
  margin-bottom: 3%;
  padding: 2% 5%;
  box-sizing: border-box;
  border-radius: 22px;
  box-shadow: 0 0 10px #f9fbbdb3, 0 0 10px #f9fbbdb3;
}
.balloon_connect p {
  font-family: "ヒラギノ明朝 ProN W6", "HiraMinProN-W6", "HG明朝E", "ＭＳ Ｐ明朝", "MS PMincho", "MS 明朝", serif;
  font-size: 1.3rem;
  line-height: 140%;
  color: #ffffff;
  letter-spacing: 0.05rem;
}

/*************************************/
/* use free menu buttons adjustment */
/***********************************/
.top_free_menu_buttons {
  text-align: center;
}
.top_free_menu_buttons button {
  width: 700px;
  height: 280px;
  padding: 0;
  border: none;
  outline: none;
  cursor: pointer;
  background-size: 100% 100%;
}
.top_free_menu_buttons img {
  width: 100%;
  height: 100%;
  border: none;
  outline: none;
}

/**********************/
/* use text menu link */
/**********************/
.appraisal_menu {
  display: flex;
  flex-flow: column;
  text-align: left;
}
.appraisal_menu img {
  width: 11%;
  float: left;
  margin-right: 2%;
}

.appraisal_menu a {
  color: #ffcf3a;
}
.appraisal_menu a:hover {
  color: #c29c27;
}
.appraisal_menu.light a {
  color: #4901a6;
}
.appraisal_menu.light a:hover {
  color: #7203ff;
}
.appraisal_menu a p {
  font-family: "ヒラギノ明朝 ProN W6", "HiraMinProN-W6", "HG明朝E", "ＭＳ Ｐ明朝", "MS PMincho", "MS 明朝", serif;
  letter-spacing: 0.05rem;
  font-size: 30px;
  font-weight: bold;
  display: inline;
  line-height: 140%;
}

.appraisal_menu .description {
  font-size: 18px;
  font-weight: normal;
  color: #ffffff;
  padding: 1%;
}
.appraisal_menu.light .description {
  color: #000000;
}

.menu_info {
  text-align: right;
  font-size: 16px;
}
.add_day {
  color: red;
}
.price {
  font-weight: bold;
}
.appraisal_menu.light .premium_price {
  color: #236310;
}
.appraisal_menu.light .common_price {
  color: #983030;
}
.premium_price {
  color: #8ede77;
}
.common_price {
  color: #FF9494;
}
/* 説明文言強調 */
.telling_background {
  width: 100%;
  background: url("https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/top/telling_introduction_sample_background.jpg") repeat-y;
  background-position: center;
  background-size: 100%;
}
.telling_description {
  font-family: "ヒラギノ明朝 ProN W6", "HiraMinProN-W6", "HG明朝E", "ＭＳ Ｐ明朝", "MS PMincho", "MS 明朝", serif;
  letter-spacing: 0.05rem;
  color: #ffffff;
  width: 95%;
  font-size: 1.3rem;
  text-align: left;
  margin: 0 auto 2%;
  line-height: 140%;
}

.telling_link_head {
  color: #fc97fd;
  font-family: "ヒラギノ明朝 ProN W6", "HiraMinProN-W6", "HG明朝E", "ＭＳ Ｐ明朝", "MS PMincho", "MS 明朝", serif;
  letter-spacing: 0.05rem;
  font-weight: bold;
  text-shadow: 0 0 10px #686860;
  width: 100%;
  font-size: 1.3rem;
  text-align: center;
  margin: 10px auto;
}

.strong-text {
  text-align: left;
  color: #FFFFFF;
}
.blue {
  text-shadow: 0 0 5px #0066CC, 0 0 5px #0066CC, 0 0 5px #0066CC, 0 0 5px #0066CC, 0 0 5px #0066CC;
}
.green {
  text-shadow: 0 0 5px #009966, 0 0 5px #009966, 0 0 5px #009966, 0 0 5px #009966, 0 0 5px #009966;
}
</style><style>
  .index_text_link {
    color: #73c2f4;
    font-size: 1.3rem;
    text-decoration: underline;
    font-weight: bold;
    font-family: "ヒラギノ明朝 ProN W6", "HiraMinProN-W6", "HG明朝E", "ＭＳ Ｐ明朝", "MS PMincho", "MS 明朝", serif;
    letter-spacing: 0.05rem;
    display: inline;
    line-height: 140%;
  }
  .index_text_link:not(:last-child) {
    margin-bottom: 7px;
  }
  .index_text_link:hover {
    color: #5b5ff1;
    text-decoration: none;
  }
  .index_text_link.link1 {
    color: #CCFFFF;
  }
  .index_text_link.link1:hover {
    color: #5b5ff1;
  }
  .index_text_link.link2 {
    color: #CC99FF;
  }
  .index_text_link.link2:hover {
    color: #e55eff;
  }
  .index_text_link.link3 {
    color: #FF99CC;
  }
  .index_text_link.link3:hover {
    color: #fb3397;
  }


  /******************************+***/
  /* use top category menu section */
  /*********************************/
  .top_menu_link_background_center {
    width: 100%;
    background: url('https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/top/top_menu_list_background.jpg') repeat-y;
    background-position: center;
    background-size: 100%;
    padding: 20px 90px 0;
    box-sizing: border-box;
  }
  .content_menu_link_background_center {
    width: 100%;
    padding: 2% 9%;
    box-sizing: border-box;
    font-size: 1.3rem;
  }
  .category_transition_link {
    font-size: 1.3rem;
    color: #ffffff;
    margin: 1% 3%;
    float: right;
  }
  .category_transition_link:hover {
    color: #73c2f4;
  }
  .content_menu_transition_buttons {
    display: flex;
    height: 110px;
  }
  .content_menu_transition_buttons a {
    width: 33.33%;
  }
  .content_menu_transition_buttons img {
    width: 100%;
    height: 106px;
  }
  .content_menu_transition_buttons div {
    background-size: 100%;
    height: 110px;
  }
  .content_menu_transition_buttons div:hover{
    background-size: 100%;
    height: 110px;
  }

  /******************************+***/
  /* use top free tarot ancker text */
  /*********************************/

  /* worries section */
  .worries-container {
    width: 100%;
    height: 100%;
    position: relative;
  }

  .worries-container img {
    width: 100%;
    height: auto;
  }

  .worries-container a {
    width: 100%;
    font-size: 1.5rem;
    color: #ffffff;
    padding: 10px;
    border-radius: 5px;
    box-shadow: rgba(0,0,0,1) 0 1px 0;
    text-shadow: rgba(0,0,0,.4) 0 1px 0;
    letter-spacing: inherit;
    cursor: pointer;
    text-decoration: underline;
  }

  .worries-container a:hover {
    color: #ffffa4;
    text-decoration: none;
  }

  .worries-container_menus {
    position: absolute;
    top: 56%;
    left: 9%;
    width: 62%;
    text-align: left;
  }

  .worries-container_menus div {
    margin-bottom: 8%;
  }

  .worries-container a.onayami-show-next {
    background-color: #6E6657;
  }
  .worries-container a.onayami-show-next:hover {
    color: #ffffa4;
    text-decoration: none;
  }

  /* Free Tarot */
  .free_tarot_background {
    width: 100%;
    min-height: 390px;
    background: url('https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/top/tarot_free_appraisal_menu_background.jpg') repeat-y;
    background-size: 100%;
    position: relative;
  }
  .free_tarot_background_inner {
    position: absolute;
    top: 0;
    left: 0;
    width: 100%;
    min-height: 390px;
  }
  .free_tarot_background_over {
    width: 100%;
    box-sizing: border-box;
    background: url('https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/top/tarot_free_appraisal_menu_background.jpg') no-repeat;
    background-size: 100% 100%;
    display: none;
  }
  .top_free_tarot_result_text_box {
    padding: 0 5% 2%;
    text-align: left;
  }
  #top_free_tarot_result_menu_link {
    margin: 2% 0;
  }
  .top_free_tarot_link_text {
    color: #e0ff80;
    font-size: 1.3rem;
    line-height: 140%;
  }
  .top_free_tarot_link_text:hover {
    color: #c1ff00;
    text-decoration: none;
  }
  .top_free_tarot_appraisal_menu_box {
    padding: 0 7%;
  }

  .free_tarot_display {
    position: absolute;
    top: 0%;
    left: 0%;
    width: 100%;
    height: 390px;
    z-index: 10;
  }
  .free_tarot_question {
    width: 100%;
    text-align: center;
    margin: 1% 0 2%;
  }
  .free_tarot_question p {
    font-family: "ヒラギノ明朝 ProN W6", "HiraMinProN-W6", "HG明朝E", "ＭＳ Ｐ明朝", "MS PMincho", "MS 明朝", serif;
    color: #ffffff;
    font-size: 2.4rem;
    letter-spacing: 0.05rem;
  }
  /* 生年月日入力欄 */
  .birthday_select_box.free_tarot_birthday_select_box {
      margin-left: 17%;
      display: flex;
      align-items: end;
      gap: 2%;
  }
  .birthday_select_box.free_tarot_birthday_select_box select {
    font-family:  "ヒラギノ明朝 ProN W6", "HiraMinProN-W6", "HG明朝E", "ＭＳ Ｐ明朝", "MS PMincho", "MS 明朝", serif;
    letter-spacing: 0.05rem;
    font-size: 2.5rem;
    line-height: 140%;
  }
  .birthday_select_box.free_tarot_birthday_select_box p {
    font-family:  "ヒラギノ明朝 ProN W6", "HiraMinProN-W6", "HG明朝E", "ＭＳ Ｐ明朝", "MS PMincho", "MS 明朝", serif;
    letter-spacing: 0.05rem;
  }

  #free_tarot_button {
    width: 464px;
    height: 196px;
    margin: 6% auto 0;
    cursor: pointer;
  }
  #free_tarot_button img {
    width: 100%;
  }

  .loading_text_box {
    position: absolute;
    top: 0%;
    left: 0%;
    width: 100%;
    height: 390px;
    text-align: left;
    display: none;
  }
  #loading_text {
    font-family: "ヒラギノ明朝 ProN W6", "HiraMinProN-W6", "HG明朝E", "ＭＳ Ｐ明朝", "MS PMincho", "MS 明朝", serif;
    font-weight: bold;
    font-size: 5rem;
    color: #ffffff;
    margin-top: 15%;
    margin-left: 25%;
    letter-spacing: 0.05rem;
  }

  .free_tarot_box {
    position: absolute;
    top: 0%;
    left: 0%;
    width: 100%;
    height: 390px;
  }
  #free_tarot_teller_box,
  #free_tarot_chakra_image,
  #free_tarot_result_box {
    display: none;
  }

  .free_tarot_teller_image {
    background: url(https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/res_type_yumeno2.jpg) no-repeat;
    background-position: center;
    background-size: 100%;
    width: 100%;
    height: 357px;
  }

  .free_tarot_teller_comment_box {
    position: absolute;
    top: 50%;
    right: 1%;
    transform: translateY(-50%);
    width: 60%;
  }
  .free_tarot_teller_comment_box p {
    font-family: "ヒラギノ明朝 ProN W6", "HiraMinProN-W6", "HG明朝E", "ＭＳ Ｐ明朝", "MS PMincho", "MS 明朝", serif;
    font-weight: bold;
    font-size: 2.8rem;
    color: #CC99FF;
    text-shadow: 0 0 4px #000000, 0 0 8px #000000, 0 0 8px #ae00ff;
    line-height: 140%;
    letter-spacing: 0.05rem;
  }
  .chakra_image_box {
    position: absolute;
    top: 50%;
    left: 66%;
    transform: translate(-50%, -50%);
    width: 300px;
    height: 300px;
  }
  .chakra_image_box img {
    width: 100%;
  }

  .free_tarot_result_text {
    width: 100%;
    text-align: left;
    font-size: 1.3rem;
    color: #ffffff;
    line-height: 140%;
  }

  /* show_text_link */
  .show-text-link a {
    font-size: 1.32rem;
  }
  .show-text-link_flex {
    display: flex;
    justify-content: space-between;
    align-items: center;
    width: 90%;
    margin: 0 auto;
  }
  .show-text-link_flex_left {
    width: 12%;
  }
  .show-text-link_flex_right {
    width: 85%;
    text-align: left;
  }
  .show-text-link_flex_right div {
    text-align: right;
  }

  .show-text-link_flex_right_new {
    font-size: 1.1rem;
    color: red;
    text-align: right;
  }

  .show-text-link_ballon {
    background: linear-gradient(to right, #ffb1aa 1%,#f16a60 10%, #f16a60 90%,#ffb1aa 99%);
    padding: 5px;
    margin-bottom: 25px;
    font-size: 1.5rem;
  }
</style><style>
.appraisal_start_button_section {
  text-align: center;
  min-height: 135px;
}
.menu_caption {
  margin: 0% 3% 2%;
  text-align: left;
  font-size: 1.3rem;
}

.woman_only {
  font-size: 1.3rem;
  color: #ffffff;
}
</style><!-- -->

<main class="content_main">
  <div class="main_shadow">
    <section id="header"><style>
            .header_background_index {
            max-width: 1000px;
            margin: 0 auto;
            background: url('https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/header/header_background.png');
            background-repeat: no-repeat;
            background-size: 100%;
            position: relative;
        }

        .header_background {
            max-width: 1000px;
            margin: 0 auto;
            background: url('https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/header/header_background_harf.png');
            background-repeat: no-repeat;
            background-size: 100%;
            position: relative;
        }
    
    /*************************************************/
    /* use free items transition navigation section */
    /***********************************************/
    .navigation_background a div {
        width: 100%;
        height: 172px;
    }

    .navigation_background .navigation_menu_links {
        width: 990px;
        height: 180px;
        display: flex;
        justify-content: space-around;
        flex-wrap: wrap;
    }

    .navigation_background .navigation_menu_links a {
        width: 330px;
        height: 176px;
        background-size: 100% 100%;
    }

    .navigation_background .navigation_menu_links img {
        width: 100%;
        height: 100%;
    }

    .navigation_background .navigation_menu_links_minori {
        width: 990px;
        height: 190px;
        display: flex;
        justify-content: space-around;
        flex-wrap: wrap;
    }

    .navigation_background .navigation_menu_links_minori a {
        width: 240px;
        height: 190px;
        background-size: 100% 100%;
    }

    .navigation_background .navigation_menu_links_minori img {
        width: 100%;
        height: 100%;
    }

    /*************************************************/
    /* use each pages tarnsition navigation section */
    /***********************************************/
    .navigation_background .navigation_menu_pages {
        width: 990px;
        height: 110px;
        box-sizing: border-box;
        background: url('https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/header/navigation_background.png') no-repeat;
        display: flex;
        justify-content: center;
        align-items: end;
        flex-wrap: wrap;
    }

    .navigation_background .navigation_menu_pages a {
        width: 270px;
        height: 90px;
        background-size: 100% 100%;
    }

    .navigation_background .navigation_menu_pages img {
        width: 100%;
        height: 100%;
    }

    /******************/
    /* use addcrumbs */
    /****************/
    .addcrumbs_text_section {
        text-align: left;
        color: #ffffff;
        font-size: 1.3rem;
        background-size: 100% 100%;
        background: url('https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/common/section_background.jpg');
        padding: 10px 50px;
    }

    .addcrumbs_text_section a {
        color: #24aaff;
    }

    .addcrumbs_text_section a:hover {
        color: #5b5ff1;
    }
</style>

<!DOCTYPE html>


<header>
    <!-- KV image -->
                <div class="header_background">
                        <section id="header" class="section_container">
                <div class="navigation_background">
                    <!-- KV image link range -->
                                            <a href="/cp_rsa/yumecakra_rsa/">
                            <div></div>
                        </a>
                                                            <section id="pageTransitionNavigation">
                        <!------------------------------------------->
                        <!-- page transition buttons section start -->
                        <!------------------------------------------->
                        <div class="navigation_menu_pages">
                                                            <a class="navigation_menu_page_button_left" href="/cp_rsa/yumecakra_rsa/teller/"><img loading="lazy" alt='監修者紹介' src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/header/navigation_button1.png" onmouseover="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/header/navigation_button1_over.png'" onmouseout="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/header/navigation_button1.png'"></a>
                                                                                        <a class="navigation_menu_page_button_center" href="/cp_rsa/yumecakra_rsa/telling/"><img loading="lazy" alt='占術紹介' src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/header/navigation_button2.png" onmouseover="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/header/navigation_button2_over.png'" onmouseout="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/header/navigation_button2.png'"></a>
                                                                                        <a target="_new" class="navigation_menu_page_button_right" href="/cp_rsa/yumecakra_rsa/recommend/"><img loading="lazy" alt='おすすめリンク' src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/header/navigation_button3.png" onmouseover="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/header/navigation_button3_over.png'" onmouseout="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/header/navigation_button3.png'"></a>
                                                    </div>
                        <!----------------------------------------->
                        <!-- page transition buttons section end -->
                        <!----------------------------------------->
                        <!------------------------------>
                        <!-- topic path section start -->
                        <!------------------------------>

                                                    <div id="topicpath" class="addcrumbs_text_section">
                                <p>
                                                                            <a href="/moon/">cocoloni占い館 Moon Top</a>&nbsp;&gt;&nbsp;<a href="/cp_rsa/yumecakra_rsa/">【ゆめの心々】チャクラ占い</a>&nbsp;&gt;&nbsp;人生掌握【ゆめの心々渾身】あなたの全運命を霊視◆1年⇒10年後/晩年                                                                    </p>
                            </div>
                                                <!------------------------------>
                        <!-- topic path section start -->
                        <!------------------------------>
                    </section>
                </div>
            </section>
            </div><!-- KV image div -->
</header></section>
    <section class="section_container section_background">
      <div style="margin: 0 50px; text-align: center;">
        <section id="contentMenuTitleDisplay">
          <style>
  /******************************/
  /* 選択アイテムメニュー表示で使用 */
  /****************************/
  .content_menu_title_background_center {
    background: url("https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/pre/choice_item_menu_background.png") repeat-y;
    background-position: center;
    text-align: left;
    padding: 0 70px;
    line-height: 190%;
    display: flex;
    align-items: center;
  }

  .content_menu_title_background_center p {
    font-size: 1.9rem;
    font-weight: bold;
    font-family: "ヒラギノ明朝 ProN W6", "HiraMinProN-W6", "HG明朝E", "ＭＳ Ｐ明朝", "MS PMincho", "MS 明朝", serif;
    letter-spacing: 0.05rem;
    color: #ffcf3a;
    line-height: 140%;
  }

  .icon_image_box {
    width: 19%;
    display: flex;
  }

  .icon_image_box img {
    width: 75px;
    height: 75px;
    margin: auto;
  }
</style>

<img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/pre/choice_item_menu_top.png" style="width: 100%; vertical-align: bottom">
<div class="content_menu_title_background_center">
  <div class="icon_image_box">
    <img src="https://img.rensa.jp.net/web/RYC/menu/icon_off/icon12.png" alt="人生"/>  </div>
  <p>    人生掌握【ゆめの心々渾身】あなたの全運命を霊視◆1年⇒10年後/晩年
</p>
</div>
<img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/pre/choice_item_menu_bottom.png" style="width: 100%; vertical-align: top;">        </section>

        <section id="preTellerComment">
          <p class="menu_caption">チャクラ占い｜目には見えない人の運命。しかし、人の体にあるチャクラとそこから流れるエネルギーを視れば、その詳細を知ることができるのです。あなたのチャクラのエネルギーから、あなただけに与えられた運命、歩んでいく人生の詳細を明らかにしていきましょう。</p>
          <img loading="lazy" alt='『気持ちが1つにならない』『想いが伝わらない』『思い通りにいかない』それはチャクラのエネルギーがうまく流れていないから。チャクラを霊視で調律し、バランスを整えエネルギーを流せばどんな願いも満願成就します。チャクラ調律師ゆめの心々のチャクラ占い' src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/top/top_billboard.jpg" style="width: 100%;">
        </section>

        <!-- start input form section transition button -->
        <div class="appraisal_start_button_section">
          <a href="#profileForm">
            <button>
              <img loading="lazy" alt='鑑定を始める' src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/form/input_profile_button.png" onmouseover="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/form/input_profile_button_over.png'" onmouseout="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/form/input_profile_button.png'">
            </button>
          </a>
        </div>

        

        <section id="subMenuTitleLists">
          <img loading="lazy" alt='鑑定項目' src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/pre/submenu_title_list_head.png" style="width: 100%; vertical-align: bottom;">
          <div class="submenu_titles_list_background_center">
            <style>
  .recommend_view_pay_item_price {
    padding: 50px 55px 0;
    text-align: center;
    font-weight: bold;
  }

  .submenu_titles_list_background_center {
    background: url('https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/pre/submenu_title_list_background.png') repeat-y;
    background-position: center;
    background-size: 100%;
    padding: 0 155px;
    color: #ffffff;
    text-align: left;
  }

  .submenu_title {
    display: flex;
    padding: 2% 0;
    align-items: start;
    justify-content: flex-start;
    gap: 4%;
  }
  .submenu_title img {
    width: 20px;
    padding-top: 0.35em;
  }
  .submenu_title p {
    font-size: 19px;
  }
</style>


  <div class="submenu_title">
    <img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/pre/submenu_title_list_star_icon.png">
    <p>あなたを巡るエネルギーの中核を視る◆チャクラ占い</p>
  </div>
  <div class="submenu_title">
    <img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/pre/submenu_title_list_star_icon.png">
    <p>第2チャクラから視る、あなたは人生で何に幸福と喜びを感じるのか</p>
  </div>
  <div class="submenu_title">
    <img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/pre/submenu_title_list_star_icon.png">
    <p>第3チャクラで分かる、あなたの人を引き付ける魅力</p>
  </div>
  <div class="submenu_title">
    <img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/pre/submenu_title_list_star_icon.png">
    <p>第5チャクラで知る、あなたらしく生きる人生の引き寄せ方</p>
  </div>
  <div class="submenu_title">
    <img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/pre/submenu_title_list_star_icon.png">
    <p>第7チャクラが教える、生まれた時から持っている人生の可能性</p>
  </div>
  <div class="submenu_title">
    <img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/pre/submenu_title_list_star_icon.png">
    <p>運勢が良い時、あなたに起こりやすい出来事</p>
  </div>
  <div class="submenu_title">
    <img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/pre/submenu_title_list_star_icon.png">
    <p>あなたが望みを叶えるための決断と選択</p>
  </div>
  <div class="submenu_title">
    <img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/pre/submenu_title_list_star_icon.png">
    <p>あなたが日常で抱えやすい問題と、その乗り越え方</p>
  </div>
  <div class="submenu_title">
    <img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/pre/submenu_title_list_star_icon.png">
    <p>あなたが感じやすいストレスと、それに対する解消法</p>
  </div>
  <div class="submenu_title">
    <img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/pre/submenu_title_list_star_icon.png">
    <p>今のあなたが、日々の生活の中で力を注ぐべきものは何？</p>
  </div>
  <div class="submenu_title">
    <img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/pre/submenu_title_list_star_icon.png">
    <p>あなたに気を付けてほしい生活習慣と健康について</p>
  </div>
  <div class="submenu_title">
    <img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/pre/submenu_title_list_star_icon.png">
    <p>エネルギーの流れから視えた運命◆チャクラ・ヴィジョン</p>
  </div>
  <div class="submenu_title">
    <img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/pre/submenu_title_list_star_icon.png">
    <p>あなたに与えられた仕事運と将来に得るもの</p>
  </div>
  <div class="submenu_title">
    <img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/pre/submenu_title_list_star_icon.png">
    <p>あなたを見ている周囲の人たちからの評価</p>
  </div>
  <div class="submenu_title">
    <img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/pre/submenu_title_list_star_icon.png">
    <p>あなたに与えられた恋愛運命と引き寄せやすい縁</p>
  </div>
  <div class="submenu_title">
    <img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/pre/submenu_title_list_star_icon.png">
    <p>この先、あなたを良き方へ導いてくれる重要人物</p>
  </div>
  <div class="submenu_title">
    <img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/pre/submenu_title_list_star_icon.png">
    <p>あなたをトラブルに巻き込んでしまう要注意人物</p>
  </div>
  <div class="submenu_title">
    <img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/pre/submenu_title_list_star_icon.png">
    <p>今、あなたの愛に訪れようとしている運命</p>
  </div>
  <div class="submenu_title">
    <img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/pre/submenu_title_list_star_icon.png">
    <p>その運命は、あなたの愛に大きな影響を与えることになる？</p>
  </div>
  <div class="submenu_title">
    <img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/pre/submenu_title_list_star_icon.png">
    <p>あなたの人生を彩る愛を、さらに呼び込むために心がけてほしいこと</p>
  </div>
  <div class="submenu_title">
    <img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/pre/submenu_title_list_star_icon.png">
    <p>あなたに与えられている金運と財運</p>
  </div>
  <div class="submenu_title">
    <img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/pre/submenu_title_list_star_icon.png">
    <p>直近であなたに訪れる金運転機</p>
  </div>
  <div class="submenu_title">
    <img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/pre/submenu_title_list_star_icon.png">
    <p>その転機によって、どれくらいの臨時収入を得ることになる？</p>
  </div>
  <div class="submenu_title">
    <img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/pre/submenu_title_list_star_icon.png">
    <p>あなたの財布がより潤っていくために意識してほしいこと</p>
  </div>
  <div class="submenu_title">
    <img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/pre/submenu_title_list_star_icon.png">
    <p>1年後のあなたはどんな生活を送っている？</p>
  </div>
  <div class="submenu_title">
    <img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/pre/submenu_title_list_star_icon.png">
    <p>この先、あなたの人生に訪れる大きな転機は【XX月XX日】</p>
  </div>
  <div class="submenu_title">
    <img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/pre/submenu_title_list_star_icon.png">
    <p>この転機は、あなたの暮らしにどんな影響を与えるのか</p>
  </div>
  <div class="submenu_title">
    <img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/pre/submenu_title_list_star_icon.png">
    <p>今から3年後、あなたはどんな日常を送っている？</p>
  </div>
  <div class="submenu_title">
    <img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/pre/submenu_title_list_star_icon.png">
    <p>今から5年後、あなたが何を得て人生を歩んでいるのか</p>
  </div>
  <div class="submenu_title">
    <img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/pre/submenu_title_list_star_icon.png">
    <p>今から10年後、あなたが人生で築き上げているもの</p>
  </div>
  <div class="submenu_title">
    <img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/pre/submenu_title_list_star_icon.png">
    <p>それまでの歩みから辿り着くあなたの晩年の暮らし</p>
  </div>
  <div class="submenu_title">
    <img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/pre/submenu_title_list_star_icon.png">
    <p>あなたは生涯を通して大きなものを成し遂げる？</p>
  </div>
  <div class="submenu_title">
    <img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/pre/submenu_title_list_star_icon.png">
    <p>より実りある晩年の生活を送れるように今からできること</p>
  </div>
  <div class="submenu_title">
    <img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/pre/submenu_title_list_star_icon.png">
    <p>あなた自身がこの人生を自分らしく歩むために</p>
  </div>
  <div class="submenu_title">
    <img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/pre/submenu_title_list_star_icon.png">
    <p>第0チャクラから視る◆次、あなたの周囲で起こり始める変化と、その影響</p>
  </div>

          </div>
          <img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/pre/submenu_title_list_bottom.png" style="width: 100%; vertical-align: top;">
        </section>

        <section id="profileForm">
          <img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/form/content_menu_list_head.jpg" style="margin-left: -1.9%; vertical-align: bottom;">
              <script src="https://web-img.rensa.jp.net/rensa/images/web/common_files/js/cookie-retention.js"></script>
<!-- form入力の警告をするためのjs -->
    <script src="https://web-img.rensa.jp.net/rensa/images/web/Cocoloni/common/js/formValidate.js"></script><!-- -->

<style>
    .profile-input-background-center.for-style {
        background: url("https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/form/content_menu_list_background.jpg") repeat-y;
        background-position: center;
        font-weight: bold;
        color: #000000;
    }

    /***********************************/
    /* use input font size Adjustment */
    /*********************************/
    .profile-input-background-center.for-style select {
        font-family: "ヒラギノ明朝 ProN W6", "HiraMinProN-W6", "HG明朝E", "ＭＳ Ｐ明朝", "MS PMincho", "MS 明朝", serif;
        font-weight: bold;
        letter-spacing: 0.05rem;
        font-size: 1.8rem;
        line-height: 140%;
        height: 45px;
    }

    .profile-input-background-center.for-style input {
        font-size: 1.8rem;
        line-height: 140%;
    }

    .profile-input-background-center.for-style input:-webkit-autofill {
        box-shadow: 0 0 0 100px #ffffff inset;
        -webkit-text-fill-color: #000000;
    }

    /***************************/
    /* use input name section */
    /**************************/
    .profile_input_area {
        padding: 0 8%;
        display: flex;
        flex-flow: column;
    }

    .profile_input_area p {
        font-family: "ヒラギノ明朝 ProN W6", "HiraMinProN-W6", "HG明朝E", "ＭＳ Ｐ明朝", "MS PMincho", "MS 明朝", serif;
        letter-spacing: 0.05rem;
    }

    .label {
        font-size: 1.8rem;
        line-height: 140%;
    }

    .note {
        font-size: 1.3rem;
        width: 90%;
        margin: 2% auto 2% 17%;
        text-align: left;
        line-height: 140%;
    }

    .note span {
        color: #983030;
    }

    /* 名前入力欄 */
    .full_name_input_box {
        display: flex;
        gap: 1%;
        margin-left: 3.5%;
        align-items: center;
    }

    #full-name,
    #target-full-name {
        font-family: "ヒラギノ明朝 ProN W6", "HiraMinProN-W6", "HG明朝E", "ＭＳ Ｐ明朝", "MS PMincho", "MS 明朝", serif;
        letter-spacing: 0.05rem;
        width: 300px;
        font-weight: bold;
    }

    /* 生年月日入力欄 */
    .birthday_select_box,
    .birthday_select_box div {
        display: flex;
        align-items: center;
        gap: 1%;
    }

    .birthday_select_box select {
        width: 160px;
    }

    /* 性別選択欄 */
    .sex_input_box {
        display: flex;
        align-items: center;
        margin-left: 7.3%;
        gap: 2%;
    }

    .sex_input_box>div {
        display: flex;
        align-items: flex-end;
        width: 17%;
    }

    #gender,
    #target-gender {
        width: 120px;
    }

    /* formボタン共通 */
    .form_branch_btn_area {
        display: flex;
        justify-content: center;
        max-height: 150px;
        margin-top: 2%;
    }

    .form_branch_btn_area button {
        width: 390px;
        height: 130px;
        padding: 0;
        border: none;
        outline: none;
        cursor: pointer;
    }

    .form_branch_btn_area button img {
        width: 100%;
        height: 100%;
        border: none;
    }

    /* anokimo button */
    .submit_branch_button_second {
        background-size: 100% 100%;
    }

    /* payment button */
    .submit_pay_image {
        background-size: 100% 100%;
    }

    /* partry free button */
    .submit_part_free_image {
        background-size: 100% 100%;
    }

    /* free button */
    .submit_free_image {
        background-size: 100% 100%;
    }


    /* checkbox */
    .cookie_check label,
    .cookie_info p,
    .cookie_check button {
        color: #000000;
        font-family: "ヒラギノ明朝 ProN W6", "HiraMinProN-W6", "HG明朝E", "MS P明朝", "MS PMincho", "MS 明朝", serif;
    }

    .cookie_check label {
        padding-right: 5px;
        font-size: 1rem;
    }

    .cookie_check button {
        background-color: #efefef;
        border: solid 1px #767676;
        border-radius: 2px;
    }

    .cookie_check button:hover {
        background-color: #d6d6d6;
    }

    .cookie_check {
        display: flex;
    }

    .cookie_check {
        align-items: center;
    }

    .cookie_info {
        font-size: 1rem;
    }

    .cookie_check {
        justify-content: center;
        gap: 30px;
    }

    .cookie-input {
        min-width: auto;
    }

    .cookie-label {
        padding-left: 10px;
        color: #000;
    }

    /* ----- */
</style>

<form method="post" accept-charset="euc-jp" id="profileForm" name="profileForm" action="/cocoloni/yumecakra_rsa/pre/life001/"><div style="display:none;"><input type="hidden" name="_method" value="POST"/></div><input type="hidden" name="itemcd" value="life001"/><input type="hidden" name="contentKey" value="CYC"/><input type="hidden" name="howToBuy" value="freeAppraisalButton"/><input type="hidden" name="TerminalModel" value="pc"/><input type="hidden" name="retensionResultDataId" value=""/><input type="hidden" name="time" value=""/><input type="hidden" name="zp_channel_id" value="105_yc0004a"/><div class="profile-input-background-center for-style" id="profileSection">
        <img loading="lazy" alt="あなたについて教えてください" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/form/input_form_my_head.png" style="width: 100%; margin: 0 auto;">
    <div class="profile_input_area">

        <!-------------------------->
        <!-- あなたの名前入力ここから -->
        <!-------------------------->
                    <div class="full_name_input_box">
                <p class="label">お名前</p>
                <div class="input text"><input type="text" name="full_name" maxlength="8" id="full-name"/></div>            </div>
            <p class="note">※「お名前」は、全角8文字以内の「ひらがな」「カタカナ」<br>「漢字」で入力ください。</p>
                <!-------------------------->
        <!-- あなたの名前入力ここまで -->
        <!-------------------------->

        <!---------------------------->
        <!-- あなたの誕生日入力ここから -->
        <!---------------------------->
                            <div class="birthday_select_box" id="birthday" name="birthday">
                <p class="label">生年月日</p>
                <div>
                    <div>
                        <div class="input select"><select name="birthday_year" class="year" id="birthday-year"><option value="1940">1940</option><option value="1941">1941</option><option value="1942">1942</option><option value="1943">1943</option><option value="1944">1944</option><option value="1945">1945</option><option value="1946">1946</option><option value="1947">1947</option><option value="1948">1948</option><option value="1949">1949</option><option value="1950">1950</option><option value="1951">1951</option><option value="1952">1952</option><option value="1953">1953</option><option value="1954">1954</option><option value="1955">1955</option><option value="1956">1956</option><option value="1957">1957</option><option value="1958">1958</option><option value="1959">1959</option><option value="1960">1960</option><option value="1961">1961</option><option value="1962">1962</option><option value="1963">1963</option><option value="1964">1964</option><option value="1965">1965</option><option value="1966">1966</option><option value="1967">1967</option><option value="1968">1968</option><option value="1969">1969</option><option value="1970">1970</option><option value="1971">1971</option><option value="1972">1972</option><option value="1973">1973</option><option value="1974">1974</option><option value="" selected="selected">--</option><option value="1975">1975</option><option value="1976">1976</option><option value="1977">1977</option><option value="1978">1978</option><option value="1979">1979</option><option value="1980">1980</option><option value="1981">1981</option><option value="1982">1982</option><option value="1983">1983</option><option value="1984">1984</option><option value="1985">1985</option><option value="1986">1986</option><option value="1987">1987</option><option value="1988">1988</option><option value="1989">1989</option><option value="1990">1990</option><option value="1991">1991</option><option value="1992">1992</option><option value="1993">1993</option><option value="1994">1994</option><option value="1995">1995</option><option value="1996">1996</option><option value="1997">1997</option><option value="1998">1998</option><option value="1999">1999</option><option value="2000">2000</option><option value="2001">2001</option><option value="2002">2002</option><option value="2003">2003</option><option value="2004">2004</option><option value="2005">2005</option><option value="2006">2006</option><option value="2007">2007</option><option value="2008">2008</option><option value="2009">2009</option><option value="2010">2010</option><option value="2011">2011</option><option value="2012">2012</option><option value="2013">2013</option><option value="2014">2014</option><option value="2015">2015</option><option value="2016">2016</option><option value="2017">2017</option><option value="2018">2018</option><option value="2019">2019</option><option value="2020">2020</option></select></div>                        <p class="label">年</p>
                    </div>
                    <div>
                        <div class="input select"><select name="birthday_month" class="month" id="birthday-month"><option value="1">1</option><option value="2">2</option><option value="3">3</option><option value="4">4</option><option value="5">5</option><option value="6">6</option><option value="" selected="selected">--</option><option value="7">7</option><option value="8">8</option><option value="9">9</option><option value="10">10</option><option value="11">11</option><option value="12">12</option></select></div>                        <p class="label">月</p>
                    </div>
                    <div>
                        <div class="input select"><select name="birthday_day" class="day" id="birthday-day"><option value="1">1</option><option value="2">2</option><option value="3">3</option><option value="4">4</option><option value="5">5</option><option value="6">6</option><option value="7">7</option><option value="8">8</option><option value="9">9</option><option value="10">10</option><option value="11">11</option><option value="12">12</option><option value="13">13</option><option value="14">14</option><option value="15">15</option><option value="" selected="selected">--</option><option value="16">16</option><option value="17">17</option><option value="18">18</option><option value="19">19</option><option value="20">20</option><option value="21">21</option><option value="22">22</option><option value="23">23</option><option value="24">24</option><option value="25">25</option><option value="26">26</option><option value="27">27</option><option value="28">28</option><option value="29">29</option><option value="30">30</option><option value="31">31</option></select></div>                        <p class="label">日</p>
                    </div>
                </div>
            </div>
            <p class="note"><span>※必須</span></p>
                <!---------------------------->
        <!-- あなたの誕生日入力ここまで -->
        <!---------------------------->

        <!-------------------------->
        <!-- あなたの性別入力ここから -->
        <!-------------------------->
                    <div class="sex_input_box">
                <p class="label">性別</p>
                                    <div class="input select"><select name="gender" id="gender"><option value="F" selected="selected">女性</option><option value="M">男性</option></select></div>                    <p class="label">で占う</p>
                            </div>
                            <p class="note"><span>※必須</span></p>
                            <!-------------------------->
        <!-- あなたの性別入力ここまで -->
        <!-------------------------->
    </div>

        <!------------------------------>
    <!-- Cookie入力情報の削除ここから -->
    <!------------------------------>
            <div class="cookie_info">
            <p>入力した情報を記録しますか？</p>
            <div class="cookie_check">
                <label><input class="cookie-input" id="checkbox" name="cwflg" value="ok" type="checkbox" checked=""><span class="cookie-label">記録する</span></label>

                <div class="input button"><label for="ji-luwo-xue-chusuru"></label><button type="button" onclick="resetCookie()" id="ji-luwo-xue-chusuru">記録を削除する</button></div>            </div>
        </div>
        <!------------------------------>
    <!-- Cookie入力情報の削除ここから -->
    <!------------------------------>
    <!--------------------->
    <!-- 遷移ボタンここから -->
    <!--------------------->
    <div class="form_branch_btn_area">
                    <!-- 引数で $branchTransitionMenu が渡されていない場合の処理 itemcd に対応して遷移する。-->
                            <!-- 一部無料ボタン -->
                <button type="button" class="submit_part_free_image" name="partlyAppraisalButton1" id="" value="life001and105_yc0004a" onclick="formButtonPrecess($(this));">
                    <img loading="lazy" alt="一部無料で鑑定" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/form/appraisal_part_free_button.png" onmouseover="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/form/appraisal_part_free_button_over.png'" onmouseout="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/form/appraisal_part_free_button.png'">
                </button>
                <!-- 有料ボタン -->
                <button type="button" class="submit_pay_image" name="paymentAppraisalButton1" id="" value="life001and105_yc0004a">
                    <img loading="lazy" alt="鑑定する（有料）" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/form/appraisal_pay_button.png" onmouseover="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/form/appraisal_pay_button_over.png'" onmouseout="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/form/appraisal_pay_button.png'">
                </button>
                        </div>
    <script>
        $("form").keydown(function(e) {
            if ((e.which && e.which === 13) || (e.keyCode && e.keyCode === 13)) {
                return false;
            } else {
                return true;
            }
        });

        var paymentSystemName = 'cocoloni';
        var paymentMetaData = [{"count":1,"method":"post","parameterName":"zp_channel_id","paymentUrl":"https:\/\/zap-happyfortune.rensa.jp.net\/cocoloni\/yumecakra_rsa\/result\/","partlyUrl":"https:\/\/honkaku-uranai.jp\/cp_rsa\/yumecakra_rsa\/result\/","freeUrl":"https:\/\/honkaku-uranai.jp\/cp_rsa\/yumecakra_rsa\/result\/life001","ids":"105_yc0004a","itemcd":"life001","price":3740,"premium_price":2700,"addCrumbPreUrl":"\/cocoloni\/yumecakra_rsa\/pre\/life001"}];

        function formButtonPrecess(button) {
            let settlementCodeDatas = button.attr("value").split("and")
            let howToBuy = button.attr("name")
            let buttonName = button.context.name;
            if (paymentSystemName == "minori") {
                var formId = button.attr("name").slice(-1);
                var partlyUrl = document.getElementsByName("partlyUrl" + formId)[0].innerHTML;
            }

            if (formValidate(button.parents("form"), 8, false)) {
                $("[name=itemcd]").val(settlementCodeDatas[0])
                buttonName.indexOf("anokimoPartlyAppraisalButton") !== -1 ? $("[name=howToBuy]").val('partlyAppraisalButton') : $("[name=howToBuy]").val(howToBuy);
                if (paymentSystemName !== "minori") {
                    actSubmit(button.parents("form"));
                }
                if (paymentSystemName == "cocoloni" || paymentSystemName == "cp_rsa" || paymentSystemName == "fortune-premium") {
                    $("[name=zp_channel_id]").val(settlementCodeDatas[1])
                    document.charset = 'euc-jp'
                }
                button.parents("form").attr("method", "post")
                if (buttonName.indexOf("freeAppraisalButton") !== -1) {
                    button.parents("form").attr("action", "https://honkaku-uranai.jp/cp_rsa/yumecakra_rsa/result/life001/").submit();
                } else if (paymentSystemName == "minori") {
                    button.parents("form").attr("action", partlyUrl).submit();
                } else {
                    button.parents("form").attr("action", "https://honkaku-uranai.jp/cp_rsa/yumecakra_rsa/result/" + settlementCodeDatas[0] + "/").submit();
                }
            }
        };

        // payment appraisal button js
        var isProcessing = false;
        var btnCount = $(".form_branch_btn_area").length;
        window.onpageshow = function() {
            for (let i = 1; i <= btnCount; i++) {
                $('button[name=paymentAppraisalButton' + i + ']').prop("disabled", false);
            }
        }
        $('button[name=paymentAppraisalButton1]').on('click', function() {
            if (formValidate($(this).parents("form"), 8, false)) {
                var btn = $('button[name=paymentAppraisalButton1]')
                btn.prop("disabled", true);
                if (paymentSystemName == "minori") {
                    // みのり 用に遷移元を ローカルストレージへ保存
                    localStorage.setItem('backUrl', location.href);
                }
                if (paymentSystemName !== "minori") {
                    actSubmit($(this).parents("form"));
                }
                if (paymentSystemName == "cocoloni" || paymentSystemName == "cp_rsa" || paymentSystemName == "fortune-premium") {
                    document.charset = 'euc-jp'
                }
                var settlementCodeDatas = $(this).attr("value").split("and")
                var howToBuy = $(this).attr("name")
                var parameterName = "zp_channel_id";
                                    var $JudgmentGender = $(this).parents("form").find("select[name='gender']").val()
                                var gender = $JudgmentGender
                var fullName = $(this).parents("form").find("input[name='full_name']").val()
                var targetGender = $(this).parents("form").find('select[name=target_gender]').val()
                var targetFullName = $(this).parents("form").find("input[name='target_full_name']").val()
                var birthday = $(this).parents("form").find("select[name='birthday_year']").val() + "-" + ('00' + $(this).parents("form").find("select[name='birthday_month']").val()).slice(-2) + "-" + ('00' + $(this).parents("form").find("select[name='birthday_day']").val()).slice(-2)
                var targetBirthday = $(this).parents("form").find("select[name='target_birthday_year']").val() + "-" + ('00' + $(this).parents("form").find("select[name='target_birthday_month']").val()).slice(-2) + "-" + ('00' + $(this).parents("form").find("select[name='target_birthday_day']").val()).slice(-2)
                $("[name=itemcd]").val(settlementCodeDatas[0])
                $("[name=howToBuy]").val(howToBuy)

                if (paymentSystemName == "minori") {
                    // みのり 用に遷移元を ローカルストレージへ保存
                    localStorage.setItem('backUrl', location.href);
                    var url = location.href;
                    var env = url.match("dev") ? 'https://dev.rensa.jp.net' : 'https://rensa.jp.net'
                    $.ajax({
                        type: "POST",
                        url: env + "https://honkaku-uranai.jp/cp_rsa/yumecakra_rsa/result/life001", //本番環境用
                        // url: "http://localhost/yumecakra/minori/result/love001",//テスト用
                        data: {
                            "isNomalPayment": true,
                            "itemcd": settlementCodeDatas[0],
                            "howToBuy": "partlyAppraisalButton",
                            "channel": settlementCodeDatas[1],
                            "full_name": fullName,
                            "birthday": birthday,
                            "gender": gender,
                            "target_full_name": targetFullName,
                            "target_birthday": targetBirthday,
                            "target_gender": targetGender,
                            "TerminalModel": "pc"
                        },
                        dataType: "html"
                    }).done(function(data) {
                        console.log(data);
                        var dom_parser = new DOMParser();
                        var retensionResultDataId = dom_parser.parseFromString(data, "text/html").getElementById("retensionResultData").innerHTML
                        $("[name=zp_channel_id]").val(settlementCodeDatas[1])
                        $("[name=retensionResultDataId]").val(retensionResultDataId.split("__rid__")[1])
                        btn.parents("form").attr("method", "post")
                        btn.parents("form").attr("action", "https://zap-happyfortune.rensa.jp.net/cocoloni/yumecakra_rsa/result/").submit();
                    }).fail(function() {
                        alert("通信に失敗しました");
                        btn.prop("disabled", false);
                    });
                } else if (paymentSystemName == "cocoloni" || paymentSystemName == "cp_rsa") {
                    let postUrl = "";
                    let locationUri = location.hostname;
                    switch (locationUri) {
                        case "honkaku-uranai.jp":
                            postUrl = "https://honkaku-uranai.jp/cp_rsa/yumecakra_rsa/result";
                            break;
                        case "test-honkaku.cocoloni.jp":
                            postUrl = "https://test-honkaku.cocoloni.jp/cp_rsa/yumecakra_rsa/result";
                            break;
                        default:
                            postUrl = "http://localhost/cocoloni/yumecakra_rsa/result/life001";
                    };
                    let time = $(this).parents("form").find("input[name='time']").val();
                    document.charset = 'euc-jp'
                    $.ajax({
                        type: "post",
                        url: postUrl,
                        data: {
                            "ajaxParameter": true,
                            "itemcd": settlementCodeDatas[0],
                            "zp_channel_id": settlementCodeDatas[1],
                            "time": time,
                            "full_name": fullName,
                            "birthday": birthday,
                            "gender": gender,
                            "target_full_name": targetFullName,
                            "target_birthday": targetBirthday,
                            "target_gender": targetGender,
                            "TerminalModel": "pc",
                            "howToBuy": "paymentAppraisalButton",
                        },
                        dataType: "html"
                    }).done(function(data) {
                        var dataValue = JSON.parse(data)
                        var zp_channel_id = dataValue.zp_channel_id
                        var zp_sid = dataValue.zp_sid
                        var zp_sig = dataValue.zp_sig
                        if (location.hostname.indexOf("test-honkaku.cocoloni.jp") >= 0) {
                            window.location.href = "https://test-honkaku.cocoloni.jp/portal/charge/?zp_cp_name=cp_rsa&zp_channel_id=" + zp_channel_id + "&zp_sid=" + zp_sid + "&zp_sig=" + zp_sig
                        } else {
                            window.location.href = "https://honkaku-uranai.jp/portal/charge/?zp_cp_name=cp_rsa&zp_channel_id=" + zp_channel_id + "&zp_sid=" + zp_sid + "&zp_sig=" + zp_sig
                        }
                    }).fail(function() {
                        alert("通信に失敗しました");
                        btn.prop("disabled", false);
                    });
                } else {
                    if (paymentSystemName == "fortune-premium") {
                        $("[name=zp_channel_id]").val(settlementCodeDatas[1])
                    }
                    btn.parents("form").attr("method", "post")
                    btn.parents("form").attr("action", "https://zap-happyfortune.rensa.jp.net/cocoloni/yumecakra_rsa/result/").submit();
                }
            }
        })
    </script>
    <!--------------------->
    <!-- 遷移ボタンここまで -->
    <!--------------------->
    </form>    <div style="text-align: center; padding: 20px 75px; clear: both; font-size: 1.1rem;">
        <style>
    .form_purchase_description,
    .privacy-policy-section a {
        color: #000;
    }

    .anokimo_button_message_color {
        color: #983030;
    }

    .strong_text_color {
        color: #983030;
    }

    .price_color {
        color: #983030;
    }

    .premium_price_color {
        color: #236310;
    }

    .free_guid_text_color {
        color: #008000;
    }

    .privacy-policy-section {
        border: 1px solid #0000005c;
        margin-top: 10px;
        padding: 7px;
        text-align: left;
    }

    .privacy-policy-section a:hover {
        color: #983030;
    }
</style>

<div class="form_purchase_description">
            <p>
            <span class="strong_text_color">「一部無料で鑑定する」</span>をクリックすると、鑑定結果の一部を無料でご覧になれます。
                    </p>
        <br>
                    <p>
                ご利用には<span class="price_color">3,740円（税込）/1回</span>が必要となります。
                <br>
                （定額制ではございません。入力項目が同じでも占う度に料金が発生いたします。）
                <br>
                <br>
                占う前に占断する内容や入力情報をご確認の上、購入お願いいたします。
                <br>
                ご購入いただくと、サービス・コンテンツの利用料金が発生します。
            </p>
            
    <div class="privacy-policy-section">
        <p>
                            株式会社レンサは、ご入力いただいた情報を、占いサービスを提供するためにのみ使用し、情報の蓄積を行ったり、他の目的で使用することはありません。                <a href='https://rensa.co.jp/privacy-policy' target="_new">個人情報保護方針（外部サイト）</a>をご確認の上、必要情報をご入力ください。また、ご購入に関しては、cocoloni占い館の<a href="/agreement/" target="_link">利用規約</a>に 同意の上、必要情報をご入力ください。
                    </p>
    </div>
</div>    </div>
</div>
<img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/form/content_menu_list_bottom.jpg" style="margin-left: -1.9%; vertical-align: top;">

<script>
    var birthdayYearSelectOptions;
    if (typeof isBirthdayYearOptionDefined === "undefined") {
        birthdayYearSelectOptions = "";
        for (var i = 1930; i <= new Date().getFullYear(); i++) {
            birthdayYearSelectOptions = birthdayYearSelectOptions + "<option value='" + i + "'>" + i + "</option>"
            if (i == 1975) {
                birthdayYearSelectOptions = birthdayYearSelectOptions + "<option value='' selected >--</option>"
            }
        }
    }
    var isBirthdayYearOptionDefined = true
    $("*[name=birthday_year]").html(birthdayYearSelectOptions);
    $("*[name=target_birthday_year]").html(birthdayYearSelectOptions);

    var birthdayInputForm = $('div[name=birthday]')

    birthdayInputForm.change(function() {
        var yearElem = $(this).find(".year")
        var monthElem = $(this).find(".month")
        var dayElem = $(this).find(".day")

        var year = yearElem.val()
        var month = monthElem.val()
        var day = dayElem.val()

        if (year == "" || month == "" || day == "") {
            return
        }

        // 閏年か否か判定
        var isLeapYear = year % 4 == 0;
        if (year % 100 == 0) {
            if (year % 400 == 0) {
                isLeapYear = true;
            }
        }

        // 該当月の最大日数を取得
        var mEndOfDay = [31, 28, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31]
        if (isLeapYear) {
            mEndOfDay[1] = 29;
        }

        if (day > mEndOfDay[parseInt(month) - 1]) {
            dayElem.val(mEndOfDay[parseInt(month) - 1]);
        }

        var today = new Date();
        if (year >= today.getFullYear()) {
            if (month >= today.getMonth() + 1) {
                monthElem.val(today.getMonth() + 1)
                if (day > today.getDate()) {
                    dayElem.val(today.getDate())
                }
                if (month > today.getMonth() + 1) {
                    dayElem.val(today.getDate())
                }
            }
        }
    });

    if (paymentSystemName !== "minori") {
        setLoad($("form"))
    }
</script>        </section>
      </div>

      <section id="footer" style="margin: 0 33px;"><style>
    .footer {
        clear: both;
        background: black;
        color: white;
        padding: 35px 90px 30px;    }
    .footer a {
        text-decoration: underline;
        color: yellow;
    }
    .footer a:hover {
        color: #ff6b00;
        text-decoration: none;
    }
    .attention-line {
        width: 100%;
        height: 2px; /* 要sp対応 */
        line-height: 0;
        margin: 10px auto; /* 要sp対応 */
        border-top: 1px dashed #542; /* 要sp対応 */
    }
    .text-center {
        text-align: center;
    }
</style>

<div class="footer">
    <style>
    .footer-text-section h3 {
        text-align: center;
    }
    .precautions-list {
        padding: 12px 0;
    }
    .copyright_text {
        text-align: center;
    }
    .teller-telling-footer-section {
        text-align: center;
    }
    .pre-footer-section ul {
        margin: 3px;
        list-style-type: circle;
    }
</style>
    <div class="pre-footer-section">
        <h3 style="text-align: center;">動作環境</h3>
        この占い番組は、次の環境でご利用ください。<br/><br/>
        ＜OS＞
        <ul>
            <li>Windows：Windows 10以降</li>
            <li>Mac(Macintosh)：macOS 10.15(Catalina)以降</li>
        </ul>
        ＜ブラウザ＞<br/>
        <ul>
            <li>Windows：Google Chrome最新版、Microsoft Edge最新版、Firefox最新版、またはそれに相当するブラウザ。</li>
            <li>Mac(Macintosh)：Safari最新版、またはそれに相当するブラウザ。</li>
        </ul>
        ※JavaScriptの設定をONにしてご利用ください。<br>
        ※NetscapeはWindows、Macintosh共に非対応です。
        <br/>
    </div>
    <div class="teller-telling-footer-section">
        <!-- @: link/ --><a href="/cp_rsa/yumecakra_rsa/" class="color-e8ca22">トップページに戻る</a><br/><br/>
        <!-- @: link/ --><a href="/cp_rsa/tokusyo/" class="link_attention" target="yumecakra_rsa_isp">特定商取引法に基づく表記</a>
    </div>
<p class="copyright_text">Copyright Rensa Co., Ltd.<br />このページの無断転用・転記を禁じます。</p>
<br/><br/>
<div class="footer_img"></div>
</div></section>
    </section>
  </div>
</main>    </div>
                <script>
        var userAgent = window.navigator.userAgent.toLowerCase();
        var isSmoothScrollDisableBrowser = false;
        var smoothScrollEnabled = true;

        if (userAgent.indexOf('msie') != -1 || userAgent.indexOf('trident') != -1) {
            isSmoothScrollDisableBrowser = true;
        } else if (userAgent.indexOf('edge') != -1) {
            isSmoothScrollDisableBrowser = true;
        } else if (userAgent.indexOf('safari') != -1) {
            isSmoothScrollDisableBrowser = true;
        }


        document.addEventListener('mousewheel', function(e) {
            if (smoothScrollEnabled) {
                e.preventDefault();
                var wd = e.wheelDelta;
                var csp = window.pageYOffset;
                window.scrollTo(0, csp - wd / 2);
            }
        }, {
            passive: false
        });

        function smoothScrollEnable() {
            smoothScrollEnabled = true;
        }

        function smoothScrollDisable() {
            smoothScrollEnabled = false;
        }

        if (isSmoothScrollDisableBrowser) {
            smoothScrollEnable()

            $("select").change(function() {
                smoothScrollEnable();
                $(this).blur()
            });
            $("select")
                .focusin(function(e) {
                    smoothScrollDisable()
                })
                .focusout(function(e) {
                    smoothScrollEnable();
                });
        }
    </script>
    </body>

</html>"""

# %%
input_df = input_html_to_df_rsa(input_html_str)

# %%
input_df
# Out:
#     index_input                     sub_title_input
# 0             1            あなたを巡るエネルギーの中核を視る◆チャクラ占い
# 1             2     第2チャクラから視る、あなたは人生で何に幸福と喜びを感じるのか
# 2             3            第3チャクラで分かる、あなたの人を引き付ける魅力
# 3             4         第5チャクラで知る、あなたらしく生きる人生の引き寄せ方
# 4             5       第7チャクラが教える、生まれた時から持っている人生の可能性
# 5             6                運勢が良い時、あなたに起こりやすい出来事
# 6             7                  あなたが望みを叶えるための決断と選択
# 7             8             あなたが日常で抱えやすい問題と、その乗り越え方
# 8             9            あなたが感じやすいストレスと、それに対する解消法
# 9            10          今のあなたが、日々の生活の中で力を注ぐべきものは何？
# 10           11             あなたに気を付けてほしい生活習慣と健康について
# 11           12          エネルギーの流れから視えた運命◆チャクラ・ヴィジョン
# 12           13                あなたに与えられた仕事運と将来に得るもの
# 13           14                 あなたを見ている周囲の人たちからの評価
# 14           15              あなたに与えられた恋愛運命と引き寄せやすい縁
# 15           16              この先、あなたを良き方へ導いてくれる重要人物
# 16           17              あなたをトラブルに巻き込んでしまう要注意人物
# ...

# %%
result_html_str = """
<!DOCTYPE html>
<html>

<head>
    <script src="https://rensa.jp.net/premium_fortune/portal_proxy_js?method=get&url=https://happyfortune.rensa.jp.net/js/Build/Yumecakra/js/result.js-d9b52662.js" type="module"></script>        <link rel="stylesheet" href="https://happyfortune.rensa.jp.net/js/Build/assets/result-1e4fe9c5.css"/><link rel="stylesheet" href="https://happyfortune.rensa.jp.net/js/Build/assets/result-cde74db8.css"/>        
    <title>
        人生掌握【ゆめの心々渾身】あなたの全運命を霊視◆1年⇒10年後/晩年 | cocoloni占い館 Moon    </title>
            <meta name="viewport" content="width=device-width, initial-scale=1.0">
    
            <!-- Google Tag Manager -->
        <script>
            (function(w, d, s, l, i) {
                w[l] = w[l] || [];
                w[l].push({
                    'gtm.start': new Date().getTime(),
                    event: 'gtm.js'
                });
                var f = d.getElementsByTagName(s)[0],
                    j = d.createElement(s),
                    dl = l != 'dataLayer' ? '&l=' + l : '';
                j.async = true;
                j.src = 'https://www.googletagmanager.com/gtm.js?id=' + i + dl;
                f.parentNode.insertBefore(j, f);
            })(window, document, 'script', 'dataLayer', 'GTM-MV3KXWG');
        </script>
        <!-- End Google Tag Manager -->
                    <!-- cocoloni bot対応 -->
            <meta name="robots" content="noindex">
            
    
    <meta charset="utf-8"/>
                                                            <meta property="og:locale" content="ja_JP" />
                
        </head>

<body>
    
            <!-- Google Tag Manager (noscript) -->
        <noscript><iframe src="https://www.googletagmanager.com/ns.html?id=GTM-MV3KXWG" height="0" width="0" style="display:none;visibility:hidden"></iframe></noscript>
        <!-- End Google Tag Manager (noscript) -->
                                    <!-- <script><//?php echo mb_convert_encoding( file_get_contents('https://630hso4ag2.user-space.cdn.idcfcloud.net/js/'.$cocoloniJsFailName ) , 'utf-8', 'euc-jp') ?></script> -->
                <script type="text/javascript" src="https://630hso4ag2.user-space.cdn.idcfcloud.net/js/honkaku_common.js" charset="EUC-JP" ;></script>
                            <!-- cocoloni header tag start -->
        <div id="honkaku_header" style="display:none;">
                                </div>
        <!-- cocoloni header tag start -->
        <!-- contents_headerCopy start -->
        <p class="contents_headerCopy">
                            人生掌握【ゆめの心々渾身】あなたの全運命を霊視◆1年⇒10年後/晩年                    </p>
        <!-- contents_headerCopy end -->
        <noscript>
            <!-- cocoloni sp javascript not working -->
            <style>
                .js-error-section {
                    margin: 1vw;
                    padding: 1vw;
                    background: #fff;
                    border: 2px solid #dc0000;
                    text-align: center;
                    font-size: 2vw;
                }
            </style>
            <div class="js-error-section">
                <p>お客様が現在お使いのブラウザでは、JavaScriptの設定が無効となっています。<br />
                    当サイトはJavaScriptを使用致しますので、設定をオンにご変更下さい。</p>
            </div>
        </noscript>
        <div id="cocoloniAttention"></div>
        <!-- cocoloniAttention -->
    
    
        
        <div class="container clearfix">

        <!-- vue を使用できるようにする -->


<!-- CSS -->
<style>
@import url('https://fonts.googleapis.com/css2?family=Noto+Sans+JP&display=swap');
body , main , h1 , h2 , h3 , h4 , h5 , p , img , div {
  margin: 0px;
  font-family: 'Noto Sans JP', sans-serif;
}
html {
  font-size: 16px;
}
a {
  transition: all 0.25s 0s ease;
  text-underline-offset: 0.25em;
}
a:hover {
  text-decoration: none;
}
button {
  cursor: pointer;
  background-color: transparent;
  border: none;
}

/********************************************************************/
/* use common background and common font size and color adjustment */
/******************************************************************/
.content_main {
  background: url("https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/common/main_background.jpg") no-repeat center top;
  background-size: 1800px 1600px;
  min-width: 990px;
  background-color: #131120;
  background-attachment: fixed;
  color: white;
  display: block;
  overflow: hidden;
}

.main_shadow {
  max-width: 1800px;
  margin: 0 auto;
  box-shadow: 100px 0 50px -50px #131120 inset, -100px 0px 50px -50px #131120 inset;
}

/**********************************/
/* use common  section adjustment */
/*********************************/
.section_container {
  width: 990px;
  margin: 0 auto;
}
.section_background {
  background: url('https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/common/section_background.jpg') repeat-y;
  background-size: 100%;
}

/* cocoloniのおすすめリンク先のスタイル */
  .content-main {
    background: url("https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/common/main_background.jpg") no-repeat center top;
    background-size: 1800px 1600px;
    min-width: 990px;
    background-color: #131120;
    background-attachment: fixed;
    color: white;
    display: block;
    overflow: hidden;
  }
  .section-container {
    width: 990px;
    margin: 0 auto;
  }
  .section-background {
    background: url('https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/common/section_background.jpg') repeat-y;
    background-size: 100%;
  }

/* つなぎ込み部分 */
.balloon_connect_background {
  background: url('https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/result_background.jpg') repeat-y;
  background-position: center;
  background-size: 100%;
  min-height: 100px;
  padding: 3% 5% 2%;
}
.balloon_connect {
  background-color: #00000080;
  width: 100%;
  min-height: 100px;
  text-align: left;
  margin-bottom: 3%;
  padding: 2% 5%;
  box-sizing: border-box;
  border-radius: 22px;
  box-shadow: 0 0 10px #f9fbbdb3, 0 0 10px #f9fbbdb3;
}
.balloon_connect p {
  font-family: "ヒラギノ明朝 ProN W6", "HiraMinProN-W6", "HG明朝E", "ＭＳ Ｐ明朝", "MS PMincho", "MS 明朝", serif;
  font-size: 1.3rem;
  line-height: 140%;
  color: #ffffff;
  letter-spacing: 0.05rem;
}

/*************************************/
/* use free menu buttons adjustment */
/***********************************/
.top_free_menu_buttons {
  text-align: center;
}
.top_free_menu_buttons button {
  width: 700px;
  height: 280px;
  padding: 0;
  border: none;
  outline: none;
  cursor: pointer;
  background-size: 100% 100%;
}
.top_free_menu_buttons img {
  width: 100%;
  height: 100%;
  border: none;
  outline: none;
}

/**********************/
/* use text menu link */
/**********************/
.appraisal_menu {
  display: flex;
  flex-flow: column;
  text-align: left;
}
.appraisal_menu img {
  width: 11%;
  float: left;
  margin-right: 2%;
}

.appraisal_menu a {
  color: #ffcf3a;
}
.appraisal_menu a:hover {
  color: #c29c27;
}
.appraisal_menu.light a {
  color: #4901a6;
}
.appraisal_menu.light a:hover {
  color: #7203ff;
}
.appraisal_menu a p {
  font-family: "ヒラギノ明朝 ProN W6", "HiraMinProN-W6", "HG明朝E", "ＭＳ Ｐ明朝", "MS PMincho", "MS 明朝", serif;
  letter-spacing: 0.05rem;
  font-size: 30px;
  font-weight: bold;
  display: inline;
  line-height: 140%;
}

.appraisal_menu .description {
  font-size: 18px;
  font-weight: normal;
  color: #ffffff;
  padding: 1%;
}
.appraisal_menu.light .description {
  color: #000000;
}

.menu_info {
  text-align: right;
  font-size: 16px;
}
.add_day {
  color: red;
}
.price {
  font-weight: bold;
}
.appraisal_menu.light .premium_price {
  color: #236310;
}
.appraisal_menu.light .common_price {
  color: #983030;
}
.premium_price {
  color: #8ede77;
}
.common_price {
  color: #FF9494;
}
/* 説明文言強調 */
.telling_background {
  width: 100%;
  background: url("https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/top/telling_introduction_sample_background.jpg") repeat-y;
  background-position: center;
  background-size: 100%;
}
.telling_description {
  font-family: "ヒラギノ明朝 ProN W6", "HiraMinProN-W6", "HG明朝E", "ＭＳ Ｐ明朝", "MS PMincho", "MS 明朝", serif;
  letter-spacing: 0.05rem;
  color: #ffffff;
  width: 95%;
  font-size: 1.3rem;
  text-align: left;
  margin: 0 auto 2%;
  line-height: 140%;
}

.telling_link_head {
  color: #fc97fd;
  font-family: "ヒラギノ明朝 ProN W6", "HiraMinProN-W6", "HG明朝E", "ＭＳ Ｐ明朝", "MS PMincho", "MS 明朝", serif;
  letter-spacing: 0.05rem;
  font-weight: bold;
  text-shadow: 0 0 10px #686860;
  width: 100%;
  font-size: 1.3rem;
  text-align: center;
  margin: 10px auto;
}

.strong-text {
  text-align: left;
  color: #FFFFFF;
}
.blue {
  text-shadow: 0 0 5px #0066CC, 0 0 5px #0066CC, 0 0 5px #0066CC, 0 0 5px #0066CC, 0 0 5px #0066CC;
}
.green {
  text-shadow: 0 0 5px #009966, 0 0 5px #009966, 0 0 5px #009966, 0 0 5px #009966, 0 0 5px #009966;
}
</style><style>
  .index_text_link {
    color: #73c2f4;
    font-size: 1.3rem;
    text-decoration: underline;
    font-weight: bold;
    font-family: "ヒラギノ明朝 ProN W6", "HiraMinProN-W6", "HG明朝E", "ＭＳ Ｐ明朝", "MS PMincho", "MS 明朝", serif;
    letter-spacing: 0.05rem;
    display: inline;
    line-height: 140%;
  }
  .index_text_link:not(:last-child) {
    margin-bottom: 7px;
  }
  .index_text_link:hover {
    color: #5b5ff1;
    text-decoration: none;
  }
  .index_text_link.link1 {
    color: #CCFFFF;
  }
  .index_text_link.link1:hover {
    color: #5b5ff1;
  }
  .index_text_link.link2 {
    color: #CC99FF;
  }
  .index_text_link.link2:hover {
    color: #e55eff;
  }
  .index_text_link.link3 {
    color: #FF99CC;
  }
  .index_text_link.link3:hover {
    color: #fb3397;
  }


  /******************************+***/
  /* use top category menu section */
  /*********************************/
  .top_menu_link_background_center {
    width: 100%;
    background: url('https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/top/top_menu_list_background.jpg') repeat-y;
    background-position: center;
    background-size: 100%;
    padding: 20px 90px 0;
    box-sizing: border-box;
  }
  .content_menu_link_background_center {
    width: 100%;
    padding: 2% 9%;
    box-sizing: border-box;
    font-size: 1.3rem;
  }
  .category_transition_link {
    font-size: 1.3rem;
    color: #ffffff;
    margin: 1% 3%;
    float: right;
  }
  .category_transition_link:hover {
    color: #73c2f4;
  }
  .content_menu_transition_buttons {
    display: flex;
    height: 110px;
  }
  .content_menu_transition_buttons a {
    width: 33.33%;
  }
  .content_menu_transition_buttons img {
    width: 100%;
    height: 106px;
  }
  .content_menu_transition_buttons div {
    background-size: 100%;
    height: 110px;
  }
  .content_menu_transition_buttons div:hover{
    background-size: 100%;
    height: 110px;
  }

  /******************************+***/
  /* use top free tarot ancker text */
  /*********************************/

  /* worries section */
  .worries-container {
    width: 100%;
    height: 100%;
    position: relative;
  }

  .worries-container img {
    width: 100%;
    height: auto;
  }

  .worries-container a {
    width: 100%;
    font-size: 1.5rem;
    color: #ffffff;
    padding: 10px;
    border-radius: 5px;
    box-shadow: rgba(0,0,0,1) 0 1px 0;
    text-shadow: rgba(0,0,0,.4) 0 1px 0;
    letter-spacing: inherit;
    cursor: pointer;
    text-decoration: underline;
  }

  .worries-container a:hover {
    color: #ffffa4;
    text-decoration: none;
  }

  .worries-container_menus {
    position: absolute;
    top: 56%;
    left: 9%;
    width: 62%;
    text-align: left;
  }

  .worries-container_menus div {
    margin-bottom: 8%;
  }

  .worries-container a.onayami-show-next {
    background-color: #6E6657;
  }
  .worries-container a.onayami-show-next:hover {
    color: #ffffa4;
    text-decoration: none;
  }

  /* Free Tarot */
  .free_tarot_background {
    width: 100%;
    min-height: 390px;
    background: url('https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/top/tarot_free_appraisal_menu_background.jpg') repeat-y;
    background-size: 100%;
    position: relative;
  }
  .free_tarot_background_inner {
    position: absolute;
    top: 0;
    left: 0;
    width: 100%;
    min-height: 390px;
  }
  .free_tarot_background_over {
    width: 100%;
    box-sizing: border-box;
    background: url('https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/top/tarot_free_appraisal_menu_background.jpg') no-repeat;
    background-size: 100% 100%;
    display: none;
  }
  .top_free_tarot_result_text_box {
    padding: 0 5% 2%;
    text-align: left;
  }
  #top_free_tarot_result_menu_link {
    margin: 2% 0;
  }
  .top_free_tarot_link_text {
    color: #e0ff80;
    font-size: 1.3rem;
    line-height: 140%;
  }
  .top_free_tarot_link_text:hover {
    color: #c1ff00;
    text-decoration: none;
  }
  .top_free_tarot_appraisal_menu_box {
    padding: 0 7%;
  }

  .free_tarot_display {
    position: absolute;
    top: 0%;
    left: 0%;
    width: 100%;
    height: 390px;
    z-index: 10;
  }
  .free_tarot_question {
    width: 100%;
    text-align: center;
    margin: 1% 0 2%;
  }
  .free_tarot_question p {
    font-family: "ヒラギノ明朝 ProN W6", "HiraMinProN-W6", "HG明朝E", "ＭＳ Ｐ明朝", "MS PMincho", "MS 明朝", serif;
    color: #ffffff;
    font-size: 2.4rem;
    letter-spacing: 0.05rem;
  }
  /* 生年月日入力欄 */
  .birthday_select_box.free_tarot_birthday_select_box {
      margin-left: 17%;
      display: flex;
      align-items: end;
      gap: 2%;
  }
  .birthday_select_box.free_tarot_birthday_select_box select {
    font-family:  "ヒラギノ明朝 ProN W6", "HiraMinProN-W6", "HG明朝E", "ＭＳ Ｐ明朝", "MS PMincho", "MS 明朝", serif;
    letter-spacing: 0.05rem;
    font-size: 2.5rem;
    line-height: 140%;
  }
  .birthday_select_box.free_tarot_birthday_select_box p {
    font-family:  "ヒラギノ明朝 ProN W6", "HiraMinProN-W6", "HG明朝E", "ＭＳ Ｐ明朝", "MS PMincho", "MS 明朝", serif;
    letter-spacing: 0.05rem;
  }

  #free_tarot_button {
    width: 464px;
    height: 196px;
    margin: 6% auto 0;
    cursor: pointer;
  }
  #free_tarot_button img {
    width: 100%;
  }

  .loading_text_box {
    position: absolute;
    top: 0%;
    left: 0%;
    width: 100%;
    height: 390px;
    text-align: left;
    display: none;
  }
  #loading_text {
    font-family: "ヒラギノ明朝 ProN W6", "HiraMinProN-W6", "HG明朝E", "ＭＳ Ｐ明朝", "MS PMincho", "MS 明朝", serif;
    font-weight: bold;
    font-size: 5rem;
    color: #ffffff;
    margin-top: 15%;
    margin-left: 25%;
    letter-spacing: 0.05rem;
  }

  .free_tarot_box {
    position: absolute;
    top: 0%;
    left: 0%;
    width: 100%;
    height: 390px;
  }
  #free_tarot_teller_box,
  #free_tarot_chakra_image,
  #free_tarot_result_box {
    display: none;
  }

  .free_tarot_teller_image {
    background: url(https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/res_type_yumeno2.jpg) no-repeat;
    background-position: center;
    background-size: 100%;
    width: 100%;
    height: 357px;
  }

  .free_tarot_teller_comment_box {
    position: absolute;
    top: 50%;
    right: 1%;
    transform: translateY(-50%);
    width: 60%;
  }
  .free_tarot_teller_comment_box p {
    font-family: "ヒラギノ明朝 ProN W6", "HiraMinProN-W6", "HG明朝E", "ＭＳ Ｐ明朝", "MS PMincho", "MS 明朝", serif;
    font-weight: bold;
    font-size: 2.8rem;
    color: #CC99FF;
    text-shadow: 0 0 4px #000000, 0 0 8px #000000, 0 0 8px #ae00ff;
    line-height: 140%;
    letter-spacing: 0.05rem;
  }
  .chakra_image_box {
    position: absolute;
    top: 50%;
    left: 66%;
    transform: translate(-50%, -50%);
    width: 300px;
    height: 300px;
  }
  .chakra_image_box img {
    width: 100%;
  }

  .free_tarot_result_text {
    width: 100%;
    text-align: left;
    font-size: 1.3rem;
    color: #ffffff;
    line-height: 140%;
  }

  /* show_text_link */
  .show-text-link a {
    font-size: 1.32rem;
  }
  .show-text-link_flex {
    display: flex;
    justify-content: space-between;
    align-items: center;
    width: 90%;
    margin: 0 auto;
  }
  .show-text-link_flex_left {
    width: 12%;
  }
  .show-text-link_flex_right {
    width: 85%;
    text-align: left;
  }
  .show-text-link_flex_right div {
    text-align: right;
  }

  .show-text-link_flex_right_new {
    font-size: 1.1rem;
    color: red;
    text-align: right;
  }

  .show-text-link_ballon {
    background: linear-gradient(to right, #ffb1aa 1%,#f16a60 10%, #f16a60 90%,#ffb1aa 99%);
    padding: 5px;
    margin-bottom: 25px;
    font-size: 1.5rem;
  }
</style><style>
.appraisal_start_button_section {
  text-align: center;
  min-height: 135px;
}
.menu_caption {
  margin: 0% 3% 2%;
  text-align: left;
  font-size: 1.3rem;
}

.woman_only {
  font-size: 1.3rem;
  color: #ffffff;
}
</style><style>
/* 結果画面冒頭の監修者コメント */
.result_teller_comment_background {
  position: relative;
  background: url('https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/result_top.jpg')no-repeat;
  background-position: center;
  background-size: 100%;
  height: 478px;
}
.result_teller_comment {
  position: absolute;
  top: 22%;
  left: 3%;
  width: 58%;
  text-align: left;
}
.result_teller_comment p {
  font-family: "ヒラギノ明朝 ProN W6", "HiraMinProN-W6", "HG明朝E", "ＭＳ Ｐ明朝", "MS PMincho", "MS 明朝", serif;
  font-size: 1.5rem;
  color: #ffffff;
  line-height: 140%;
  text-shadow: 2px 2px 2px #000000, 2px 2px 2px #000000, 2px 2px 2px #000000;
  letter-spacing: 0.05rem;
}

/* 結果全体の背景 */
.result_background {
  background: url('https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/result_description_background.jpg') repeat-y;
  background-position: center;
  background-size: 100%;
}

/* プロフィール表示部分 */
.profile_display_section {
  display: flex;
  flex-flow: column;
  align-items: center;
  text-align: left;
}
.profile_display_section p {
  font-size: 1.3rem;
  font-family: "ヒラギノ明朝 ProN W6", "HiraMinProN-W6", "HG明朝E", "ＭＳ Ｐ明朝", "MS PMincho", "MS 明朝", serif;
  letter-spacing: 0.05rem;
  line-height: 140%;
}

/* 小メニューのスタイル */
.result_subheading_background_center {
  background: url('https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/result_subheading_background.jpg');
  background-position: center;
  background-size: 100%;
  font-size: 1.6rem;
  padding: 0 60px;
  font-weight: bold;
  line-height: 2.4rem;
}
.result_subheading_background_center p {
  color: #ffcf3a;
  font-family: "ヒラギノ明朝 ProN W6", "HiraMinProN-W6", "HG明朝E", "ＭＳ Ｐ明朝", "MS PMincho", "MS 明朝", serif;
  font-weight: bold;
}

/* 原稿のスタイル */
.result_description_background_center {
  background: url('https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/result_description_background.jpg') repeat-y;
  background-position: center;
  background-size: 100%;
  padding: 0 40px;
  font-size: 1.3rem;
  text-align: left;
  color: #ffffff;
}

/* 一部無料時のラスト */
.line_background {
  background: url("https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/result_description_background.jpg") repeat-y;
  background-size: 100% 100%;
}
.paid_menu {
  font-size: 1.23rem;
  background: url("https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/result_description_background.jpg") repeat-y;
  background-size: 100%;
  padding: 3% 5% 0;
  text-align: center;
}

/* 原稿の非表示  class="manuscript_display_none"    */
.manuscript_display_none {
  display: none;
}

/* 特殊枠1（チャクラ占い）の詳細 */
.chakra_telling_result_background {
  background: url('https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/res_motif_background1.jpg') no-repeat;
  background-position: center;
  background-size: 100%;
  width: 890px;
  height: 290px;
  display: flex;
  flex-flow: row;
}
.chakra_telling_result_image {
  display: flex;
  margin: auto;
  width: 450px;
}
.chakra_telling_result_image.left {
  margin-left: 3%;
}
.chakra_telling_result_image.right {
  margin-right: 3%;
}
.chakra_telling_result_image img {
  margin: auto;
  width: 100%;
}

.beginning_text_background.chakra_telling_result_text .beginning_text_balloon {
  width: 90%;
  padding: 3% 5%;
  margin: auto;
  background-color: #000000ad;
  box-shadow: 0 0 10px #331967, 0 0 10px #683b6a;
}
.beginning_text_background.chakra_telling_result_text .beginning_text_balloon p {
  font-size: 1.3rem;
}

/* 特殊枠3（チャクラ大小） */
.result_teller_background {
  background: url('https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/res_type_yumeno1.jpg') no-repeat;
  background-position: center;
  background-size: 100%;
  height: 370px;
  display: flex;
  align-items: center;
}
.result_teller_background .chakra_big_small_balloon {
  width: 56%;
  background-color: #00000080;
  box-shadow: 0 0 15px #f9fbbdb3, 0 0 15px #f9fbbdb3;
  border-radius: 30px;
  margin: auto 35% auto 5%;
  padding: 3%;
  text-align: left;
}
.result_teller_background .chakra_big_small_balloon p {
  font-family: "ヒラギノ明朝 ProN W6", "HiraMinProN-W6", "HG明朝E", "ＭＳ Ｐ明朝", "MS PMincho", "MS 明朝", serif;
  font-size: 1.3rem;
  line-height: 140%;
  letter-spacing: 0.05rem;
  color: #ffffff;
}

.result_teller_background.two {
  background: url('https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/res_type_yumeno2.jpg') no-repeat;
  background-position: center;
  background-size: 100%;
}
.result_teller_background.two .chakra_big_small_balloon {
  margin: auto 5% auto 35%;
}

.beginning_text_balloon.chakra_big_small_result_text {
  box-shadow: 0 0 10px #331967, 0 0 10px #683b6a;
}

/* 特殊枠5（グラフ）の一部無料時の表示 */
.graph_display {
  position: relative; /* 有料ボタンの位置調整のためにここに記述 */
  height: 550px;
}

.graph_charge_transition_button {
  position: absolute;
  top: 50%;
  left: 50%;
  transform: translate(-50%, -50%);
  opacity: 0;
}

/* 特殊枠6（一問一答）, 特殊枠7（YESNO）, 特殊枠8（時期だし）　の冒頭文 */
.beginning_text_background {
  width: 100%;
  min-height: 100px;
  display: flex;
}

.beginning_text_balloon {
  width: 90%;
  min-height: 60px;
  text-align: left;
  margin: 2% auto;
  padding: 2% 4%;
  box-sizing: border-box;
  background-color: #00000080;
  border-radius: 22px;
  box-shadow: 0 0 10px #f9fbbdb3, 0 0 10px #f9fbbdb3;
}
.beginning_text_balloon p {
  font-family: "ヒラギノ明朝 ProN W6", "HiraMinProN-W6", "HG明朝E", "ＭＳ Ｐ明朝", "MS PMincho", "MS 明朝", serif;
  font-size: 1.3rem;
  line-height: 140%;
  color: #ffffff;
  letter-spacing: 0.05rem;
}

/* 特殊枠5（グラフ）・特殊枠9（最終アドバイス） */
.result_explanation_box {
  background: url('https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/res_type_background4_body.jpg') repeat-y;
  background-position: center;
  background-size: 100%;
  padding: 0% 8%;
  text-align: left;
  margin: -1px 0;
}
.result_explanation_box p {
  font-family: "ヒラギノ明朝 ProN W6", "HiraMinProN-W6", "HG明朝E", "ＭＳ Ｐ明朝", "MS PMincho", "MS 明朝", serif;
  letter-spacing: 0.05rem;
  font-size: 1.3rem;
  line-height: 140%;
  color: #000000;
}

</style>
<!-- -->


<main class="content_main">
  <div class="main_shadow">
    <section id="header"><style>
            .header_background_index {
            max-width: 1000px;
            margin: 0 auto;
            background: url('https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/header/header_background.png');
            background-repeat: no-repeat;
            background-size: 100%;
            position: relative;
        }

        .header_background {
            max-width: 1000px;
            margin: 0 auto;
            background: url('https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/header/header_background_harf.png');
            background-repeat: no-repeat;
            background-size: 100%;
            position: relative;
        }
    
    /*************************************************/
    /* use free items transition navigation section */
    /***********************************************/
    .navigation_background a div {
        width: 100%;
        height: 172px;
    }

    .navigation_background .navigation_menu_links {
        width: 990px;
        height: 180px;
        display: flex;
        justify-content: space-around;
        flex-wrap: wrap;
    }

    .navigation_background .navigation_menu_links a {
        width: 330px;
        height: 176px;
        background-size: 100% 100%;
    }

    .navigation_background .navigation_menu_links img {
        width: 100%;
        height: 100%;
    }

    .navigation_background .navigation_menu_links_minori {
        width: 990px;
        height: 190px;
        display: flex;
        justify-content: space-around;
        flex-wrap: wrap;
    }

    .navigation_background .navigation_menu_links_minori a {
        width: 240px;
        height: 190px;
        background-size: 100% 100%;
    }

    .navigation_background .navigation_menu_links_minori img {
        width: 100%;
        height: 100%;
    }

    /*************************************************/
    /* use each pages tarnsition navigation section */
    /***********************************************/
    .navigation_background .navigation_menu_pages {
        width: 990px;
        height: 110px;
        box-sizing: border-box;
        background: url('https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/header/navigation_background.png') no-repeat;
        display: flex;
        justify-content: center;
        align-items: end;
        flex-wrap: wrap;
    }

    .navigation_background .navigation_menu_pages a {
        width: 270px;
        height: 90px;
        background-size: 100% 100%;
    }

    .navigation_background .navigation_menu_pages img {
        width: 100%;
        height: 100%;
    }

    /******************/
    /* use addcrumbs */
    /****************/
    .addcrumbs_text_section {
        text-align: left;
        color: #ffffff;
        font-size: 1.3rem;
        background-size: 100% 100%;
        background: url('https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/common/section_background.jpg');
        padding: 10px 50px;
    }

    .addcrumbs_text_section a {
        color: #24aaff;
    }

    .addcrumbs_text_section a:hover {
        color: #5b5ff1;
    }
</style>

<!DOCTYPE html>


<header>
    <!-- KV image -->
                <div class="header_background">
                        <section id="header" class="section_container">
                <div class="navigation_background">
                    <!-- KV image link range -->
                                            <a href="/cp_rsa/yumecakra_rsa/">
                            <div></div>
                        </a>
                                                            <section id="pageTransitionNavigation">
                        <!------------------------------------------->
                        <!-- page transition buttons section start -->
                        <!------------------------------------------->
                        <div class="navigation_menu_pages">
                                                            <a class="navigation_menu_page_button_left" href="/cp_rsa/yumecakra_rsa/teller/"><img loading="lazy" alt='監修者紹介' src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/header/navigation_button1.png" onmouseover="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/header/navigation_button1_over.png'" onmouseout="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/header/navigation_button1.png'"></a>
                                                                                        <a class="navigation_menu_page_button_center" href="/cp_rsa/yumecakra_rsa/telling/"><img loading="lazy" alt='占術紹介' src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/header/navigation_button2.png" onmouseover="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/header/navigation_button2_over.png'" onmouseout="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/header/navigation_button2.png'"></a>
                                                                                        <a target="_new" class="navigation_menu_page_button_right" href="/cp_rsa/yumecakra_rsa/recommend/"><img loading="lazy" alt='おすすめリンク' src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/header/navigation_button3.png" onmouseover="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/header/navigation_button3_over.png'" onmouseout="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/header/navigation_button3.png'"></a>
                                                    </div>
                        <!----------------------------------------->
                        <!-- page transition buttons section end -->
                        <!----------------------------------------->
                        <!------------------------------>
                        <!-- topic path section start -->
                        <!------------------------------>

                                                    <div id="topicpath" class="addcrumbs_text_section">
                                <p>
                                                                                                                        <a href="/moon/">cocoloni占い館 Moon Top</a>&nbsp;&gt;&nbsp;<a href="/cp_rsa/yumecakra_rsa/">【ゆめの心々】チャクラ占い</a>&nbsp;&gt;&nbsp;<a href="/cp_rsa/yumecakra_rsa/pre/life001/">人生掌握【ゆめの心々渾身】あなたの全運命を霊視◆1年⇒10年後/晩年</a>&nbsp;&gt;&nbsp;一部無料鑑定結果
                                                                                                            </p>
                            </div>
                                                <!------------------------------>
                        <!-- topic path section start -->
                        <!------------------------------>
                    </section>
                </div>
            </section>
            </div><!-- KV image div -->
</header></section>

    <section class="section_container section_background">
      <div style="margin: 0 33px; text-align: center;">
        <!---------------------------------------------->
        <!-- content menu title dispaly section start -->
        <!---------------------------------------------->
        <section id="contentMenuTitleDisplay">
          <style>
  /******************************/
  /* 選択アイテムメニュー表示で使用 */
  /****************************/
  .content_menu_title_background_center {
    background: url("https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/pre/choice_item_menu_background.png") repeat-y;
    background-position: center;
    text-align: left;
    padding: 0 70px;
    line-height: 190%;
    display: flex;
    align-items: center;
  }

  .content_menu_title_background_center p {
    font-size: 1.9rem;
    font-weight: bold;
    font-family: "ヒラギノ明朝 ProN W6", "HiraMinProN-W6", "HG明朝E", "ＭＳ Ｐ明朝", "MS PMincho", "MS 明朝", serif;
    letter-spacing: 0.05rem;
    color: #ffcf3a;
    line-height: 140%;
  }

  .icon_image_box {
    width: 19%;
    display: flex;
  }

  .icon_image_box img {
    width: 75px;
    height: 75px;
    margin: auto;
  }
</style>

<img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/pre/choice_item_menu_top.png" style="width: 100%; vertical-align: bottom">
<div class="content_menu_title_background_center">
  <div class="icon_image_box">
    <img src="https://img.rensa.jp.net/web/RYC/menu/icon_off/icon12.png" alt="人生"/>  </div>
  <p>    人生掌握【ゆめの心々渾身】あなたの全運命を霊視◆1年⇒10年後/晩年
</p>
</div>
<img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/pre/choice_item_menu_bottom.png" style="width: 100%; vertical-align: top;">        </section>
        <!-------------------------------------------->
        <!-- content menu title dispaly section end -->
        <!-------------------------------------------->

        <section id="resultTellerComment">
          <div class="result_teller_comment_background">
            <div class="result_teller_comment">
              <p>&emsp;パフォーマンスを上げる際に個性や特徴を発揮することを「自分の色を出す」と言いますが、あさんの「色」はどんな色でしょうか。チャクラ占いでは体に流れるエネルギーの源にあるチャクラを視て、<span class="strong-text blue">その人が本来持っている特色</span>を知ることができます。<br>&emsp;ここではあさんが持つ特色を正しく理解することで、この先の人生で訪れるチャンスを逃さず掴むことができるのです。どうぞ、最後までお読みください。</p>
            </div>
          </div>
        </section>


        <!----------------------------------->
        <!-- profile display section start -->
        <!----------------------------------->
        <div class="result_background">
          <img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/top/line.png">
          <section id="profileDisplaySection" class="profile_display_section">
            <div>
              <p>
                あ&emsp;
                1976年08月17日&emsp;
                女性              </p>
            </div>
                      </section>
          <img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/top/line2.png" style='margin-bottom: 2%'>
        </div>
        <!----------------------------------->
        <!-- profile display section end -->
        <!----------------------------------->
        <script>
          var subMenuCount = 36;
        </script>

        <!------------------------------>
        <!-- small menu section start -->
        <!------------------------------>
        <div class="result_background">
                      

<!--　特殊枠1（チャクラ占い）　-->
<section id="chakra_telling_section">
      <!-- 看板画像 -->
          <img loading="lazy" alt='あなたを巡るエネルギーの中核を視る チャクラ占い' src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/res_type_title1.png" style="width: 100%; vertical-align: bottom;">
    
    <!-- vue start -->
    <div id="chakra_telling_1" class="chakra_telling">
      <chakra-telling
        result="[&quot;\u7279\u6b8a\u67a01\uff08\u30c1\u30e3\u30af\u30e9\u5360\u3044\uff09&quot;,&quot;\u7b2c2\u30c1\u30e3\u30af\u30e9&quot;,&quot;\u7b2c3\u30c1\u30e3\u30af\u30e9&quot;,&quot;\u7b2c5\u30c1\u30e3\u30af\u30e9&quot;,&quot;\u7b2c7\u30c1\u30e3\u30af\u30e9&quot;,&quot;&lt;span class=\&quot;strong-text blue\&quot;&gt;\u7b2c7\u30c1\u30e3\u30af\u30e9&lt;\/span&gt;\uff1a\u5927&lt;br&gt;\u3042\u306a\u305f\u306e\u970a\u529b&quot;,&quot;&lt;span class=\&quot;strong-text blue\&quot;&gt;\u7b2c6\u30c1\u30e3\u30af\u30e9&lt;\/span&gt;\uff1a\u4e2d&lt;br&gt;\u3042\u306a\u305f\u306e\u76f4\u611f\u529b&quot;,&quot;&lt;span class=\&quot;strong-text blue\&quot;&gt;\u7b2c5\u30c1\u30e3\u30af\u30e9&lt;\/span&gt;\uff1a\u4e2d&lt;br&gt;\u3042\u306a\u305f\u306e\u8868\u73fe\u529b&quot;,&quot;&lt;span class=\&quot;strong-text blue\&quot;&gt;\u7b2c4\u30c1\u30e3\u30af\u30e9&lt;\/span&gt;\uff1a\u4e2d&lt;br&gt;\u3042\u306a\u305f\u306e\u611b&quot;,&quot;&lt;span class=\&quot;strong-text blue\&quot;&gt;\u7b2c3\u30c1\u30e3\u30af\u30e9&lt;\/span&gt;\uff1a\u4e2d&lt;br&gt;\u3042\u306a\u305f\u306e\u81ea\u610f\u8b58&quot;,&quot;&lt;span class=\&quot;strong-text blue\&quot;&gt;\u7b2c2\u30c1\u30e3\u30af\u30e9&lt;\/span&gt;\uff1a\u4e2d&lt;br&gt;\u3042\u306a\u305f\u306e\u81ea\u7acb\u5fc3&quot;,&quot;&lt;span class=\&quot;strong-text blue\&quot;&gt;\u7b2c1\u30c1\u30e3\u30af\u30e9&lt;\/span&gt;\uff1a\u5c0f&lt;br&gt;\u3042\u306a\u305f\u306e\u751f\u547d\u529b&quot;,&quot;\u3042\u306a\u305f\u304c\u3053\u306e\u5148\u3001\u4eca\u4ee5\u4e0a\u306b\u6e80\u8db3\u3067\u304d\u308b\u65e5\u3005\u3092\u9001\u308b\u305f\u3081\u306b\u306f\u3001\u30c1\u30e3\u30af\u30e9\u304b\u3089\u5de1\u3063\u3066\u3044\u308b\u30a8\u30cd\u30eb\u30ae\u30fc\u3092\u610f\u8b58\u3059\u308b\u3053\u3068\u304c\u6709\u52b9\u3067\u3059\u3002\u4eca\u3001\u3042\u306a\u305f\u304c\u6301\u3064&lt;span class=\&quot;strong-text green\&quot;&gt;\u6ce8\u76ee\u3059\u3079\u304d4\u3064\u306e\u30c1\u30e3\u30af\u30e9&lt;\/span&gt;\u3068\u3001&lt;span class=\&quot;strong-text green\&quot;&gt;\u6d3b\u6027\u5316\u3057\u3066\u3044\u308b\u30c1\u30e3\u30af\u30e9&lt;\/span&gt;\u306e\u30a8\u30cd\u30eb\u30ae\u30fc\u304b\u3089\u3001\u3088\u308a\u3088\u3044\u672a\u6765\u3092\u8fce\u3048\u308b\u305f\u3081\u306e\u304a\u8a71\u3092\u3057\u3066\u3044\u304d\u307e\u3059\u3002&quot;]"
        result-image="[&quot;https:\/\/img.rensa.jp.net\/web\/RYC\/motif\/type1\/res_type1_701.png||RYC01&quot;,&quot;https:\/\/img.rensa.jp.net\/web\/RYC\/motif\/type1\/res_type1_602.png||RYC01&quot;,&quot;https:\/\/img.rensa.jp.net\/web\/RYC\/motif\/type1\/res_type1_502.png||RYC01&quot;,&quot;https:\/\/img.rensa.jp.net\/web\/RYC\/motif\/type1\/res_type1_402.png||RYC01&quot;,&quot;https:\/\/img.rensa.jp.net\/web\/RYC\/motif\/type1\/res_type1_302.png||RYC01&quot;,&quot;https:\/\/img.rensa.jp.net\/web\/RYC\/motif\/type1\/res_type1_202.png||RYC01&quot;,&quot;https:\/\/img.rensa.jp.net\/web\/RYC\/motif\/type1\/res_type1_103.png||RYC01&quot;]"
        person="1"
        profile-data="{&quot;full_name&quot;:&quot;\u3042&quot;,&quot;first_name&quot;:&quot;&quot;,&quot;last_name&quot;:&quot;&quot;,&quot;first_name_kana&quot;:&quot;&quot;,&quot;last_name_kana&quot;:&quot;&quot;,&quot;birthday&quot;:&quot;1976-08-17&quot;,&quot;birthtime&quot;:&quot;0000&quot;,&quot;birth_place&quot;:&quot;&quot;,&quot;gender&quot;:&quot;F&quot;,&quot;target_full_name&quot;:&quot;&quot;,&quot;target_first_name&quot;:&quot;&quot;,&quot;target_last_name&quot;:&quot;&quot;,&quot;target_first_name_kana&quot;:&quot;&quot;,&quot;target_last_name_kana&quot;:&quot;&quot;,&quot;target_birthday&quot;:&quot;0000-00-00&quot;,&quot;target_birthtime&quot;:&quot;0000&quot;,&quot;target_birth_place&quot;:&quot;&quot;,&quot;target_gender&quot;:&quot;&quot;}"
        index-number="1"
        add-index-number="0"
      />
    </div>
    <!-- vue end -->

  </section>                      

<!--　特殊枠1（チャクラ占い）　-->
<section id="chakra_telling_section">
      <!-- 見出し -->
    <img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/result_subheading_top.jpg" style="width: 100%; vertical-align: bottom;">
    <div class="result_subheading_background_center">
      <p>第2チャクラから視る、あなたは人生で何に幸福と喜びを感じるのか</p>
    </div>
    <img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/result_subheading_bottom.jpg" style="width: 100%; vertical-align: top;">

    <!-- 原稿 -->
    <div id="chakra_telling_manuscript_2" class="manuscript_display_none">
      <!-- 結果テキスト -->
      <div class="chakra_telling_result_background">
                  <div class="chakra_telling_result_image left">
            <img loading="lazy" src="https://img.rensa.jp.net/web/RYC/motif/type1/res_type1_202.png">
          </div>
          <div class="beginning_text_background chakra_telling_result_text">
            <div class="beginning_text_balloon">
                              <p>自立心を司る<span class="strong-text blue">『第2チャクラ』</span>から、あなたが何に幸福と喜びを感じるのかがわかりました。それは<span class="strong-text green">XXXXられる時間</span>です。このことについて詳しくお話ししていきましょう。</p>
                          </div>
          </div>
              </div>

      <div class="result_description_background_center">
                  &emsp;あなたの体を巡るエネルギーとチャクラから、「慈悲の心」が伝わってきます。自分を大切にするのは当然のことではありますが、そのうえさらにあさんは、周囲の人達に対する優しい思いやりが感じられます。自分のことだけではなく、あなたは……          <style>
  .charge_transition_screen_button {
    width: 308px;
    height: 104px;
    padding: 0;
    border: none;
    outline: none;
    cursor: pointer;
  }

  .charge_transition_screen_button img {
    width: 100%;
    height: 100%;
    border: none;
  }

  .mosaic_text_background {
    background: url("https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/result_mosaic_text.png") no-repeat;
    background-size: 115% 100%;
    background-position: center;
    width: 100%;
    height: 180px;
    text-align: center;
    padding-top: 10%;
  }

  .graph_charge_transition_screen_button {
    height: 125px;
    width: 375px;
    padding: 0;
    border: none;
    outline: none;
    cursor: pointer;
  }

  .graph_charge_transition_screen_button img {
    width: 100%;
  }
</style>

<form method="post" accept-charset="euc-jp" id="buyMoreProfileForm" action="https://zap-happyfortune.rensa.jp.net/cocoloni/yumecakra_rsa/result/"><div style="display:none;"><input type="hidden" name="_method" value="POST"/></div><input type="hidden" name="itemcd" value="life001"/><input type="hidden" name="howToBuy" value="paymentAppraisalButton"/><input type="hidden" name="TerminalModel" value="pc"/><input type="hidden" name="time" value=""/><input type="hidden" name="zp_channel_id" value="105_yc0004a"/><input type="hidden" name="contentKey" value="CYC"/><input type="hidden" name="full_name" value="あ"/><input type="hidden" name="birthday" value="1976-08-17"/><input type="hidden" name="gender" value="F"/>  <div class="mosaic_text_background">
    <button type="button" class="charge_transition_screen_button" name="paymentAppraisalButtonOfAjax">
      <img loading="lazy" alt="続きを見る(有料)" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/charge_transition_screen_button.png" onmouseover="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/charge_transition_screen_button_over.png'" onmouseout="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/charge_transition_screen_button.png'">
    </button>
  </div>
</form>
<script>
  window.onload = () => {
    var processing = false;
    $('button[name=paymentAppraisalButtonOfAjax]').on('click', function() {
      if (processing) {
        return;
      }
      processing = true;
      var paymentSystemName = 'cocoloni';
      var form = $(this).parents("form");
      var itemcd = form.find('input:hidden[name=itemcd]').val()
      var channel = form.find('input:hidden[name=zp_channel_id]').val()
      var fullName = form.find("input:hidden[name='full_name']").val()
      var birthday = form.find('input:hidden[name=birthday]').val()
      var gender = form.find("input:hidden[name=gender]").val()
      var targetFullName = form.find("input:hidden[name='target_full_name']").val()
      var targetBirthday = form.find('input:hidden[name=target_birthday]').val()
      var targetGender = form.find('input:hidden[name=target_gender]').val()

      if (paymentSystemName == "minori") {
        var url = location.href;
        var env = url.match("dev") ? 'https://dev.rensa.jp.net' : 'https://rensa.jp.net';
        $.ajax({
          type: "POST",
          url: env + "https://honkaku-uranai.jp/cp_rsa/yumecakra_rsa/result/life001", //本番環境用
          //url: "http://localhost/maki/minori/result/life001",//テスト用
          data: {
            "isNomalPayment": true,
            "itemcd": itemcd,
            "howToBuy": "partlyAppraisalButton",
            "full_name": fullName,
            "birthday": birthday,
            "gender": gender,
            "target_full_name": targetFullName,
            "target_birthday": targetBirthday,
            "target_gender": targetGender,
            "TerminalModel": "pc"
          },
          dataType: "html"
        }).done(function(data) {
          console.log(data);
          var dom_parser = new DOMParser();
          var retensionResultDataId = dom_parser.parseFromString(data, "text/html").getElementById("retensionResultData").innerHTML
          $("[name=retensionResultDataId]").val(retensionResultDataId.split("__rid__")[1])
          form.attr("method", "post")
          form.attr("action", "https://zap-happyfortune.rensa.jp.net/cocoloni/yumecakra_rsa/result/").submit();
          processing = false;
        }).fail(function() {
          alert("通信に失敗しました");
          processing = false;
        });
      } else if (paymentSystemName == "cocoloni" || paymentSystemName == "cp_rsa") {
        let postUrl = "";
        let locationUri = location.hostname;
        switch (locationUri) {
            case "honkaku-uranai.jp":
                postUrl = "https://honkaku-uranai.jp/cp_rsa/yumecakra_rsa/result";
                break;
            case "test-honkaku.cocoloni.jp":
                postUrl = "https://test-honkaku.cocoloni.jp/cp_rsa/yumecakra_rsa/result";
                break;
            default:
                postUrl = "http://localhost/cocoloni/yumecakra_rsa/result/life001";
        };
        let time = form.find("input[name='time']").val();
        $.ajax({
          type: "POST",
          url: postUrl,
          data: {
            "ajaxParameter": true,
            "itemcd": itemcd,
            "zp_channel_id": channel,
            "time": time,
            "full_name": fullName,
            "birthday": birthday,
            "gender": gender,
            "target_full_name": targetFullName,
            "target_birthday": targetBirthday,
            "target_gender": targetGender,
            "TerminalModel": "pc",
            "howToBuy": "paymentAppraisalButton",
          }
        }).done(function(data) {
          var dataValue = JSON.parse(data)
          var zp_channel_id = dataValue.zp_channel_id
          var zp_sid = dataValue.zp_sid
          var zp_sig = dataValue.zp_sig
          processing = false;
          if (location.hostname.includes("test-honkaku.cocoloni.jp") !== false) {
            window.location.href = "https://test-honkaku.cocoloni.jp/portal/charge/?zp_cp_name=cp_rsa&zp_channel_id=" + zp_channel_id + "&zp_sid=" + zp_sid + "&zp_sig=" + zp_sig
          } else {
            window.location.href = "https://honkaku-uranai.jp/portal/charge/?zp_cp_name=cp_rsa&zp_channel_id=" + zp_channel_id + "&zp_sid=" + zp_sid + "&zp_sig=" + zp_sig
          }
        }).fail(function() {
          alert("通信に失敗しました");
          processing = false;
        });
      }
    })
  };
</script>              </div>
    </div>
  </section>                      

<!--　特殊枠1（チャクラ占い）　-->
<section id="chakra_telling_section">
      <!-- 見出し -->
    <img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/result_subheading_top.jpg" style="width: 100%; vertical-align: bottom;">
    <div class="result_subheading_background_center">
      <p>第3チャクラで分かる、あなたの人を引き付ける魅力</p>
    </div>
    <img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/result_subheading_bottom.jpg" style="width: 100%; vertical-align: top;">

    <!-- 原稿 -->
    <div id="chakra_telling_manuscript_3" class="manuscript_display_none">
      <!-- 結果テキスト -->
      <div class="chakra_telling_result_background">
                  <div class="beginning_text_background chakra_telling_result_text">
            <div class="beginning_text_balloon">
                              <p>あなたの自意識を司る<span class="strong-text blue">『第3チャクラ』</span>から、あなたには<span class="strong-text green">XXXXXXX</span>という魅力が備わっているということがわかります。</p>
                          </div>
          </div>
          <div class="chakra_telling_result_image right">
            <img loading="lazy" src="https://img.rensa.jp.net/web/RYC/motif/type1/res_type1_302.png">
          </div>
              </div>

      <div class="result_description_background_center">
                  &emsp;「腹部」にあるチャクラからは、あなたの「サービス精神」が見えてきました。とてもユニークな性質をあなたは持っていますから、人を喜ばせることに適性があるでしょう。サプライズを……          <style>
  .charge_transition_screen_button {
    width: 308px;
    height: 104px;
    padding: 0;
    border: none;
    outline: none;
    cursor: pointer;
  }

  .charge_transition_screen_button img {
    width: 100%;
    height: 100%;
    border: none;
  }

  .mosaic_text_background {
    background: url("https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/result_mosaic_text.png") no-repeat;
    background-size: 115% 100%;
    background-position: center;
    width: 100%;
    height: 180px;
    text-align: center;
    padding-top: 10%;
  }

  .graph_charge_transition_screen_button {
    height: 125px;
    width: 375px;
    padding: 0;
    border: none;
    outline: none;
    cursor: pointer;
  }

  .graph_charge_transition_screen_button img {
    width: 100%;
  }
</style>

<form method="post" accept-charset="euc-jp" id="buyMoreProfileForm" action="https://zap-happyfortune.rensa.jp.net/cocoloni/yumecakra_rsa/result/"><div style="display:none;"><input type="hidden" name="_method" value="POST"/></div><input type="hidden" name="itemcd" value="life001"/><input type="hidden" name="howToBuy" value="paymentAppraisalButton"/><input type="hidden" name="TerminalModel" value="pc"/><input type="hidden" name="time" value=""/><input type="hidden" name="zp_channel_id" value="105_yc0004a"/><input type="hidden" name="contentKey" value="CYC"/><input type="hidden" name="full_name" value="あ"/><input type="hidden" name="birthday" value="1976-08-17"/><input type="hidden" name="gender" value="F"/>  <div class="mosaic_text_background">
    <button type="button" class="charge_transition_screen_button" name="paymentAppraisalButtonOfAjax">
      <img loading="lazy" alt="続きを見る(有料)" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/charge_transition_screen_button.png" onmouseover="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/charge_transition_screen_button_over.png'" onmouseout="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/charge_transition_screen_button.png'">
    </button>
  </div>
</form>
<script>
  window.onload = () => {
    var processing = false;
    $('button[name=paymentAppraisalButtonOfAjax]').on('click', function() {
      if (processing) {
        return;
      }
      processing = true;
      var paymentSystemName = 'cocoloni';
      var form = $(this).parents("form");
      var itemcd = form.find('input:hidden[name=itemcd]').val()
      var channel = form.find('input:hidden[name=zp_channel_id]').val()
      var fullName = form.find("input:hidden[name='full_name']").val()
      var birthday = form.find('input:hidden[name=birthday]').val()
      var gender = form.find("input:hidden[name=gender]").val()
      var targetFullName = form.find("input:hidden[name='target_full_name']").val()
      var targetBirthday = form.find('input:hidden[name=target_birthday]').val()
      var targetGender = form.find('input:hidden[name=target_gender]').val()

      if (paymentSystemName == "minori") {
        var url = location.href;
        var env = url.match("dev") ? 'https://dev.rensa.jp.net' : 'https://rensa.jp.net';
        $.ajax({
          type: "POST",
          url: env + "https://honkaku-uranai.jp/cp_rsa/yumecakra_rsa/result/life001", //本番環境用
          //url: "http://localhost/maki/minori/result/life001",//テスト用
          data: {
            "isNomalPayment": true,
            "itemcd": itemcd,
            "howToBuy": "partlyAppraisalButton",
            "full_name": fullName,
            "birthday": birthday,
            "gender": gender,
            "target_full_name": targetFullName,
            "target_birthday": targetBirthday,
            "target_gender": targetGender,
            "TerminalModel": "pc"
          },
          dataType: "html"
        }).done(function(data) {
          console.log(data);
          var dom_parser = new DOMParser();
          var retensionResultDataId = dom_parser.parseFromString(data, "text/html").getElementById("retensionResultData").innerHTML
          $("[name=retensionResultDataId]").val(retensionResultDataId.split("__rid__")[1])
          form.attr("method", "post")
          form.attr("action", "https://zap-happyfortune.rensa.jp.net/cocoloni/yumecakra_rsa/result/").submit();
          processing = false;
        }).fail(function() {
          alert("通信に失敗しました");
          processing = false;
        });
      } else if (paymentSystemName == "cocoloni" || paymentSystemName == "cp_rsa") {
        let postUrl = "";
        let locationUri = location.hostname;
        switch (locationUri) {
            case "honkaku-uranai.jp":
                postUrl = "https://honkaku-uranai.jp/cp_rsa/yumecakra_rsa/result";
                break;
            case "test-honkaku.cocoloni.jp":
                postUrl = "https://test-honkaku.cocoloni.jp/cp_rsa/yumecakra_rsa/result";
                break;
            default:
                postUrl = "http://localhost/cocoloni/yumecakra_rsa/result/life001";
        };
        let time = form.find("input[name='time']").val();
        $.ajax({
          type: "POST",
          url: postUrl,
          data: {
            "ajaxParameter": true,
            "itemcd": itemcd,
            "zp_channel_id": channel,
            "time": time,
            "full_name": fullName,
            "birthday": birthday,
            "gender": gender,
            "target_full_name": targetFullName,
            "target_birthday": targetBirthday,
            "target_gender": targetGender,
            "TerminalModel": "pc",
            "howToBuy": "paymentAppraisalButton",
          }
        }).done(function(data) {
          var dataValue = JSON.parse(data)
          var zp_channel_id = dataValue.zp_channel_id
          var zp_sid = dataValue.zp_sid
          var zp_sig = dataValue.zp_sig
          processing = false;
          if (location.hostname.includes("test-honkaku.cocoloni.jp") !== false) {
            window.location.href = "https://test-honkaku.cocoloni.jp/portal/charge/?zp_cp_name=cp_rsa&zp_channel_id=" + zp_channel_id + "&zp_sid=" + zp_sid + "&zp_sig=" + zp_sig
          } else {
            window.location.href = "https://honkaku-uranai.jp/portal/charge/?zp_cp_name=cp_rsa&zp_channel_id=" + zp_channel_id + "&zp_sid=" + zp_sid + "&zp_sig=" + zp_sig
          }
        }).fail(function() {
          alert("通信に失敗しました");
          processing = false;
        });
      }
    })
  };
</script>              </div>
    </div>
  </section>                      

<!--　特殊枠1（チャクラ占い）　-->
<section id="chakra_telling_section">
      <!-- 見出し -->
    <img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/result_subheading_top.jpg" style="width: 100%; vertical-align: bottom;">
    <div class="result_subheading_background_center">
      <p>第5チャクラで知る、あなたらしく生きる人生の引き寄せ方</p>
    </div>
    <img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/result_subheading_bottom.jpg" style="width: 100%; vertical-align: top;">

    <!-- 原稿 -->
    <div id="chakra_telling_manuscript_4" class="manuscript_display_none">
      <!-- 結果テキスト -->
      <div class="chakra_telling_result_background">
                  <div class="chakra_telling_result_image left">
            <img loading="lazy" src="https://img.rensa.jp.net/web/RYC/motif/type1/res_type1_502.png">
          </div>
          <div class="beginning_text_background chakra_telling_result_text">
            <div class="beginning_text_balloon">
                              <p>あなたの表現力を司る<span class="strong-text blue">『第5チャクラ』</span>から、あなたが自分らしく生きるためには<span class="strong-text green">XXXXXXX</span>ということが必要だとわかりました。</p>
                          </div>
          </div>
              </div>

      <div class="result_description_background_center">
                  &emsp;「のど」に位置するチャクラからは、あなたの「誠実さ」がはっきりと伝わってきます。ちょっとスピリチュアルな話をすると、あなたにはご先祖からの加護が強くあり、大抵の物事は……          <style>
  .charge_transition_screen_button {
    width: 308px;
    height: 104px;
    padding: 0;
    border: none;
    outline: none;
    cursor: pointer;
  }

  .charge_transition_screen_button img {
    width: 100%;
    height: 100%;
    border: none;
  }

  .mosaic_text_background {
    background: url("https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/result_mosaic_text.png") no-repeat;
    background-size: 115% 100%;
    background-position: center;
    width: 100%;
    height: 180px;
    text-align: center;
    padding-top: 10%;
  }

  .graph_charge_transition_screen_button {
    height: 125px;
    width: 375px;
    padding: 0;
    border: none;
    outline: none;
    cursor: pointer;
  }

  .graph_charge_transition_screen_button img {
    width: 100%;
  }
</style>

<form method="post" accept-charset="euc-jp" id="buyMoreProfileForm" action="https://zap-happyfortune.rensa.jp.net/cocoloni/yumecakra_rsa/result/"><div style="display:none;"><input type="hidden" name="_method" value="POST"/></div><input type="hidden" name="itemcd" value="life001"/><input type="hidden" name="howToBuy" value="paymentAppraisalButton"/><input type="hidden" name="TerminalModel" value="pc"/><input type="hidden" name="time" value=""/><input type="hidden" name="zp_channel_id" value="105_yc0004a"/><input type="hidden" name="contentKey" value="CYC"/><input type="hidden" name="full_name" value="あ"/><input type="hidden" name="birthday" value="1976-08-17"/><input type="hidden" name="gender" value="F"/>  <div class="mosaic_text_background">
    <button type="button" class="charge_transition_screen_button" name="paymentAppraisalButtonOfAjax">
      <img loading="lazy" alt="続きを見る(有料)" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/charge_transition_screen_button.png" onmouseover="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/charge_transition_screen_button_over.png'" onmouseout="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/charge_transition_screen_button.png'">
    </button>
  </div>
</form>
<script>
  window.onload = () => {
    var processing = false;
    $('button[name=paymentAppraisalButtonOfAjax]').on('click', function() {
      if (processing) {
        return;
      }
      processing = true;
      var paymentSystemName = 'cocoloni';
      var form = $(this).parents("form");
      var itemcd = form.find('input:hidden[name=itemcd]').val()
      var channel = form.find('input:hidden[name=zp_channel_id]').val()
      var fullName = form.find("input:hidden[name='full_name']").val()
      var birthday = form.find('input:hidden[name=birthday]').val()
      var gender = form.find("input:hidden[name=gender]").val()
      var targetFullName = form.find("input:hidden[name='target_full_name']").val()
      var targetBirthday = form.find('input:hidden[name=target_birthday]').val()
      var targetGender = form.find('input:hidden[name=target_gender]').val()

      if (paymentSystemName == "minori") {
        var url = location.href;
        var env = url.match("dev") ? 'https://dev.rensa.jp.net' : 'https://rensa.jp.net';
        $.ajax({
          type: "POST",
          url: env + "https://honkaku-uranai.jp/cp_rsa/yumecakra_rsa/result/life001", //本番環境用
          //url: "http://localhost/maki/minori/result/life001",//テスト用
          data: {
            "isNomalPayment": true,
            "itemcd": itemcd,
            "howToBuy": "partlyAppraisalButton",
            "full_name": fullName,
            "birthday": birthday,
            "gender": gender,
            "target_full_name": targetFullName,
            "target_birthday": targetBirthday,
            "target_gender": targetGender,
            "TerminalModel": "pc"
          },
          dataType: "html"
        }).done(function(data) {
          console.log(data);
          var dom_parser = new DOMParser();
          var retensionResultDataId = dom_parser.parseFromString(data, "text/html").getElementById("retensionResultData").innerHTML
          $("[name=retensionResultDataId]").val(retensionResultDataId.split("__rid__")[1])
          form.attr("method", "post")
          form.attr("action", "https://zap-happyfortune.rensa.jp.net/cocoloni/yumecakra_rsa/result/").submit();
          processing = false;
        }).fail(function() {
          alert("通信に失敗しました");
          processing = false;
        });
      } else if (paymentSystemName == "cocoloni" || paymentSystemName == "cp_rsa") {
        let postUrl = "";
        let locationUri = location.hostname;
        switch (locationUri) {
            case "honkaku-uranai.jp":
                postUrl = "https://honkaku-uranai.jp/cp_rsa/yumecakra_rsa/result";
                break;
            case "test-honkaku.cocoloni.jp":
                postUrl = "https://test-honkaku.cocoloni.jp/cp_rsa/yumecakra_rsa/result";
                break;
            default:
                postUrl = "http://localhost/cocoloni/yumecakra_rsa/result/life001";
        };
        let time = form.find("input[name='time']").val();
        $.ajax({
          type: "POST",
          url: postUrl,
          data: {
            "ajaxParameter": true,
            "itemcd": itemcd,
            "zp_channel_id": channel,
            "time": time,
            "full_name": fullName,
            "birthday": birthday,
            "gender": gender,
            "target_full_name": targetFullName,
            "target_birthday": targetBirthday,
            "target_gender": targetGender,
            "TerminalModel": "pc",
            "howToBuy": "paymentAppraisalButton",
          }
        }).done(function(data) {
          var dataValue = JSON.parse(data)
          var zp_channel_id = dataValue.zp_channel_id
          var zp_sid = dataValue.zp_sid
          var zp_sig = dataValue.zp_sig
          processing = false;
          if (location.hostname.includes("test-honkaku.cocoloni.jp") !== false) {
            window.location.href = "https://test-honkaku.cocoloni.jp/portal/charge/?zp_cp_name=cp_rsa&zp_channel_id=" + zp_channel_id + "&zp_sid=" + zp_sid + "&zp_sig=" + zp_sig
          } else {
            window.location.href = "https://honkaku-uranai.jp/portal/charge/?zp_cp_name=cp_rsa&zp_channel_id=" + zp_channel_id + "&zp_sid=" + zp_sid + "&zp_sig=" + zp_sig
          }
        }).fail(function() {
          alert("通信に失敗しました");
          processing = false;
        });
      }
    })
  };
</script>              </div>
    </div>
  </section>                      

<!--　特殊枠1（チャクラ占い）　-->
<section id="chakra_telling_section">
      <!-- 見出し -->
    <img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/result_subheading_top.jpg" style="width: 100%; vertical-align: bottom;">
    <div class="result_subheading_background_center">
      <p>第7チャクラが教える、生まれた時から持っている人生の可能性</p>
    </div>
    <img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/result_subheading_bottom.jpg" style="width: 100%; vertical-align: top;">

    <!-- 原稿 -->
    <div id="chakra_telling_manuscript_5" class="manuscript_display_none">
      <!-- 結果テキスト -->
      <div class="chakra_telling_result_background">
                  <div class="beginning_text_background chakra_telling_result_text">
            <div class="beginning_text_balloon">
                              <p>あなたの霊力を司る<span class="strong-text blue">『第7チャクラ』</span>から、あなたが生まれ持った可能性がわかりました。それは<span class="strong-text green">XXXXXXX</span>です。その可能性をより活かすためのお話をしましょう。</p>
                          </div>
          </div>
          <div class="chakra_telling_result_image right">
            <img loading="lazy" src="https://img.rensa.jp.net/web/RYC/motif/type1/res_type1_701.png">
          </div>
              </div>

      <div class="result_description_background_center">
                  &emsp;「体の最も高い位置」にあるチャクラからは、あなたの「上昇志向の強さ」が伝わってきました。誰に対しても上手に合わせられるあなたはソフトな印象を周囲に与えていますが、意外とあさんは……          <style>
  .charge_transition_screen_button {
    width: 308px;
    height: 104px;
    padding: 0;
    border: none;
    outline: none;
    cursor: pointer;
  }

  .charge_transition_screen_button img {
    width: 100%;
    height: 100%;
    border: none;
  }

  .mosaic_text_background {
    background: url("https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/result_mosaic_text.png") no-repeat;
    background-size: 115% 100%;
    background-position: center;
    width: 100%;
    height: 180px;
    text-align: center;
    padding-top: 10%;
  }

  .graph_charge_transition_screen_button {
    height: 125px;
    width: 375px;
    padding: 0;
    border: none;
    outline: none;
    cursor: pointer;
  }

  .graph_charge_transition_screen_button img {
    width: 100%;
  }
</style>

<form method="post" accept-charset="euc-jp" id="buyMoreProfileForm" action="https://zap-happyfortune.rensa.jp.net/cocoloni/yumecakra_rsa/result/"><div style="display:none;"><input type="hidden" name="_method" value="POST"/></div><input type="hidden" name="itemcd" value="life001"/><input type="hidden" name="howToBuy" value="paymentAppraisalButton"/><input type="hidden" name="TerminalModel" value="pc"/><input type="hidden" name="time" value=""/><input type="hidden" name="zp_channel_id" value="105_yc0004a"/><input type="hidden" name="contentKey" value="CYC"/><input type="hidden" name="full_name" value="あ"/><input type="hidden" name="birthday" value="1976-08-17"/><input type="hidden" name="gender" value="F"/>  <div class="mosaic_text_background">
    <button type="button" class="charge_transition_screen_button" name="paymentAppraisalButtonOfAjax">
      <img loading="lazy" alt="続きを見る(有料)" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/charge_transition_screen_button.png" onmouseover="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/charge_transition_screen_button_over.png'" onmouseout="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/charge_transition_screen_button.png'">
    </button>
  </div>
</form>
<script>
  window.onload = () => {
    var processing = false;
    $('button[name=paymentAppraisalButtonOfAjax]').on('click', function() {
      if (processing) {
        return;
      }
      processing = true;
      var paymentSystemName = 'cocoloni';
      var form = $(this).parents("form");
      var itemcd = form.find('input:hidden[name=itemcd]').val()
      var channel = form.find('input:hidden[name=zp_channel_id]').val()
      var fullName = form.find("input:hidden[name='full_name']").val()
      var birthday = form.find('input:hidden[name=birthday]').val()
      var gender = form.find("input:hidden[name=gender]").val()
      var targetFullName = form.find("input:hidden[name='target_full_name']").val()
      var targetBirthday = form.find('input:hidden[name=target_birthday]').val()
      var targetGender = form.find('input:hidden[name=target_gender]').val()

      if (paymentSystemName == "minori") {
        var url = location.href;
        var env = url.match("dev") ? 'https://dev.rensa.jp.net' : 'https://rensa.jp.net';
        $.ajax({
          type: "POST",
          url: env + "https://honkaku-uranai.jp/cp_rsa/yumecakra_rsa/result/life001", //本番環境用
          //url: "http://localhost/maki/minori/result/life001",//テスト用
          data: {
            "isNomalPayment": true,
            "itemcd": itemcd,
            "howToBuy": "partlyAppraisalButton",
            "full_name": fullName,
            "birthday": birthday,
            "gender": gender,
            "target_full_name": targetFullName,
            "target_birthday": targetBirthday,
            "target_gender": targetGender,
            "TerminalModel": "pc"
          },
          dataType: "html"
        }).done(function(data) {
          console.log(data);
          var dom_parser = new DOMParser();
          var retensionResultDataId = dom_parser.parseFromString(data, "text/html").getElementById("retensionResultData").innerHTML
          $("[name=retensionResultDataId]").val(retensionResultDataId.split("__rid__")[1])
          form.attr("method", "post")
          form.attr("action", "https://zap-happyfortune.rensa.jp.net/cocoloni/yumecakra_rsa/result/").submit();
          processing = false;
        }).fail(function() {
          alert("通信に失敗しました");
          processing = false;
        });
      } else if (paymentSystemName == "cocoloni" || paymentSystemName == "cp_rsa") {
        let postUrl = "";
        let locationUri = location.hostname;
        switch (locationUri) {
            case "honkaku-uranai.jp":
                postUrl = "https://honkaku-uranai.jp/cp_rsa/yumecakra_rsa/result";
                break;
            case "test-honkaku.cocoloni.jp":
                postUrl = "https://test-honkaku.cocoloni.jp/cp_rsa/yumecakra_rsa/result";
                break;
            default:
                postUrl = "http://localhost/cocoloni/yumecakra_rsa/result/life001";
        };
        let time = form.find("input[name='time']").val();
        $.ajax({
          type: "POST",
          url: postUrl,
          data: {
            "ajaxParameter": true,
            "itemcd": itemcd,
            "zp_channel_id": channel,
            "time": time,
            "full_name": fullName,
            "birthday": birthday,
            "gender": gender,
            "target_full_name": targetFullName,
            "target_birthday": targetBirthday,
            "target_gender": targetGender,
            "TerminalModel": "pc",
            "howToBuy": "paymentAppraisalButton",
          }
        }).done(function(data) {
          var dataValue = JSON.parse(data)
          var zp_channel_id = dataValue.zp_channel_id
          var zp_sid = dataValue.zp_sid
          var zp_sig = dataValue.zp_sig
          processing = false;
          if (location.hostname.includes("test-honkaku.cocoloni.jp") !== false) {
            window.location.href = "https://test-honkaku.cocoloni.jp/portal/charge/?zp_cp_name=cp_rsa&zp_channel_id=" + zp_channel_id + "&zp_sid=" + zp_sid + "&zp_sig=" + zp_sig
          } else {
            window.location.href = "https://honkaku-uranai.jp/portal/charge/?zp_cp_name=cp_rsa&zp_channel_id=" + zp_channel_id + "&zp_sid=" + zp_sid + "&zp_sig=" + zp_sig
          }
        }).fail(function() {
          alert("通信に失敗しました");
          processing = false;
        });
      }
    })
  };
</script>              </div>
    </div>
  </section>                      
<!-- caption start -->
<img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/result_subheading_top.jpg" style="width: 100%; vertical-align: bottom;">
<div class="result_subheading_background_center">
  <p>運勢が良い時、あなたに起こりやすい出来事</p>
</div>
<img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/result_subheading_bottom.jpg" style="width: 100%; vertical-align: top;">
<!-- caption end -->

<section id="normalSection">
  <div class="result_description_background_center">
          &emsp;あさんの運気が上がる前には、必ず躓きがあります。ちょっとしたミスなどで落ち込んでいるときこそが……      <style>
  .charge_transition_screen_button {
    width: 308px;
    height: 104px;
    padding: 0;
    border: none;
    outline: none;
    cursor: pointer;
  }

  .charge_transition_screen_button img {
    width: 100%;
    height: 100%;
    border: none;
  }

  .mosaic_text_background {
    background: url("https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/result_mosaic_text.png") no-repeat;
    background-size: 115% 100%;
    background-position: center;
    width: 100%;
    height: 180px;
    text-align: center;
    padding-top: 10%;
  }

  .graph_charge_transition_screen_button {
    height: 125px;
    width: 375px;
    padding: 0;
    border: none;
    outline: none;
    cursor: pointer;
  }

  .graph_charge_transition_screen_button img {
    width: 100%;
  }
</style>

<form method="post" accept-charset="euc-jp" id="buyMoreProfileForm" action="https://zap-happyfortune.rensa.jp.net/cocoloni/yumecakra_rsa/result/"><div style="display:none;"><input type="hidden" name="_method" value="POST"/></div><input type="hidden" name="itemcd" value="life001"/><input type="hidden" name="howToBuy" value="paymentAppraisalButton"/><input type="hidden" name="TerminalModel" value="pc"/><input type="hidden" name="time" value=""/><input type="hidden" name="zp_channel_id" value="105_yc0004a"/><input type="hidden" name="contentKey" value="CYC"/><input type="hidden" name="full_name" value="あ"/><input type="hidden" name="birthday" value="1976-08-17"/><input type="hidden" name="gender" value="F"/>  <div class="mosaic_text_background">
    <button type="button" class="charge_transition_screen_button" name="paymentAppraisalButtonOfAjax">
      <img loading="lazy" alt="続きを見る(有料)" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/charge_transition_screen_button.png" onmouseover="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/charge_transition_screen_button_over.png'" onmouseout="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/charge_transition_screen_button.png'">
    </button>
  </div>
</form>
<script>
  window.onload = () => {
    var processing = false;
    $('button[name=paymentAppraisalButtonOfAjax]').on('click', function() {
      if (processing) {
        return;
      }
      processing = true;
      var paymentSystemName = 'cocoloni';
      var form = $(this).parents("form");
      var itemcd = form.find('input:hidden[name=itemcd]').val()
      var channel = form.find('input:hidden[name=zp_channel_id]').val()
      var fullName = form.find("input:hidden[name='full_name']").val()
      var birthday = form.find('input:hidden[name=birthday]').val()
      var gender = form.find("input:hidden[name=gender]").val()
      var targetFullName = form.find("input:hidden[name='target_full_name']").val()
      var targetBirthday = form.find('input:hidden[name=target_birthday]').val()
      var targetGender = form.find('input:hidden[name=target_gender]').val()

      if (paymentSystemName == "minori") {
        var url = location.href;
        var env = url.match("dev") ? 'https://dev.rensa.jp.net' : 'https://rensa.jp.net';
        $.ajax({
          type: "POST",
          url: env + "https://honkaku-uranai.jp/cp_rsa/yumecakra_rsa/result/life001", //本番環境用
          //url: "http://localhost/maki/minori/result/life001",//テスト用
          data: {
            "isNomalPayment": true,
            "itemcd": itemcd,
            "howToBuy": "partlyAppraisalButton",
            "full_name": fullName,
            "birthday": birthday,
            "gender": gender,
            "target_full_name": targetFullName,
            "target_birthday": targetBirthday,
            "target_gender": targetGender,
            "TerminalModel": "pc"
          },
          dataType: "html"
        }).done(function(data) {
          console.log(data);
          var dom_parser = new DOMParser();
          var retensionResultDataId = dom_parser.parseFromString(data, "text/html").getElementById("retensionResultData").innerHTML
          $("[name=retensionResultDataId]").val(retensionResultDataId.split("__rid__")[1])
          form.attr("method", "post")
          form.attr("action", "https://zap-happyfortune.rensa.jp.net/cocoloni/yumecakra_rsa/result/").submit();
          processing = false;
        }).fail(function() {
          alert("通信に失敗しました");
          processing = false;
        });
      } else if (paymentSystemName == "cocoloni" || paymentSystemName == "cp_rsa") {
        let postUrl = "";
        let locationUri = location.hostname;
        switch (locationUri) {
            case "honkaku-uranai.jp":
                postUrl = "https://honkaku-uranai.jp/cp_rsa/yumecakra_rsa/result";
                break;
            case "test-honkaku.cocoloni.jp":
                postUrl = "https://test-honkaku.cocoloni.jp/cp_rsa/yumecakra_rsa/result";
                break;
            default:
                postUrl = "http://localhost/cocoloni/yumecakra_rsa/result/life001";
        };
        let time = form.find("input[name='time']").val();
        $.ajax({
          type: "POST",
          url: postUrl,
          data: {
            "ajaxParameter": true,
            "itemcd": itemcd,
            "zp_channel_id": channel,
            "time": time,
            "full_name": fullName,
            "birthday": birthday,
            "gender": gender,
            "target_full_name": targetFullName,
            "target_birthday": targetBirthday,
            "target_gender": targetGender,
            "TerminalModel": "pc",
            "howToBuy": "paymentAppraisalButton",
          }
        }).done(function(data) {
          var dataValue = JSON.parse(data)
          var zp_channel_id = dataValue.zp_channel_id
          var zp_sid = dataValue.zp_sid
          var zp_sig = dataValue.zp_sig
          processing = false;
          if (location.hostname.includes("test-honkaku.cocoloni.jp") !== false) {
            window.location.href = "https://test-honkaku.cocoloni.jp/portal/charge/?zp_cp_name=cp_rsa&zp_channel_id=" + zp_channel_id + "&zp_sid=" + zp_sid + "&zp_sig=" + zp_sig
          } else {
            window.location.href = "https://honkaku-uranai.jp/portal/charge/?zp_cp_name=cp_rsa&zp_channel_id=" + zp_channel_id + "&zp_sid=" + zp_sid + "&zp_sig=" + zp_sig
          }
        }).fail(function() {
          alert("通信に失敗しました");
          processing = false;
        });
      }
    })
  };
</script>      </div>
</section>                      

<!--　特殊枠3（チャクラ大小）　-->
<section id="chakra_big_small_section">
      <img loading="lazy" style="width: 100%;" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/top/line.png">
    <!-- 冒頭の監修者による説明 -->
          <div class="result_teller_background">
          <div class="chakra_big_small_balloon">
        <p>チャクラのエネルギーが強いから良い、弱いから悪い、というものではありません。状態によってエネルギーは変化しますし、適性に合った活かし方が大切です。今、<span class="strong-text green">活性化しているチャクラ</span>から<span class="strong-text green">あなたが成功するために必要な決断</span>は何かをお伝えします。</p>
      </div>
    </div>
  
  <!-- 見出し -->
  <img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/result_subheading_top.jpg" style="width: 100%; vertical-align: bottom;">
  <div class="result_subheading_background_center">
    <p>あなたが望みを叶えるための決断と選択</p>
  </div>
  <img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/result_subheading_bottom.jpg" style="width: 100%; vertical-align: top;">

  <!-- 結果テキスト -->
  <div class="beginning_text_balloon chakra_big_small_result_text">
          <p>今、特に<span class="strong-text green">活性化しているチャクラ</span>から、あなたがすべき決断と選択が視えました。<span class="strong-text green">XXXXXXX</span>が必要でしょう。</p>
      </div>

  <!-- 結果アニメーション -->
  <!-- vue start -->
  <div id="chakra_big_small_7" class="chakra_big_small">
    <chakra-big-small
      result-image="&quot;https:\/\/img.rensa.jp.net\/web\/RYC\/motif\/type1\/res_type1_701.png&quot;"
      index-number="7"
    />
  </div>
  <!-- vue end -->

  <!-- 原稿 -->
  <div id="chakra_big_small_manuscript_7" class="manuscript_display_none">
    <div class="result_description_background_center">
              &emsp;あさんは今、自分の夢や目標に向けてたゆまぬ努力を続けていることでしょう。神頼みももちろん大切ですが、それ以前にあなたがすべきこと、努力を怠っていたならば……        <style>
  .charge_transition_screen_button {
    width: 308px;
    height: 104px;
    padding: 0;
    border: none;
    outline: none;
    cursor: pointer;
  }

  .charge_transition_screen_button img {
    width: 100%;
    height: 100%;
    border: none;
  }

  .mosaic_text_background {
    background: url("https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/result_mosaic_text.png") no-repeat;
    background-size: 115% 100%;
    background-position: center;
    width: 100%;
    height: 180px;
    text-align: center;
    padding-top: 10%;
  }

  .graph_charge_transition_screen_button {
    height: 125px;
    width: 375px;
    padding: 0;
    border: none;
    outline: none;
    cursor: pointer;
  }

  .graph_charge_transition_screen_button img {
    width: 100%;
  }
</style>

<form method="post" accept-charset="euc-jp" id="buyMoreProfileForm" action="https://zap-happyfortune.rensa.jp.net/cocoloni/yumecakra_rsa/result/"><div style="display:none;"><input type="hidden" name="_method" value="POST"/></div><input type="hidden" name="itemcd" value="life001"/><input type="hidden" name="howToBuy" value="paymentAppraisalButton"/><input type="hidden" name="TerminalModel" value="pc"/><input type="hidden" name="time" value=""/><input type="hidden" name="zp_channel_id" value="105_yc0004a"/><input type="hidden" name="contentKey" value="CYC"/><input type="hidden" name="full_name" value="あ"/><input type="hidden" name="birthday" value="1976-08-17"/><input type="hidden" name="gender" value="F"/>  <div class="mosaic_text_background">
    <button type="button" class="charge_transition_screen_button" name="paymentAppraisalButtonOfAjax">
      <img loading="lazy" alt="続きを見る(有料)" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/charge_transition_screen_button.png" onmouseover="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/charge_transition_screen_button_over.png'" onmouseout="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/charge_transition_screen_button.png'">
    </button>
  </div>
</form>
<script>
  window.onload = () => {
    var processing = false;
    $('button[name=paymentAppraisalButtonOfAjax]').on('click', function() {
      if (processing) {
        return;
      }
      processing = true;
      var paymentSystemName = 'cocoloni';
      var form = $(this).parents("form");
      var itemcd = form.find('input:hidden[name=itemcd]').val()
      var channel = form.find('input:hidden[name=zp_channel_id]').val()
      var fullName = form.find("input:hidden[name='full_name']").val()
      var birthday = form.find('input:hidden[name=birthday]').val()
      var gender = form.find("input:hidden[name=gender]").val()
      var targetFullName = form.find("input:hidden[name='target_full_name']").val()
      var targetBirthday = form.find('input:hidden[name=target_birthday]').val()
      var targetGender = form.find('input:hidden[name=target_gender]').val()

      if (paymentSystemName == "minori") {
        var url = location.href;
        var env = url.match("dev") ? 'https://dev.rensa.jp.net' : 'https://rensa.jp.net';
        $.ajax({
          type: "POST",
          url: env + "https://honkaku-uranai.jp/cp_rsa/yumecakra_rsa/result/life001", //本番環境用
          //url: "http://localhost/maki/minori/result/life001",//テスト用
          data: {
            "isNomalPayment": true,
            "itemcd": itemcd,
            "howToBuy": "partlyAppraisalButton",
            "full_name": fullName,
            "birthday": birthday,
            "gender": gender,
            "target_full_name": targetFullName,
            "target_birthday": targetBirthday,
            "target_gender": targetGender,
            "TerminalModel": "pc"
          },
          dataType: "html"
        }).done(function(data) {
          console.log(data);
          var dom_parser = new DOMParser();
          var retensionResultDataId = dom_parser.parseFromString(data, "text/html").getElementById("retensionResultData").innerHTML
          $("[name=retensionResultDataId]").val(retensionResultDataId.split("__rid__")[1])
          form.attr("method", "post")
          form.attr("action", "https://zap-happyfortune.rensa.jp.net/cocoloni/yumecakra_rsa/result/").submit();
          processing = false;
        }).fail(function() {
          alert("通信に失敗しました");
          processing = false;
        });
      } else if (paymentSystemName == "cocoloni" || paymentSystemName == "cp_rsa") {
        let postUrl = "";
        let locationUri = location.hostname;
        switch (locationUri) {
            case "honkaku-uranai.jp":
                postUrl = "https://honkaku-uranai.jp/cp_rsa/yumecakra_rsa/result";
                break;
            case "test-honkaku.cocoloni.jp":
                postUrl = "https://test-honkaku.cocoloni.jp/cp_rsa/yumecakra_rsa/result";
                break;
            default:
                postUrl = "http://localhost/cocoloni/yumecakra_rsa/result/life001";
        };
        let time = form.find("input[name='time']").val();
        $.ajax({
          type: "POST",
          url: postUrl,
          data: {
            "ajaxParameter": true,
            "itemcd": itemcd,
            "zp_channel_id": channel,
            "time": time,
            "full_name": fullName,
            "birthday": birthday,
            "gender": gender,
            "target_full_name": targetFullName,
            "target_birthday": targetBirthday,
            "target_gender": targetGender,
            "TerminalModel": "pc",
            "howToBuy": "paymentAppraisalButton",
          }
        }).done(function(data) {
          var dataValue = JSON.parse(data)
          var zp_channel_id = dataValue.zp_channel_id
          var zp_sid = dataValue.zp_sid
          var zp_sig = dataValue.zp_sig
          processing = false;
          if (location.hostname.includes("test-honkaku.cocoloni.jp") !== false) {
            window.location.href = "https://test-honkaku.cocoloni.jp/portal/charge/?zp_cp_name=cp_rsa&zp_channel_id=" + zp_channel_id + "&zp_sid=" + zp_sid + "&zp_sig=" + zp_sig
          } else {
            window.location.href = "https://honkaku-uranai.jp/portal/charge/?zp_cp_name=cp_rsa&zp_channel_id=" + zp_channel_id + "&zp_sid=" + zp_sid + "&zp_sig=" + zp_sig
          }
        }).fail(function() {
          alert("通信に失敗しました");
          processing = false;
        });
      }
    })
  };
</script>          </div>
  </div>
</section>                      

<!--　特殊枠3（チャクラ大小）　-->
<section id="chakra_big_small_section">
  
  <!-- 見出し -->
  <img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/result_subheading_top.jpg" style="width: 100%; vertical-align: bottom;">
  <div class="result_subheading_background_center">
    <p>あなたが日常で抱えやすい問題と、その乗り越え方</p>
  </div>
  <img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/result_subheading_bottom.jpg" style="width: 100%; vertical-align: top;">

  <!-- 結果テキスト -->
  <div class="beginning_text_balloon chakra_big_small_result_text">
          <p>次に流れが<span class="strong-text green">縮小しているチャクラ</span>から、あなたが問題を乗り越える方法として<span class="strong-text green">XXXXXXX</span>が良いとわかりました。その様子を詳しくお伝えしましょう。</p>
      </div>

  <!-- 結果アニメーション -->
  <!-- vue start -->
  <div id="chakra_big_small_8" class="chakra_big_small">
    <chakra-big-small
      result-image="&quot;https:\/\/img.rensa.jp.net\/web\/RYC\/motif\/type1\/res_type1_103.png&quot;"
      index-number="8"
    />
  </div>
  <!-- vue end -->

  <!-- 原稿 -->
  <div id="chakra_big_small_manuscript_8" class="manuscript_display_none">
    <div class="result_description_background_center">
              &emsp;あなたは、のどかな雰囲気で実力を発揮することが出来るタイプです。気心知れた友人と一緒ならば、新しいことや苦手なことに対しても……        <style>
  .charge_transition_screen_button {
    width: 308px;
    height: 104px;
    padding: 0;
    border: none;
    outline: none;
    cursor: pointer;
  }

  .charge_transition_screen_button img {
    width: 100%;
    height: 100%;
    border: none;
  }

  .mosaic_text_background {
    background: url("https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/result_mosaic_text.png") no-repeat;
    background-size: 115% 100%;
    background-position: center;
    width: 100%;
    height: 180px;
    text-align: center;
    padding-top: 10%;
  }

  .graph_charge_transition_screen_button {
    height: 125px;
    width: 375px;
    padding: 0;
    border: none;
    outline: none;
    cursor: pointer;
  }

  .graph_charge_transition_screen_button img {
    width: 100%;
  }
</style>

<form method="post" accept-charset="euc-jp" id="buyMoreProfileForm" action="https://zap-happyfortune.rensa.jp.net/cocoloni/yumecakra_rsa/result/"><div style="display:none;"><input type="hidden" name="_method" value="POST"/></div><input type="hidden" name="itemcd" value="life001"/><input type="hidden" name="howToBuy" value="paymentAppraisalButton"/><input type="hidden" name="TerminalModel" value="pc"/><input type="hidden" name="time" value=""/><input type="hidden" name="zp_channel_id" value="105_yc0004a"/><input type="hidden" name="contentKey" value="CYC"/><input type="hidden" name="full_name" value="あ"/><input type="hidden" name="birthday" value="1976-08-17"/><input type="hidden" name="gender" value="F"/>  <div class="mosaic_text_background">
    <button type="button" class="charge_transition_screen_button" name="paymentAppraisalButtonOfAjax">
      <img loading="lazy" alt="続きを見る(有料)" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/charge_transition_screen_button.png" onmouseover="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/charge_transition_screen_button_over.png'" onmouseout="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/charge_transition_screen_button.png'">
    </button>
  </div>
</form>
<script>
  window.onload = () => {
    var processing = false;
    $('button[name=paymentAppraisalButtonOfAjax]').on('click', function() {
      if (processing) {
        return;
      }
      processing = true;
      var paymentSystemName = 'cocoloni';
      var form = $(this).parents("form");
      var itemcd = form.find('input:hidden[name=itemcd]').val()
      var channel = form.find('input:hidden[name=zp_channel_id]').val()
      var fullName = form.find("input:hidden[name='full_name']").val()
      var birthday = form.find('input:hidden[name=birthday]').val()
      var gender = form.find("input:hidden[name=gender]").val()
      var targetFullName = form.find("input:hidden[name='target_full_name']").val()
      var targetBirthday = form.find('input:hidden[name=target_birthday]').val()
      var targetGender = form.find('input:hidden[name=target_gender]').val()

      if (paymentSystemName == "minori") {
        var url = location.href;
        var env = url.match("dev") ? 'https://dev.rensa.jp.net' : 'https://rensa.jp.net';
        $.ajax({
          type: "POST",
          url: env + "https://honkaku-uranai.jp/cp_rsa/yumecakra_rsa/result/life001", //本番環境用
          //url: "http://localhost/maki/minori/result/life001",//テスト用
          data: {
            "isNomalPayment": true,
            "itemcd": itemcd,
            "howToBuy": "partlyAppraisalButton",
            "full_name": fullName,
            "birthday": birthday,
            "gender": gender,
            "target_full_name": targetFullName,
            "target_birthday": targetBirthday,
            "target_gender": targetGender,
            "TerminalModel": "pc"
          },
          dataType: "html"
        }).done(function(data) {
          console.log(data);
          var dom_parser = new DOMParser();
          var retensionResultDataId = dom_parser.parseFromString(data, "text/html").getElementById("retensionResultData").innerHTML
          $("[name=retensionResultDataId]").val(retensionResultDataId.split("__rid__")[1])
          form.attr("method", "post")
          form.attr("action", "https://zap-happyfortune.rensa.jp.net/cocoloni/yumecakra_rsa/result/").submit();
          processing = false;
        }).fail(function() {
          alert("通信に失敗しました");
          processing = false;
        });
      } else if (paymentSystemName == "cocoloni" || paymentSystemName == "cp_rsa") {
        let postUrl = "";
        let locationUri = location.hostname;
        switch (locationUri) {
            case "honkaku-uranai.jp":
                postUrl = "https://honkaku-uranai.jp/cp_rsa/yumecakra_rsa/result";
                break;
            case "test-honkaku.cocoloni.jp":
                postUrl = "https://test-honkaku.cocoloni.jp/cp_rsa/yumecakra_rsa/result";
                break;
            default:
                postUrl = "http://localhost/cocoloni/yumecakra_rsa/result/life001";
        };
        let time = form.find("input[name='time']").val();
        $.ajax({
          type: "POST",
          url: postUrl,
          data: {
            "ajaxParameter": true,
            "itemcd": itemcd,
            "zp_channel_id": channel,
            "time": time,
            "full_name": fullName,
            "birthday": birthday,
            "gender": gender,
            "target_full_name": targetFullName,
            "target_birthday": targetBirthday,
            "target_gender": targetGender,
            "TerminalModel": "pc",
            "howToBuy": "paymentAppraisalButton",
          }
        }).done(function(data) {
          var dataValue = JSON.parse(data)
          var zp_channel_id = dataValue.zp_channel_id
          var zp_sid = dataValue.zp_sid
          var zp_sig = dataValue.zp_sig
          processing = false;
          if (location.hostname.includes("test-honkaku.cocoloni.jp") !== false) {
            window.location.href = "https://test-honkaku.cocoloni.jp/portal/charge/?zp_cp_name=cp_rsa&zp_channel_id=" + zp_channel_id + "&zp_sid=" + zp_sid + "&zp_sig=" + zp_sig
          } else {
            window.location.href = "https://honkaku-uranai.jp/portal/charge/?zp_cp_name=cp_rsa&zp_channel_id=" + zp_channel_id + "&zp_sid=" + zp_sid + "&zp_sig=" + zp_sig
          }
        }).fail(function() {
          alert("通信に失敗しました");
          processing = false;
        });
      }
    })
  };
</script>          </div>
  </div>
</section>                      
<!-- caption start -->
<img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/result_subheading_top.jpg" style="width: 100%; vertical-align: bottom;">
<div class="result_subheading_background_center">
  <p>あなたが感じやすいストレスと、それに対する解消法</p>
</div>
<img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/result_subheading_bottom.jpg" style="width: 100%; vertical-align: top;">
<!-- caption end -->

<section id="normalSection">
  <div class="result_description_background_center">
          &emsp;あなたが感じやすいストレスは、やはり、自分のペースを乱されることでしょう。あさんは割とスピーディーなタイプです。でも、集団行動を強制される場面では、一番遅い子を待って次の段階へと進まなくてはならず……      <style>
  .charge_transition_screen_button {
    width: 308px;
    height: 104px;
    padding: 0;
    border: none;
    outline: none;
    cursor: pointer;
  }

  .charge_transition_screen_button img {
    width: 100%;
    height: 100%;
    border: none;
  }

  .mosaic_text_background {
    background: url("https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/result_mosaic_text.png") no-repeat;
    background-size: 115% 100%;
    background-position: center;
    width: 100%;
    height: 180px;
    text-align: center;
    padding-top: 10%;
  }

  .graph_charge_transition_screen_button {
    height: 125px;
    width: 375px;
    padding: 0;
    border: none;
    outline: none;
    cursor: pointer;
  }

  .graph_charge_transition_screen_button img {
    width: 100%;
  }
</style>

<form method="post" accept-charset="euc-jp" id="buyMoreProfileForm" action="https://zap-happyfortune.rensa.jp.net/cocoloni/yumecakra_rsa/result/"><div style="display:none;"><input type="hidden" name="_method" value="POST"/></div><input type="hidden" name="itemcd" value="life001"/><input type="hidden" name="howToBuy" value="paymentAppraisalButton"/><input type="hidden" name="TerminalModel" value="pc"/><input type="hidden" name="time" value=""/><input type="hidden" name="zp_channel_id" value="105_yc0004a"/><input type="hidden" name="contentKey" value="CYC"/><input type="hidden" name="full_name" value="あ"/><input type="hidden" name="birthday" value="1976-08-17"/><input type="hidden" name="gender" value="F"/>  <div class="mosaic_text_background">
    <button type="button" class="charge_transition_screen_button" name="paymentAppraisalButtonOfAjax">
      <img loading="lazy" alt="続きを見る(有料)" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/charge_transition_screen_button.png" onmouseover="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/charge_transition_screen_button_over.png'" onmouseout="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/charge_transition_screen_button.png'">
    </button>
  </div>
</form>
<script>
  window.onload = () => {
    var processing = false;
    $('button[name=paymentAppraisalButtonOfAjax]').on('click', function() {
      if (processing) {
        return;
      }
      processing = true;
      var paymentSystemName = 'cocoloni';
      var form = $(this).parents("form");
      var itemcd = form.find('input:hidden[name=itemcd]').val()
      var channel = form.find('input:hidden[name=zp_channel_id]').val()
      var fullName = form.find("input:hidden[name='full_name']").val()
      var birthday = form.find('input:hidden[name=birthday]').val()
      var gender = form.find("input:hidden[name=gender]").val()
      var targetFullName = form.find("input:hidden[name='target_full_name']").val()
      var targetBirthday = form.find('input:hidden[name=target_birthday]').val()
      var targetGender = form.find('input:hidden[name=target_gender]').val()

      if (paymentSystemName == "minori") {
        var url = location.href;
        var env = url.match("dev") ? 'https://dev.rensa.jp.net' : 'https://rensa.jp.net';
        $.ajax({
          type: "POST",
          url: env + "https://honkaku-uranai.jp/cp_rsa/yumecakra_rsa/result/life001", //本番環境用
          //url: "http://localhost/maki/minori/result/life001",//テスト用
          data: {
            "isNomalPayment": true,
            "itemcd": itemcd,
            "howToBuy": "partlyAppraisalButton",
            "full_name": fullName,
            "birthday": birthday,
            "gender": gender,
            "target_full_name": targetFullName,
            "target_birthday": targetBirthday,
            "target_gender": targetGender,
            "TerminalModel": "pc"
          },
          dataType: "html"
        }).done(function(data) {
          console.log(data);
          var dom_parser = new DOMParser();
          var retensionResultDataId = dom_parser.parseFromString(data, "text/html").getElementById("retensionResultData").innerHTML
          $("[name=retensionResultDataId]").val(retensionResultDataId.split("__rid__")[1])
          form.attr("method", "post")
          form.attr("action", "https://zap-happyfortune.rensa.jp.net/cocoloni/yumecakra_rsa/result/").submit();
          processing = false;
        }).fail(function() {
          alert("通信に失敗しました");
          processing = false;
        });
      } else if (paymentSystemName == "cocoloni" || paymentSystemName == "cp_rsa") {
        let postUrl = "";
        let locationUri = location.hostname;
        switch (locationUri) {
            case "honkaku-uranai.jp":
                postUrl = "https://honkaku-uranai.jp/cp_rsa/yumecakra_rsa/result";
                break;
            case "test-honkaku.cocoloni.jp":
                postUrl = "https://test-honkaku.cocoloni.jp/cp_rsa/yumecakra_rsa/result";
                break;
            default:
                postUrl = "http://localhost/cocoloni/yumecakra_rsa/result/life001";
        };
        let time = form.find("input[name='time']").val();
        $.ajax({
          type: "POST",
          url: postUrl,
          data: {
            "ajaxParameter": true,
            "itemcd": itemcd,
            "zp_channel_id": channel,
            "time": time,
            "full_name": fullName,
            "birthday": birthday,
            "gender": gender,
            "target_full_name": targetFullName,
            "target_birthday": targetBirthday,
            "target_gender": targetGender,
            "TerminalModel": "pc",
            "howToBuy": "paymentAppraisalButton",
          }
        }).done(function(data) {
          var dataValue = JSON.parse(data)
          var zp_channel_id = dataValue.zp_channel_id
          var zp_sid = dataValue.zp_sid
          var zp_sig = dataValue.zp_sig
          processing = false;
          if (location.hostname.includes("test-honkaku.cocoloni.jp") !== false) {
            window.location.href = "https://test-honkaku.cocoloni.jp/portal/charge/?zp_cp_name=cp_rsa&zp_channel_id=" + zp_channel_id + "&zp_sid=" + zp_sid + "&zp_sig=" + zp_sig
          } else {
            window.location.href = "https://honkaku-uranai.jp/portal/charge/?zp_cp_name=cp_rsa&zp_channel_id=" + zp_channel_id + "&zp_sid=" + zp_sid + "&zp_sig=" + zp_sig
          }
        }).fail(function() {
          alert("通信に失敗しました");
          processing = false;
        });
      }
    })
  };
</script>      </div>
</section>                      
<img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/top/line.png" style="width: 100%;">

<!--　特殊枠6（一問一答）　-->
<section id="one_to_one_question_section">
  <!-- 背景画像 -->
  <div class="beginning_text_background">
    <!-- 冒頭文 -->
    <div class="beginning_text_balloon">
      <p>今、あなたはどんな状況にいて、何を求められているのでしょうか。自分だけではなかなか導き出せない問題も、チャクラから読み取りズバリお答えします。</p>
    </div>
  </div>

  <!-- 見出し -->
  <img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/result_subheading_top.jpg" style="width: 100%; vertical-align: bottom;">
  <div class="result_subheading_background_center">
    <p>今のあなたが、日々の生活の中で力を注ぐべきものは何？</p>
  </div>
  <img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/result_subheading_bottom.jpg" style="width: 100%; vertical-align: top;">

  <!-- vue start -->
  <div id="one_to_one_question_10" class="one_to_one_question">
    <one-to-one-question
      result="[&quot;\u4e00\u554f\u4e00\u7b54&quot;,&quot;\u4eca\u3001\u3042\u306a\u305f\u306f\u3069\u3093\u306a\u72b6\u6cc1\u306b\u3044\u3066\u3001\u4f55\u3092\u6c42\u3081\u3089\u308c\u3066\u3044\u308b\u306e\u3067\u3057\u3087\u3046\u304b\u3002\u81ea\u5206\u3060\u3051\u3067\u306f\u306a\u304b\u306a\u304b\u5c0e\u304d\u51fa\u305b\u306a\u3044\u554f\u984c\u3082\u3001\u30c1\u30e3\u30af\u30e9\u304b\u3089\u8aad\u307f\u53d6\u308a\u30ba\u30d0\u30ea\u304a\u7b54\u3048\u3057\u307e\u3059\u3002&quot;,&quot;\u81ea\u5206\u306e\u8eab\u306e&lt;br&gt;\u56de\u308a\u306e\u7269\u4e8b\u3092&lt;br&gt;XXX\u308b\u6642\u671f&quot;,&quot;\u81ea\u5206\u306e\u8eab\u306e&lt;br&gt;\u56de\u308a\u306e\u7269\u4e8b\u3092&lt;br&gt;\u6574\u3048\u308b\u6642\u671f&quot;,&quot;&amp;emsp;\u4eca\u306e\u3042\u3055\u3093\u306f\u3001\u81ea\u5206\u306e\u8eab\u306e\u56de\u308a\u306e\u7269\u4e8b\u3092XXXXX\u3066\u3044\u304f\u6642\u671f\u3068\u3044\u3048\u307e\u3059\u3002XXX\u306eXXXX\u306a\u3069\u3092\u3057\u3066\u3001\u5feb\u9069\u306a\u52d5\u7dda\u3092&quot;,&quot;&amp;emsp;\u4eca\u306e\u3042\u3055\u3093\u306f\u3001\u81ea\u5206\u306e\u8eab\u306e\u56de\u308a\u306e\u7269\u4e8b\u3092\u4e01\u5be7\u306b\u6574\u3048\u3066\u3044\u304f\u6642\u671f\u3068\u3044\u3048\u307e\u3059\u3002\u90e8\u5c4b\u306e\u6a21\u69d8\u66ff\u3048\u306a\u3069\u3092\u3057\u3066\u3001\u5feb\u9069\u306a\u52d5\u7dda\u3092\u78ba\u4fdd\u3059\u308b\u3068\u4eba\u751f\u305d\u306e\u3082\u306e\u304c\u30b9\u30e0\u30fc\u30ba\u306b\u9032\u5c55\u3057\u3066\u3044\u304d\u307e\u3059\u3002\u305d\u306e\u3068\u304d\u306b\u3001\u904b\u6c17\u3092\u610f\u8b58\u3057\u305f\u5bb6\u5177\u306e\u914d\u7f6e\u3092\u5fc3\u639b\u3051\u3066\u307f\u308b\u3068\u3001\u4eca\u3088\u308a\u3082\u3082\u3063\u3068\u81ea\u5206\u3089\u3057\u3055\u3092\u767a\u63ee\u3067\u304d\u308b\u3088\u3046\u306a\u4eba\u751f\u306b\u5207\u308a\u66ff\u308f\u3063\u3066\u3044\u304d\u307e\u3059\u3002&lt;br&gt;&lt;br&gt;\u3000\u7279\u306b\u3001\u7720\u308b\u3068\u304d\u306e\u30d9\u30c3\u30c9\u306e\u4f4d\u7f6e\u3092\u91cd\u8996\u3057\u3066\u307f\u3066\u304f\u3060\u3055\u3044\u3002\u3042\u306a\u305f\u304c\u65e5\u3005\u3092\u523a\u6fc0\u306b\u6e80\u3061\u305f\u3082\u306e\u306b\u3057\u305f\u3044\u306e\u3067\u3042\u308c\u3070\u5357\u6795\u3067\u3001\u5fc3\u8eab\u3068\u3082\u306b\u6df1\u304f\u4f11\u307f\u305f\u3044\u3068\u3044\u3046\u306e\u3067\u3042\u308c\u3070\u5317\u6795\u3067\u7720\u308b\u3053\u3068\u3067\u9858\u3063\u305f\u3068\u304a\u308a\u306e\u4eba\u751f\u306e\u6ce2\u3092\u5f15\u304d\u5bc4\u305b\u307e\u3059\u3002&lt;br&gt;&lt;br&gt;\u3000\u307e\u305f\u3001\u8eab\u306b\u7740\u3051\u308b\u3082\u306e\u3084\u65e5\u7528\u54c1\u306b\u59a5\u5354\u3057\u306a\u3044\u3053\u3068\u306b\u3088\u308a\u3001\u5468\u56f2\u306e\u4eba\u9054\u304b\u3089\u3082\u304b\u306a\u308a\u5c0a\u91cd\u3055\u308c\u308b\u3088\u3046\u306b\u306a\u308b\u3067\u3057\u3087\u3046\u3002&quot;]"
      how-to-buy-flag="&quot;partlyAppraisalButton1&quot;"
      index-number="10"
    />
  </div>
  <!-- vue end -->

  <!-- 原稿 -->
  <div id="one_to_one_question_manuscript_10" class="manuscript_display_none">
    <div class="result_description_background_center">
              &emsp;今のあさんは、自分の身の回りの物事をXXXXXていく時期といえます。XXXのXXXXなどをして、快適な動線を……        <style>
  .charge_transition_screen_button {
    width: 308px;
    height: 104px;
    padding: 0;
    border: none;
    outline: none;
    cursor: pointer;
  }

  .charge_transition_screen_button img {
    width: 100%;
    height: 100%;
    border: none;
  }

  .mosaic_text_background {
    background: url("https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/result_mosaic_text.png") no-repeat;
    background-size: 115% 100%;
    background-position: center;
    width: 100%;
    height: 180px;
    text-align: center;
    padding-top: 10%;
  }

  .graph_charge_transition_screen_button {
    height: 125px;
    width: 375px;
    padding: 0;
    border: none;
    outline: none;
    cursor: pointer;
  }

  .graph_charge_transition_screen_button img {
    width: 100%;
  }
</style>

<form method="post" accept-charset="euc-jp" id="buyMoreProfileForm" action="https://zap-happyfortune.rensa.jp.net/cocoloni/yumecakra_rsa/result/"><div style="display:none;"><input type="hidden" name="_method" value="POST"/></div><input type="hidden" name="itemcd" value="life001"/><input type="hidden" name="howToBuy" value="paymentAppraisalButton"/><input type="hidden" name="TerminalModel" value="pc"/><input type="hidden" name="time" value=""/><input type="hidden" name="zp_channel_id" value="105_yc0004a"/><input type="hidden" name="contentKey" value="CYC"/><input type="hidden" name="full_name" value="あ"/><input type="hidden" name="birthday" value="1976-08-17"/><input type="hidden" name="gender" value="F"/>  <div class="mosaic_text_background">
    <button type="button" class="charge_transition_screen_button" name="paymentAppraisalButtonOfAjax">
      <img loading="lazy" alt="続きを見る(有料)" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/charge_transition_screen_button.png" onmouseover="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/charge_transition_screen_button_over.png'" onmouseout="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/charge_transition_screen_button.png'">
    </button>
  </div>
</form>
<script>
  window.onload = () => {
    var processing = false;
    $('button[name=paymentAppraisalButtonOfAjax]').on('click', function() {
      if (processing) {
        return;
      }
      processing = true;
      var paymentSystemName = 'cocoloni';
      var form = $(this).parents("form");
      var itemcd = form.find('input:hidden[name=itemcd]').val()
      var channel = form.find('input:hidden[name=zp_channel_id]').val()
      var fullName = form.find("input:hidden[name='full_name']").val()
      var birthday = form.find('input:hidden[name=birthday]').val()
      var gender = form.find("input:hidden[name=gender]").val()
      var targetFullName = form.find("input:hidden[name='target_full_name']").val()
      var targetBirthday = form.find('input:hidden[name=target_birthday]').val()
      var targetGender = form.find('input:hidden[name=target_gender]').val()

      if (paymentSystemName == "minori") {
        var url = location.href;
        var env = url.match("dev") ? 'https://dev.rensa.jp.net' : 'https://rensa.jp.net';
        $.ajax({
          type: "POST",
          url: env + "https://honkaku-uranai.jp/cp_rsa/yumecakra_rsa/result/life001", //本番環境用
          //url: "http://localhost/maki/minori/result/life001",//テスト用
          data: {
            "isNomalPayment": true,
            "itemcd": itemcd,
            "howToBuy": "partlyAppraisalButton",
            "full_name": fullName,
            "birthday": birthday,
            "gender": gender,
            "target_full_name": targetFullName,
            "target_birthday": targetBirthday,
            "target_gender": targetGender,
            "TerminalModel": "pc"
          },
          dataType: "html"
        }).done(function(data) {
          console.log(data);
          var dom_parser = new DOMParser();
          var retensionResultDataId = dom_parser.parseFromString(data, "text/html").getElementById("retensionResultData").innerHTML
          $("[name=retensionResultDataId]").val(retensionResultDataId.split("__rid__")[1])
          form.attr("method", "post")
          form.attr("action", "https://zap-happyfortune.rensa.jp.net/cocoloni/yumecakra_rsa/result/").submit();
          processing = false;
        }).fail(function() {
          alert("通信に失敗しました");
          processing = false;
        });
      } else if (paymentSystemName == "cocoloni" || paymentSystemName == "cp_rsa") {
        let postUrl = "";
        let locationUri = location.hostname;
        switch (locationUri) {
            case "honkaku-uranai.jp":
                postUrl = "https://honkaku-uranai.jp/cp_rsa/yumecakra_rsa/result";
                break;
            case "test-honkaku.cocoloni.jp":
                postUrl = "https://test-honkaku.cocoloni.jp/cp_rsa/yumecakra_rsa/result";
                break;
            default:
                postUrl = "http://localhost/cocoloni/yumecakra_rsa/result/life001";
        };
        let time = form.find("input[name='time']").val();
        $.ajax({
          type: "POST",
          url: postUrl,
          data: {
            "ajaxParameter": true,
            "itemcd": itemcd,
            "zp_channel_id": channel,
            "time": time,
            "full_name": fullName,
            "birthday": birthday,
            "gender": gender,
            "target_full_name": targetFullName,
            "target_birthday": targetBirthday,
            "target_gender": targetGender,
            "TerminalModel": "pc",
            "howToBuy": "paymentAppraisalButton",
          }
        }).done(function(data) {
          var dataValue = JSON.parse(data)
          var zp_channel_id = dataValue.zp_channel_id
          var zp_sid = dataValue.zp_sid
          var zp_sig = dataValue.zp_sig
          processing = false;
          if (location.hostname.includes("test-honkaku.cocoloni.jp") !== false) {
            window.location.href = "https://test-honkaku.cocoloni.jp/portal/charge/?zp_cp_name=cp_rsa&zp_channel_id=" + zp_channel_id + "&zp_sid=" + zp_sid + "&zp_sig=" + zp_sig
          } else {
            window.location.href = "https://honkaku-uranai.jp/portal/charge/?zp_cp_name=cp_rsa&zp_channel_id=" + zp_channel_id + "&zp_sid=" + zp_sid + "&zp_sig=" + zp_sig
          }
        }).fail(function() {
          alert("通信に失敗しました");
          processing = false;
        });
      }
    })
  };
</script>          </div>
  </div>
</section>                      
<!-- caption start -->
<img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/result_subheading_top.jpg" style="width: 100%; vertical-align: bottom;">
<div class="result_subheading_background_center">
  <p>あなたに気を付けてほしい生活習慣と健康について</p>
</div>
<img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/result_subheading_bottom.jpg" style="width: 100%; vertical-align: top;">
<!-- caption end -->

<section id="normalSection">
  <div class="result_description_background_center">
          &emsp;基本的に生命力にあふれているあさんですから、多少の無理もものともしません。調子に乗っているときに……      <style>
  .charge_transition_screen_button {
    width: 308px;
    height: 104px;
    padding: 0;
    border: none;
    outline: none;
    cursor: pointer;
  }

  .charge_transition_screen_button img {
    width: 100%;
    height: 100%;
    border: none;
  }

  .mosaic_text_background {
    background: url("https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/result_mosaic_text.png") no-repeat;
    background-size: 115% 100%;
    background-position: center;
    width: 100%;
    height: 180px;
    text-align: center;
    padding-top: 10%;
  }

  .graph_charge_transition_screen_button {
    height: 125px;
    width: 375px;
    padding: 0;
    border: none;
    outline: none;
    cursor: pointer;
  }

  .graph_charge_transition_screen_button img {
    width: 100%;
  }
</style>

<form method="post" accept-charset="euc-jp" id="buyMoreProfileForm" action="https://zap-happyfortune.rensa.jp.net/cocoloni/yumecakra_rsa/result/"><div style="display:none;"><input type="hidden" name="_method" value="POST"/></div><input type="hidden" name="itemcd" value="life001"/><input type="hidden" name="howToBuy" value="paymentAppraisalButton"/><input type="hidden" name="TerminalModel" value="pc"/><input type="hidden" name="time" value=""/><input type="hidden" name="zp_channel_id" value="105_yc0004a"/><input type="hidden" name="contentKey" value="CYC"/><input type="hidden" name="full_name" value="あ"/><input type="hidden" name="birthday" value="1976-08-17"/><input type="hidden" name="gender" value="F"/>  <div class="mosaic_text_background">
    <button type="button" class="charge_transition_screen_button" name="paymentAppraisalButtonOfAjax">
      <img loading="lazy" alt="続きを見る(有料)" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/charge_transition_screen_button.png" onmouseover="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/charge_transition_screen_button_over.png'" onmouseout="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/charge_transition_screen_button.png'">
    </button>
  </div>
</form>
<script>
  window.onload = () => {
    var processing = false;
    $('button[name=paymentAppraisalButtonOfAjax]').on('click', function() {
      if (processing) {
        return;
      }
      processing = true;
      var paymentSystemName = 'cocoloni';
      var form = $(this).parents("form");
      var itemcd = form.find('input:hidden[name=itemcd]').val()
      var channel = form.find('input:hidden[name=zp_channel_id]').val()
      var fullName = form.find("input:hidden[name='full_name']").val()
      var birthday = form.find('input:hidden[name=birthday]').val()
      var gender = form.find("input:hidden[name=gender]").val()
      var targetFullName = form.find("input:hidden[name='target_full_name']").val()
      var targetBirthday = form.find('input:hidden[name=target_birthday]').val()
      var targetGender = form.find('input:hidden[name=target_gender]').val()

      if (paymentSystemName == "minori") {
        var url = location.href;
        var env = url.match("dev") ? 'https://dev.rensa.jp.net' : 'https://rensa.jp.net';
        $.ajax({
          type: "POST",
          url: env + "https://honkaku-uranai.jp/cp_rsa/yumecakra_rsa/result/life001", //本番環境用
          //url: "http://localhost/maki/minori/result/life001",//テスト用
          data: {
            "isNomalPayment": true,
            "itemcd": itemcd,
            "howToBuy": "partlyAppraisalButton",
            "full_name": fullName,
            "birthday": birthday,
            "gender": gender,
            "target_full_name": targetFullName,
            "target_birthday": targetBirthday,
            "target_gender": targetGender,
            "TerminalModel": "pc"
          },
          dataType: "html"
        }).done(function(data) {
          console.log(data);
          var dom_parser = new DOMParser();
          var retensionResultDataId = dom_parser.parseFromString(data, "text/html").getElementById("retensionResultData").innerHTML
          $("[name=retensionResultDataId]").val(retensionResultDataId.split("__rid__")[1])
          form.attr("method", "post")
          form.attr("action", "https://zap-happyfortune.rensa.jp.net/cocoloni/yumecakra_rsa/result/").submit();
          processing = false;
        }).fail(function() {
          alert("通信に失敗しました");
          processing = false;
        });
      } else if (paymentSystemName == "cocoloni" || paymentSystemName == "cp_rsa") {
        let postUrl = "";
        let locationUri = location.hostname;
        switch (locationUri) {
            case "honkaku-uranai.jp":
                postUrl = "https://honkaku-uranai.jp/cp_rsa/yumecakra_rsa/result";
                break;
            case "test-honkaku.cocoloni.jp":
                postUrl = "https://test-honkaku.cocoloni.jp/cp_rsa/yumecakra_rsa/result";
                break;
            default:
                postUrl = "http://localhost/cocoloni/yumecakra_rsa/result/life001";
        };
        let time = form.find("input[name='time']").val();
        $.ajax({
          type: "POST",
          url: postUrl,
          data: {
            "ajaxParameter": true,
            "itemcd": itemcd,
            "zp_channel_id": channel,
            "time": time,
            "full_name": fullName,
            "birthday": birthday,
            "gender": gender,
            "target_full_name": targetFullName,
            "target_birthday": targetBirthday,
            "target_gender": targetGender,
            "TerminalModel": "pc",
            "howToBuy": "paymentAppraisalButton",
          }
        }).done(function(data) {
          var dataValue = JSON.parse(data)
          var zp_channel_id = dataValue.zp_channel_id
          var zp_sid = dataValue.zp_sid
          var zp_sig = dataValue.zp_sig
          processing = false;
          if (location.hostname.includes("test-honkaku.cocoloni.jp") !== false) {
            window.location.href = "https://test-honkaku.cocoloni.jp/portal/charge/?zp_cp_name=cp_rsa&zp_channel_id=" + zp_channel_id + "&zp_sid=" + zp_sid + "&zp_sig=" + zp_sig
          } else {
            window.location.href = "https://honkaku-uranai.jp/portal/charge/?zp_cp_name=cp_rsa&zp_channel_id=" + zp_channel_id + "&zp_sid=" + zp_sid + "&zp_sig=" + zp_sig
          }
        }).fail(function() {
          alert("通信に失敗しました");
          processing = false;
        });
      }
    })
  };
</script>      </div>
</section>                      

<!--　特殊枠4（チャクラ・ヴィジョン）　-->
<section id="chakra_vision_section">
      <!-- 看板画像 -->
    <img loading="lazy" alt='エネルギーの流れから視えた運命 チャクラ・ヴィジョン' src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/res_type_title4.png" style="width: 100%; vertical-align: bottom;">

    <!-- vue start -->
    <div id="chakra_vision_12" class="chakra_vision">
      <chakra-vision
        result="[&quot;\u7279\u6b8a\u67a04\uff08\u30f4\u30a3\u30b8\u30e7\u30f3\uff09&quot;,&quot;&lt;span class=\&quot;strong-text blue\&quot;&gt;XXXXXXX&lt;br&gt;XXXXXXX&lt;\/span&gt;&quot;,&quot;&lt;span class=\&quot;strong-text blue\&quot;&gt;\u4e0d\u601d\u8b70\u306a\u5b58\u5728\u611f&lt;br&gt;\u5c0a\u91cd\u3055\u308c\u308b&lt;\/span&gt;&quot;,&quot;\u3055\u3089\u306b\u3001\u3042\u306a\u305f\u306e\u30c1\u30e3\u30af\u30e9\u5168\u4f53\u304b\u3089\u611f\u3058\u3089\u308c\u308b\u30a4\u30e1\u30fc\u30b8\u3068\u30e1\u30c3\u30bb\u30fc\u30b8\u3092\u660e\u3089\u304b\u306b\u3057\u3066\u3044\u304d\u307e\u3059\u3002&quot;]"
        result-image="[&quot;https:\/\/img.rensa.jp.net\/web\/RYC\/motif\/visionA\/res_visionA_106.png||RYC29&quot;,&quot;https:\/\/img.rensa.jp.net\/web\/RYC\/motif\/visionA\/res_visionA_206.png||RYC29&quot;]"
        person="1"
        how-to-buy-flag="&quot;partlyAppraisalButton1&quot;"
        index-number="12"
        add-index-number="50"
      />
    </div>
    <!-- vue end -->

  </section>                      

<!--　特殊枠4（チャクラ・ヴィジョン）　-->
<section id="chakra_vision_section">
      <!-- 見出し -->
    <img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/result_subheading_top.jpg" style="width: 100%; vertical-align: bottom;">
    <div class="result_subheading_background_center">
      <p>あなたに与えられた仕事運と将来に得るもの</p>
    </div>
    <img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/result_subheading_bottom.jpg" style="width: 100%; vertical-align: top;">


      <!-- 結果アニメーション -->
      <!-- vue start -->
      <div id="chakra_vision_detail_13" class="chakra_vision_detail manuscript_display_none">
        <chakra-vision-detail
          result="[&quot;\u7279\u6b8a\u67a04\uff08\u8a73\u7d30\uff09&quot;,&quot;&lt;span class=\&quot;strong-text blue\&quot;&gt;\u300e\u5927\u6a39\u300f&lt;\/span&gt;\u304c\u8996\u3048\u307e\u3057\u305f\u3002\u3042\u306a\u305f\u304c\u5c06\u6765&lt;span class=\&quot;strong-text green\&quot;&gt;XXXXXXX&lt;\/span&gt;\u4eba\u7269\u3067\u3042\u308b\u3053\u3068\u3092\u793a\u3057\u3066\u3044\u307e\u3059\u3002&quot;,&quot;&lt;span class=\&quot;strong-text blue\&quot;&gt;\u300e\u5927\u6a39\u300f&lt;\/span&gt;\u304c\u8996\u3048\u307e\u3057\u305f\u3002\u3042\u306a\u305f\u304c\u5c06\u6765&lt;span class=\&quot;strong-text green\&quot;&gt;\u30a2\u30a4\u30c7\u30a3\u30a2\u3067\u6210\u529f\u3059\u308b&lt;\/span&gt;\u4eba\u7269\u3067\u3042\u308b\u3053\u3068\u3092\u793a\u3057\u3066\u3044\u307e\u3059\u3002&quot;,&quot;&amp;emsp;\u30d0\u30e9\u30f3\u30b9\u306e\u53d6\u308c\u305f\u4eba\u751f\u3092\u671b\u3080\u3042\u3055\u3093\u306b\u3068\u3063\u3066\u3001\u4ed5\u4e8b\u3068\u306f\u751f\u6d3b\u306e\u7ce7\u3092\u5f97\u308b\u624b\u6bb5\u3067\u3057\u3087\u3046\u3002\u3067\u3059\u304b\u3089\u3001\u306a\u308b\u3079\u304f\u8ca0\u62c5\u304c\u5c11\u306a\u3044\u4ed5\u4e8b\u3092&quot;,&quot;&amp;emsp;\u30d0\u30e9\u30f3\u30b9\u306e\u53d6\u308c\u305f\u4eba\u751f\u3092\u671b\u3080\u3042\u3055\u3093\u306b\u3068\u3063\u3066\u3001\u4ed5\u4e8b\u3068\u306f\u751f\u6d3b\u306e\u7ce7\u3092\u5f97\u308b\u624b\u6bb5\u3067\u3057\u3087\u3046\u3002\u3067\u3059\u304b\u3089\u3001\u306a\u308b\u3079\u304f\u8ca0\u62c5\u304c\u5c11\u306a\u3044\u4ed5\u4e8b\u3092\u9078\u3073\u3001\u305d\u308c\u3067\u3044\u3066\u5f85\u9047\u3082\u3044\u3044\u72b6\u614b\u3092\u5fc3\u304b\u3089\u671b\u3093\u3067\u3044\u307e\u3059\u3002\u305d\u308c\u304c\u591a\u304f\u306e\u4eba\u306b\u3068\u3063\u3066\u4e00\u756a\u306e\u671b\u307f\u3060\u3068\u3044\u3046\u306e\u304c\u672c\u97f3\u304b\u3082\u3057\u308c\u307e\u305b\u3093\u3002&lt;br&gt;&lt;br&gt;\u3000\u305f\u3060\u3001\u3042\u306a\u305f\u306f\u3068\u3066\u3082\u512a\u79c0\u3067\u982d\u304c\u3044\u3044\u306e\u3067\u3059\u304b\u3089\u3001\u305d\u306e&lt;span class=\&quot;strong-text green\&quot;&gt;\u77e5\u6027\u3092\u4e16\u306e\u4e2d\u306e\u305f\u3081\u306b&lt;\/span&gt;\u6d3b\u304b\u3059\u5fc5\u8981\u304c\u3042\u308a\u307e\u3059\u3002\u3060\u304b\u3089\u3068\u3044\u3063\u3066\u904e\u52b4\u6b7b\u3092\u3059\u308b\u3088\u3046\u306a\u50cd\u304d\u65b9\u3092\u9078\u3076\u5fc5\u8981\u306f\u3042\u308a\u307e\u305b\u3093\u304c\u3001\u540c\u50da\u3084\u30af\u30e9\u30a4\u30a2\u30f3\u30c8\u306b\u4f55\u304b\u3092\u76f8\u8ac7\u3055\u308c\u305f\u306a\u3089\u3070\u771f\u646f\u306b\u306a\u3063\u3066\u826f\u3044\u89e3\u6c7a\u7b56\u3092\u898b\u3064\u3051\u3066\u3042\u3052\u308b\u3053\u3068\u304c\u4f7f\u547d\u3067\u3057\u3087\u3046\u3002&lt;br&gt;&lt;br&gt;\u3000\u6cd5\u5f8b\u95a2\u4fc2\u3084\u7d4c\u55b6\u30b3\u30f3\u30b5\u30eb\u30bf\u30f3\u30c8\u306a\u3069\u304c\u3042\u306a\u305f\u306e\u80fd\u529b\u3092\u6d3b\u304b\u3057\u307e\u3059\u3002\u305f\u3086\u307e\u306c\u52aa\u529b\u3092\u6301\u3063\u3066\u6700\u65b0\u306e\u77e5\u8b58\u3092\u66f4\u65b0\u3057\u7d9a\u3051\u307e\u3057\u3087\u3046\u3002&quot;]"
          result-image="[&quot;https:\/\/img.rensa.jp.net\/web\/RYC\/motif\/type1\/res_type1_701.png||RYC31&quot;,&quot;https:\/\/img.rensa.jp.net\/web\/RYC\/motif\/visionA\/res_visionA_106.png||RYC31&quot;]"
          index-number="13"
          how-to-buy-flag="&quot;partlyAppraisalButton1&quot;"
          bool-result-image="true"
          mosaic-class="null"
        />
      </div>
      <!-- vue end -->

      <!-- 原稿 -->
      <div id="chakra_vision_detail_manuscript_13" class="manuscript_display_none">
        <div class="result_description_background_center">
                      &emsp;バランスの取れた人生を望むあさんにとって、仕事とは生活の糧を得る手段でしょう。ですから、なるべく負担が少ない仕事を……            <style>
  .charge_transition_screen_button {
    width: 308px;
    height: 104px;
    padding: 0;
    border: none;
    outline: none;
    cursor: pointer;
  }

  .charge_transition_screen_button img {
    width: 100%;
    height: 100%;
    border: none;
  }

  .mosaic_text_background {
    background: url("https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/result_mosaic_text.png") no-repeat;
    background-size: 115% 100%;
    background-position: center;
    width: 100%;
    height: 180px;
    text-align: center;
    padding-top: 10%;
  }

  .graph_charge_transition_screen_button {
    height: 125px;
    width: 375px;
    padding: 0;
    border: none;
    outline: none;
    cursor: pointer;
  }

  .graph_charge_transition_screen_button img {
    width: 100%;
  }
</style>

<form method="post" accept-charset="euc-jp" id="buyMoreProfileForm" action="https://zap-happyfortune.rensa.jp.net/cocoloni/yumecakra_rsa/result/"><div style="display:none;"><input type="hidden" name="_method" value="POST"/></div><input type="hidden" name="itemcd" value="life001"/><input type="hidden" name="howToBuy" value="paymentAppraisalButton"/><input type="hidden" name="TerminalModel" value="pc"/><input type="hidden" name="time" value=""/><input type="hidden" name="zp_channel_id" value="105_yc0004a"/><input type="hidden" name="contentKey" value="CYC"/><input type="hidden" name="full_name" value="あ"/><input type="hidden" name="birthday" value="1976-08-17"/><input type="hidden" name="gender" value="F"/>  <div class="mosaic_text_background">
    <button type="button" class="charge_transition_screen_button" name="paymentAppraisalButtonOfAjax">
      <img loading="lazy" alt="続きを見る(有料)" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/charge_transition_screen_button.png" onmouseover="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/charge_transition_screen_button_over.png'" onmouseout="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/charge_transition_screen_button.png'">
    </button>
  </div>
</form>
<script>
  window.onload = () => {
    var processing = false;
    $('button[name=paymentAppraisalButtonOfAjax]').on('click', function() {
      if (processing) {
        return;
      }
      processing = true;
      var paymentSystemName = 'cocoloni';
      var form = $(this).parents("form");
      var itemcd = form.find('input:hidden[name=itemcd]').val()
      var channel = form.find('input:hidden[name=zp_channel_id]').val()
      var fullName = form.find("input:hidden[name='full_name']").val()
      var birthday = form.find('input:hidden[name=birthday]').val()
      var gender = form.find("input:hidden[name=gender]").val()
      var targetFullName = form.find("input:hidden[name='target_full_name']").val()
      var targetBirthday = form.find('input:hidden[name=target_birthday]').val()
      var targetGender = form.find('input:hidden[name=target_gender]').val()

      if (paymentSystemName == "minori") {
        var url = location.href;
        var env = url.match("dev") ? 'https://dev.rensa.jp.net' : 'https://rensa.jp.net';
        $.ajax({
          type: "POST",
          url: env + "https://honkaku-uranai.jp/cp_rsa/yumecakra_rsa/result/life001", //本番環境用
          //url: "http://localhost/maki/minori/result/life001",//テスト用
          data: {
            "isNomalPayment": true,
            "itemcd": itemcd,
            "howToBuy": "partlyAppraisalButton",
            "full_name": fullName,
            "birthday": birthday,
            "gender": gender,
            "target_full_name": targetFullName,
            "target_birthday": targetBirthday,
            "target_gender": targetGender,
            "TerminalModel": "pc"
          },
          dataType: "html"
        }).done(function(data) {
          console.log(data);
          var dom_parser = new DOMParser();
          var retensionResultDataId = dom_parser.parseFromString(data, "text/html").getElementById("retensionResultData").innerHTML
          $("[name=retensionResultDataId]").val(retensionResultDataId.split("__rid__")[1])
          form.attr("method", "post")
          form.attr("action", "https://zap-happyfortune.rensa.jp.net/cocoloni/yumecakra_rsa/result/").submit();
          processing = false;
        }).fail(function() {
          alert("通信に失敗しました");
          processing = false;
        });
      } else if (paymentSystemName == "cocoloni" || paymentSystemName == "cp_rsa") {
        let postUrl = "";
        let locationUri = location.hostname;
        switch (locationUri) {
            case "honkaku-uranai.jp":
                postUrl = "https://honkaku-uranai.jp/cp_rsa/yumecakra_rsa/result";
                break;
            case "test-honkaku.cocoloni.jp":
                postUrl = "https://test-honkaku.cocoloni.jp/cp_rsa/yumecakra_rsa/result";
                break;
            default:
                postUrl = "http://localhost/cocoloni/yumecakra_rsa/result/life001";
        };
        let time = form.find("input[name='time']").val();
        $.ajax({
          type: "POST",
          url: postUrl,
          data: {
            "ajaxParameter": true,
            "itemcd": itemcd,
            "zp_channel_id": channel,
            "time": time,
            "full_name": fullName,
            "birthday": birthday,
            "gender": gender,
            "target_full_name": targetFullName,
            "target_birthday": targetBirthday,
            "target_gender": targetGender,
            "TerminalModel": "pc",
            "howToBuy": "paymentAppraisalButton",
          }
        }).done(function(data) {
          var dataValue = JSON.parse(data)
          var zp_channel_id = dataValue.zp_channel_id
          var zp_sid = dataValue.zp_sid
          var zp_sig = dataValue.zp_sig
          processing = false;
          if (location.hostname.includes("test-honkaku.cocoloni.jp") !== false) {
            window.location.href = "https://test-honkaku.cocoloni.jp/portal/charge/?zp_cp_name=cp_rsa&zp_channel_id=" + zp_channel_id + "&zp_sid=" + zp_sid + "&zp_sig=" + zp_sig
          } else {
            window.location.href = "https://honkaku-uranai.jp/portal/charge/?zp_cp_name=cp_rsa&zp_channel_id=" + zp_channel_id + "&zp_sid=" + zp_sid + "&zp_sig=" + zp_sig
          }
        }).fail(function() {
          alert("通信に失敗しました");
          processing = false;
        });
      }
    })
  };
</script>                  </div>
      </div>
  </section>                      

<!--　特殊枠4（チャクラ・ヴィジョン）　-->
<section id="chakra_vision_section">
      <!-- 見出し -->
    <img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/result_subheading_top.jpg" style="width: 100%; vertical-align: bottom;">
    <div class="result_subheading_background_center">
      <p>あなたを見ている周囲の人たちからの評価</p>
    </div>
    <img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/result_subheading_bottom.jpg" style="width: 100%; vertical-align: top;">


      <!-- 結果アニメーション -->
      <!-- vue start -->
      <div id="chakra_vision_detail_14" class="chakra_vision_detail manuscript_display_none">
        <chakra-vision-detail
          result="[&quot;\u7279\u6b8a\u67a04\uff08\u8a73\u7d30\uff09&quot;,&quot;&lt;span class=\&quot;strong-text blue\&quot;&gt;XXXXXXX&lt;br&gt;XXXXXXX&lt;\/span&gt;&quot;,&quot;&lt;span class=\&quot;strong-text blue\&quot;&gt;\u4e0d\u601d\u8b70\u306a\u5b58\u5728\u611f&lt;br&gt;\u5c0a\u91cd\u3055\u308c\u308b&lt;\/span&gt;&quot;,&quot;\u6b21\u306b\u3042\u306a\u305f\u306e\u30c1\u30e3\u30af\u30e9\u5168\u4f53\u304b\u3089&lt;span class=\&quot;strong-text blue\&quot;&gt;\u300eXXXXXXX\u300f&lt;\/span&gt;\u3068&lt;span class=\&quot;strong-text blue\&quot;&gt;\u300eXXXXXXX\u300f&lt;\/span&gt;\u3068\u3044\u3046\u8a00\u8449\u304c\u4f1d\u308f\u308a\u307e\u3057\u305f\u3002\u3053\u3053\u304b\u3089\u3042\u306a\u305f\u304c&lt;span class=\&quot;strong-text green\&quot;&gt;XXXXXX&lt;\/span&gt;\u3068\u5468\u56f2\u304b\u3089\u8a55\u4fa1\u3092\u53d7\u3051\u3066\u3044\u308b\u3053\u3068\u304c\u308f\u304b\u308a\u307e\u3057\u305f\u3002&quot;,&quot;&lt;span class=\&quot;strong-text blue\&quot;&gt;\u300e\u4e0d\u601d\u8b70\u306a\u5b58\u5728\u611f\u300f&lt;\/span&gt;\u3068&lt;span class=\&quot;strong-text blue\&quot;&gt;\u300e\u5c0a\u91cd\u3055\u308c\u308b\u300f&lt;\/span&gt;\u3068\u3044\u3046\u8a00\u8449\u304c\u4f1d\u308f\u308a\u307e\u3057\u305f\u3002\u3053\u3053\u304b\u3089\u3042\u306a\u305f\u304c&lt;span class=\&quot;strong-text green\&quot;&gt;\u6ce8\u76ee\u3092\u96c6\u3081\u308b\u4eba\u7269&lt;\/span&gt;\u3068\u5468\u56f2\u304b\u3089\u8a55\u4fa1\u3092\u53d7\u3051\u3066\u3044\u308b\u3053\u3068\u304c\u308f\u304b\u308a\u307e\u3057\u305f\u3002&quot;,&quot;&amp;emsp;\u3042\u306a\u305f\u306f\u3001\u3068\u3066\u3082\u5802\u3005\u3068\u3057\u3066\u3044\u307e\u3059\u3002\u305d\u306e\u614b\u5ea6\u306b\u76f8\u5fdc\u3057\u3044\u5b9f\u529b\u3092\u3082\u5099\u3048\u3066\u3044\u307e\u3059\u304b\u3089\u3001\u305f\u3044\u3057\u305f\u3082\u3093\u3060\u3068\u5468\u308a\u306e\u4eba\u9054\u3082\u3042\u306a\u305f\u306f\u3001\u3068\u3066\u3082\u5802\u3005\u3068\u3057\u3066\u3044\u307e\u3059\u3002\u305d\u306e\u614b\u5ea6\u306b\u76f8\u5fdc\u3057\u3044\u5b9f\u529b\u3092\u3082\u5099\u3048\u3066\u3044\u307e\u3059\u304b\u3089\u3001\u305f\u3044\u3057\u305f\u3082\u3093\u3060\u3068\u5468\u308a\u306e\u4eba\u9054\u3082\u601d\u3063\u3066\u3044\u308b\u3067\u3057\u3087\u3046\u3002\u3082\u3061\u308d\u3093\u8b19\u865a\u3067\u8170\u304c\u4f4e\u3044\u3042\u3055\u3093\u3067\u306f\u3042\u308a\u307e\u3059\u304c\u3001\u306a\u305c\u304b\u3042\u306a\u305f\u306b\u6ce8\u76ee\u304c\u96c6\u307e\u308b\u3068\u3044\u3046&quot;,&quot;&amp;emsp;\u3042\u306a\u305f\u306f\u3001\u3068\u3066\u3082\u5802\u3005\u3068\u3057\u3066\u3044\u307e\u3059\u3002\u305d\u306e\u614b\u5ea6\u306b\u76f8\u5fdc\u3057\u3044\u5b9f\u529b\u3092\u3082\u5099\u3048\u3066\u3044\u307e\u3059\u304b\u3089\u3001\u305f\u3044\u3057\u305f\u3082\u3093\u3060\u3068\u5468\u308a\u306e\u4eba\u9054\u3082\u3042\u306a\u305f\u306f\u3001\u3068\u3066\u3082\u5802\u3005\u3068\u3057\u3066\u3044\u307e\u3059\u3002\u305d\u306e\u614b\u5ea6\u306b\u76f8\u5fdc\u3057\u3044\u5b9f\u529b\u3092\u3082\u5099\u3048\u3066\u3044\u307e\u3059\u304b\u3089\u3001\u305f\u3044\u3057\u305f\u3082\u3093\u3060\u3068\u5468\u308a\u306e\u4eba\u9054\u3082\u601d\u3063\u3066\u3044\u308b\u3067\u3057\u3087\u3046\u3002\u3082\u3061\u308d\u3093\u8b19\u865a\u3067\u8170\u304c\u4f4e\u3044\u3042\u3055\u3093\u3067\u306f\u3042\u308a\u307e\u3059\u304c\u3001\u306a\u305c\u304b\u3042\u306a\u305f\u306b\u6ce8\u76ee\u304c\u96c6\u307e\u308b\u3068\u3044\u3046&lt;span class=\&quot;strong-text green\&quot;&gt;\u4e0d\u601d\u8b70\u306a\u5b58\u5728\u611f&lt;\/span&gt;\u3092\u6301\u3063\u3066\u3044\u308b\u306e\u3067\u3059\u3002&lt;br&gt;&lt;br&gt;\u3000\u3069\u3093\u306a\u306b\u4e0b\u306e\u7acb\u5834\u306b\u7f6e\u304b\u308c\u3066\u3044\u305f\u3068\u3057\u3066\u3082\u3001\u3042\u306a\u305f\u306f\u5468\u308a\u304b\u3089&lt;span class=\&quot;strong-text green\&quot;&gt;\u5c0a\u91cd\u3055\u308c\u308b&lt;\/span&gt;\u3053\u3068\u3068\u306a\u308a\u307e\u3059\u3002\u305d\u308c\u306f\u3001\u3042\u306a\u305f\u306e\u6301\u3064\u30aa\u30fc\u30e9\u304c\u3068\u3066\u3082\u5f37\u3044\u304b\u3089\u3067\u3057\u3087\u3046\u3002\u3069\u3046\u3057\u3066\u3042\u306a\u305f\u306e\u30aa\u30fc\u30e9\u304c\u305d\u3093\u306a\u306b\u5f37\u3044\u306e\u304b\u3068\u3044\u3048\u3070\u3001\u305d\u308c\u306f\u3001\u3042\u306a\u305f\u304c\u4e0d\u65ad\u306e\u52aa\u529b\u3092\u7a4d\u307f\u91cd\u306d\u3066\u3044\u308b\u304b\u3089\u3067\u3059\u3002&lt;br&gt;&lt;br&gt;\u3000\u305d\u306e\u304a\u304b\u3052\u3067\u3042\u306a\u305f\u306b\u306f\u6f20\u7136\u3068\u3057\u305f\u81ea\u4fe1\u304c\u3042\u308a\u3001\u305d\u308c\u304c\u5468\u56f2\u306b\u3082\u4f1d\u308f\u308a\u307e\u3059\u3002\u4eca\u5f8c\u3082\u52aa\u529b\u3092\u3057\u7d9a\u3051\u3066\u3001\u4eba\u9593\u95a2\u4fc2\u3067\u6709\u5229\u306a\u7acb\u5834\u3092\u5f97\u3066\u3044\u304d\u307e\u3057\u3087\u3046\u3002&quot;]"
          result-image="[&quot;https:\/\/img.rensa.jp.net\/web\/RYC\/motif\/type1\/res_type1_701.png||RYC33&quot;]"
          index-number="14"
          how-to-buy-flag="&quot;partlyAppraisalButton1&quot;"
          bool-result-image="false"
          mosaic-class="null"
        />
      </div>
      <!-- vue end -->

      <!-- 原稿 -->
      <div id="chakra_vision_detail_manuscript_14" class="manuscript_display_none">
        <div class="result_description_background_center">
                      &emsp;あなたは、とても堂々としています。その態度に相応しい実力をも備えていますから、たいしたもんだと周りの人達もあなたは、とても堂々としています。その態度に相応しい実力をも備えていますから、たいしたもんだと周りの人達も思っているでしょう。もちろん謙虚で腰が低いあさんではありますが、なぜかあなたに注目が集まるという……            <style>
  .charge_transition_screen_button {
    width: 308px;
    height: 104px;
    padding: 0;
    border: none;
    outline: none;
    cursor: pointer;
  }

  .charge_transition_screen_button img {
    width: 100%;
    height: 100%;
    border: none;
  }

  .mosaic_text_background {
    background: url("https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/result_mosaic_text.png") no-repeat;
    background-size: 115% 100%;
    background-position: center;
    width: 100%;
    height: 180px;
    text-align: center;
    padding-top: 10%;
  }

  .graph_charge_transition_screen_button {
    height: 125px;
    width: 375px;
    padding: 0;
    border: none;
    outline: none;
    cursor: pointer;
  }

  .graph_charge_transition_screen_button img {
    width: 100%;
  }
</style>

<form method="post" accept-charset="euc-jp" id="buyMoreProfileForm" action="https://zap-happyfortune.rensa.jp.net/cocoloni/yumecakra_rsa/result/"><div style="display:none;"><input type="hidden" name="_method" value="POST"/></div><input type="hidden" name="itemcd" value="life001"/><input type="hidden" name="howToBuy" value="paymentAppraisalButton"/><input type="hidden" name="TerminalModel" value="pc"/><input type="hidden" name="time" value=""/><input type="hidden" name="zp_channel_id" value="105_yc0004a"/><input type="hidden" name="contentKey" value="CYC"/><input type="hidden" name="full_name" value="あ"/><input type="hidden" name="birthday" value="1976-08-17"/><input type="hidden" name="gender" value="F"/>  <div class="mosaic_text_background">
    <button type="button" class="charge_transition_screen_button" name="paymentAppraisalButtonOfAjax">
      <img loading="lazy" alt="続きを見る(有料)" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/charge_transition_screen_button.png" onmouseover="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/charge_transition_screen_button_over.png'" onmouseout="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/charge_transition_screen_button.png'">
    </button>
  </div>
</form>
<script>
  window.onload = () => {
    var processing = false;
    $('button[name=paymentAppraisalButtonOfAjax]').on('click', function() {
      if (processing) {
        return;
      }
      processing = true;
      var paymentSystemName = 'cocoloni';
      var form = $(this).parents("form");
      var itemcd = form.find('input:hidden[name=itemcd]').val()
      var channel = form.find('input:hidden[name=zp_channel_id]').val()
      var fullName = form.find("input:hidden[name='full_name']").val()
      var birthday = form.find('input:hidden[name=birthday]').val()
      var gender = form.find("input:hidden[name=gender]").val()
      var targetFullName = form.find("input:hidden[name='target_full_name']").val()
      var targetBirthday = form.find('input:hidden[name=target_birthday]').val()
      var targetGender = form.find('input:hidden[name=target_gender]').val()

      if (paymentSystemName == "minori") {
        var url = location.href;
        var env = url.match("dev") ? 'https://dev.rensa.jp.net' : 'https://rensa.jp.net';
        $.ajax({
          type: "POST",
          url: env + "https://honkaku-uranai.jp/cp_rsa/yumecakra_rsa/result/life001", //本番環境用
          //url: "http://localhost/maki/minori/result/life001",//テスト用
          data: {
            "isNomalPayment": true,
            "itemcd": itemcd,
            "howToBuy": "partlyAppraisalButton",
            "full_name": fullName,
            "birthday": birthday,
            "gender": gender,
            "target_full_name": targetFullName,
            "target_birthday": targetBirthday,
            "target_gender": targetGender,
            "TerminalModel": "pc"
          },
          dataType: "html"
        }).done(function(data) {
          console.log(data);
          var dom_parser = new DOMParser();
          var retensionResultDataId = dom_parser.parseFromString(data, "text/html").getElementById("retensionResultData").innerHTML
          $("[name=retensionResultDataId]").val(retensionResultDataId.split("__rid__")[1])
          form.attr("method", "post")
          form.attr("action", "https://zap-happyfortune.rensa.jp.net/cocoloni/yumecakra_rsa/result/").submit();
          processing = false;
        }).fail(function() {
          alert("通信に失敗しました");
          processing = false;
        });
      } else if (paymentSystemName == "cocoloni" || paymentSystemName == "cp_rsa") {
        let postUrl = "";
        let locationUri = location.hostname;
        switch (locationUri) {
            case "honkaku-uranai.jp":
                postUrl = "https://honkaku-uranai.jp/cp_rsa/yumecakra_rsa/result";
                break;
            case "test-honkaku.cocoloni.jp":
                postUrl = "https://test-honkaku.cocoloni.jp/cp_rsa/yumecakra_rsa/result";
                break;
            default:
                postUrl = "http://localhost/cocoloni/yumecakra_rsa/result/life001";
        };
        let time = form.find("input[name='time']").val();
        $.ajax({
          type: "POST",
          url: postUrl,
          data: {
            "ajaxParameter": true,
            "itemcd": itemcd,
            "zp_channel_id": channel,
            "time": time,
            "full_name": fullName,
            "birthday": birthday,
            "gender": gender,
            "target_full_name": targetFullName,
            "target_birthday": targetBirthday,
            "target_gender": targetGender,
            "TerminalModel": "pc",
            "howToBuy": "paymentAppraisalButton",
          }
        }).done(function(data) {
          var dataValue = JSON.parse(data)
          var zp_channel_id = dataValue.zp_channel_id
          var zp_sid = dataValue.zp_sid
          var zp_sig = dataValue.zp_sig
          processing = false;
          if (location.hostname.includes("test-honkaku.cocoloni.jp") !== false) {
            window.location.href = "https://test-honkaku.cocoloni.jp/portal/charge/?zp_cp_name=cp_rsa&zp_channel_id=" + zp_channel_id + "&zp_sid=" + zp_sid + "&zp_sig=" + zp_sig
          } else {
            window.location.href = "https://honkaku-uranai.jp/portal/charge/?zp_cp_name=cp_rsa&zp_channel_id=" + zp_channel_id + "&zp_sid=" + zp_sid + "&zp_sig=" + zp_sig
          }
        }).fail(function() {
          alert("通信に失敗しました");
          processing = false;
        });
      }
    })
  };
</script>                  </div>
      </div>
  </section>                      

<!--　特殊枠4（チャクラ・ヴィジョン）　-->
<section id="chakra_vision_section">
      <!-- 見出し -->
    <img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/result_subheading_top.jpg" style="width: 100%; vertical-align: bottom;">
    <div class="result_subheading_background_center">
      <p>あなたに与えられた恋愛運命と引き寄せやすい縁</p>
    </div>
    <img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/result_subheading_bottom.jpg" style="width: 100%; vertical-align: top;">


      <!-- 結果アニメーション -->
      <!-- vue start -->
      <div id="chakra_vision_detail_15" class="chakra_vision_detail manuscript_display_none">
        <chakra-vision-detail
          result="[&quot;\u7279\u6b8a\u67a04\uff08\u8a73\u7d30\uff09&quot;,&quot;&lt;span class=\&quot;strong-text blue\&quot;&gt;\u300eXXX\u300f&lt;\/span&gt;\u304c\u8996\u3048\u307e\u3057\u305f\u3002\u3042\u306a\u305f\u306f&lt;span class=\&quot;strong-text green\&quot;&gt;XXXXXXX&lt;\/span&gt;\u3068\u306e\u7e01\u304c\u7d50\u3070\u308c\u3066\u3044\u307e\u3059\u3002&quot;,&quot;&lt;span class=\&quot;strong-text blue\&quot;&gt;\u300e\u5e02\u5834\u300f&lt;\/span&gt;\u304c\u8996\u3048\u307e\u3057\u305f\u3002\u3042\u306a\u305f\u306f&lt;span class=\&quot;strong-text green\&quot;&gt;\u80a9\u306e\u51dd\u3089\u306a\u3044\u4eba&lt;\/span&gt;\u3068\u306e\u7e01\u304c\u7d50\u3070\u308c\u3066\u3044\u307e\u3059\u3002&quot;,&quot;&amp;emsp;\u3042\u306a\u305f\u306b\u4e0e\u3048\u3089\u308c\u305f\u604b\u306e\u7279\u5fb4\u306f\u3001\u3068\u3066\u3082\u697d\u3057\u3044\u3068\u3044\u3046\u3053\u3068\u3002\u3068\u306b\u304b\u304f\u3042\u3055\u3093\u306f\u4eba\u751f\u3092\u601d\u3044\u304d\u308a\u697d\u3057\u307f\u305f\u3044\u3068\u3044\u3046\u30bf\u30a4\u30d7\u3067\u3059\u304b\u3089&quot;,&quot;&amp;emsp;\u3042\u306a\u305f\u306b\u4e0e\u3048\u3089\u308c\u305f\u604b\u306e\u7279\u5fb4\u306f\u3001\u3068\u3066\u3082\u697d\u3057\u3044\u3068\u3044\u3046\u3053\u3068\u3002\u3068\u306b\u304b\u304f\u3042\u3055\u3093\u306f\u4eba\u751f\u3092\u601d\u3044\u304d\u308a\u697d\u3057\u307f\u305f\u3044\u3068\u3044\u3046\u30bf\u30a4\u30d7\u3067\u3059\u304b\u3089\u3001\u604b\u611b\u611f\u60c5\u304c\u304b\u3089\u3082\u3046\u304c\u304b\u3089\u307e\u306a\u3044\u3060\u308d\u3046\u304c\u3001\u4e00\u7dd2\u306b\u3044\u3066\u5feb\u9069\u3067\u3001\u306a\u304a\u304b\u3064\u7b11\u3044\u304c\u305f\u3048\u306a\u3044\u3088\u3046\u306a\u7570\u6027\u3068\u306e\u95a2\u4fc2\u3092\u91cd\u8996\u3057\u3066\u3044\u308b\u3053\u3068\u3067\u3057\u3087\u3046\u3002&lt;br&gt;&lt;br&gt;\u3000\u305d\u3093\u306a\u3042\u306a\u305f\u306f\u3001&lt;span class=\&quot;strong-text green\&quot;&gt;\u80a9\u306e\u51dd\u3089\u306a\u3044\u4eba&lt;\/span&gt;\u3068\u7d50\u3070\u308c\u308b\u3053\u3068\u3068\u306a\u308a\u307e\u3059\u3002\u3044\u304f\u3089\u898b\u305f\u76ee\u304c\u826f\u304f\u3066\u3082\u3001\u30b9\u30da\u30c3\u30af\u304c\u9ad8\u304f\u3066\u5730\u4f4d\u304c\u3042\u308b\u4eba\u3067\u3082\u3001\u4e00\u7dd2\u306b\u3044\u3066\u7dca\u5f35\u3057\u305f\u308a\u3059\u308b\u3088\u3046\u3067\u306f\u3042\u306a\u305f\u306f\u604b\u3092\u3057\u307e\u305b\u3093\u3002\u305d\u308c\u3088\u308a\u3082\u3001\u6c17\u3055\u304f\u306b\u80a9\u3092\u53e9\u304d\u3042\u3044\u306a\u304c\u3089\u7b11\u3044\u3042\u3048\u308b\u3001\u6c17\u304c\u5408\u3046\u7570\u6027\u3092\u597d\u304d\u306b\u306a\u308b\u306e\u3067\u3059\u3002&lt;br&gt;&lt;br&gt;\u3000\u3067\u3059\u304b\u3089\u3001\u604b\u3092\u3057\u3066\u3082\u3042\u306a\u305f\u306e\u4eba\u751f\u306f\u5927\u5e45\u306b\u5909\u308f\u308b\u3053\u3068\u306f\u306a\u3044\u3067\u3057\u3087\u3046\u3002\u3042\u306a\u305f\u304c\u5e38\u306b\u3042\u306a\u305f\u3089\u3057\u304f\u751f\u304d\u3089\u308c\u308b\u3053\u3068\u3053\u305d\u304c\u5927\u5207\u306a\u306e\u3067\u3059\u3002&quot;]"
          result-image="[&quot;https:\/\/img.rensa.jp.net\/web\/RYC\/motif\/type1\/res_type1_701.png||RYC35&quot;,&quot;https:\/\/img.rensa.jp.net\/web\/RYC\/motif\/visionA\/res_visionA_206.png||RYC35&quot;]"
          index-number="15"
          how-to-buy-flag="&quot;partlyAppraisalButton1&quot;"
          bool-result-image="true"
          mosaic-class="&quot;mosaic&quot;"
        />
      </div>
      <!-- vue end -->

      <!-- 原稿 -->
      <div id="chakra_vision_detail_manuscript_15" class="manuscript_display_none">
        <div class="result_description_background_center">
                      &emsp;あなたに与えられた恋の特徴は、とても楽しいということ。とにかくあさんは人生を思いきり楽しみたいというタイプですから……            <style>
  .charge_transition_screen_button {
    width: 308px;
    height: 104px;
    padding: 0;
    border: none;
    outline: none;
    cursor: pointer;
  }

  .charge_transition_screen_button img {
    width: 100%;
    height: 100%;
    border: none;
  }

  .mosaic_text_background {
    background: url("https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/result_mosaic_text.png") no-repeat;
    background-size: 115% 100%;
    background-position: center;
    width: 100%;
    height: 180px;
    text-align: center;
    padding-top: 10%;
  }

  .graph_charge_transition_screen_button {
    height: 125px;
    width: 375px;
    padding: 0;
    border: none;
    outline: none;
    cursor: pointer;
  }

  .graph_charge_transition_screen_button img {
    width: 100%;
  }
</style>

<form method="post" accept-charset="euc-jp" id="buyMoreProfileForm" action="https://zap-happyfortune.rensa.jp.net/cocoloni/yumecakra_rsa/result/"><div style="display:none;"><input type="hidden" name="_method" value="POST"/></div><input type="hidden" name="itemcd" value="life001"/><input type="hidden" name="howToBuy" value="paymentAppraisalButton"/><input type="hidden" name="TerminalModel" value="pc"/><input type="hidden" name="time" value=""/><input type="hidden" name="zp_channel_id" value="105_yc0004a"/><input type="hidden" name="contentKey" value="CYC"/><input type="hidden" name="full_name" value="あ"/><input type="hidden" name="birthday" value="1976-08-17"/><input type="hidden" name="gender" value="F"/>  <div class="mosaic_text_background">
    <button type="button" class="charge_transition_screen_button" name="paymentAppraisalButtonOfAjax">
      <img loading="lazy" alt="続きを見る(有料)" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/charge_transition_screen_button.png" onmouseover="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/charge_transition_screen_button_over.png'" onmouseout="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/charge_transition_screen_button.png'">
    </button>
  </div>
</form>
<script>
  window.onload = () => {
    var processing = false;
    $('button[name=paymentAppraisalButtonOfAjax]').on('click', function() {
      if (processing) {
        return;
      }
      processing = true;
      var paymentSystemName = 'cocoloni';
      var form = $(this).parents("form");
      var itemcd = form.find('input:hidden[name=itemcd]').val()
      var channel = form.find('input:hidden[name=zp_channel_id]').val()
      var fullName = form.find("input:hidden[name='full_name']").val()
      var birthday = form.find('input:hidden[name=birthday]').val()
      var gender = form.find("input:hidden[name=gender]").val()
      var targetFullName = form.find("input:hidden[name='target_full_name']").val()
      var targetBirthday = form.find('input:hidden[name=target_birthday]').val()
      var targetGender = form.find('input:hidden[name=target_gender]').val()

      if (paymentSystemName == "minori") {
        var url = location.href;
        var env = url.match("dev") ? 'https://dev.rensa.jp.net' : 'https://rensa.jp.net';
        $.ajax({
          type: "POST",
          url: env + "https://honkaku-uranai.jp/cp_rsa/yumecakra_rsa/result/life001", //本番環境用
          //url: "http://localhost/maki/minori/result/life001",//テスト用
          data: {
            "isNomalPayment": true,
            "itemcd": itemcd,
            "howToBuy": "partlyAppraisalButton",
            "full_name": fullName,
            "birthday": birthday,
            "gender": gender,
            "target_full_name": targetFullName,
            "target_birthday": targetBirthday,
            "target_gender": targetGender,
            "TerminalModel": "pc"
          },
          dataType: "html"
        }).done(function(data) {
          console.log(data);
          var dom_parser = new DOMParser();
          var retensionResultDataId = dom_parser.parseFromString(data, "text/html").getElementById("retensionResultData").innerHTML
          $("[name=retensionResultDataId]").val(retensionResultDataId.split("__rid__")[1])
          form.attr("method", "post")
          form.attr("action", "https://zap-happyfortune.rensa.jp.net/cocoloni/yumecakra_rsa/result/").submit();
          processing = false;
        }).fail(function() {
          alert("通信に失敗しました");
          processing = false;
        });
      } else if (paymentSystemName == "cocoloni" || paymentSystemName == "cp_rsa") {
        let postUrl = "";
        let locationUri = location.hostname;
        switch (locationUri) {
            case "honkaku-uranai.jp":
                postUrl = "https://honkaku-uranai.jp/cp_rsa/yumecakra_rsa/result";
                break;
            case "test-honkaku.cocoloni.jp":
                postUrl = "https://test-honkaku.cocoloni.jp/cp_rsa/yumecakra_rsa/result";
                break;
            default:
                postUrl = "http://localhost/cocoloni/yumecakra_rsa/result/life001";
        };
        let time = form.find("input[name='time']").val();
        $.ajax({
          type: "POST",
          url: postUrl,
          data: {
            "ajaxParameter": true,
            "itemcd": itemcd,
            "zp_channel_id": channel,
            "time": time,
            "full_name": fullName,
            "birthday": birthday,
            "gender": gender,
            "target_full_name": targetFullName,
            "target_birthday": targetBirthday,
            "target_gender": targetGender,
            "TerminalModel": "pc",
            "howToBuy": "paymentAppraisalButton",
          }
        }).done(function(data) {
          var dataValue = JSON.parse(data)
          var zp_channel_id = dataValue.zp_channel_id
          var zp_sid = dataValue.zp_sid
          var zp_sig = dataValue.zp_sig
          processing = false;
          if (location.hostname.includes("test-honkaku.cocoloni.jp") !== false) {
            window.location.href = "https://test-honkaku.cocoloni.jp/portal/charge/?zp_cp_name=cp_rsa&zp_channel_id=" + zp_channel_id + "&zp_sid=" + zp_sid + "&zp_sig=" + zp_sig
          } else {
            window.location.href = "https://honkaku-uranai.jp/portal/charge/?zp_cp_name=cp_rsa&zp_channel_id=" + zp_channel_id + "&zp_sid=" + zp_sid + "&zp_sig=" + zp_sig
          }
        }).fail(function() {
          alert("通信に失敗しました");
          processing = false;
        });
      }
    })
  };
</script>                  </div>
      </div>
  </section>                      
<!-- caption start -->
<img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/result_subheading_top.jpg" style="width: 100%; vertical-align: bottom;">
<div class="result_subheading_background_center">
  <p>この先、あなたを良き方へ導いてくれる重要人物</p>
</div>
<img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/result_subheading_bottom.jpg" style="width: 100%; vertical-align: top;">
<!-- caption end -->

<section id="normalSection">
  <div class="result_description_background_center">
                <style>
  .charge_transition_screen_button {
    width: 308px;
    height: 104px;
    padding: 0;
    border: none;
    outline: none;
    cursor: pointer;
  }

  .charge_transition_screen_button img {
    width: 100%;
    height: 100%;
    border: none;
  }

  .mosaic_text_background {
    background: url("https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/result_mosaic_text.png") no-repeat;
    background-size: 115% 100%;
    background-position: center;
    width: 100%;
    height: 180px;
    text-align: center;
    padding-top: 10%;
  }

  .graph_charge_transition_screen_button {
    height: 125px;
    width: 375px;
    padding: 0;
    border: none;
    outline: none;
    cursor: pointer;
  }

  .graph_charge_transition_screen_button img {
    width: 100%;
  }
</style>

<form method="post" accept-charset="euc-jp" id="buyMoreProfileForm" action="https://zap-happyfortune.rensa.jp.net/cocoloni/yumecakra_rsa/result/"><div style="display:none;"><input type="hidden" name="_method" value="POST"/></div><input type="hidden" name="itemcd" value="life001"/><input type="hidden" name="howToBuy" value="paymentAppraisalButton"/><input type="hidden" name="TerminalModel" value="pc"/><input type="hidden" name="time" value=""/><input type="hidden" name="zp_channel_id" value="105_yc0004a"/><input type="hidden" name="contentKey" value="CYC"/><input type="hidden" name="full_name" value="あ"/><input type="hidden" name="birthday" value="1976-08-17"/><input type="hidden" name="gender" value="F"/>  <div class="mosaic_text_background">
    <button type="button" class="charge_transition_screen_button" name="paymentAppraisalButtonOfAjax">
      <img loading="lazy" alt="続きを見る(有料)" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/charge_transition_screen_button.png" onmouseover="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/charge_transition_screen_button_over.png'" onmouseout="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/charge_transition_screen_button.png'">
    </button>
  </div>
</form>
<script>
  window.onload = () => {
    var processing = false;
    $('button[name=paymentAppraisalButtonOfAjax]').on('click', function() {
      if (processing) {
        return;
      }
      processing = true;
      var paymentSystemName = 'cocoloni';
      var form = $(this).parents("form");
      var itemcd = form.find('input:hidden[name=itemcd]').val()
      var channel = form.find('input:hidden[name=zp_channel_id]').val()
      var fullName = form.find("input:hidden[name='full_name']").val()
      var birthday = form.find('input:hidden[name=birthday]').val()
      var gender = form.find("input:hidden[name=gender]").val()
      var targetFullName = form.find("input:hidden[name='target_full_name']").val()
      var targetBirthday = form.find('input:hidden[name=target_birthday]').val()
      var targetGender = form.find('input:hidden[name=target_gender]').val()

      if (paymentSystemName == "minori") {
        var url = location.href;
        var env = url.match("dev") ? 'https://dev.rensa.jp.net' : 'https://rensa.jp.net';
        $.ajax({
          type: "POST",
          url: env + "https://honkaku-uranai.jp/cp_rsa/yumecakra_rsa/result/life001", //本番環境用
          //url: "http://localhost/maki/minori/result/life001",//テスト用
          data: {
            "isNomalPayment": true,
            "itemcd": itemcd,
            "howToBuy": "partlyAppraisalButton",
            "full_name": fullName,
            "birthday": birthday,
            "gender": gender,
            "target_full_name": targetFullName,
            "target_birthday": targetBirthday,
            "target_gender": targetGender,
            "TerminalModel": "pc"
          },
          dataType: "html"
        }).done(function(data) {
          console.log(data);
          var dom_parser = new DOMParser();
          var retensionResultDataId = dom_parser.parseFromString(data, "text/html").getElementById("retensionResultData").innerHTML
          $("[name=retensionResultDataId]").val(retensionResultDataId.split("__rid__")[1])
          form.attr("method", "post")
          form.attr("action", "https://zap-happyfortune.rensa.jp.net/cocoloni/yumecakra_rsa/result/").submit();
          processing = false;
        }).fail(function() {
          alert("通信に失敗しました");
          processing = false;
        });
      } else if (paymentSystemName == "cocoloni" || paymentSystemName == "cp_rsa") {
        let postUrl = "";
        let locationUri = location.hostname;
        switch (locationUri) {
            case "honkaku-uranai.jp":
                postUrl = "https://honkaku-uranai.jp/cp_rsa/yumecakra_rsa/result";
                break;
            case "test-honkaku.cocoloni.jp":
                postUrl = "https://test-honkaku.cocoloni.jp/cp_rsa/yumecakra_rsa/result";
                break;
            default:
                postUrl = "http://localhost/cocoloni/yumecakra_rsa/result/life001";
        };
        let time = form.find("input[name='time']").val();
        $.ajax({
          type: "POST",
          url: postUrl,
          data: {
            "ajaxParameter": true,
            "itemcd": itemcd,
            "zp_channel_id": channel,
            "time": time,
            "full_name": fullName,
            "birthday": birthday,
            "gender": gender,
            "target_full_name": targetFullName,
            "target_birthday": targetBirthday,
            "target_gender": targetGender,
            "TerminalModel": "pc",
            "howToBuy": "paymentAppraisalButton",
          }
        }).done(function(data) {
          var dataValue = JSON.parse(data)
          var zp_channel_id = dataValue.zp_channel_id
          var zp_sid = dataValue.zp_sid
          var zp_sig = dataValue.zp_sig
          processing = false;
          if (location.hostname.includes("test-honkaku.cocoloni.jp") !== false) {
            window.location.href = "https://test-honkaku.cocoloni.jp/portal/charge/?zp_cp_name=cp_rsa&zp_channel_id=" + zp_channel_id + "&zp_sid=" + zp_sid + "&zp_sig=" + zp_sig
          } else {
            window.location.href = "https://honkaku-uranai.jp/portal/charge/?zp_cp_name=cp_rsa&zp_channel_id=" + zp_channel_id + "&zp_sid=" + zp_sid + "&zp_sig=" + zp_sig
          }
        }).fail(function() {
          alert("通信に失敗しました");
          processing = false;
        });
      }
    })
  };
</script>      </div>
</section>                      
<!-- caption start -->
<img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/result_subheading_top.jpg" style="width: 100%; vertical-align: bottom;">
<div class="result_subheading_background_center">
  <p>あなたをトラブルに巻き込んでしまう要注意人物</p>
</div>
<img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/result_subheading_bottom.jpg" style="width: 100%; vertical-align: top;">
<!-- caption end -->

<section id="normalSection">
  <div class="result_description_background_center">
                <style>
  .charge_transition_screen_button {
    width: 308px;
    height: 104px;
    padding: 0;
    border: none;
    outline: none;
    cursor: pointer;
  }

  .charge_transition_screen_button img {
    width: 100%;
    height: 100%;
    border: none;
  }

  .mosaic_text_background {
    background: url("https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/result_mosaic_text.png") no-repeat;
    background-size: 115% 100%;
    background-position: center;
    width: 100%;
    height: 180px;
    text-align: center;
    padding-top: 10%;
  }

  .graph_charge_transition_screen_button {
    height: 125px;
    width: 375px;
    padding: 0;
    border: none;
    outline: none;
    cursor: pointer;
  }

  .graph_charge_transition_screen_button img {
    width: 100%;
  }
</style>

<form method="post" accept-charset="euc-jp" id="buyMoreProfileForm" action="https://zap-happyfortune.rensa.jp.net/cocoloni/yumecakra_rsa/result/"><div style="display:none;"><input type="hidden" name="_method" value="POST"/></div><input type="hidden" name="itemcd" value="life001"/><input type="hidden" name="howToBuy" value="paymentAppraisalButton"/><input type="hidden" name="TerminalModel" value="pc"/><input type="hidden" name="time" value=""/><input type="hidden" name="zp_channel_id" value="105_yc0004a"/><input type="hidden" name="contentKey" value="CYC"/><input type="hidden" name="full_name" value="あ"/><input type="hidden" name="birthday" value="1976-08-17"/><input type="hidden" name="gender" value="F"/>  <div class="mosaic_text_background">
    <button type="button" class="charge_transition_screen_button" name="paymentAppraisalButtonOfAjax">
      <img loading="lazy" alt="続きを見る(有料)" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/charge_transition_screen_button.png" onmouseover="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/charge_transition_screen_button_over.png'" onmouseout="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/charge_transition_screen_button.png'">
    </button>
  </div>
</form>
<script>
  window.onload = () => {
    var processing = false;
    $('button[name=paymentAppraisalButtonOfAjax]').on('click', function() {
      if (processing) {
        return;
      }
      processing = true;
      var paymentSystemName = 'cocoloni';
      var form = $(this).parents("form");
      var itemcd = form.find('input:hidden[name=itemcd]').val()
      var channel = form.find('input:hidden[name=zp_channel_id]').val()
      var fullName = form.find("input:hidden[name='full_name']").val()
      var birthday = form.find('input:hidden[name=birthday]').val()
      var gender = form.find("input:hidden[name=gender]").val()
      var targetFullName = form.find("input:hidden[name='target_full_name']").val()
      var targetBirthday = form.find('input:hidden[name=target_birthday]').val()
      var targetGender = form.find('input:hidden[name=target_gender]').val()

      if (paymentSystemName == "minori") {
        var url = location.href;
        var env = url.match("dev") ? 'https://dev.rensa.jp.net' : 'https://rensa.jp.net';
        $.ajax({
          type: "POST",
          url: env + "https://honkaku-uranai.jp/cp_rsa/yumecakra_rsa/result/life001", //本番環境用
          //url: "http://localhost/maki/minori/result/life001",//テスト用
          data: {
            "isNomalPayment": true,
            "itemcd": itemcd,
            "howToBuy": "partlyAppraisalButton",
            "full_name": fullName,
            "birthday": birthday,
            "gender": gender,
            "target_full_name": targetFullName,
            "target_birthday": targetBirthday,
            "target_gender": targetGender,
            "TerminalModel": "pc"
          },
          dataType: "html"
        }).done(function(data) {
          console.log(data);
          var dom_parser = new DOMParser();
          var retensionResultDataId = dom_parser.parseFromString(data, "text/html").getElementById("retensionResultData").innerHTML
          $("[name=retensionResultDataId]").val(retensionResultDataId.split("__rid__")[1])
          form.attr("method", "post")
          form.attr("action", "https://zap-happyfortune.rensa.jp.net/cocoloni/yumecakra_rsa/result/").submit();
          processing = false;
        }).fail(function() {
          alert("通信に失敗しました");
          processing = false;
        });
      } else if (paymentSystemName == "cocoloni" || paymentSystemName == "cp_rsa") {
        let postUrl = "";
        let locationUri = location.hostname;
        switch (locationUri) {
            case "honkaku-uranai.jp":
                postUrl = "https://honkaku-uranai.jp/cp_rsa/yumecakra_rsa/result";
                break;
            case "test-honkaku.cocoloni.jp":
                postUrl = "https://test-honkaku.cocoloni.jp/cp_rsa/yumecakra_rsa/result";
                break;
            default:
                postUrl = "http://localhost/cocoloni/yumecakra_rsa/result/life001";
        };
        let time = form.find("input[name='time']").val();
        $.ajax({
          type: "POST",
          url: postUrl,
          data: {
            "ajaxParameter": true,
            "itemcd": itemcd,
            "zp_channel_id": channel,
            "time": time,
            "full_name": fullName,
            "birthday": birthday,
            "gender": gender,
            "target_full_name": targetFullName,
            "target_birthday": targetBirthday,
            "target_gender": targetGender,
            "TerminalModel": "pc",
            "howToBuy": "paymentAppraisalButton",
          }
        }).done(function(data) {
          var dataValue = JSON.parse(data)
          var zp_channel_id = dataValue.zp_channel_id
          var zp_sid = dataValue.zp_sid
          var zp_sig = dataValue.zp_sig
          processing = false;
          if (location.hostname.includes("test-honkaku.cocoloni.jp") !== false) {
            window.location.href = "https://test-honkaku.cocoloni.jp/portal/charge/?zp_cp_name=cp_rsa&zp_channel_id=" + zp_channel_id + "&zp_sid=" + zp_sid + "&zp_sig=" + zp_sig
          } else {
            window.location.href = "https://honkaku-uranai.jp/portal/charge/?zp_cp_name=cp_rsa&zp_channel_id=" + zp_channel_id + "&zp_sid=" + zp_sid + "&zp_sig=" + zp_sig
          }
        }).fail(function() {
          alert("通信に失敗しました");
          processing = false;
        });
      }
    })
  };
</script>      </div>
</section>                      
<!-- caption start -->
<img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/result_subheading_top.jpg" style="width: 100%; vertical-align: bottom;">
<div class="result_subheading_background_center">
  <p>今、あなたの愛に訪れようとしている運命</p>
</div>
<img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/result_subheading_bottom.jpg" style="width: 100%; vertical-align: top;">
<!-- caption end -->

<section id="normalSection">
  <div class="result_description_background_center">
                <style>
  .charge_transition_screen_button {
    width: 308px;
    height: 104px;
    padding: 0;
    border: none;
    outline: none;
    cursor: pointer;
  }

  .charge_transition_screen_button img {
    width: 100%;
    height: 100%;
    border: none;
  }

  .mosaic_text_background {
    background: url("https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/result_mosaic_text.png") no-repeat;
    background-size: 115% 100%;
    background-position: center;
    width: 100%;
    height: 180px;
    text-align: center;
    padding-top: 10%;
  }

  .graph_charge_transition_screen_button {
    height: 125px;
    width: 375px;
    padding: 0;
    border: none;
    outline: none;
    cursor: pointer;
  }

  .graph_charge_transition_screen_button img {
    width: 100%;
  }
</style>

<form method="post" accept-charset="euc-jp" id="buyMoreProfileForm" action="https://zap-happyfortune.rensa.jp.net/cocoloni/yumecakra_rsa/result/"><div style="display:none;"><input type="hidden" name="_method" value="POST"/></div><input type="hidden" name="itemcd" value="life001"/><input type="hidden" name="howToBuy" value="paymentAppraisalButton"/><input type="hidden" name="TerminalModel" value="pc"/><input type="hidden" name="time" value=""/><input type="hidden" name="zp_channel_id" value="105_yc0004a"/><input type="hidden" name="contentKey" value="CYC"/><input type="hidden" name="full_name" value="あ"/><input type="hidden" name="birthday" value="1976-08-17"/><input type="hidden" name="gender" value="F"/>  <div class="mosaic_text_background">
    <button type="button" class="charge_transition_screen_button" name="paymentAppraisalButtonOfAjax">
      <img loading="lazy" alt="続きを見る(有料)" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/charge_transition_screen_button.png" onmouseover="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/charge_transition_screen_button_over.png'" onmouseout="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/charge_transition_screen_button.png'">
    </button>
  </div>
</form>
<script>
  window.onload = () => {
    var processing = false;
    $('button[name=paymentAppraisalButtonOfAjax]').on('click', function() {
      if (processing) {
        return;
      }
      processing = true;
      var paymentSystemName = 'cocoloni';
      var form = $(this).parents("form");
      var itemcd = form.find('input:hidden[name=itemcd]').val()
      var channel = form.find('input:hidden[name=zp_channel_id]').val()
      var fullName = form.find("input:hidden[name='full_name']").val()
      var birthday = form.find('input:hidden[name=birthday]').val()
      var gender = form.find("input:hidden[name=gender]").val()
      var targetFullName = form.find("input:hidden[name='target_full_name']").val()
      var targetBirthday = form.find('input:hidden[name=target_birthday]').val()
      var targetGender = form.find('input:hidden[name=target_gender]').val()

      if (paymentSystemName == "minori") {
        var url = location.href;
        var env = url.match("dev") ? 'https://dev.rensa.jp.net' : 'https://rensa.jp.net';
        $.ajax({
          type: "POST",
          url: env + "https://honkaku-uranai.jp/cp_rsa/yumecakra_rsa/result/life001", //本番環境用
          //url: "http://localhost/maki/minori/result/life001",//テスト用
          data: {
            "isNomalPayment": true,
            "itemcd": itemcd,
            "howToBuy": "partlyAppraisalButton",
            "full_name": fullName,
            "birthday": birthday,
            "gender": gender,
            "target_full_name": targetFullName,
            "target_birthday": targetBirthday,
            "target_gender": targetGender,
            "TerminalModel": "pc"
          },
          dataType: "html"
        }).done(function(data) {
          console.log(data);
          var dom_parser = new DOMParser();
          var retensionResultDataId = dom_parser.parseFromString(data, "text/html").getElementById("retensionResultData").innerHTML
          $("[name=retensionResultDataId]").val(retensionResultDataId.split("__rid__")[1])
          form.attr("method", "post")
          form.attr("action", "https://zap-happyfortune.rensa.jp.net/cocoloni/yumecakra_rsa/result/").submit();
          processing = false;
        }).fail(function() {
          alert("通信に失敗しました");
          processing = false;
        });
      } else if (paymentSystemName == "cocoloni" || paymentSystemName == "cp_rsa") {
        let postUrl = "";
        let locationUri = location.hostname;
        switch (locationUri) {
            case "honkaku-uranai.jp":
                postUrl = "https://honkaku-uranai.jp/cp_rsa/yumecakra_rsa/result";
                break;
            case "test-honkaku.cocoloni.jp":
                postUrl = "https://test-honkaku.cocoloni.jp/cp_rsa/yumecakra_rsa/result";
                break;
            default:
                postUrl = "http://localhost/cocoloni/yumecakra_rsa/result/life001";
        };
        let time = form.find("input[name='time']").val();
        $.ajax({
          type: "POST",
          url: postUrl,
          data: {
            "ajaxParameter": true,
            "itemcd": itemcd,
            "zp_channel_id": channel,
            "time": time,
            "full_name": fullName,
            "birthday": birthday,
            "gender": gender,
            "target_full_name": targetFullName,
            "target_birthday": targetBirthday,
            "target_gender": targetGender,
            "TerminalModel": "pc",
            "howToBuy": "paymentAppraisalButton",
          }
        }).done(function(data) {
          var dataValue = JSON.parse(data)
          var zp_channel_id = dataValue.zp_channel_id
          var zp_sid = dataValue.zp_sid
          var zp_sig = dataValue.zp_sig
          processing = false;
          if (location.hostname.includes("test-honkaku.cocoloni.jp") !== false) {
            window.location.href = "https://test-honkaku.cocoloni.jp/portal/charge/?zp_cp_name=cp_rsa&zp_channel_id=" + zp_channel_id + "&zp_sid=" + zp_sid + "&zp_sig=" + zp_sig
          } else {
            window.location.href = "https://honkaku-uranai.jp/portal/charge/?zp_cp_name=cp_rsa&zp_channel_id=" + zp_channel_id + "&zp_sid=" + zp_sid + "&zp_sig=" + zp_sig
          }
        }).fail(function() {
          alert("通信に失敗しました");
          processing = false;
        });
      }
    })
  };
</script>      </div>
</section>                      
<img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/top/line.png" style="width: 100%;">

<!--　特殊枠7（YESNO）　-->
<section id="yes_no_section">
  <!-- 背景画像 -->
  <div class="beginning_text_background">
    <!-- 冒頭文 -->
    <div class="beginning_text_balloon">
      <p>あなたのチャクラから読み取った、“この先”を左右する問題や気になる点について「YES」か「NO」その2つでハッキリとお答えいたします。</p>
    </div>
  </div>

  <!-- 見出し -->
  <img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/result_subheading_top.jpg" style="width: 100%; vertical-align: bottom;">
  <div class="result_subheading_background_center">
    <p>その運命は、あなたの愛に大きな影響を与えることになる？</p>
  </div>
  <img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/result_subheading_bottom.jpg" style="width: 100%; vertical-align: top;">

  <!-- vue start -->
  <div id="yes_no_19" class="yes_no">
    <yes-no
      result="[&quot;YESNO&quot;,&quot;\u3042\u306a\u305f\u306e\u30c1\u30e3\u30af\u30e9\u304b\u3089\u8aad\u307f\u53d6\u3063\u305f\u3001\u201c\u3053\u306e\u5148\u201d\u3092\u5de6\u53f3\u3059\u308b\u554f\u984c\u3084\u6c17\u306b\u306a\u308b\u70b9\u306b\u3064\u3044\u3066\u300cYES\u300d\u304b\u300cNO\u300d\u305d\u306e2\u3064\u3067\u30cf\u30c3\u30ad\u30ea\u3068\u304a\u7b54\u3048\u3044\u305f\u3057\u307e\u3059\u3002&quot;,&quot;\u30c1\u30e3\u30af\u30e9\u304b\u3089&lt;br&gt;\u8996\u3048\u305f\u7b54\u3048\u306f&lt;br&gt;XXX\u3067\u3059&quot;,&quot;\u30c1\u30e3\u30af\u30e9\u304b\u3089&lt;br&gt;\u8996\u3048\u305f\u7b54\u3048\u306f&lt;br&gt;YES\u3067\u3059&quot;,&quot;&amp;emsp;\u304a\u4e92\u3044\u306b\u826f\u3044\u5f71\u97ff\u3092\u4e0e\u3048\u3042\u3048\u308b\u904b\u547d\u306e\u611b\u306b\u3088\u3063\u3066\u3001\u3042\u3055\u3093\u3082\u305d\u306e\u304a\u76f8\u624b\u3082\u3001\u3042\u308b\u7a2e\u306e\u30b7\u30e7\u30c3\u30af\u7642\u6cd5\u3092\u53d7\u3051\u308b\u3053\u3068\u3068\u306a\u308a\u307e\u3059\u3002\u306f\u3058\u3081\u306f&quot;,&quot;&amp;emsp;\u304a\u4e92\u3044\u306b\u826f\u3044\u5f71\u97ff\u3092\u4e0e\u3048\u3042\u3048\u308b\u904b\u547d\u306e\u611b\u306b\u3088\u3063\u3066\u3001\u3042\u3055\u3093\u3082\u305d\u306e\u304a\u76f8\u624b\u3082\u3001\u3042\u308b\u7a2e\u306e\u30b7\u30e7\u30c3\u30af\u7642\u6cd5\u3092\u53d7\u3051\u308b\u3053\u3068\u3068\u306a\u308a\u307e\u3059\u3002\u306f\u3058\u3081\u306f\u304a\u4e92\u3044\u306e\u9055\u3044\u306b\u3088\u3063\u3066\u5f37\u70c8\u306b\u60f9\u304b\u308c\u3042\u3044\u306a\u304c\u3089\u3082\u3001\u3068\u304d\u306b\u306f\u6fc0\u3057\u304f\u3076\u3064\u304b\u308b\u3053\u3068\u3082\u3042\u308b\u3067\u3057\u3087\u3046\u3002&lt;br&gt;&lt;br&gt;\u3000\u3067\u3082\u3001\u304a\u4e92\u3044\u304c\u76f8\u624b\u304b\u3089\u9003\u3052\u308b\u3053\u3068\u306a\u304f\u771f\u646f\u306b\u5411\u304d\u5408\u3044\u3001\u5fc5\u6b7b\u306b\u76f8\u624b\u3092\u7406\u89e3\u3057\u3088\u3046\u3068\u3059\u308b\u3053\u3068\u306b\u3088\u308a\u30012\u4eba\u306e\u7d46\u306f\u3068\u3066\u3082\u5f37\u304f\u306a\u3063\u3066\u3044\u304f\u306e\u3067\u3059\u3002\u77e5\u308c\u3070\u77e5\u308b\u307b\u3069\u306b\u3001\u304a\u4e92\u3044\u304c\u76f8\u624b\u306e\u6df1\u307f\u3042\u308b\u4eba\u683c\u306b\u60f9\u304b\u308c\u3066\u3044\u304f\u3067\u3057\u3087\u3046\u3002&lt;br&gt;&lt;br&gt;\u3000\u305d\u3057\u3066\u3001\u304a\u4e92\u3044\u304c\u76f8\u624b\u306e\u6b20\u70b9\u3092\u88dc\u3044\u5408\u3048\u308b\u7d20\u6674\u3089\u3057\u3044\u76f8\u6027\u3067\u3042\u308b\u3053\u3068\u3092\u81ea\u899a\u3057\u307e\u3059\u304b\u3089\u3001\u6700\u7d42\u7684\u306b\u306f\u7d50\u5a5a\u3092\u6c7a\u610f\u3059\u308b\u3053\u3068\u3067\u3057\u3087\u3046\u3002\u4eba\u751f\u306e\u30d1\u30fc\u30c8\u30ca\u30fc\u3068\u3057\u3066\u3053\u308c\u4ee5\u4e0a\u76f8\u5fdc\u3057\u3044\u4eba\u306f\u4ed6\u306b\u306f\u3044\u306a\u3044\u3068\u3044\u3046\u3053\u3068\u3092\u3001\u3042\u306a\u305f\u3082\u305d\u306e\u4eba\u3082\u78ba\u4fe1\u3059\u308b\u306e\u3067\u3059\u3002&quot;]"
      how-to-buy-flag="&quot;partlyAppraisalButton1&quot;"
      index-number="19"
    />
  </div>
  <!-- vue end -->

  <!-- 原稿 -->
  <div id="yes_no_manuscript_19" class="manuscript_display_none">
    <div class="result_description_background_center">
              &emsp;お互いに良い影響を与えあえる運命の愛によって、あさんもそのお相手も、ある種のショック療法を受けることとなります。はじめは……        <style>
  .charge_transition_screen_button {
    width: 308px;
    height: 104px;
    padding: 0;
    border: none;
    outline: none;
    cursor: pointer;
  }

  .charge_transition_screen_button img {
    width: 100%;
    height: 100%;
    border: none;
  }

  .mosaic_text_background {
    background: url("https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/result_mosaic_text.png") no-repeat;
    background-size: 115% 100%;
    background-position: center;
    width: 100%;
    height: 180px;
    text-align: center;
    padding-top: 10%;
  }

  .graph_charge_transition_screen_button {
    height: 125px;
    width: 375px;
    padding: 0;
    border: none;
    outline: none;
    cursor: pointer;
  }

  .graph_charge_transition_screen_button img {
    width: 100%;
  }
</style>

<form method="post" accept-charset="euc-jp" id="buyMoreProfileForm" action="https://zap-happyfortune.rensa.jp.net/cocoloni/yumecakra_rsa/result/"><div style="display:none;"><input type="hidden" name="_method" value="POST"/></div><input type="hidden" name="itemcd" value="life001"/><input type="hidden" name="howToBuy" value="paymentAppraisalButton"/><input type="hidden" name="TerminalModel" value="pc"/><input type="hidden" name="time" value=""/><input type="hidden" name="zp_channel_id" value="105_yc0004a"/><input type="hidden" name="contentKey" value="CYC"/><input type="hidden" name="full_name" value="あ"/><input type="hidden" name="birthday" value="1976-08-17"/><input type="hidden" name="gender" value="F"/>  <div class="mosaic_text_background">
    <button type="button" class="charge_transition_screen_button" name="paymentAppraisalButtonOfAjax">
      <img loading="lazy" alt="続きを見る(有料)" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/charge_transition_screen_button.png" onmouseover="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/charge_transition_screen_button_over.png'" onmouseout="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/charge_transition_screen_button.png'">
    </button>
  </div>
</form>
<script>
  window.onload = () => {
    var processing = false;
    $('button[name=paymentAppraisalButtonOfAjax]').on('click', function() {
      if (processing) {
        return;
      }
      processing = true;
      var paymentSystemName = 'cocoloni';
      var form = $(this).parents("form");
      var itemcd = form.find('input:hidden[name=itemcd]').val()
      var channel = form.find('input:hidden[name=zp_channel_id]').val()
      var fullName = form.find("input:hidden[name='full_name']").val()
      var birthday = form.find('input:hidden[name=birthday]').val()
      var gender = form.find("input:hidden[name=gender]").val()
      var targetFullName = form.find("input:hidden[name='target_full_name']").val()
      var targetBirthday = form.find('input:hidden[name=target_birthday]').val()
      var targetGender = form.find('input:hidden[name=target_gender]').val()

      if (paymentSystemName == "minori") {
        var url = location.href;
        var env = url.match("dev") ? 'https://dev.rensa.jp.net' : 'https://rensa.jp.net';
        $.ajax({
          type: "POST",
          url: env + "https://honkaku-uranai.jp/cp_rsa/yumecakra_rsa/result/life001", //本番環境用
          //url: "http://localhost/maki/minori/result/life001",//テスト用
          data: {
            "isNomalPayment": true,
            "itemcd": itemcd,
            "howToBuy": "partlyAppraisalButton",
            "full_name": fullName,
            "birthday": birthday,
            "gender": gender,
            "target_full_name": targetFullName,
            "target_birthday": targetBirthday,
            "target_gender": targetGender,
            "TerminalModel": "pc"
          },
          dataType: "html"
        }).done(function(data) {
          console.log(data);
          var dom_parser = new DOMParser();
          var retensionResultDataId = dom_parser.parseFromString(data, "text/html").getElementById("retensionResultData").innerHTML
          $("[name=retensionResultDataId]").val(retensionResultDataId.split("__rid__")[1])
          form.attr("method", "post")
          form.attr("action", "https://zap-happyfortune.rensa.jp.net/cocoloni/yumecakra_rsa/result/").submit();
          processing = false;
        }).fail(function() {
          alert("通信に失敗しました");
          processing = false;
        });
      } else if (paymentSystemName == "cocoloni" || paymentSystemName == "cp_rsa") {
        let postUrl = "";
        let locationUri = location.hostname;
        switch (locationUri) {
            case "honkaku-uranai.jp":
                postUrl = "https://honkaku-uranai.jp/cp_rsa/yumecakra_rsa/result";
                break;
            case "test-honkaku.cocoloni.jp":
                postUrl = "https://test-honkaku.cocoloni.jp/cp_rsa/yumecakra_rsa/result";
                break;
            default:
                postUrl = "http://localhost/cocoloni/yumecakra_rsa/result/life001";
        };
        let time = form.find("input[name='time']").val();
        $.ajax({
          type: "POST",
          url: postUrl,
          data: {
            "ajaxParameter": true,
            "itemcd": itemcd,
            "zp_channel_id": channel,
            "time": time,
            "full_name": fullName,
            "birthday": birthday,
            "gender": gender,
            "target_full_name": targetFullName,
            "target_birthday": targetBirthday,
            "target_gender": targetGender,
            "TerminalModel": "pc",
            "howToBuy": "paymentAppraisalButton",
          }
        }).done(function(data) {
          var dataValue = JSON.parse(data)
          var zp_channel_id = dataValue.zp_channel_id
          var zp_sid = dataValue.zp_sid
          var zp_sig = dataValue.zp_sig
          processing = false;
          if (location.hostname.includes("test-honkaku.cocoloni.jp") !== false) {
            window.location.href = "https://test-honkaku.cocoloni.jp/portal/charge/?zp_cp_name=cp_rsa&zp_channel_id=" + zp_channel_id + "&zp_sid=" + zp_sid + "&zp_sig=" + zp_sig
          } else {
            window.location.href = "https://honkaku-uranai.jp/portal/charge/?zp_cp_name=cp_rsa&zp_channel_id=" + zp_channel_id + "&zp_sid=" + zp_sid + "&zp_sig=" + zp_sig
          }
        }).fail(function() {
          alert("通信に失敗しました");
          processing = false;
        });
      }
    })
  };
</script>          </div>
  </div>
</section>                      
<!-- caption start -->
<img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/result_subheading_top.jpg" style="width: 100%; vertical-align: bottom;">
<div class="result_subheading_background_center">
  <p>あなたの人生を彩る愛を、さらに呼び込むために心がけてほしいこと</p>
</div>
<img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/result_subheading_bottom.jpg" style="width: 100%; vertical-align: top;">
<!-- caption end -->

<section id="normalSection">
  <div class="result_description_background_center">
                <style>
  .charge_transition_screen_button {
    width: 308px;
    height: 104px;
    padding: 0;
    border: none;
    outline: none;
    cursor: pointer;
  }

  .charge_transition_screen_button img {
    width: 100%;
    height: 100%;
    border: none;
  }

  .mosaic_text_background {
    background: url("https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/result_mosaic_text.png") no-repeat;
    background-size: 115% 100%;
    background-position: center;
    width: 100%;
    height: 180px;
    text-align: center;
    padding-top: 10%;
  }

  .graph_charge_transition_screen_button {
    height: 125px;
    width: 375px;
    padding: 0;
    border: none;
    outline: none;
    cursor: pointer;
  }

  .graph_charge_transition_screen_button img {
    width: 100%;
  }
</style>

<form method="post" accept-charset="euc-jp" id="buyMoreProfileForm" action="https://zap-happyfortune.rensa.jp.net/cocoloni/yumecakra_rsa/result/"><div style="display:none;"><input type="hidden" name="_method" value="POST"/></div><input type="hidden" name="itemcd" value="life001"/><input type="hidden" name="howToBuy" value="paymentAppraisalButton"/><input type="hidden" name="TerminalModel" value="pc"/><input type="hidden" name="time" value=""/><input type="hidden" name="zp_channel_id" value="105_yc0004a"/><input type="hidden" name="contentKey" value="CYC"/><input type="hidden" name="full_name" value="あ"/><input type="hidden" name="birthday" value="1976-08-17"/><input type="hidden" name="gender" value="F"/>  <div class="mosaic_text_background">
    <button type="button" class="charge_transition_screen_button" name="paymentAppraisalButtonOfAjax">
      <img loading="lazy" alt="続きを見る(有料)" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/charge_transition_screen_button.png" onmouseover="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/charge_transition_screen_button_over.png'" onmouseout="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/charge_transition_screen_button.png'">
    </button>
  </div>
</form>
<script>
  window.onload = () => {
    var processing = false;
    $('button[name=paymentAppraisalButtonOfAjax]').on('click', function() {
      if (processing) {
        return;
      }
      processing = true;
      var paymentSystemName = 'cocoloni';
      var form = $(this).parents("form");
      var itemcd = form.find('input:hidden[name=itemcd]').val()
      var channel = form.find('input:hidden[name=zp_channel_id]').val()
      var fullName = form.find("input:hidden[name='full_name']").val()
      var birthday = form.find('input:hidden[name=birthday]').val()
      var gender = form.find("input:hidden[name=gender]").val()
      var targetFullName = form.find("input:hidden[name='target_full_name']").val()
      var targetBirthday = form.find('input:hidden[name=target_birthday]').val()
      var targetGender = form.find('input:hidden[name=target_gender]').val()

      if (paymentSystemName == "minori") {
        var url = location.href;
        var env = url.match("dev") ? 'https://dev.rensa.jp.net' : 'https://rensa.jp.net';
        $.ajax({
          type: "POST",
          url: env + "https://honkaku-uranai.jp/cp_rsa/yumecakra_rsa/result/life001", //本番環境用
          //url: "http://localhost/maki/minori/result/life001",//テスト用
          data: {
            "isNomalPayment": true,
            "itemcd": itemcd,
            "howToBuy": "partlyAppraisalButton",
            "full_name": fullName,
            "birthday": birthday,
            "gender": gender,
            "target_full_name": targetFullName,
            "target_birthday": targetBirthday,
            "target_gender": targetGender,
            "TerminalModel": "pc"
          },
          dataType: "html"
        }).done(function(data) {
          console.log(data);
          var dom_parser = new DOMParser();
          var retensionResultDataId = dom_parser.parseFromString(data, "text/html").getElementById("retensionResultData").innerHTML
          $("[name=retensionResultDataId]").val(retensionResultDataId.split("__rid__")[1])
          form.attr("method", "post")
          form.attr("action", "https://zap-happyfortune.rensa.jp.net/cocoloni/yumecakra_rsa/result/").submit();
          processing = false;
        }).fail(function() {
          alert("通信に失敗しました");
          processing = false;
        });
      } else if (paymentSystemName == "cocoloni" || paymentSystemName == "cp_rsa") {
        let postUrl = "";
        let locationUri = location.hostname;
        switch (locationUri) {
            case "honkaku-uranai.jp":
                postUrl = "https://honkaku-uranai.jp/cp_rsa/yumecakra_rsa/result";
                break;
            case "test-honkaku.cocoloni.jp":
                postUrl = "https://test-honkaku.cocoloni.jp/cp_rsa/yumecakra_rsa/result";
                break;
            default:
                postUrl = "http://localhost/cocoloni/yumecakra_rsa/result/life001";
        };
        let time = form.find("input[name='time']").val();
        $.ajax({
          type: "POST",
          url: postUrl,
          data: {
            "ajaxParameter": true,
            "itemcd": itemcd,
            "zp_channel_id": channel,
            "time": time,
            "full_name": fullName,
            "birthday": birthday,
            "gender": gender,
            "target_full_name": targetFullName,
            "target_birthday": targetBirthday,
            "target_gender": targetGender,
            "TerminalModel": "pc",
            "howToBuy": "paymentAppraisalButton",
          }
        }).done(function(data) {
          var dataValue = JSON.parse(data)
          var zp_channel_id = dataValue.zp_channel_id
          var zp_sid = dataValue.zp_sid
          var zp_sig = dataValue.zp_sig
          processing = false;
          if (location.hostname.includes("test-honkaku.cocoloni.jp") !== false) {
            window.location.href = "https://test-honkaku.cocoloni.jp/portal/charge/?zp_cp_name=cp_rsa&zp_channel_id=" + zp_channel_id + "&zp_sid=" + zp_sid + "&zp_sig=" + zp_sig
          } else {
            window.location.href = "https://honkaku-uranai.jp/portal/charge/?zp_cp_name=cp_rsa&zp_channel_id=" + zp_channel_id + "&zp_sid=" + zp_sid + "&zp_sig=" + zp_sig
          }
        }).fail(function() {
          alert("通信に失敗しました");
          processing = false;
        });
      }
    })
  };
</script>      </div>
</section>                      
<!-- caption start -->
<img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/result_subheading_top.jpg" style="width: 100%; vertical-align: bottom;">
<div class="result_subheading_background_center">
  <p>あなたに与えられている金運と財運</p>
</div>
<img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/result_subheading_bottom.jpg" style="width: 100%; vertical-align: top;">
<!-- caption end -->

<section id="normalSection">
  <div class="result_description_background_center">
                <style>
  .charge_transition_screen_button {
    width: 308px;
    height: 104px;
    padding: 0;
    border: none;
    outline: none;
    cursor: pointer;
  }

  .charge_transition_screen_button img {
    width: 100%;
    height: 100%;
    border: none;
  }

  .mosaic_text_background {
    background: url("https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/result_mosaic_text.png") no-repeat;
    background-size: 115% 100%;
    background-position: center;
    width: 100%;
    height: 180px;
    text-align: center;
    padding-top: 10%;
  }

  .graph_charge_transition_screen_button {
    height: 125px;
    width: 375px;
    padding: 0;
    border: none;
    outline: none;
    cursor: pointer;
  }

  .graph_charge_transition_screen_button img {
    width: 100%;
  }
</style>

<form method="post" accept-charset="euc-jp" id="buyMoreProfileForm" action="https://zap-happyfortune.rensa.jp.net/cocoloni/yumecakra_rsa/result/"><div style="display:none;"><input type="hidden" name="_method" value="POST"/></div><input type="hidden" name="itemcd" value="life001"/><input type="hidden" name="howToBuy" value="paymentAppraisalButton"/><input type="hidden" name="TerminalModel" value="pc"/><input type="hidden" name="time" value=""/><input type="hidden" name="zp_channel_id" value="105_yc0004a"/><input type="hidden" name="contentKey" value="CYC"/><input type="hidden" name="full_name" value="あ"/><input type="hidden" name="birthday" value="1976-08-17"/><input type="hidden" name="gender" value="F"/>  <div class="mosaic_text_background">
    <button type="button" class="charge_transition_screen_button" name="paymentAppraisalButtonOfAjax">
      <img loading="lazy" alt="続きを見る(有料)" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/charge_transition_screen_button.png" onmouseover="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/charge_transition_screen_button_over.png'" onmouseout="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/charge_transition_screen_button.png'">
    </button>
  </div>
</form>
<script>
  window.onload = () => {
    var processing = false;
    $('button[name=paymentAppraisalButtonOfAjax]').on('click', function() {
      if (processing) {
        return;
      }
      processing = true;
      var paymentSystemName = 'cocoloni';
      var form = $(this).parents("form");
      var itemcd = form.find('input:hidden[name=itemcd]').val()
      var channel = form.find('input:hidden[name=zp_channel_id]').val()
      var fullName = form.find("input:hidden[name='full_name']").val()
      var birthday = form.find('input:hidden[name=birthday]').val()
      var gender = form.find("input:hidden[name=gender]").val()
      var targetFullName = form.find("input:hidden[name='target_full_name']").val()
      var targetBirthday = form.find('input:hidden[name=target_birthday]').val()
      var targetGender = form.find('input:hidden[name=target_gender]').val()

      if (paymentSystemName == "minori") {
        var url = location.href;
        var env = url.match("dev") ? 'https://dev.rensa.jp.net' : 'https://rensa.jp.net';
        $.ajax({
          type: "POST",
          url: env + "https://honkaku-uranai.jp/cp_rsa/yumecakra_rsa/result/life001", //本番環境用
          //url: "http://localhost/maki/minori/result/life001",//テスト用
          data: {
            "isNomalPayment": true,
            "itemcd": itemcd,
            "howToBuy": "partlyAppraisalButton",
            "full_name": fullName,
            "birthday": birthday,
            "gender": gender,
            "target_full_name": targetFullName,
            "target_birthday": targetBirthday,
            "target_gender": targetGender,
            "TerminalModel": "pc"
          },
          dataType: "html"
        }).done(function(data) {
          console.log(data);
          var dom_parser = new DOMParser();
          var retensionResultDataId = dom_parser.parseFromString(data, "text/html").getElementById("retensionResultData").innerHTML
          $("[name=retensionResultDataId]").val(retensionResultDataId.split("__rid__")[1])
          form.attr("method", "post")
          form.attr("action", "https://zap-happyfortune.rensa.jp.net/cocoloni/yumecakra_rsa/result/").submit();
          processing = false;
        }).fail(function() {
          alert("通信に失敗しました");
          processing = false;
        });
      } else if (paymentSystemName == "cocoloni" || paymentSystemName == "cp_rsa") {
        let postUrl = "";
        let locationUri = location.hostname;
        switch (locationUri) {
            case "honkaku-uranai.jp":
                postUrl = "https://honkaku-uranai.jp/cp_rsa/yumecakra_rsa/result";
                break;
            case "test-honkaku.cocoloni.jp":
                postUrl = "https://test-honkaku.cocoloni.jp/cp_rsa/yumecakra_rsa/result";
                break;
            default:
                postUrl = "http://localhost/cocoloni/yumecakra_rsa/result/life001";
        };
        let time = form.find("input[name='time']").val();
        $.ajax({
          type: "POST",
          url: postUrl,
          data: {
            "ajaxParameter": true,
            "itemcd": itemcd,
            "zp_channel_id": channel,
            "time": time,
            "full_name": fullName,
            "birthday": birthday,
            "gender": gender,
            "target_full_name": targetFullName,
            "target_birthday": targetBirthday,
            "target_gender": targetGender,
            "TerminalModel": "pc",
            "howToBuy": "paymentAppraisalButton",
          }
        }).done(function(data) {
          var dataValue = JSON.parse(data)
          var zp_channel_id = dataValue.zp_channel_id
          var zp_sid = dataValue.zp_sid
          var zp_sig = dataValue.zp_sig
          processing = false;
          if (location.hostname.includes("test-honkaku.cocoloni.jp") !== false) {
            window.location.href = "https://test-honkaku.cocoloni.jp/portal/charge/?zp_cp_name=cp_rsa&zp_channel_id=" + zp_channel_id + "&zp_sid=" + zp_sid + "&zp_sig=" + zp_sig
          } else {
            window.location.href = "https://honkaku-uranai.jp/portal/charge/?zp_cp_name=cp_rsa&zp_channel_id=" + zp_channel_id + "&zp_sid=" + zp_sid + "&zp_sig=" + zp_sig
          }
        }).fail(function() {
          alert("通信に失敗しました");
          processing = false;
        });
      }
    })
  };
</script>      </div>
</section>                      
<!-- caption start -->
<img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/result_subheading_top.jpg" style="width: 100%; vertical-align: bottom;">
<div class="result_subheading_background_center">
  <p>直近であなたに訪れる金運転機</p>
</div>
<img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/result_subheading_bottom.jpg" style="width: 100%; vertical-align: top;">
<!-- caption end -->

<section id="normalSection">
  <div class="result_description_background_center">
                <style>
  .charge_transition_screen_button {
    width: 308px;
    height: 104px;
    padding: 0;
    border: none;
    outline: none;
    cursor: pointer;
  }

  .charge_transition_screen_button img {
    width: 100%;
    height: 100%;
    border: none;
  }

  .mosaic_text_background {
    background: url("https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/result_mosaic_text.png") no-repeat;
    background-size: 115% 100%;
    background-position: center;
    width: 100%;
    height: 180px;
    text-align: center;
    padding-top: 10%;
  }

  .graph_charge_transition_screen_button {
    height: 125px;
    width: 375px;
    padding: 0;
    border: none;
    outline: none;
    cursor: pointer;
  }

  .graph_charge_transition_screen_button img {
    width: 100%;
  }
</style>

<form method="post" accept-charset="euc-jp" id="buyMoreProfileForm" action="https://zap-happyfortune.rensa.jp.net/cocoloni/yumecakra_rsa/result/"><div style="display:none;"><input type="hidden" name="_method" value="POST"/></div><input type="hidden" name="itemcd" value="life001"/><input type="hidden" name="howToBuy" value="paymentAppraisalButton"/><input type="hidden" name="TerminalModel" value="pc"/><input type="hidden" name="time" value=""/><input type="hidden" name="zp_channel_id" value="105_yc0004a"/><input type="hidden" name="contentKey" value="CYC"/><input type="hidden" name="full_name" value="あ"/><input type="hidden" name="birthday" value="1976-08-17"/><input type="hidden" name="gender" value="F"/>  <div class="mosaic_text_background">
    <button type="button" class="charge_transition_screen_button" name="paymentAppraisalButtonOfAjax">
      <img loading="lazy" alt="続きを見る(有料)" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/charge_transition_screen_button.png" onmouseover="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/charge_transition_screen_button_over.png'" onmouseout="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/charge_transition_screen_button.png'">
    </button>
  </div>
</form>
<script>
  window.onload = () => {
    var processing = false;
    $('button[name=paymentAppraisalButtonOfAjax]').on('click', function() {
      if (processing) {
        return;
      }
      processing = true;
      var paymentSystemName = 'cocoloni';
      var form = $(this).parents("form");
      var itemcd = form.find('input:hidden[name=itemcd]').val()
      var channel = form.find('input:hidden[name=zp_channel_id]').val()
      var fullName = form.find("input:hidden[name='full_name']").val()
      var birthday = form.find('input:hidden[name=birthday]').val()
      var gender = form.find("input:hidden[name=gender]").val()
      var targetFullName = form.find("input:hidden[name='target_full_name']").val()
      var targetBirthday = form.find('input:hidden[name=target_birthday]').val()
      var targetGender = form.find('input:hidden[name=target_gender]').val()

      if (paymentSystemName == "minori") {
        var url = location.href;
        var env = url.match("dev") ? 'https://dev.rensa.jp.net' : 'https://rensa.jp.net';
        $.ajax({
          type: "POST",
          url: env + "https://honkaku-uranai.jp/cp_rsa/yumecakra_rsa/result/life001", //本番環境用
          //url: "http://localhost/maki/minori/result/life001",//テスト用
          data: {
            "isNomalPayment": true,
            "itemcd": itemcd,
            "howToBuy": "partlyAppraisalButton",
            "full_name": fullName,
            "birthday": birthday,
            "gender": gender,
            "target_full_name": targetFullName,
            "target_birthday": targetBirthday,
            "target_gender": targetGender,
            "TerminalModel": "pc"
          },
          dataType: "html"
        }).done(function(data) {
          console.log(data);
          var dom_parser = new DOMParser();
          var retensionResultDataId = dom_parser.parseFromString(data, "text/html").getElementById("retensionResultData").innerHTML
          $("[name=retensionResultDataId]").val(retensionResultDataId.split("__rid__")[1])
          form.attr("method", "post")
          form.attr("action", "https://zap-happyfortune.rensa.jp.net/cocoloni/yumecakra_rsa/result/").submit();
          processing = false;
        }).fail(function() {
          alert("通信に失敗しました");
          processing = false;
        });
      } else if (paymentSystemName == "cocoloni" || paymentSystemName == "cp_rsa") {
        let postUrl = "";
        let locationUri = location.hostname;
        switch (locationUri) {
            case "honkaku-uranai.jp":
                postUrl = "https://honkaku-uranai.jp/cp_rsa/yumecakra_rsa/result";
                break;
            case "test-honkaku.cocoloni.jp":
                postUrl = "https://test-honkaku.cocoloni.jp/cp_rsa/yumecakra_rsa/result";
                break;
            default:
                postUrl = "http://localhost/cocoloni/yumecakra_rsa/result/life001";
        };
        let time = form.find("input[name='time']").val();
        $.ajax({
          type: "POST",
          url: postUrl,
          data: {
            "ajaxParameter": true,
            "itemcd": itemcd,
            "zp_channel_id": channel,
            "time": time,
            "full_name": fullName,
            "birthday": birthday,
            "gender": gender,
            "target_full_name": targetFullName,
            "target_birthday": targetBirthday,
            "target_gender": targetGender,
            "TerminalModel": "pc",
            "howToBuy": "paymentAppraisalButton",
          }
        }).done(function(data) {
          var dataValue = JSON.parse(data)
          var zp_channel_id = dataValue.zp_channel_id
          var zp_sid = dataValue.zp_sid
          var zp_sig = dataValue.zp_sig
          processing = false;
          if (location.hostname.includes("test-honkaku.cocoloni.jp") !== false) {
            window.location.href = "https://test-honkaku.cocoloni.jp/portal/charge/?zp_cp_name=cp_rsa&zp_channel_id=" + zp_channel_id + "&zp_sid=" + zp_sid + "&zp_sig=" + zp_sig
          } else {
            window.location.href = "https://honkaku-uranai.jp/portal/charge/?zp_cp_name=cp_rsa&zp_channel_id=" + zp_channel_id + "&zp_sid=" + zp_sid + "&zp_sig=" + zp_sig
          }
        }).fail(function() {
          alert("通信に失敗しました");
          processing = false;
        });
      }
    })
  };
</script>      </div>
</section>                      
<img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/top/line.png" style="width: 100%;">

<!--　特殊枠6（一問一答）　-->
<section id="one_to_one_question_section">
  <!-- 背景画像 -->
  <div class="beginning_text_background">
    <!-- 冒頭文 -->
    <div class="beginning_text_balloon">
      <p>あなたが気になっていること、決めかねていることに対してオーラから読み取ります。あなたの現実を映し出すオーラが、数ある選択肢から正しい答えへと導くのです。</p>
    </div>
  </div>

  <!-- 見出し -->
  <img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/result_subheading_top.jpg" style="width: 100%; vertical-align: bottom;">
  <div class="result_subheading_background_center">
    <p>その転機によって、どれくらいの臨時収入を得ることになる？</p>
  </div>
  <img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/result_subheading_bottom.jpg" style="width: 100%; vertical-align: top;">

  <!-- vue start -->
  <div id="one_to_one_question_23" class="one_to_one_question">
    <one-to-one-question
      result="[&quot;\u4e00\u554f\u4e00\u7b54&quot;,&quot;\u3042\u306a\u305f\u304c\u6c17\u306b\u306a\u3063\u3066\u3044\u308b\u3053\u3068\u3001\u6c7a\u3081\u304b\u306d\u3066\u3044\u308b\u3053\u3068\u306b\u5bfe\u3057\u3066\u30aa\u30fc\u30e9\u304b\u3089\u8aad\u307f\u53d6\u308a\u307e\u3059\u3002\u3042\u306a\u305f\u306e\u73fe\u5b9f\u3092\u6620\u3057\u51fa\u3059\u30aa\u30fc\u30e9\u304c\u3001\u6570\u3042\u308b\u9078\u629e\u80a2\u304b\u3089\u6b63\u3057\u3044\u7b54\u3048\u3078\u3068\u5c0e\u304f\u306e\u3067\u3059\u3002&quot;,&quot;\u3042\u306a\u305f\u306e\u5fc3\u306b&lt;br&gt;XXXXXXX&lt;br&gt;\u3060\u3051\u306e\u53ce\u5165&quot;,&quot;\u3042\u306a\u305f\u306e\u5fc3\u306b&lt;br&gt;\u4f59\u88d5\u3092\u6301\u3066\u308b&lt;br&gt;\u3060\u3051\u306e\u53ce\u5165&quot;,&quot;&amp;emsp;XXX\u3092\u59cb\u3081\u308b\u3053\u3068\u306b\u3088\u308a\u3001\u3042\u3055\u3093\u306e\u7d4c\u6e08\u72b6\u6cc1\u306f\u3050\u3093\u3068\u826f\u304f\u306a\u3063\u3066\u3044\u304d\u307e\u3059\u3002\u6295\u8cc7\u4fe1\u8a17\u3092\u30e1\u30a4\u30f3\u3068\u3057\u3066\u3001XXXX\u304c\u9b45\u529b\u7684\u306a&quot;,&quot;&amp;emsp;\u6295\u8cc7\u3092\u59cb\u3081\u308b\u3053\u3068\u306b\u3088\u308a\u3001\u3042\u3055\u3093\u306e\u7d4c\u6e08\u72b6\u6cc1\u306f\u3050\u3093\u3068\u826f\u304f\u306a\u3063\u3066\u3044\u304d\u307e\u3059\u3002\u6295\u8cc7\u4fe1\u8a17\u3092\u30e1\u30a4\u30f3\u3068\u3057\u3066\u3001\u682a\u4e3b\u512a\u5f85\u304c\u9b45\u529b\u7684\u306a\u4f01\u696d\u306e\u682a\u3082\u8cfc\u5165\u3059\u308b\u3053\u3068\u3068\u306a\u308a\u3001\u914d\u5f53\u3082\u624b\u306b\u3059\u308b\u3053\u3068\u3068\u306a\u308b\u306e\u3067\u3059\u3002&lt;br&gt;&lt;br&gt;\u3000\u304b\u3068\u3044\u3063\u3066\u3001\u914d\u5f53\u53ce\u5165\u3060\u3051\u3067\u751f\u6d3b\u3067\u304d\u308b\u3088\u3046\u306b\u306a\u308b\u306b\u306f\u7a0b\u9060\u3044\u3067\u3059\u304c\u3001\u91d1\u878d\u6a5f\u95a2\u306b\u9810\u3051\u3066\u304a\u304f\u3088\u308a\u306f\u968f\u5206\u3068\u5229\u7387\u304c\u9b45\u529b\u7684\u306a\u305f\u3081\u3001\u3042\u306a\u305f\u306e\u6c17\u6301\u3061\u306f\u6f64\u3063\u3066\u304f\u308b\u3067\u3057\u3087\u3046\u3002&lt;br&gt;&lt;br&gt;\u3000\u305d\u3057\u3066\u3042\u306a\u305f\u306f\u3001\u682a\u4e3b\u512a\u5f85\u306e\u5272\u5f15\u5238\u306a\u3069\u3067\u4e0a\u624b\u306b\u8cb7\u3044\u7269\u3092\u3059\u308b\u3053\u3068\u3068\u306a\u308a\u307e\u3059\u3002\u5916\u98df\u30c1\u30a7\u30fc\u30f3\u306e\u512a\u5f85\u5238\u306a\u3069\u3082\u624b\u306b\u3057\u3066\u306f\u3001\u4f11\u65e5\u306e\u5a2f\u697d\u306f\u682a\u4e3b\u512a\u5f85\u306e\u304a\u4e16\u8a71\u306b\u306a\u3063\u3066\u3044\u304f\u3067\u3057\u3087\u3046\u3002\u81ea\u5206\u306e\u304a\u91d1\u3092\u3042\u307e\u308a\u6e1b\u3089\u3059\u3053\u3068\u306a\u304f\u697d\u3057\u304f\u6bce\u65e5\u3092\u904e\u3054\u305b\u308b\u3053\u3068\u3067\u3001\u5fc3\u306e\u4f59\u88d5\u3082\u5927\u304d\u304f\u80b2\u3063\u3066\u3044\u304d\u307e\u3059\u3002\u8c4a\u304b\u3055\u3092\u611f\u3058\u3089\u308c\u308b\u3067\u3057\u3087\u3046\u3002&quot;]"
      how-to-buy-flag="&quot;partlyAppraisalButton1&quot;"
      index-number="23"
    />
  </div>
  <!-- vue end -->

  <!-- 原稿 -->
  <div id="one_to_one_question_manuscript_23" class="manuscript_display_none">
    <div class="result_description_background_center">
              &emsp;XXXを始めることにより、あさんの経済状況はぐんと良くなっていきます。投資信託をメインとして、XXXXが魅力的な……        <style>
  .charge_transition_screen_button {
    width: 308px;
    height: 104px;
    padding: 0;
    border: none;
    outline: none;
    cursor: pointer;
  }

  .charge_transition_screen_button img {
    width: 100%;
    height: 100%;
    border: none;
  }

  .mosaic_text_background {
    background: url("https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/result_mosaic_text.png") no-repeat;
    background-size: 115% 100%;
    background-position: center;
    width: 100%;
    height: 180px;
    text-align: center;
    padding-top: 10%;
  }

  .graph_charge_transition_screen_button {
    height: 125px;
    width: 375px;
    padding: 0;
    border: none;
    outline: none;
    cursor: pointer;
  }

  .graph_charge_transition_screen_button img {
    width: 100%;
  }
</style>

<form method="post" accept-charset="euc-jp" id="buyMoreProfileForm" action="https://zap-happyfortune.rensa.jp.net/cocoloni/yumecakra_rsa/result/"><div style="display:none;"><input type="hidden" name="_method" value="POST"/></div><input type="hidden" name="itemcd" value="life001"/><input type="hidden" name="howToBuy" value="paymentAppraisalButton"/><input type="hidden" name="TerminalModel" value="pc"/><input type="hidden" name="time" value=""/><input type="hidden" name="zp_channel_id" value="105_yc0004a"/><input type="hidden" name="contentKey" value="CYC"/><input type="hidden" name="full_name" value="あ"/><input type="hidden" name="birthday" value="1976-08-17"/><input type="hidden" name="gender" value="F"/>  <div class="mosaic_text_background">
    <button type="button" class="charge_transition_screen_button" name="paymentAppraisalButtonOfAjax">
      <img loading="lazy" alt="続きを見る(有料)" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/charge_transition_screen_button.png" onmouseover="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/charge_transition_screen_button_over.png'" onmouseout="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/charge_transition_screen_button.png'">
    </button>
  </div>
</form>
<script>
  window.onload = () => {
    var processing = false;
    $('button[name=paymentAppraisalButtonOfAjax]').on('click', function() {
      if (processing) {
        return;
      }
      processing = true;
      var paymentSystemName = 'cocoloni';
      var form = $(this).parents("form");
      var itemcd = form.find('input:hidden[name=itemcd]').val()
      var channel = form.find('input:hidden[name=zp_channel_id]').val()
      var fullName = form.find("input:hidden[name='full_name']").val()
      var birthday = form.find('input:hidden[name=birthday]').val()
      var gender = form.find("input:hidden[name=gender]").val()
      var targetFullName = form.find("input:hidden[name='target_full_name']").val()
      var targetBirthday = form.find('input:hidden[name=target_birthday]').val()
      var targetGender = form.find('input:hidden[name=target_gender]').val()

      if (paymentSystemName == "minori") {
        var url = location.href;
        var env = url.match("dev") ? 'https://dev.rensa.jp.net' : 'https://rensa.jp.net';
        $.ajax({
          type: "POST",
          url: env + "https://honkaku-uranai.jp/cp_rsa/yumecakra_rsa/result/life001", //本番環境用
          //url: "http://localhost/maki/minori/result/life001",//テスト用
          data: {
            "isNomalPayment": true,
            "itemcd": itemcd,
            "howToBuy": "partlyAppraisalButton",
            "full_name": fullName,
            "birthday": birthday,
            "gender": gender,
            "target_full_name": targetFullName,
            "target_birthday": targetBirthday,
            "target_gender": targetGender,
            "TerminalModel": "pc"
          },
          dataType: "html"
        }).done(function(data) {
          console.log(data);
          var dom_parser = new DOMParser();
          var retensionResultDataId = dom_parser.parseFromString(data, "text/html").getElementById("retensionResultData").innerHTML
          $("[name=retensionResultDataId]").val(retensionResultDataId.split("__rid__")[1])
          form.attr("method", "post")
          form.attr("action", "https://zap-happyfortune.rensa.jp.net/cocoloni/yumecakra_rsa/result/").submit();
          processing = false;
        }).fail(function() {
          alert("通信に失敗しました");
          processing = false;
        });
      } else if (paymentSystemName == "cocoloni" || paymentSystemName == "cp_rsa") {
        let postUrl = "";
        let locationUri = location.hostname;
        switch (locationUri) {
            case "honkaku-uranai.jp":
                postUrl = "https://honkaku-uranai.jp/cp_rsa/yumecakra_rsa/result";
                break;
            case "test-honkaku.cocoloni.jp":
                postUrl = "https://test-honkaku.cocoloni.jp/cp_rsa/yumecakra_rsa/result";
                break;
            default:
                postUrl = "http://localhost/cocoloni/yumecakra_rsa/result/life001";
        };
        let time = form.find("input[name='time']").val();
        $.ajax({
          type: "POST",
          url: postUrl,
          data: {
            "ajaxParameter": true,
            "itemcd": itemcd,
            "zp_channel_id": channel,
            "time": time,
            "full_name": fullName,
            "birthday": birthday,
            "gender": gender,
            "target_full_name": targetFullName,
            "target_birthday": targetBirthday,
            "target_gender": targetGender,
            "TerminalModel": "pc",
            "howToBuy": "paymentAppraisalButton",
          }
        }).done(function(data) {
          var dataValue = JSON.parse(data)
          var zp_channel_id = dataValue.zp_channel_id
          var zp_sid = dataValue.zp_sid
          var zp_sig = dataValue.zp_sig
          processing = false;
          if (location.hostname.includes("test-honkaku.cocoloni.jp") !== false) {
            window.location.href = "https://test-honkaku.cocoloni.jp/portal/charge/?zp_cp_name=cp_rsa&zp_channel_id=" + zp_channel_id + "&zp_sid=" + zp_sid + "&zp_sig=" + zp_sig
          } else {
            window.location.href = "https://honkaku-uranai.jp/portal/charge/?zp_cp_name=cp_rsa&zp_channel_id=" + zp_channel_id + "&zp_sid=" + zp_sid + "&zp_sig=" + zp_sig
          }
        }).fail(function() {
          alert("通信に失敗しました");
          processing = false;
        });
      }
    })
  };
</script>          </div>
  </div>
</section>                      
<!-- caption start -->
<img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/result_subheading_top.jpg" style="width: 100%; vertical-align: bottom;">
<div class="result_subheading_background_center">
  <p>あなたの財布がより潤っていくために意識してほしいこと</p>
</div>
<img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/result_subheading_bottom.jpg" style="width: 100%; vertical-align: top;">
<!-- caption end -->

<section id="normalSection">
  <div class="result_description_background_center">
                <style>
  .charge_transition_screen_button {
    width: 308px;
    height: 104px;
    padding: 0;
    border: none;
    outline: none;
    cursor: pointer;
  }

  .charge_transition_screen_button img {
    width: 100%;
    height: 100%;
    border: none;
  }

  .mosaic_text_background {
    background: url("https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/result_mosaic_text.png") no-repeat;
    background-size: 115% 100%;
    background-position: center;
    width: 100%;
    height: 180px;
    text-align: center;
    padding-top: 10%;
  }

  .graph_charge_transition_screen_button {
    height: 125px;
    width: 375px;
    padding: 0;
    border: none;
    outline: none;
    cursor: pointer;
  }

  .graph_charge_transition_screen_button img {
    width: 100%;
  }
</style>

<form method="post" accept-charset="euc-jp" id="buyMoreProfileForm" action="https://zap-happyfortune.rensa.jp.net/cocoloni/yumecakra_rsa/result/"><div style="display:none;"><input type="hidden" name="_method" value="POST"/></div><input type="hidden" name="itemcd" value="life001"/><input type="hidden" name="howToBuy" value="paymentAppraisalButton"/><input type="hidden" name="TerminalModel" value="pc"/><input type="hidden" name="time" value=""/><input type="hidden" name="zp_channel_id" value="105_yc0004a"/><input type="hidden" name="contentKey" value="CYC"/><input type="hidden" name="full_name" value="あ"/><input type="hidden" name="birthday" value="1976-08-17"/><input type="hidden" name="gender" value="F"/>  <div class="mosaic_text_background">
    <button type="button" class="charge_transition_screen_button" name="paymentAppraisalButtonOfAjax">
      <img loading="lazy" alt="続きを見る(有料)" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/charge_transition_screen_button.png" onmouseover="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/charge_transition_screen_button_over.png'" onmouseout="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/charge_transition_screen_button.png'">
    </button>
  </div>
</form>
<script>
  window.onload = () => {
    var processing = false;
    $('button[name=paymentAppraisalButtonOfAjax]').on('click', function() {
      if (processing) {
        return;
      }
      processing = true;
      var paymentSystemName = 'cocoloni';
      var form = $(this).parents("form");
      var itemcd = form.find('input:hidden[name=itemcd]').val()
      var channel = form.find('input:hidden[name=zp_channel_id]').val()
      var fullName = form.find("input:hidden[name='full_name']").val()
      var birthday = form.find('input:hidden[name=birthday]').val()
      var gender = form.find("input:hidden[name=gender]").val()
      var targetFullName = form.find("input:hidden[name='target_full_name']").val()
      var targetBirthday = form.find('input:hidden[name=target_birthday]').val()
      var targetGender = form.find('input:hidden[name=target_gender]').val()

      if (paymentSystemName == "minori") {
        var url = location.href;
        var env = url.match("dev") ? 'https://dev.rensa.jp.net' : 'https://rensa.jp.net';
        $.ajax({
          type: "POST",
          url: env + "https://honkaku-uranai.jp/cp_rsa/yumecakra_rsa/result/life001", //本番環境用
          //url: "http://localhost/maki/minori/result/life001",//テスト用
          data: {
            "isNomalPayment": true,
            "itemcd": itemcd,
            "howToBuy": "partlyAppraisalButton",
            "full_name": fullName,
            "birthday": birthday,
            "gender": gender,
            "target_full_name": targetFullName,
            "target_birthday": targetBirthday,
            "target_gender": targetGender,
            "TerminalModel": "pc"
          },
          dataType: "html"
        }).done(function(data) {
          console.log(data);
          var dom_parser = new DOMParser();
          var retensionResultDataId = dom_parser.parseFromString(data, "text/html").getElementById("retensionResultData").innerHTML
          $("[name=retensionResultDataId]").val(retensionResultDataId.split("__rid__")[1])
          form.attr("method", "post")
          form.attr("action", "https://zap-happyfortune.rensa.jp.net/cocoloni/yumecakra_rsa/result/").submit();
          processing = false;
        }).fail(function() {
          alert("通信に失敗しました");
          processing = false;
        });
      } else if (paymentSystemName == "cocoloni" || paymentSystemName == "cp_rsa") {
        let postUrl = "";
        let locationUri = location.hostname;
        switch (locationUri) {
            case "honkaku-uranai.jp":
                postUrl = "https://honkaku-uranai.jp/cp_rsa/yumecakra_rsa/result";
                break;
            case "test-honkaku.cocoloni.jp":
                postUrl = "https://test-honkaku.cocoloni.jp/cp_rsa/yumecakra_rsa/result";
                break;
            default:
                postUrl = "http://localhost/cocoloni/yumecakra_rsa/result/life001";
        };
        let time = form.find("input[name='time']").val();
        $.ajax({
          type: "POST",
          url: postUrl,
          data: {
            "ajaxParameter": true,
            "itemcd": itemcd,
            "zp_channel_id": channel,
            "time": time,
            "full_name": fullName,
            "birthday": birthday,
            "gender": gender,
            "target_full_name": targetFullName,
            "target_birthday": targetBirthday,
            "target_gender": targetGender,
            "TerminalModel": "pc",
            "howToBuy": "paymentAppraisalButton",
          }
        }).done(function(data) {
          var dataValue = JSON.parse(data)
          var zp_channel_id = dataValue.zp_channel_id
          var zp_sid = dataValue.zp_sid
          var zp_sig = dataValue.zp_sig
          processing = false;
          if (location.hostname.includes("test-honkaku.cocoloni.jp") !== false) {
            window.location.href = "https://test-honkaku.cocoloni.jp/portal/charge/?zp_cp_name=cp_rsa&zp_channel_id=" + zp_channel_id + "&zp_sid=" + zp_sid + "&zp_sig=" + zp_sig
          } else {
            window.location.href = "https://honkaku-uranai.jp/portal/charge/?zp_cp_name=cp_rsa&zp_channel_id=" + zp_channel_id + "&zp_sid=" + zp_sid + "&zp_sig=" + zp_sig
          }
        }).fail(function() {
          alert("通信に失敗しました");
          processing = false;
        });
      }
    })
  };
</script>      </div>
</section>                      
<!-- caption start -->
<img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/result_subheading_top.jpg" style="width: 100%; vertical-align: bottom;">
<div class="result_subheading_background_center">
  <p>1年後のあなたはどんな生活を送っている？</p>
</div>
<img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/result_subheading_bottom.jpg" style="width: 100%; vertical-align: top;">
<!-- caption end -->

<section id="normalSection">
  <div class="result_description_background_center">
                <style>
  .charge_transition_screen_button {
    width: 308px;
    height: 104px;
    padding: 0;
    border: none;
    outline: none;
    cursor: pointer;
  }

  .charge_transition_screen_button img {
    width: 100%;
    height: 100%;
    border: none;
  }

  .mosaic_text_background {
    background: url("https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/result_mosaic_text.png") no-repeat;
    background-size: 115% 100%;
    background-position: center;
    width: 100%;
    height: 180px;
    text-align: center;
    padding-top: 10%;
  }

  .graph_charge_transition_screen_button {
    height: 125px;
    width: 375px;
    padding: 0;
    border: none;
    outline: none;
    cursor: pointer;
  }

  .graph_charge_transition_screen_button img {
    width: 100%;
  }
</style>

<form method="post" accept-charset="euc-jp" id="buyMoreProfileForm" action="https://zap-happyfortune.rensa.jp.net/cocoloni/yumecakra_rsa/result/"><div style="display:none;"><input type="hidden" name="_method" value="POST"/></div><input type="hidden" name="itemcd" value="life001"/><input type="hidden" name="howToBuy" value="paymentAppraisalButton"/><input type="hidden" name="TerminalModel" value="pc"/><input type="hidden" name="time" value=""/><input type="hidden" name="zp_channel_id" value="105_yc0004a"/><input type="hidden" name="contentKey" value="CYC"/><input type="hidden" name="full_name" value="あ"/><input type="hidden" name="birthday" value="1976-08-17"/><input type="hidden" name="gender" value="F"/>  <div class="mosaic_text_background">
    <button type="button" class="charge_transition_screen_button" name="paymentAppraisalButtonOfAjax">
      <img loading="lazy" alt="続きを見る(有料)" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/charge_transition_screen_button.png" onmouseover="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/charge_transition_screen_button_over.png'" onmouseout="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/charge_transition_screen_button.png'">
    </button>
  </div>
</form>
<script>
  window.onload = () => {
    var processing = false;
    $('button[name=paymentAppraisalButtonOfAjax]').on('click', function() {
      if (processing) {
        return;
      }
      processing = true;
      var paymentSystemName = 'cocoloni';
      var form = $(this).parents("form");
      var itemcd = form.find('input:hidden[name=itemcd]').val()
      var channel = form.find('input:hidden[name=zp_channel_id]').val()
      var fullName = form.find("input:hidden[name='full_name']").val()
      var birthday = form.find('input:hidden[name=birthday]').val()
      var gender = form.find("input:hidden[name=gender]").val()
      var targetFullName = form.find("input:hidden[name='target_full_name']").val()
      var targetBirthday = form.find('input:hidden[name=target_birthday]').val()
      var targetGender = form.find('input:hidden[name=target_gender]').val()

      if (paymentSystemName == "minori") {
        var url = location.href;
        var env = url.match("dev") ? 'https://dev.rensa.jp.net' : 'https://rensa.jp.net';
        $.ajax({
          type: "POST",
          url: env + "https://honkaku-uranai.jp/cp_rsa/yumecakra_rsa/result/life001", //本番環境用
          //url: "http://localhost/maki/minori/result/life001",//テスト用
          data: {
            "isNomalPayment": true,
            "itemcd": itemcd,
            "howToBuy": "partlyAppraisalButton",
            "full_name": fullName,
            "birthday": birthday,
            "gender": gender,
            "target_full_name": targetFullName,
            "target_birthday": targetBirthday,
            "target_gender": targetGender,
            "TerminalModel": "pc"
          },
          dataType: "html"
        }).done(function(data) {
          console.log(data);
          var dom_parser = new DOMParser();
          var retensionResultDataId = dom_parser.parseFromString(data, "text/html").getElementById("retensionResultData").innerHTML
          $("[name=retensionResultDataId]").val(retensionResultDataId.split("__rid__")[1])
          form.attr("method", "post")
          form.attr("action", "https://zap-happyfortune.rensa.jp.net/cocoloni/yumecakra_rsa/result/").submit();
          processing = false;
        }).fail(function() {
          alert("通信に失敗しました");
          processing = false;
        });
      } else if (paymentSystemName == "cocoloni" || paymentSystemName == "cp_rsa") {
        let postUrl = "";
        let locationUri = location.hostname;
        switch (locationUri) {
            case "honkaku-uranai.jp":
                postUrl = "https://honkaku-uranai.jp/cp_rsa/yumecakra_rsa/result";
                break;
            case "test-honkaku.cocoloni.jp":
                postUrl = "https://test-honkaku.cocoloni.jp/cp_rsa/yumecakra_rsa/result";
                break;
            default:
                postUrl = "http://localhost/cocoloni/yumecakra_rsa/result/life001";
        };
        let time = form.find("input[name='time']").val();
        $.ajax({
          type: "POST",
          url: postUrl,
          data: {
            "ajaxParameter": true,
            "itemcd": itemcd,
            "zp_channel_id": channel,
            "time": time,
            "full_name": fullName,
            "birthday": birthday,
            "gender": gender,
            "target_full_name": targetFullName,
            "target_birthday": targetBirthday,
            "target_gender": targetGender,
            "TerminalModel": "pc",
            "howToBuy": "paymentAppraisalButton",
          }
        }).done(function(data) {
          var dataValue = JSON.parse(data)
          var zp_channel_id = dataValue.zp_channel_id
          var zp_sid = dataValue.zp_sid
          var zp_sig = dataValue.zp_sig
          processing = false;
          if (location.hostname.includes("test-honkaku.cocoloni.jp") !== false) {
            window.location.href = "https://test-honkaku.cocoloni.jp/portal/charge/?zp_cp_name=cp_rsa&zp_channel_id=" + zp_channel_id + "&zp_sid=" + zp_sid + "&zp_sig=" + zp_sig
          } else {
            window.location.href = "https://honkaku-uranai.jp/portal/charge/?zp_cp_name=cp_rsa&zp_channel_id=" + zp_channel_id + "&zp_sid=" + zp_sid + "&zp_sig=" + zp_sig
          }
        }).fail(function() {
          alert("通信に失敗しました");
          processing = false;
        });
      }
    })
  };
</script>      </div>
</section>                      
<!--　特殊枠5（グラフ）　-->
<section id="graph_section">
  <!-- 看板画像 -->
  <img loading="lazy" alt='運命の巡りの起伏を霊視 チャクラ・グラフ' src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/res_type_title5.png" style="width: 100%; vertical-align: bottom;">

  <!-- グラフの表示部分 -->
  <div class="graph_display">
    <!-- vue start -->
    <div id="graph_animation_26" class="graph_animation">
      <graph-animation
        result-image="[&quot;2025\/06\/09||RYC61&quot;]"
        how-to-buy-flag="&quot;partlyAppraisalButton1&quot;"
        index-number="26"
        add-index-number="null"
        itemcd="&quot;life001&quot;"
      />
    </div>
    <!-- vue end -->

          <div id="graph_charge_transition_button_26" class="graph_charge_transition_button">
        <style>
  .charge_transition_screen_button {
    width: 308px;
    height: 104px;
    padding: 0;
    border: none;
    outline: none;
    cursor: pointer;
  }

  .charge_transition_screen_button img {
    width: 100%;
    height: 100%;
    border: none;
  }

  .mosaic_text_background {
    background: url("https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/result_mosaic_text.png") no-repeat;
    background-size: 115% 100%;
    background-position: center;
    width: 100%;
    height: 180px;
    text-align: center;
    padding-top: 10%;
  }

  .graph_charge_transition_screen_button {
    height: 125px;
    width: 375px;
    padding: 0;
    border: none;
    outline: none;
    cursor: pointer;
  }

  .graph_charge_transition_screen_button img {
    width: 100%;
  }
</style>

<form method="post" accept-charset="euc-jp" id="buyMoreProfileForm" action="https://zap-happyfortune.rensa.jp.net/cocoloni/yumecakra_rsa/result/"><div style="display:none;"><input type="hidden" name="_method" value="POST"/></div><input type="hidden" name="itemcd" value="life001"/><input type="hidden" name="howToBuy" value="paymentAppraisalButton"/><input type="hidden" name="TerminalModel" value="pc"/><input type="hidden" name="time" value=""/><input type="hidden" name="zp_channel_id" value="105_yc0004a"/><input type="hidden" name="contentKey" value="CYC"/><input type="hidden" name="full_name" value="あ"/><input type="hidden" name="birthday" value="1976-08-17"/><input type="hidden" name="gender" value="F"/>  <div>
    <button class="graph_charge_transition_screen_button" type="button" name="paymentAppraisalButtonOfAjax">
      <img loading="lazy" alt='続きを見る(有料)' src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/charge_transition_screen_button.png" onmouseover="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/charge_transition_screen_button_over.png'" onmouseout="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/charge_transition_screen_button.png'">
    </button>
  </div>
</form>
<script>
  window.onload = () => {
    var processing = false;
    $('button[name=paymentAppraisalButtonOfAjax]').on('click', function() {
      if (processing) {
        return;
      }
      processing = true;
      var paymentSystemName = 'cocoloni';
      var form = $(this).parents("form");
      var itemcd = form.find('input:hidden[name=itemcd]').val()
      var channel = form.find('input:hidden[name=zp_channel_id]').val()
      var fullName = form.find("input:hidden[name='full_name']").val()
      var birthday = form.find('input:hidden[name=birthday]').val()
      var gender = form.find("input:hidden[name=gender]").val()
      var targetFullName = form.find("input:hidden[name='target_full_name']").val()
      var targetBirthday = form.find('input:hidden[name=target_birthday]').val()
      var targetGender = form.find('input:hidden[name=target_gender]').val()

      if (paymentSystemName == "minori") {
        var url = location.href;
        var env = url.match("dev") ? 'https://dev.rensa.jp.net' : 'https://rensa.jp.net';
        $.ajax({
          type: "POST",
          url: env + "https://honkaku-uranai.jp/cp_rsa/yumecakra_rsa/result/life001", //本番環境用
          //url: "http://localhost/maki/minori/result/life001",//テスト用
          data: {
            "isNomalPayment": true,
            "itemcd": itemcd,
            "howToBuy": "partlyAppraisalButton",
            "full_name": fullName,
            "birthday": birthday,
            "gender": gender,
            "target_full_name": targetFullName,
            "target_birthday": targetBirthday,
            "target_gender": targetGender,
            "TerminalModel": "pc"
          },
          dataType: "html"
        }).done(function(data) {
          console.log(data);
          var dom_parser = new DOMParser();
          var retensionResultDataId = dom_parser.parseFromString(data, "text/html").getElementById("retensionResultData").innerHTML
          $("[name=retensionResultDataId]").val(retensionResultDataId.split("__rid__")[1])
          form.attr("method", "post")
          form.attr("action", "https://zap-happyfortune.rensa.jp.net/cocoloni/yumecakra_rsa/result/").submit();
          processing = false;
        }).fail(function() {
          alert("通信に失敗しました");
          processing = false;
        });
      } else if (paymentSystemName == "cocoloni" || paymentSystemName == "cp_rsa") {
        let postUrl = "";
        let locationUri = location.hostname;
        switch (locationUri) {
            case "honkaku-uranai.jp":
                postUrl = "https://honkaku-uranai.jp/cp_rsa/yumecakra_rsa/result";
                break;
            case "test-honkaku.cocoloni.jp":
                postUrl = "https://test-honkaku.cocoloni.jp/cp_rsa/yumecakra_rsa/result";
                break;
            default:
                postUrl = "http://localhost/cocoloni/yumecakra_rsa/result/life001";
        };
        let time = form.find("input[name='time']").val();
        $.ajax({
          type: "POST",
          url: postUrl,
          data: {
            "ajaxParameter": true,
            "itemcd": itemcd,
            "zp_channel_id": channel,
            "time": time,
            "full_name": fullName,
            "birthday": birthday,
            "gender": gender,
            "target_full_name": targetFullName,
            "target_birthday": targetBirthday,
            "target_gender": targetGender,
            "TerminalModel": "pc",
            "howToBuy": "paymentAppraisalButton",
          }
        }).done(function(data) {
          var dataValue = JSON.parse(data)
          var zp_channel_id = dataValue.zp_channel_id
          var zp_sid = dataValue.zp_sid
          var zp_sig = dataValue.zp_sig
          processing = false;
          if (location.hostname.includes("test-honkaku.cocoloni.jp") !== false) {
            window.location.href = "https://test-honkaku.cocoloni.jp/portal/charge/?zp_cp_name=cp_rsa&zp_channel_id=" + zp_channel_id + "&zp_sid=" + zp_sid + "&zp_sig=" + zp_sig
          } else {
            window.location.href = "https://honkaku-uranai.jp/portal/charge/?zp_cp_name=cp_rsa&zp_channel_id=" + zp_channel_id + "&zp_sid=" + zp_sid + "&zp_sig=" + zp_sig
          }
        }).fail(function() {
          alert("通信に失敗しました");
          processing = false;
        });
      }
    })
  };
</script>      </div>
      </div>

  <!-- 結果説明テキスト -->
  <div id="result_explanation_26" class="manuscript_display_none">
    <img src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/res_type_background4_top.jpg" style="width: 100%; vertical-align: bottom;">
    <div class="result_explanation_box">
              <p>あなたの人生に大きな影響を与える<span class="strong-text green">重要な転機日</span>がわかりました。この注目すべき日を見過ごさないよう、今のうちに何が起こるのかまで知っておきましょう。</p>
          </div>
    <img src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/res_type_background4_bottom.jpg" style="width: 100%; vertical-align: top;">
  </div>

  <!-- 原稿 -->
  <div id="graph_manuscript_26" class="manuscript_display_none">
    <div class="result_description_background_center">
              &emsp;この先あさんは、会社から転勤を命じられます。いずれはそういうこともあろうかと心のどこかでは思ってはいたものの、いざ辞令が下りると覚悟が足りなかったと……        <style>
  .charge_transition_screen_button {
    width: 308px;
    height: 104px;
    padding: 0;
    border: none;
    outline: none;
    cursor: pointer;
  }

  .charge_transition_screen_button img {
    width: 100%;
    height: 100%;
    border: none;
  }

  .mosaic_text_background {
    background: url("https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/result_mosaic_text.png") no-repeat;
    background-size: 115% 100%;
    background-position: center;
    width: 100%;
    height: 180px;
    text-align: center;
    padding-top: 10%;
  }

  .graph_charge_transition_screen_button {
    height: 125px;
    width: 375px;
    padding: 0;
    border: none;
    outline: none;
    cursor: pointer;
  }

  .graph_charge_transition_screen_button img {
    width: 100%;
  }
</style>

<form method="post" accept-charset="euc-jp" id="buyMoreProfileForm" action="https://zap-happyfortune.rensa.jp.net/cocoloni/yumecakra_rsa/result/"><div style="display:none;"><input type="hidden" name="_method" value="POST"/></div><input type="hidden" name="itemcd" value="life001"/><input type="hidden" name="howToBuy" value="paymentAppraisalButton"/><input type="hidden" name="TerminalModel" value="pc"/><input type="hidden" name="time" value=""/><input type="hidden" name="zp_channel_id" value="105_yc0004a"/><input type="hidden" name="contentKey" value="CYC"/><input type="hidden" name="full_name" value="あ"/><input type="hidden" name="birthday" value="1976-08-17"/><input type="hidden" name="gender" value="F"/>  <div class="mosaic_text_background">
    <button type="button" class="charge_transition_screen_button" name="paymentAppraisalButtonOfAjax">
      <img loading="lazy" alt="続きを見る(有料)" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/charge_transition_screen_button.png" onmouseover="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/charge_transition_screen_button_over.png'" onmouseout="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/charge_transition_screen_button.png'">
    </button>
  </div>
</form>
<script>
  window.onload = () => {
    var processing = false;
    $('button[name=paymentAppraisalButtonOfAjax]').on('click', function() {
      if (processing) {
        return;
      }
      processing = true;
      var paymentSystemName = 'cocoloni';
      var form = $(this).parents("form");
      var itemcd = form.find('input:hidden[name=itemcd]').val()
      var channel = form.find('input:hidden[name=zp_channel_id]').val()
      var fullName = form.find("input:hidden[name='full_name']").val()
      var birthday = form.find('input:hidden[name=birthday]').val()
      var gender = form.find("input:hidden[name=gender]").val()
      var targetFullName = form.find("input:hidden[name='target_full_name']").val()
      var targetBirthday = form.find('input:hidden[name=target_birthday]').val()
      var targetGender = form.find('input:hidden[name=target_gender]').val()

      if (paymentSystemName == "minori") {
        var url = location.href;
        var env = url.match("dev") ? 'https://dev.rensa.jp.net' : 'https://rensa.jp.net';
        $.ajax({
          type: "POST",
          url: env + "https://honkaku-uranai.jp/cp_rsa/yumecakra_rsa/result/life001", //本番環境用
          //url: "http://localhost/maki/minori/result/life001",//テスト用
          data: {
            "isNomalPayment": true,
            "itemcd": itemcd,
            "howToBuy": "partlyAppraisalButton",
            "full_name": fullName,
            "birthday": birthday,
            "gender": gender,
            "target_full_name": targetFullName,
            "target_birthday": targetBirthday,
            "target_gender": targetGender,
            "TerminalModel": "pc"
          },
          dataType: "html"
        }).done(function(data) {
          console.log(data);
          var dom_parser = new DOMParser();
          var retensionResultDataId = dom_parser.parseFromString(data, "text/html").getElementById("retensionResultData").innerHTML
          $("[name=retensionResultDataId]").val(retensionResultDataId.split("__rid__")[1])
          form.attr("method", "post")
          form.attr("action", "https://zap-happyfortune.rensa.jp.net/cocoloni/yumecakra_rsa/result/").submit();
          processing = false;
        }).fail(function() {
          alert("通信に失敗しました");
          processing = false;
        });
      } else if (paymentSystemName == "cocoloni" || paymentSystemName == "cp_rsa") {
        let postUrl = "";
        let locationUri = location.hostname;
        switch (locationUri) {
            case "honkaku-uranai.jp":
                postUrl = "https://honkaku-uranai.jp/cp_rsa/yumecakra_rsa/result";
                break;
            case "test-honkaku.cocoloni.jp":
                postUrl = "https://test-honkaku.cocoloni.jp/cp_rsa/yumecakra_rsa/result";
                break;
            default:
                postUrl = "http://localhost/cocoloni/yumecakra_rsa/result/life001";
        };
        let time = form.find("input[name='time']").val();
        $.ajax({
          type: "POST",
          url: postUrl,
          data: {
            "ajaxParameter": true,
            "itemcd": itemcd,
            "zp_channel_id": channel,
            "time": time,
            "full_name": fullName,
            "birthday": birthday,
            "gender": gender,
            "target_full_name": targetFullName,
            "target_birthday": targetBirthday,
            "target_gender": targetGender,
            "TerminalModel": "pc",
            "howToBuy": "paymentAppraisalButton",
          }
        }).done(function(data) {
          var dataValue = JSON.parse(data)
          var zp_channel_id = dataValue.zp_channel_id
          var zp_sid = dataValue.zp_sid
          var zp_sig = dataValue.zp_sig
          processing = false;
          if (location.hostname.includes("test-honkaku.cocoloni.jp") !== false) {
            window.location.href = "https://test-honkaku.cocoloni.jp/portal/charge/?zp_cp_name=cp_rsa&zp_channel_id=" + zp_channel_id + "&zp_sid=" + zp_sid + "&zp_sig=" + zp_sig
          } else {
            window.location.href = "https://honkaku-uranai.jp/portal/charge/?zp_cp_name=cp_rsa&zp_channel_id=" + zp_channel_id + "&zp_sid=" + zp_sid + "&zp_sig=" + zp_sig
          }
        }).fail(function() {
          alert("通信に失敗しました");
          processing = false;
        });
      }
    })
  };
</script>          </div>
  </div>
</section>                      
<!-- caption start -->
<img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/result_subheading_top.jpg" style="width: 100%; vertical-align: bottom;">
<div class="result_subheading_background_center">
  <p>この転機は、あなたの暮らしにどんな影響を与えるのか</p>
</div>
<img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/result_subheading_bottom.jpg" style="width: 100%; vertical-align: top;">
<!-- caption end -->

<section id="normalSection">
  <div class="result_description_background_center">
                <style>
  .charge_transition_screen_button {
    width: 308px;
    height: 104px;
    padding: 0;
    border: none;
    outline: none;
    cursor: pointer;
  }

  .charge_transition_screen_button img {
    width: 100%;
    height: 100%;
    border: none;
  }

  .mosaic_text_background {
    background: url("https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/result_mosaic_text.png") no-repeat;
    background-size: 115% 100%;
    background-position: center;
    width: 100%;
    height: 180px;
    text-align: center;
    padding-top: 10%;
  }

  .graph_charge_transition_screen_button {
    height: 125px;
    width: 375px;
    padding: 0;
    border: none;
    outline: none;
    cursor: pointer;
  }

  .graph_charge_transition_screen_button img {
    width: 100%;
  }
</style>

<form method="post" accept-charset="euc-jp" id="buyMoreProfileForm" action="https://zap-happyfortune.rensa.jp.net/cocoloni/yumecakra_rsa/result/"><div style="display:none;"><input type="hidden" name="_method" value="POST"/></div><input type="hidden" name="itemcd" value="life001"/><input type="hidden" name="howToBuy" value="paymentAppraisalButton"/><input type="hidden" name="TerminalModel" value="pc"/><input type="hidden" name="time" value=""/><input type="hidden" name="zp_channel_id" value="105_yc0004a"/><input type="hidden" name="contentKey" value="CYC"/><input type="hidden" name="full_name" value="あ"/><input type="hidden" name="birthday" value="1976-08-17"/><input type="hidden" name="gender" value="F"/>  <div class="mosaic_text_background">
    <button type="button" class="charge_transition_screen_button" name="paymentAppraisalButtonOfAjax">
      <img loading="lazy" alt="続きを見る(有料)" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/charge_transition_screen_button.png" onmouseover="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/charge_transition_screen_button_over.png'" onmouseout="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/charge_transition_screen_button.png'">
    </button>
  </div>
</form>
<script>
  window.onload = () => {
    var processing = false;
    $('button[name=paymentAppraisalButtonOfAjax]').on('click', function() {
      if (processing) {
        return;
      }
      processing = true;
      var paymentSystemName = 'cocoloni';
      var form = $(this).parents("form");
      var itemcd = form.find('input:hidden[name=itemcd]').val()
      var channel = form.find('input:hidden[name=zp_channel_id]').val()
      var fullName = form.find("input:hidden[name='full_name']").val()
      var birthday = form.find('input:hidden[name=birthday]').val()
      var gender = form.find("input:hidden[name=gender]").val()
      var targetFullName = form.find("input:hidden[name='target_full_name']").val()
      var targetBirthday = form.find('input:hidden[name=target_birthday]').val()
      var targetGender = form.find('input:hidden[name=target_gender]').val()

      if (paymentSystemName == "minori") {
        var url = location.href;
        var env = url.match("dev") ? 'https://dev.rensa.jp.net' : 'https://rensa.jp.net';
        $.ajax({
          type: "POST",
          url: env + "https://honkaku-uranai.jp/cp_rsa/yumecakra_rsa/result/life001", //本番環境用
          //url: "http://localhost/maki/minori/result/life001",//テスト用
          data: {
            "isNomalPayment": true,
            "itemcd": itemcd,
            "howToBuy": "partlyAppraisalButton",
            "full_name": fullName,
            "birthday": birthday,
            "gender": gender,
            "target_full_name": targetFullName,
            "target_birthday": targetBirthday,
            "target_gender": targetGender,
            "TerminalModel": "pc"
          },
          dataType: "html"
        }).done(function(data) {
          console.log(data);
          var dom_parser = new DOMParser();
          var retensionResultDataId = dom_parser.parseFromString(data, "text/html").getElementById("retensionResultData").innerHTML
          $("[name=retensionResultDataId]").val(retensionResultDataId.split("__rid__")[1])
          form.attr("method", "post")
          form.attr("action", "https://zap-happyfortune.rensa.jp.net/cocoloni/yumecakra_rsa/result/").submit();
          processing = false;
        }).fail(function() {
          alert("通信に失敗しました");
          processing = false;
        });
      } else if (paymentSystemName == "cocoloni" || paymentSystemName == "cp_rsa") {
        let postUrl = "";
        let locationUri = location.hostname;
        switch (locationUri) {
            case "honkaku-uranai.jp":
                postUrl = "https://honkaku-uranai.jp/cp_rsa/yumecakra_rsa/result";
                break;
            case "test-honkaku.cocoloni.jp":
                postUrl = "https://test-honkaku.cocoloni.jp/cp_rsa/yumecakra_rsa/result";
                break;
            default:
                postUrl = "http://localhost/cocoloni/yumecakra_rsa/result/life001";
        };
        let time = form.find("input[name='time']").val();
        $.ajax({
          type: "POST",
          url: postUrl,
          data: {
            "ajaxParameter": true,
            "itemcd": itemcd,
            "zp_channel_id": channel,
            "time": time,
            "full_name": fullName,
            "birthday": birthday,
            "gender": gender,
            "target_full_name": targetFullName,
            "target_birthday": targetBirthday,
            "target_gender": targetGender,
            "TerminalModel": "pc",
            "howToBuy": "paymentAppraisalButton",
          }
        }).done(function(data) {
          var dataValue = JSON.parse(data)
          var zp_channel_id = dataValue.zp_channel_id
          var zp_sid = dataValue.zp_sid
          var zp_sig = dataValue.zp_sig
          processing = false;
          if (location.hostname.includes("test-honkaku.cocoloni.jp") !== false) {
            window.location.href = "https://test-honkaku.cocoloni.jp/portal/charge/?zp_cp_name=cp_rsa&zp_channel_id=" + zp_channel_id + "&zp_sid=" + zp_sid + "&zp_sig=" + zp_sig
          } else {
            window.location.href = "https://honkaku-uranai.jp/portal/charge/?zp_cp_name=cp_rsa&zp_channel_id=" + zp_channel_id + "&zp_sid=" + zp_sid + "&zp_sig=" + zp_sig
          }
        }).fail(function() {
          alert("通信に失敗しました");
          processing = false;
        });
      }
    })
  };
</script>      </div>
</section>                      
<!-- caption start -->
<img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/result_subheading_top.jpg" style="width: 100%; vertical-align: bottom;">
<div class="result_subheading_background_center">
  <p>今から3年後、あなたはどんな日常を送っている？</p>
</div>
<img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/result_subheading_bottom.jpg" style="width: 100%; vertical-align: top;">
<!-- caption end -->

<section id="normalSection">
  <div class="result_description_background_center">
                <style>
  .charge_transition_screen_button {
    width: 308px;
    height: 104px;
    padding: 0;
    border: none;
    outline: none;
    cursor: pointer;
  }

  .charge_transition_screen_button img {
    width: 100%;
    height: 100%;
    border: none;
  }

  .mosaic_text_background {
    background: url("https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/result_mosaic_text.png") no-repeat;
    background-size: 115% 100%;
    background-position: center;
    width: 100%;
    height: 180px;
    text-align: center;
    padding-top: 10%;
  }

  .graph_charge_transition_screen_button {
    height: 125px;
    width: 375px;
    padding: 0;
    border: none;
    outline: none;
    cursor: pointer;
  }

  .graph_charge_transition_screen_button img {
    width: 100%;
  }
</style>

<form method="post" accept-charset="euc-jp" id="buyMoreProfileForm" action="https://zap-happyfortune.rensa.jp.net/cocoloni/yumecakra_rsa/result/"><div style="display:none;"><input type="hidden" name="_method" value="POST"/></div><input type="hidden" name="itemcd" value="life001"/><input type="hidden" name="howToBuy" value="paymentAppraisalButton"/><input type="hidden" name="TerminalModel" value="pc"/><input type="hidden" name="time" value=""/><input type="hidden" name="zp_channel_id" value="105_yc0004a"/><input type="hidden" name="contentKey" value="CYC"/><input type="hidden" name="full_name" value="あ"/><input type="hidden" name="birthday" value="1976-08-17"/><input type="hidden" name="gender" value="F"/>  <div class="mosaic_text_background">
    <button type="button" class="charge_transition_screen_button" name="paymentAppraisalButtonOfAjax">
      <img loading="lazy" alt="続きを見る(有料)" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/charge_transition_screen_button.png" onmouseover="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/charge_transition_screen_button_over.png'" onmouseout="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/charge_transition_screen_button.png'">
    </button>
  </div>
</form>
<script>
  window.onload = () => {
    var processing = false;
    $('button[name=paymentAppraisalButtonOfAjax]').on('click', function() {
      if (processing) {
        return;
      }
      processing = true;
      var paymentSystemName = 'cocoloni';
      var form = $(this).parents("form");
      var itemcd = form.find('input:hidden[name=itemcd]').val()
      var channel = form.find('input:hidden[name=zp_channel_id]').val()
      var fullName = form.find("input:hidden[name='full_name']").val()
      var birthday = form.find('input:hidden[name=birthday]').val()
      var gender = form.find("input:hidden[name=gender]").val()
      var targetFullName = form.find("input:hidden[name='target_full_name']").val()
      var targetBirthday = form.find('input:hidden[name=target_birthday]').val()
      var targetGender = form.find('input:hidden[name=target_gender]').val()

      if (paymentSystemName == "minori") {
        var url = location.href;
        var env = url.match("dev") ? 'https://dev.rensa.jp.net' : 'https://rensa.jp.net';
        $.ajax({
          type: "POST",
          url: env + "https://honkaku-uranai.jp/cp_rsa/yumecakra_rsa/result/life001", //本番環境用
          //url: "http://localhost/maki/minori/result/life001",//テスト用
          data: {
            "isNomalPayment": true,
            "itemcd": itemcd,
            "howToBuy": "partlyAppraisalButton",
            "full_name": fullName,
            "birthday": birthday,
            "gender": gender,
            "target_full_name": targetFullName,
            "target_birthday": targetBirthday,
            "target_gender": targetGender,
            "TerminalModel": "pc"
          },
          dataType: "html"
        }).done(function(data) {
          console.log(data);
          var dom_parser = new DOMParser();
          var retensionResultDataId = dom_parser.parseFromString(data, "text/html").getElementById("retensionResultData").innerHTML
          $("[name=retensionResultDataId]").val(retensionResultDataId.split("__rid__")[1])
          form.attr("method", "post")
          form.attr("action", "https://zap-happyfortune.rensa.jp.net/cocoloni/yumecakra_rsa/result/").submit();
          processing = false;
        }).fail(function() {
          alert("通信に失敗しました");
          processing = false;
        });
      } else if (paymentSystemName == "cocoloni" || paymentSystemName == "cp_rsa") {
        let postUrl = "";
        let locationUri = location.hostname;
        switch (locationUri) {
            case "honkaku-uranai.jp":
                postUrl = "https://honkaku-uranai.jp/cp_rsa/yumecakra_rsa/result";
                break;
            case "test-honkaku.cocoloni.jp":
                postUrl = "https://test-honkaku.cocoloni.jp/cp_rsa/yumecakra_rsa/result";
                break;
            default:
                postUrl = "http://localhost/cocoloni/yumecakra_rsa/result/life001";
        };
        let time = form.find("input[name='time']").val();
        $.ajax({
          type: "POST",
          url: postUrl,
          data: {
            "ajaxParameter": true,
            "itemcd": itemcd,
            "zp_channel_id": channel,
            "time": time,
            "full_name": fullName,
            "birthday": birthday,
            "gender": gender,
            "target_full_name": targetFullName,
            "target_birthday": targetBirthday,
            "target_gender": targetGender,
            "TerminalModel": "pc",
            "howToBuy": "paymentAppraisalButton",
          }
        }).done(function(data) {
          var dataValue = JSON.parse(data)
          var zp_channel_id = dataValue.zp_channel_id
          var zp_sid = dataValue.zp_sid
          var zp_sig = dataValue.zp_sig
          processing = false;
          if (location.hostname.includes("test-honkaku.cocoloni.jp") !== false) {
            window.location.href = "https://test-honkaku.cocoloni.jp/portal/charge/?zp_cp_name=cp_rsa&zp_channel_id=" + zp_channel_id + "&zp_sid=" + zp_sid + "&zp_sig=" + zp_sig
          } else {
            window.location.href = "https://honkaku-uranai.jp/portal/charge/?zp_cp_name=cp_rsa&zp_channel_id=" + zp_channel_id + "&zp_sid=" + zp_sid + "&zp_sig=" + zp_sig
          }
        }).fail(function() {
          alert("通信に失敗しました");
          processing = false;
        });
      }
    })
  };
</script>      </div>
</section>                      
<!-- caption start -->
<img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/result_subheading_top.jpg" style="width: 100%; vertical-align: bottom;">
<div class="result_subheading_background_center">
  <p>今から5年後、あなたが何を得て人生を歩んでいるのか</p>
</div>
<img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/result_subheading_bottom.jpg" style="width: 100%; vertical-align: top;">
<!-- caption end -->

<section id="normalSection">
  <div class="result_description_background_center">
                <style>
  .charge_transition_screen_button {
    width: 308px;
    height: 104px;
    padding: 0;
    border: none;
    outline: none;
    cursor: pointer;
  }

  .charge_transition_screen_button img {
    width: 100%;
    height: 100%;
    border: none;
  }

  .mosaic_text_background {
    background: url("https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/result_mosaic_text.png") no-repeat;
    background-size: 115% 100%;
    background-position: center;
    width: 100%;
    height: 180px;
    text-align: center;
    padding-top: 10%;
  }

  .graph_charge_transition_screen_button {
    height: 125px;
    width: 375px;
    padding: 0;
    border: none;
    outline: none;
    cursor: pointer;
  }

  .graph_charge_transition_screen_button img {
    width: 100%;
  }
</style>

<form method="post" accept-charset="euc-jp" id="buyMoreProfileForm" action="https://zap-happyfortune.rensa.jp.net/cocoloni/yumecakra_rsa/result/"><div style="display:none;"><input type="hidden" name="_method" value="POST"/></div><input type="hidden" name="itemcd" value="life001"/><input type="hidden" name="howToBuy" value="paymentAppraisalButton"/><input type="hidden" name="TerminalModel" value="pc"/><input type="hidden" name="time" value=""/><input type="hidden" name="zp_channel_id" value="105_yc0004a"/><input type="hidden" name="contentKey" value="CYC"/><input type="hidden" name="full_name" value="あ"/><input type="hidden" name="birthday" value="1976-08-17"/><input type="hidden" name="gender" value="F"/>  <div class="mosaic_text_background">
    <button type="button" class="charge_transition_screen_button" name="paymentAppraisalButtonOfAjax">
      <img loading="lazy" alt="続きを見る(有料)" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/charge_transition_screen_button.png" onmouseover="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/charge_transition_screen_button_over.png'" onmouseout="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/charge_transition_screen_button.png'">
    </button>
  </div>
</form>
<script>
  window.onload = () => {
    var processing = false;
    $('button[name=paymentAppraisalButtonOfAjax]').on('click', function() {
      if (processing) {
        return;
      }
      processing = true;
      var paymentSystemName = 'cocoloni';
      var form = $(this).parents("form");
      var itemcd = form.find('input:hidden[name=itemcd]').val()
      var channel = form.find('input:hidden[name=zp_channel_id]').val()
      var fullName = form.find("input:hidden[name='full_name']").val()
      var birthday = form.find('input:hidden[name=birthday]').val()
      var gender = form.find("input:hidden[name=gender]").val()
      var targetFullName = form.find("input:hidden[name='target_full_name']").val()
      var targetBirthday = form.find('input:hidden[name=target_birthday]').val()
      var targetGender = form.find('input:hidden[name=target_gender]').val()

      if (paymentSystemName == "minori") {
        var url = location.href;
        var env = url.match("dev") ? 'https://dev.rensa.jp.net' : 'https://rensa.jp.net';
        $.ajax({
          type: "POST",
          url: env + "https://honkaku-uranai.jp/cp_rsa/yumecakra_rsa/result/life001", //本番環境用
          //url: "http://localhost/maki/minori/result/life001",//テスト用
          data: {
            "isNomalPayment": true,
            "itemcd": itemcd,
            "howToBuy": "partlyAppraisalButton",
            "full_name": fullName,
            "birthday": birthday,
            "gender": gender,
            "target_full_name": targetFullName,
            "target_birthday": targetBirthday,
            "target_gender": targetGender,
            "TerminalModel": "pc"
          },
          dataType: "html"
        }).done(function(data) {
          console.log(data);
          var dom_parser = new DOMParser();
          var retensionResultDataId = dom_parser.parseFromString(data, "text/html").getElementById("retensionResultData").innerHTML
          $("[name=retensionResultDataId]").val(retensionResultDataId.split("__rid__")[1])
          form.attr("method", "post")
          form.attr("action", "https://zap-happyfortune.rensa.jp.net/cocoloni/yumecakra_rsa/result/").submit();
          processing = false;
        }).fail(function() {
          alert("通信に失敗しました");
          processing = false;
        });
      } else if (paymentSystemName == "cocoloni" || paymentSystemName == "cp_rsa") {
        let postUrl = "";
        let locationUri = location.hostname;
        switch (locationUri) {
            case "honkaku-uranai.jp":
                postUrl = "https://honkaku-uranai.jp/cp_rsa/yumecakra_rsa/result";
                break;
            case "test-honkaku.cocoloni.jp":
                postUrl = "https://test-honkaku.cocoloni.jp/cp_rsa/yumecakra_rsa/result";
                break;
            default:
                postUrl = "http://localhost/cocoloni/yumecakra_rsa/result/life001";
        };
        let time = form.find("input[name='time']").val();
        $.ajax({
          type: "POST",
          url: postUrl,
          data: {
            "ajaxParameter": true,
            "itemcd": itemcd,
            "zp_channel_id": channel,
            "time": time,
            "full_name": fullName,
            "birthday": birthday,
            "gender": gender,
            "target_full_name": targetFullName,
            "target_birthday": targetBirthday,
            "target_gender": targetGender,
            "TerminalModel": "pc",
            "howToBuy": "paymentAppraisalButton",
          }
        }).done(function(data) {
          var dataValue = JSON.parse(data)
          var zp_channel_id = dataValue.zp_channel_id
          var zp_sid = dataValue.zp_sid
          var zp_sig = dataValue.zp_sig
          processing = false;
          if (location.hostname.includes("test-honkaku.cocoloni.jp") !== false) {
            window.location.href = "https://test-honkaku.cocoloni.jp/portal/charge/?zp_cp_name=cp_rsa&zp_channel_id=" + zp_channel_id + "&zp_sid=" + zp_sid + "&zp_sig=" + zp_sig
          } else {
            window.location.href = "https://honkaku-uranai.jp/portal/charge/?zp_cp_name=cp_rsa&zp_channel_id=" + zp_channel_id + "&zp_sid=" + zp_sid + "&zp_sig=" + zp_sig
          }
        }).fail(function() {
          alert("通信に失敗しました");
          processing = false;
        });
      }
    })
  };
</script>      </div>
</section>                      
<!-- caption start -->
<img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/result_subheading_top.jpg" style="width: 100%; vertical-align: bottom;">
<div class="result_subheading_background_center">
  <p>今から10年後、あなたが人生で築き上げているもの</p>
</div>
<img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/result_subheading_bottom.jpg" style="width: 100%; vertical-align: top;">
<!-- caption end -->

<section id="normalSection">
  <div class="result_description_background_center">
                <style>
  .charge_transition_screen_button {
    width: 308px;
    height: 104px;
    padding: 0;
    border: none;
    outline: none;
    cursor: pointer;
  }

  .charge_transition_screen_button img {
    width: 100%;
    height: 100%;
    border: none;
  }

  .mosaic_text_background {
    background: url("https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/result_mosaic_text.png") no-repeat;
    background-size: 115% 100%;
    background-position: center;
    width: 100%;
    height: 180px;
    text-align: center;
    padding-top: 10%;
  }

  .graph_charge_transition_screen_button {
    height: 125px;
    width: 375px;
    padding: 0;
    border: none;
    outline: none;
    cursor: pointer;
  }

  .graph_charge_transition_screen_button img {
    width: 100%;
  }
</style>

<form method="post" accept-charset="euc-jp" id="buyMoreProfileForm" action="https://zap-happyfortune.rensa.jp.net/cocoloni/yumecakra_rsa/result/"><div style="display:none;"><input type="hidden" name="_method" value="POST"/></div><input type="hidden" name="itemcd" value="life001"/><input type="hidden" name="howToBuy" value="paymentAppraisalButton"/><input type="hidden" name="TerminalModel" value="pc"/><input type="hidden" name="time" value=""/><input type="hidden" name="zp_channel_id" value="105_yc0004a"/><input type="hidden" name="contentKey" value="CYC"/><input type="hidden" name="full_name" value="あ"/><input type="hidden" name="birthday" value="1976-08-17"/><input type="hidden" name="gender" value="F"/>  <div class="mosaic_text_background">
    <button type="button" class="charge_transition_screen_button" name="paymentAppraisalButtonOfAjax">
      <img loading="lazy" alt="続きを見る(有料)" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/charge_transition_screen_button.png" onmouseover="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/charge_transition_screen_button_over.png'" onmouseout="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/charge_transition_screen_button.png'">
    </button>
  </div>
</form>
<script>
  window.onload = () => {
    var processing = false;
    $('button[name=paymentAppraisalButtonOfAjax]').on('click', function() {
      if (processing) {
        return;
      }
      processing = true;
      var paymentSystemName = 'cocoloni';
      var form = $(this).parents("form");
      var itemcd = form.find('input:hidden[name=itemcd]').val()
      var channel = form.find('input:hidden[name=zp_channel_id]').val()
      var fullName = form.find("input:hidden[name='full_name']").val()
      var birthday = form.find('input:hidden[name=birthday]').val()
      var gender = form.find("input:hidden[name=gender]").val()
      var targetFullName = form.find("input:hidden[name='target_full_name']").val()
      var targetBirthday = form.find('input:hidden[name=target_birthday]').val()
      var targetGender = form.find('input:hidden[name=target_gender]').val()

      if (paymentSystemName == "minori") {
        var url = location.href;
        var env = url.match("dev") ? 'https://dev.rensa.jp.net' : 'https://rensa.jp.net';
        $.ajax({
          type: "POST",
          url: env + "https://honkaku-uranai.jp/cp_rsa/yumecakra_rsa/result/life001", //本番環境用
          //url: "http://localhost/maki/minori/result/life001",//テスト用
          data: {
            "isNomalPayment": true,
            "itemcd": itemcd,
            "howToBuy": "partlyAppraisalButton",
            "full_name": fullName,
            "birthday": birthday,
            "gender": gender,
            "target_full_name": targetFullName,
            "target_birthday": targetBirthday,
            "target_gender": targetGender,
            "TerminalModel": "pc"
          },
          dataType: "html"
        }).done(function(data) {
          console.log(data);
          var dom_parser = new DOMParser();
          var retensionResultDataId = dom_parser.parseFromString(data, "text/html").getElementById("retensionResultData").innerHTML
          $("[name=retensionResultDataId]").val(retensionResultDataId.split("__rid__")[1])
          form.attr("method", "post")
          form.attr("action", "https://zap-happyfortune.rensa.jp.net/cocoloni/yumecakra_rsa/result/").submit();
          processing = false;
        }).fail(function() {
          alert("通信に失敗しました");
          processing = false;
        });
      } else if (paymentSystemName == "cocoloni" || paymentSystemName == "cp_rsa") {
        let postUrl = "";
        let locationUri = location.hostname;
        switch (locationUri) {
            case "honkaku-uranai.jp":
                postUrl = "https://honkaku-uranai.jp/cp_rsa/yumecakra_rsa/result";
                break;
            case "test-honkaku.cocoloni.jp":
                postUrl = "https://test-honkaku.cocoloni.jp/cp_rsa/yumecakra_rsa/result";
                break;
            default:
                postUrl = "http://localhost/cocoloni/yumecakra_rsa/result/life001";
        };
        let time = form.find("input[name='time']").val();
        $.ajax({
          type: "POST",
          url: postUrl,
          data: {
            "ajaxParameter": true,
            "itemcd": itemcd,
            "zp_channel_id": channel,
            "time": time,
            "full_name": fullName,
            "birthday": birthday,
            "gender": gender,
            "target_full_name": targetFullName,
            "target_birthday": targetBirthday,
            "target_gender": targetGender,
            "TerminalModel": "pc",
            "howToBuy": "paymentAppraisalButton",
          }
        }).done(function(data) {
          var dataValue = JSON.parse(data)
          var zp_channel_id = dataValue.zp_channel_id
          var zp_sid = dataValue.zp_sid
          var zp_sig = dataValue.zp_sig
          processing = false;
          if (location.hostname.includes("test-honkaku.cocoloni.jp") !== false) {
            window.location.href = "https://test-honkaku.cocoloni.jp/portal/charge/?zp_cp_name=cp_rsa&zp_channel_id=" + zp_channel_id + "&zp_sid=" + zp_sid + "&zp_sig=" + zp_sig
          } else {
            window.location.href = "https://honkaku-uranai.jp/portal/charge/?zp_cp_name=cp_rsa&zp_channel_id=" + zp_channel_id + "&zp_sid=" + zp_sid + "&zp_sig=" + zp_sig
          }
        }).fail(function() {
          alert("通信に失敗しました");
          processing = false;
        });
      }
    })
  };
</script>      </div>
</section>                      
<!-- caption start -->
<img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/result_subheading_top.jpg" style="width: 100%; vertical-align: bottom;">
<div class="result_subheading_background_center">
  <p>それまでの歩みから辿り着くあなたの晩年の暮らし</p>
</div>
<img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/result_subheading_bottom.jpg" style="width: 100%; vertical-align: top;">
<!-- caption end -->

<section id="normalSection">
  <div class="result_description_background_center">
                <style>
  .charge_transition_screen_button {
    width: 308px;
    height: 104px;
    padding: 0;
    border: none;
    outline: none;
    cursor: pointer;
  }

  .charge_transition_screen_button img {
    width: 100%;
    height: 100%;
    border: none;
  }

  .mosaic_text_background {
    background: url("https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/result_mosaic_text.png") no-repeat;
    background-size: 115% 100%;
    background-position: center;
    width: 100%;
    height: 180px;
    text-align: center;
    padding-top: 10%;
  }

  .graph_charge_transition_screen_button {
    height: 125px;
    width: 375px;
    padding: 0;
    border: none;
    outline: none;
    cursor: pointer;
  }

  .graph_charge_transition_screen_button img {
    width: 100%;
  }
</style>

<form method="post" accept-charset="euc-jp" id="buyMoreProfileForm" action="https://zap-happyfortune.rensa.jp.net/cocoloni/yumecakra_rsa/result/"><div style="display:none;"><input type="hidden" name="_method" value="POST"/></div><input type="hidden" name="itemcd" value="life001"/><input type="hidden" name="howToBuy" value="paymentAppraisalButton"/><input type="hidden" name="TerminalModel" value="pc"/><input type="hidden" name="time" value=""/><input type="hidden" name="zp_channel_id" value="105_yc0004a"/><input type="hidden" name="contentKey" value="CYC"/><input type="hidden" name="full_name" value="あ"/><input type="hidden" name="birthday" value="1976-08-17"/><input type="hidden" name="gender" value="F"/>  <div class="mosaic_text_background">
    <button type="button" class="charge_transition_screen_button" name="paymentAppraisalButtonOfAjax">
      <img loading="lazy" alt="続きを見る(有料)" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/charge_transition_screen_button.png" onmouseover="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/charge_transition_screen_button_over.png'" onmouseout="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/charge_transition_screen_button.png'">
    </button>
  </div>
</form>
<script>
  window.onload = () => {
    var processing = false;
    $('button[name=paymentAppraisalButtonOfAjax]').on('click', function() {
      if (processing) {
        return;
      }
      processing = true;
      var paymentSystemName = 'cocoloni';
      var form = $(this).parents("form");
      var itemcd = form.find('input:hidden[name=itemcd]').val()
      var channel = form.find('input:hidden[name=zp_channel_id]').val()
      var fullName = form.find("input:hidden[name='full_name']").val()
      var birthday = form.find('input:hidden[name=birthday]').val()
      var gender = form.find("input:hidden[name=gender]").val()
      var targetFullName = form.find("input:hidden[name='target_full_name']").val()
      var targetBirthday = form.find('input:hidden[name=target_birthday]').val()
      var targetGender = form.find('input:hidden[name=target_gender]').val()

      if (paymentSystemName == "minori") {
        var url = location.href;
        var env = url.match("dev") ? 'https://dev.rensa.jp.net' : 'https://rensa.jp.net';
        $.ajax({
          type: "POST",
          url: env + "https://honkaku-uranai.jp/cp_rsa/yumecakra_rsa/result/life001", //本番環境用
          //url: "http://localhost/maki/minori/result/life001",//テスト用
          data: {
            "isNomalPayment": true,
            "itemcd": itemcd,
            "howToBuy": "partlyAppraisalButton",
            "full_name": fullName,
            "birthday": birthday,
            "gender": gender,
            "target_full_name": targetFullName,
            "target_birthday": targetBirthday,
            "target_gender": targetGender,
            "TerminalModel": "pc"
          },
          dataType: "html"
        }).done(function(data) {
          console.log(data);
          var dom_parser = new DOMParser();
          var retensionResultDataId = dom_parser.parseFromString(data, "text/html").getElementById("retensionResultData").innerHTML
          $("[name=retensionResultDataId]").val(retensionResultDataId.split("__rid__")[1])
          form.attr("method", "post")
          form.attr("action", "https://zap-happyfortune.rensa.jp.net/cocoloni/yumecakra_rsa/result/").submit();
          processing = false;
        }).fail(function() {
          alert("通信に失敗しました");
          processing = false;
        });
      } else if (paymentSystemName == "cocoloni" || paymentSystemName == "cp_rsa") {
        let postUrl = "";
        let locationUri = location.hostname;
        switch (locationUri) {
            case "honkaku-uranai.jp":
                postUrl = "https://honkaku-uranai.jp/cp_rsa/yumecakra_rsa/result";
                break;
            case "test-honkaku.cocoloni.jp":
                postUrl = "https://test-honkaku.cocoloni.jp/cp_rsa/yumecakra_rsa/result";
                break;
            default:
                postUrl = "http://localhost/cocoloni/yumecakra_rsa/result/life001";
        };
        let time = form.find("input[name='time']").val();
        $.ajax({
          type: "POST",
          url: postUrl,
          data: {
            "ajaxParameter": true,
            "itemcd": itemcd,
            "zp_channel_id": channel,
            "time": time,
            "full_name": fullName,
            "birthday": birthday,
            "gender": gender,
            "target_full_name": targetFullName,
            "target_birthday": targetBirthday,
            "target_gender": targetGender,
            "TerminalModel": "pc",
            "howToBuy": "paymentAppraisalButton",
          }
        }).done(function(data) {
          var dataValue = JSON.parse(data)
          var zp_channel_id = dataValue.zp_channel_id
          var zp_sid = dataValue.zp_sid
          var zp_sig = dataValue.zp_sig
          processing = false;
          if (location.hostname.includes("test-honkaku.cocoloni.jp") !== false) {
            window.location.href = "https://test-honkaku.cocoloni.jp/portal/charge/?zp_cp_name=cp_rsa&zp_channel_id=" + zp_channel_id + "&zp_sid=" + zp_sid + "&zp_sig=" + zp_sig
          } else {
            window.location.href = "https://honkaku-uranai.jp/portal/charge/?zp_cp_name=cp_rsa&zp_channel_id=" + zp_channel_id + "&zp_sid=" + zp_sid + "&zp_sig=" + zp_sig
          }
        }).fail(function() {
          alert("通信に失敗しました");
          processing = false;
        });
      }
    })
  };
</script>      </div>
</section>                      
<img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/top/line.png" style="width: 100%;">

<!--　特殊枠7（YESNO）　-->
<section id="yes_no_section">
  <!-- 背景画像 -->
  <div class="beginning_text_background">
    <!-- 冒頭文 -->
    <div class="beginning_text_balloon">
      <p>あなたのチャクラから読み取った、“この先”を左右する問題や気になる点について「YES」か「NO」その2つでハッキリとお答えいたします。</p>
    </div>
  </div>

  <!-- 見出し -->
  <img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/result_subheading_top.jpg" style="width: 100%; vertical-align: bottom;">
  <div class="result_subheading_background_center">
    <p>あなたは生涯を通して大きなものを成し遂げる？</p>
  </div>
  <img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/result_subheading_bottom.jpg" style="width: 100%; vertical-align: top;">

  <!-- vue start -->
  <div id="yes_no_32" class="yes_no">
    <yes-no
      result="[&quot;YESNO&quot;,&quot;\u3042\u306a\u305f\u306e\u30c1\u30e3\u30af\u30e9\u304b\u3089\u8aad\u307f\u53d6\u3063\u305f\u3001\u201c\u3053\u306e\u5148\u201d\u3092\u5de6\u53f3\u3059\u308b\u554f\u984c\u3084\u6c17\u306b\u306a\u308b\u70b9\u306b\u3064\u3044\u3066\u300cYES\u300d\u304b\u300cNO\u300d\u305d\u306e2\u3064\u3067\u30cf\u30c3\u30ad\u30ea\u3068\u304a\u7b54\u3048\u3044\u305f\u3057\u307e\u3059\u3002&quot;,&quot;\u30c1\u30e3\u30af\u30e9\u304b\u3089&lt;br&gt;\u8996\u3048\u305f\u7b54\u3048\u306f&lt;br&gt;XXX\u3067\u3059&quot;,&quot;\u30c1\u30e3\u30af\u30e9\u304b\u3089&lt;br&gt;\u8996\u3048\u305f\u7b54\u3048\u306f&lt;br&gt;YES\u3067\u3059&quot;,&quot;&amp;emsp;\u3042\u306a\u305f\u306f\u3053\u306e\u4eba\u751f\u3092\u901a\u3057\u3066\u3001\u3084\u308a\u305f\u3044\u4ed5\u4e8b\u3092\u601d\u3044\u304d\u308a\u697d\u3057\u3080\u3053\u3068\u304c\u51fa\u6765\u308b\u3067\u3057\u3087\u3046\u3002\u3042\u3055\u30931\u4eba\u306e\u4ed5\u4e8b\u3067\u4e16\u306e\u4e2d\u3092\u52d5\u304b\u3059\u3053\u3068\u306f&quot;,&quot;&amp;emsp;\u3042\u306a\u305f\u306f\u3053\u306e\u4eba\u751f\u3092\u901a\u3057\u3066\u3001\u3084\u308a\u305f\u3044\u4ed5\u4e8b\u3092\u601d\u3044\u304d\u308a\u697d\u3057\u3080\u3053\u3068\u304c\u51fa\u6765\u308b\u3067\u3057\u3087\u3046\u3002\u3042\u3055\u30931\u4eba\u306e\u4ed5\u4e8b\u3067\u4e16\u306e\u4e2d\u3092\u52d5\u304b\u3059\u3053\u3068\u306f\u96e3\u3057\u3044\u304b\u3082\u3057\u308c\u307e\u305b\u3093\u304c\u3001\u305d\u308c\u3067\u3082\u8eab\u8fd1\u306a\u4eba\u305f\u3061\u3068\u306e\u89aa\u3057\u3044\u95a2\u4fc2\u306e\u4e2d\u3067\u3001\u304a\u4e92\u3044\u304c\u826f\u3044\u5f71\u97ff\u3092\u4e0e\u3048\u3042\u3063\u3066\u5e78\u305b\u3092\u5b9f\u611f\u3057\u3066\u3044\u307e\u3059\u3002&lt;br&gt;&lt;br&gt;\u3000\u307e\u305f\u3001\u5bb6\u65cf\u306a\u3069\u306e\u5927\u5207\u306a\u4eba\u3068\u306e\u95a2\u4fc2\u3082\u826f\u597d\u3067\u3001\u3068\u304d\u306b\u306f\u55a7\u5629\u3092\u3057\u305f\u308a\u3082\u3057\u307e\u3059\u304c\u3001\u56f0\u3063\u305f\u6642\u306b\u306f\u652f\u3048\u3042\u3044\u3001\u6fc3\u5bc6\u306a\u6642\u9593\u3092\u904e\u3054\u3057\u3066\u3044\u304f\u3067\u3057\u3087\u3046\u3002&lt;br&gt;&lt;br&gt;\u3000\u53cb\u4eba\u305f\u3061\u3068\u3082\u9069\u5ea6\u306a\u8ddd\u96e2\u611f\u3092\u4fdd\u3061\u306a\u304c\u3089\u3001\u4e00\u7dd2\u306b\u540c\u3058\u6642\u4ee3\u3092\u99c6\u3051\u629c\u3051\u305f\u3053\u3068\u3092\u8a87\u308a\u306b\u601d\u3044\u3042\u3046\u3067\u3057\u3087\u3046\u3002\u305f\u304f\u3055\u3093\u306e\u7d4c\u9a13\u3092\u5171\u6709\u3057\u3042\u3063\u305f\u53cb\u4eba\u305f\u3061\u3068\u3001\u601d\u3044\u51fa\u8a71\u306b\u82b1\u3092\u54b2\u304b\u305b\u3066\u6bce\u65e5\u3092\u697d\u3057\u304f\u904e\u3054\u3057\u307e\u3059\u3002\u3042\u306a\u305f\u306f\u3001\u81ea\u5206\u306e\u529b\u3067\u81ea\u5206\u81ea\u8eab\u3092\u5e78\u305b\u306b\u3059\u308b\u3053\u3068\u304c\u51fa\u6765\u308b\u7d20\u6674\u3089\u3057\u3044\u4e00\u751f\u3092\u9001\u308b\u306e\u3067\u3059\u3002&quot;]"
      how-to-buy-flag="&quot;partlyAppraisalButton1&quot;"
      index-number="32"
    />
  </div>
  <!-- vue end -->

  <!-- 原稿 -->
  <div id="yes_no_manuscript_32" class="manuscript_display_none">
    <div class="result_description_background_center">
              &emsp;あなたはこの人生を通して、やりたい仕事を思いきり楽しむことが出来るでしょう。あさん1人の仕事で世の中を動かすことは……        <style>
  .charge_transition_screen_button {
    width: 308px;
    height: 104px;
    padding: 0;
    border: none;
    outline: none;
    cursor: pointer;
  }

  .charge_transition_screen_button img {
    width: 100%;
    height: 100%;
    border: none;
  }

  .mosaic_text_background {
    background: url("https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/result_mosaic_text.png") no-repeat;
    background-size: 115% 100%;
    background-position: center;
    width: 100%;
    height: 180px;
    text-align: center;
    padding-top: 10%;
  }

  .graph_charge_transition_screen_button {
    height: 125px;
    width: 375px;
    padding: 0;
    border: none;
    outline: none;
    cursor: pointer;
  }

  .graph_charge_transition_screen_button img {
    width: 100%;
  }
</style>

<form method="post" accept-charset="euc-jp" id="buyMoreProfileForm" action="https://zap-happyfortune.rensa.jp.net/cocoloni/yumecakra_rsa/result/"><div style="display:none;"><input type="hidden" name="_method" value="POST"/></div><input type="hidden" name="itemcd" value="life001"/><input type="hidden" name="howToBuy" value="paymentAppraisalButton"/><input type="hidden" name="TerminalModel" value="pc"/><input type="hidden" name="time" value=""/><input type="hidden" name="zp_channel_id" value="105_yc0004a"/><input type="hidden" name="contentKey" value="CYC"/><input type="hidden" name="full_name" value="あ"/><input type="hidden" name="birthday" value="1976-08-17"/><input type="hidden" name="gender" value="F"/>  <div class="mosaic_text_background">
    <button type="button" class="charge_transition_screen_button" name="paymentAppraisalButtonOfAjax">
      <img loading="lazy" alt="続きを見る(有料)" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/charge_transition_screen_button.png" onmouseover="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/charge_transition_screen_button_over.png'" onmouseout="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/charge_transition_screen_button.png'">
    </button>
  </div>
</form>
<script>
  window.onload = () => {
    var processing = false;
    $('button[name=paymentAppraisalButtonOfAjax]').on('click', function() {
      if (processing) {
        return;
      }
      processing = true;
      var paymentSystemName = 'cocoloni';
      var form = $(this).parents("form");
      var itemcd = form.find('input:hidden[name=itemcd]').val()
      var channel = form.find('input:hidden[name=zp_channel_id]').val()
      var fullName = form.find("input:hidden[name='full_name']").val()
      var birthday = form.find('input:hidden[name=birthday]').val()
      var gender = form.find("input:hidden[name=gender]").val()
      var targetFullName = form.find("input:hidden[name='target_full_name']").val()
      var targetBirthday = form.find('input:hidden[name=target_birthday]').val()
      var targetGender = form.find('input:hidden[name=target_gender]').val()

      if (paymentSystemName == "minori") {
        var url = location.href;
        var env = url.match("dev") ? 'https://dev.rensa.jp.net' : 'https://rensa.jp.net';
        $.ajax({
          type: "POST",
          url: env + "https://honkaku-uranai.jp/cp_rsa/yumecakra_rsa/result/life001", //本番環境用
          //url: "http://localhost/maki/minori/result/life001",//テスト用
          data: {
            "isNomalPayment": true,
            "itemcd": itemcd,
            "howToBuy": "partlyAppraisalButton",
            "full_name": fullName,
            "birthday": birthday,
            "gender": gender,
            "target_full_name": targetFullName,
            "target_birthday": targetBirthday,
            "target_gender": targetGender,
            "TerminalModel": "pc"
          },
          dataType: "html"
        }).done(function(data) {
          console.log(data);
          var dom_parser = new DOMParser();
          var retensionResultDataId = dom_parser.parseFromString(data, "text/html").getElementById("retensionResultData").innerHTML
          $("[name=retensionResultDataId]").val(retensionResultDataId.split("__rid__")[1])
          form.attr("method", "post")
          form.attr("action", "https://zap-happyfortune.rensa.jp.net/cocoloni/yumecakra_rsa/result/").submit();
          processing = false;
        }).fail(function() {
          alert("通信に失敗しました");
          processing = false;
        });
      } else if (paymentSystemName == "cocoloni" || paymentSystemName == "cp_rsa") {
        let postUrl = "";
        let locationUri = location.hostname;
        switch (locationUri) {
            case "honkaku-uranai.jp":
                postUrl = "https://honkaku-uranai.jp/cp_rsa/yumecakra_rsa/result";
                break;
            case "test-honkaku.cocoloni.jp":
                postUrl = "https://test-honkaku.cocoloni.jp/cp_rsa/yumecakra_rsa/result";
                break;
            default:
                postUrl = "http://localhost/cocoloni/yumecakra_rsa/result/life001";
        };
        let time = form.find("input[name='time']").val();
        $.ajax({
          type: "POST",
          url: postUrl,
          data: {
            "ajaxParameter": true,
            "itemcd": itemcd,
            "zp_channel_id": channel,
            "time": time,
            "full_name": fullName,
            "birthday": birthday,
            "gender": gender,
            "target_full_name": targetFullName,
            "target_birthday": targetBirthday,
            "target_gender": targetGender,
            "TerminalModel": "pc",
            "howToBuy": "paymentAppraisalButton",
          }
        }).done(function(data) {
          var dataValue = JSON.parse(data)
          var zp_channel_id = dataValue.zp_channel_id
          var zp_sid = dataValue.zp_sid
          var zp_sig = dataValue.zp_sig
          processing = false;
          if (location.hostname.includes("test-honkaku.cocoloni.jp") !== false) {
            window.location.href = "https://test-honkaku.cocoloni.jp/portal/charge/?zp_cp_name=cp_rsa&zp_channel_id=" + zp_channel_id + "&zp_sid=" + zp_sid + "&zp_sig=" + zp_sig
          } else {
            window.location.href = "https://honkaku-uranai.jp/portal/charge/?zp_cp_name=cp_rsa&zp_channel_id=" + zp_channel_id + "&zp_sid=" + zp_sid + "&zp_sig=" + zp_sig
          }
        }).fail(function() {
          alert("通信に失敗しました");
          processing = false;
        });
      }
    })
  };
</script>          </div>
  </div>
</section>                      
<!-- caption start -->
<img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/result_subheading_top.jpg" style="width: 100%; vertical-align: bottom;">
<div class="result_subheading_background_center">
  <p>より実りある晩年の生活を送れるように今からできること</p>
</div>
<img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/result_subheading_bottom.jpg" style="width: 100%; vertical-align: top;">
<!-- caption end -->

<section id="normalSection">
  <div class="result_description_background_center">
                <style>
  .charge_transition_screen_button {
    width: 308px;
    height: 104px;
    padding: 0;
    border: none;
    outline: none;
    cursor: pointer;
  }

  .charge_transition_screen_button img {
    width: 100%;
    height: 100%;
    border: none;
  }

  .mosaic_text_background {
    background: url("https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/result_mosaic_text.png") no-repeat;
    background-size: 115% 100%;
    background-position: center;
    width: 100%;
    height: 180px;
    text-align: center;
    padding-top: 10%;
  }

  .graph_charge_transition_screen_button {
    height: 125px;
    width: 375px;
    padding: 0;
    border: none;
    outline: none;
    cursor: pointer;
  }

  .graph_charge_transition_screen_button img {
    width: 100%;
  }
</style>

<form method="post" accept-charset="euc-jp" id="buyMoreProfileForm" action="https://zap-happyfortune.rensa.jp.net/cocoloni/yumecakra_rsa/result/"><div style="display:none;"><input type="hidden" name="_method" value="POST"/></div><input type="hidden" name="itemcd" value="life001"/><input type="hidden" name="howToBuy" value="paymentAppraisalButton"/><input type="hidden" name="TerminalModel" value="pc"/><input type="hidden" name="time" value=""/><input type="hidden" name="zp_channel_id" value="105_yc0004a"/><input type="hidden" name="contentKey" value="CYC"/><input type="hidden" name="full_name" value="あ"/><input type="hidden" name="birthday" value="1976-08-17"/><input type="hidden" name="gender" value="F"/>  <div class="mosaic_text_background">
    <button type="button" class="charge_transition_screen_button" name="paymentAppraisalButtonOfAjax">
      <img loading="lazy" alt="続きを見る(有料)" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/charge_transition_screen_button.png" onmouseover="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/charge_transition_screen_button_over.png'" onmouseout="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/charge_transition_screen_button.png'">
    </button>
  </div>
</form>
<script>
  window.onload = () => {
    var processing = false;
    $('button[name=paymentAppraisalButtonOfAjax]').on('click', function() {
      if (processing) {
        return;
      }
      processing = true;
      var paymentSystemName = 'cocoloni';
      var form = $(this).parents("form");
      var itemcd = form.find('input:hidden[name=itemcd]').val()
      var channel = form.find('input:hidden[name=zp_channel_id]').val()
      var fullName = form.find("input:hidden[name='full_name']").val()
      var birthday = form.find('input:hidden[name=birthday]').val()
      var gender = form.find("input:hidden[name=gender]").val()
      var targetFullName = form.find("input:hidden[name='target_full_name']").val()
      var targetBirthday = form.find('input:hidden[name=target_birthday]').val()
      var targetGender = form.find('input:hidden[name=target_gender]').val()

      if (paymentSystemName == "minori") {
        var url = location.href;
        var env = url.match("dev") ? 'https://dev.rensa.jp.net' : 'https://rensa.jp.net';
        $.ajax({
          type: "POST",
          url: env + "https://honkaku-uranai.jp/cp_rsa/yumecakra_rsa/result/life001", //本番環境用
          //url: "http://localhost/maki/minori/result/life001",//テスト用
          data: {
            "isNomalPayment": true,
            "itemcd": itemcd,
            "howToBuy": "partlyAppraisalButton",
            "full_name": fullName,
            "birthday": birthday,
            "gender": gender,
            "target_full_name": targetFullName,
            "target_birthday": targetBirthday,
            "target_gender": targetGender,
            "TerminalModel": "pc"
          },
          dataType: "html"
        }).done(function(data) {
          console.log(data);
          var dom_parser = new DOMParser();
          var retensionResultDataId = dom_parser.parseFromString(data, "text/html").getElementById("retensionResultData").innerHTML
          $("[name=retensionResultDataId]").val(retensionResultDataId.split("__rid__")[1])
          form.attr("method", "post")
          form.attr("action", "https://zap-happyfortune.rensa.jp.net/cocoloni/yumecakra_rsa/result/").submit();
          processing = false;
        }).fail(function() {
          alert("通信に失敗しました");
          processing = false;
        });
      } else if (paymentSystemName == "cocoloni" || paymentSystemName == "cp_rsa") {
        let postUrl = "";
        let locationUri = location.hostname;
        switch (locationUri) {
            case "honkaku-uranai.jp":
                postUrl = "https://honkaku-uranai.jp/cp_rsa/yumecakra_rsa/result";
                break;
            case "test-honkaku.cocoloni.jp":
                postUrl = "https://test-honkaku.cocoloni.jp/cp_rsa/yumecakra_rsa/result";
                break;
            default:
                postUrl = "http://localhost/cocoloni/yumecakra_rsa/result/life001";
        };
        let time = form.find("input[name='time']").val();
        $.ajax({
          type: "POST",
          url: postUrl,
          data: {
            "ajaxParameter": true,
            "itemcd": itemcd,
            "zp_channel_id": channel,
            "time": time,
            "full_name": fullName,
            "birthday": birthday,
            "gender": gender,
            "target_full_name": targetFullName,
            "target_birthday": targetBirthday,
            "target_gender": targetGender,
            "TerminalModel": "pc",
            "howToBuy": "paymentAppraisalButton",
          }
        }).done(function(data) {
          var dataValue = JSON.parse(data)
          var zp_channel_id = dataValue.zp_channel_id
          var zp_sid = dataValue.zp_sid
          var zp_sig = dataValue.zp_sig
          processing = false;
          if (location.hostname.includes("test-honkaku.cocoloni.jp") !== false) {
            window.location.href = "https://test-honkaku.cocoloni.jp/portal/charge/?zp_cp_name=cp_rsa&zp_channel_id=" + zp_channel_id + "&zp_sid=" + zp_sid + "&zp_sig=" + zp_sig
          } else {
            window.location.href = "https://honkaku-uranai.jp/portal/charge/?zp_cp_name=cp_rsa&zp_channel_id=" + zp_channel_id + "&zp_sid=" + zp_sid + "&zp_sig=" + zp_sig
          }
        }).fail(function() {
          alert("通信に失敗しました");
          processing = false;
        });
      }
    })
  };
</script>      </div>
</section>                      
<!-- caption start -->
<img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/result_subheading_top.jpg" style="width: 100%; vertical-align: bottom;">
<div class="result_subheading_background_center">
  <p>あなた自身がこの人生を自分らしく歩むために</p>
</div>
<img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/result_subheading_bottom.jpg" style="width: 100%; vertical-align: top;">
<!-- caption end -->

<section id="normalSection">
  <div class="result_description_background_center">
                <style>
  .charge_transition_screen_button {
    width: 308px;
    height: 104px;
    padding: 0;
    border: none;
    outline: none;
    cursor: pointer;
  }

  .charge_transition_screen_button img {
    width: 100%;
    height: 100%;
    border: none;
  }

  .mosaic_text_background {
    background: url("https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/result_mosaic_text.png") no-repeat;
    background-size: 115% 100%;
    background-position: center;
    width: 100%;
    height: 180px;
    text-align: center;
    padding-top: 10%;
  }

  .graph_charge_transition_screen_button {
    height: 125px;
    width: 375px;
    padding: 0;
    border: none;
    outline: none;
    cursor: pointer;
  }

  .graph_charge_transition_screen_button img {
    width: 100%;
  }
</style>

<form method="post" accept-charset="euc-jp" id="buyMoreProfileForm" action="https://zap-happyfortune.rensa.jp.net/cocoloni/yumecakra_rsa/result/"><div style="display:none;"><input type="hidden" name="_method" value="POST"/></div><input type="hidden" name="itemcd" value="life001"/><input type="hidden" name="howToBuy" value="paymentAppraisalButton"/><input type="hidden" name="TerminalModel" value="pc"/><input type="hidden" name="time" value=""/><input type="hidden" name="zp_channel_id" value="105_yc0004a"/><input type="hidden" name="contentKey" value="CYC"/><input type="hidden" name="full_name" value="あ"/><input type="hidden" name="birthday" value="1976-08-17"/><input type="hidden" name="gender" value="F"/>  <div class="mosaic_text_background">
    <button type="button" class="charge_transition_screen_button" name="paymentAppraisalButtonOfAjax">
      <img loading="lazy" alt="続きを見る(有料)" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/charge_transition_screen_button.png" onmouseover="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/charge_transition_screen_button_over.png'" onmouseout="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/charge_transition_screen_button.png'">
    </button>
  </div>
</form>
<script>
  window.onload = () => {
    var processing = false;
    $('button[name=paymentAppraisalButtonOfAjax]').on('click', function() {
      if (processing) {
        return;
      }
      processing = true;
      var paymentSystemName = 'cocoloni';
      var form = $(this).parents("form");
      var itemcd = form.find('input:hidden[name=itemcd]').val()
      var channel = form.find('input:hidden[name=zp_channel_id]').val()
      var fullName = form.find("input:hidden[name='full_name']").val()
      var birthday = form.find('input:hidden[name=birthday]').val()
      var gender = form.find("input:hidden[name=gender]").val()
      var targetFullName = form.find("input:hidden[name='target_full_name']").val()
      var targetBirthday = form.find('input:hidden[name=target_birthday]').val()
      var targetGender = form.find('input:hidden[name=target_gender]').val()

      if (paymentSystemName == "minori") {
        var url = location.href;
        var env = url.match("dev") ? 'https://dev.rensa.jp.net' : 'https://rensa.jp.net';
        $.ajax({
          type: "POST",
          url: env + "https://honkaku-uranai.jp/cp_rsa/yumecakra_rsa/result/life001", //本番環境用
          //url: "http://localhost/maki/minori/result/life001",//テスト用
          data: {
            "isNomalPayment": true,
            "itemcd": itemcd,
            "howToBuy": "partlyAppraisalButton",
            "full_name": fullName,
            "birthday": birthday,
            "gender": gender,
            "target_full_name": targetFullName,
            "target_birthday": targetBirthday,
            "target_gender": targetGender,
            "TerminalModel": "pc"
          },
          dataType: "html"
        }).done(function(data) {
          console.log(data);
          var dom_parser = new DOMParser();
          var retensionResultDataId = dom_parser.parseFromString(data, "text/html").getElementById("retensionResultData").innerHTML
          $("[name=retensionResultDataId]").val(retensionResultDataId.split("__rid__")[1])
          form.attr("method", "post")
          form.attr("action", "https://zap-happyfortune.rensa.jp.net/cocoloni/yumecakra_rsa/result/").submit();
          processing = false;
        }).fail(function() {
          alert("通信に失敗しました");
          processing = false;
        });
      } else if (paymentSystemName == "cocoloni" || paymentSystemName == "cp_rsa") {
        let postUrl = "";
        let locationUri = location.hostname;
        switch (locationUri) {
            case "honkaku-uranai.jp":
                postUrl = "https://honkaku-uranai.jp/cp_rsa/yumecakra_rsa/result";
                break;
            case "test-honkaku.cocoloni.jp":
                postUrl = "https://test-honkaku.cocoloni.jp/cp_rsa/yumecakra_rsa/result";
                break;
            default:
                postUrl = "http://localhost/cocoloni/yumecakra_rsa/result/life001";
        };
        let time = form.find("input[name='time']").val();
        $.ajax({
          type: "POST",
          url: postUrl,
          data: {
            "ajaxParameter": true,
            "itemcd": itemcd,
            "zp_channel_id": channel,
            "time": time,
            "full_name": fullName,
            "birthday": birthday,
            "gender": gender,
            "target_full_name": targetFullName,
            "target_birthday": targetBirthday,
            "target_gender": targetGender,
            "TerminalModel": "pc",
            "howToBuy": "paymentAppraisalButton",
          }
        }).done(function(data) {
          var dataValue = JSON.parse(data)
          var zp_channel_id = dataValue.zp_channel_id
          var zp_sid = dataValue.zp_sid
          var zp_sig = dataValue.zp_sig
          processing = false;
          if (location.hostname.includes("test-honkaku.cocoloni.jp") !== false) {
            window.location.href = "https://test-honkaku.cocoloni.jp/portal/charge/?zp_cp_name=cp_rsa&zp_channel_id=" + zp_channel_id + "&zp_sid=" + zp_sid + "&zp_sig=" + zp_sig
          } else {
            window.location.href = "https://honkaku-uranai.jp/portal/charge/?zp_cp_name=cp_rsa&zp_channel_id=" + zp_channel_id + "&zp_sid=" + zp_sid + "&zp_sig=" + zp_sig
          }
        }).fail(function() {
          alert("通信に失敗しました");
          processing = false;
        });
      }
    })
  };
</script>      </div>
</section>                      

<img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/top/line.png" style="width: 92%;">

<!--　特殊枠9（最終アドバイス）　-->
<section id="last_advice_section">
  <!-- 背景画像 -->
  <div class="beginning_text_background">
    <!-- 冒頭文 -->
    <div class="beginning_text_balloon">
      <p>最後に大地からのエネルギーとの繋がりを示す<span class="strong-text blue">『第0チャクラ』</span>を視てみましょう。大きな存在が示すメッセージを受け取ってください</p>
    </div>
  </div>

  <img loading="lazy" alt='チャクラから視えた あなたに贈るメッセージ' src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/res_type_title6.png" style="width: 100%;">

  <!-- 見出し -->
  <img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/result_subheading_top.jpg" style="width: 100%; vertical-align: bottom;">
  <div class="result_subheading_background_center">
    <p>第0チャクラから視る◆次、あなたの周囲で起こり始める変化と、その影響</p>
  </div>
  <img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/result_subheading_bottom.jpg" style="width: 100%; vertical-align: top;">

  <!-- vue start -->
  <div id="last_advice_35" class="last_advice">
    <last-advice
      result="[&quot;\u7279\u6b8a\u67a09\uff08\u6700\u7d42\uff09&quot;,&quot;\u6700\u5f8c\u306b\u5927\u5730\u304b\u3089\u306e\u30a8\u30cd\u30eb\u30ae\u30fc\u3068\u306e\u7e4b\u304c\u308a\u3092\u793a\u3059&lt;span class=\&quot;strong-text blue\&quot;&gt;\u300e\u7b2c0\u30c1\u30e3\u30af\u30e9\u300f&lt;\/span&gt;\u3092\u8996\u3066\u307f\u307e\u3057\u3087\u3046\u3002\u5927\u304d\u306a\u5b58\u5728\u304c\u793a\u3059\u30e1\u30c3\u30bb\u30fc\u30b8\u3092\u53d7\u3051\u53d6\u3063\u3066\u304f\u3060\u3055\u3044&quot;,&quot;XXXXXXX&quot;,&quot;\u30c1\u30e3\u30f3\u30b9\u306e\u5230\u6765&quot;,&quot;\u3042\u306a\u305f\u3068\u5927\u5730\u3092\u7e4b\u3050\u300c\u8db3\u306e\u88cf\u300d\u306b\u3042\u308b\u30c1\u30e3\u30af\u30e9\u306b\u3088\u3063\u3066\u7279\u5225\u306a\u30e1\u30c3\u30bb\u30fc\u30b8\u3092\u53d7\u3051\u53d6\u308a\u307e\u3057\u305f\u3002\u3053\u3053\u304b\u3089\u3001&lt;span class=\&quot;strong-text green\&quot;&gt;\u3042\u306a\u305f\u3068\u305d\u306e\u5468\u56f2\u306b\u8d77\u3053\u308a\u59cb\u3081\u308b\u5909\u5316\u3068\u3001\u305d\u306e\u5f71\u97ff&lt;\/span&gt;\u306b\u3064\u3044\u3066\u3054\u8aac\u660e\u3057\u307e\u3059\u3002&quot;,&quot;\u3042\u306a\u305f\u3068\u5927\u5730\u3092\u7e4b\u3050\u300c\u8db3\u306e\u88cf\u300d\u306b\u3042\u308b\u30c1\u30e3\u30af\u30e9\u306b\u3088\u3063\u3066\u7279\u5225\u306a\u30e1\u30c3\u30bb\u30fc\u30b8\u3092\u53d7\u3051\u53d6\u308a\u307e\u3057\u305f\u3002\u3053\u3053\u304b\u3089\u3001&lt;span class=\&quot;strong-text green\&quot;&gt;\u3042\u306a\u305f\u3068\u305d\u306e\u5468\u56f2\u306b\u8d77\u3053\u308a\u59cb\u3081\u308b\u5909\u5316\u3068\u3001\u305d\u306e\u5f71\u97ff&lt;\/span&gt;\u306b\u3064\u3044\u3066\u3054\u8aac\u660e\u3057\u307e\u3059\u3002&quot;,&quot;&amp;emsp;\u3042\u3055\u3093\u306e\u672c\u8cea\u3068\u3064\u306a\u304c\u308b&lt;span class=\&quot;strong-text blue\&quot;&gt;\u300e\u7b2c0\u30c1\u30e3\u30af\u30e9\u300f&lt;\/span&gt;\u304b\u3089\u8996\u3048\u3066\u304f\u308b\u3082\u306e\u3002\u305d\u308c\u306f\u3001\u300c\u4eba\u3092\u60f9\u304d\u3064\u3051\u308b\u9b45\u529b\u300d\u306b\u307b\u304b\u306a\u308a\u307e\u305b\u3093\u3002\u3042\u306a\u305f\u306b\u306f&quot;,&quot;&amp;emsp;\u3042\u3055\u3093\u306e\u672c\u8cea\u3068\u3064\u306a\u304c\u308b&lt;span class=\&quot;strong-text blue\&quot;&gt;\u300e\u7b2c0\u30c1\u30e3\u30af\u30e9\u300f&lt;\/span&gt;\u304b\u3089\u8996\u3048\u3066\u304f\u308b\u3082\u306e\u3002\u305d\u308c\u306f\u3001\u300c\u4eba\u3092\u60f9\u304d\u3064\u3051\u308b\u9b45\u529b\u300d\u306b\u307b\u304b\u306a\u308a\u307e\u305b\u3093\u3002\u3042\u306a\u305f\u306b\u306f\u3001\u30ab\u30ea\u30b9\u30de\u6027\u3084\u3001\u30ea\u30fc\u30c0\u30b7\u30c3\u30d7\u304c\u3042\u308b\u3053\u3068\u304c\u308f\u304b\u308a\u307e\u3059\u3002\u305d\u306e\u9b45\u529b\u306f\u3001\u5927\u304d\u306a\u5f71\u97ff\u529b\u3092\u6301\u3063\u3066\u3044\u307e\u3059\u3002\u4ed5\u4e8b\u3067\u3082\u30d7\u30e9\u30a4\u30d9\u30fc\u30c8\u3067\u3082\u3001\u3042\u306a\u305f\u306f\u5468\u56f2\u306e\u4eba\u3005\u304b\u3089\u6ce8\u76ee\u3055\u308c\u3066\u3044\u308b\u3067\u3057\u3087\u3046\u3002\u305d\u306e\u4e2d\u3067\u3001\u3042\u306a\u305f\u307b\u3069\u3067\u306f\u306a\u3044\u3082\u306e\u306e\u3001\u540c\u3058\u3088\u3046\u306b\u5f71\u97ff\u529b\u3092\u6301\u3063\u305f\u4eba\u7269\u306e\u5b58\u5728\u304c\u611f\u3058\u3089\u308c\u307e\u3059\u3002\u305d\u306e\u4eba\u7269\u304c\u3001\u5468\u56f2\u306e\u4eba\u3005\u3084\u3001\u3042\u306a\u305f\u3092\u53d6\u308a\u5dfb\u304f\u74b0\u5883\u306b\u5909\u5316\u3092\u3082\u305f\u3089\u3059\u3053\u3068\u306b\u306a\u308b\u306e\u3067\u3059\u3002&lt;br&gt;&lt;br&gt;\u3000\u305d\u306e\u4eba\u7269\u306f\u3001\u3042\u306a\u305f\u306b\u61a7\u308c\u3066\u304a\u308a\u3001\u3042\u306a\u305f\u306e\u7d20\u6674\u3089\u3057\u3055\u3092\u5468\u56f2\u306e\u4eba\u3005\u306b\u4f1d\u3048\u3066\u304f\u308c\u307e\u3059\u3002\u77e5\u3089\u306a\u3044\u3068\u3053\u308d\u3067\u3001\u3042\u306a\u305f\u306e\u8a55\u5224\u306f\u4e0a\u304c\u3063\u3066\u3044\u304d\u307e\u3059\u3002\u305d\u3057\u3066\u3001&lt;span class=\&quot;strong-text green\&quot;&gt;\u4ed5\u4e8b\u306b\u3064\u306a\u304c\u308b\u3001\u5927\u304d\u306a\u30c1\u30e3\u30f3\u30b9\u304c\u821e\u3044\u8fbc\u3093\u3067\u304f\u308b&lt;\/span&gt;\u306e\u3067\u3059\u3002&quot;]"
      how-to-buy-flag="&quot;partlyAppraisalButton1&quot;"
      person="1"
      index-number="35"
    />
  </div>
  <!-- vue end -->

  <!-- 結果説明テキスト -->
  <div id="result_explanation_35" class="manuscript_display_none">
    <img src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/res_type_background4_top.jpg" style="width: 100%; vertical-align: bottom;">
    <div class="result_explanation_box">
              <p>あなたと大地を繋ぐ「足の裏」にあるチャクラによって特別なメッセージを受け取りました。ここから、<span class="strong-text green">あなたとその周囲に起こり始める変化と、その影響</span>についてご説明します。</p>
          </div>
    <img src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/res_type_background4_bottom.jpg" style="width: 100%; vertical-align: top;">
  </div>


  <!-- 原稿 -->
  <div id="last_advice_manuscript_35" class="manuscript_display_none">
    <div class="result_description_background_center">
              &emsp;あさんの本質とつながる<span class="strong-text blue">『第0チャクラ』</span>から視えてくるもの。それは、「人を惹きつける魅力」にほかなりません。あなたには……        <style>
  .charge_transition_screen_button {
    width: 308px;
    height: 104px;
    padding: 0;
    border: none;
    outline: none;
    cursor: pointer;
  }

  .charge_transition_screen_button img {
    width: 100%;
    height: 100%;
    border: none;
  }

  .mosaic_text_background {
    background: url("https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/result_mosaic_text.png") no-repeat;
    background-size: 115% 100%;
    background-position: center;
    width: 100%;
    height: 180px;
    text-align: center;
    padding-top: 10%;
  }

  .graph_charge_transition_screen_button {
    height: 125px;
    width: 375px;
    padding: 0;
    border: none;
    outline: none;
    cursor: pointer;
  }

  .graph_charge_transition_screen_button img {
    width: 100%;
  }
</style>

<form method="post" accept-charset="euc-jp" id="buyMoreProfileForm" action="https://zap-happyfortune.rensa.jp.net/cocoloni/yumecakra_rsa/result/"><div style="display:none;"><input type="hidden" name="_method" value="POST"/></div><input type="hidden" name="itemcd" value="life001"/><input type="hidden" name="howToBuy" value="paymentAppraisalButton"/><input type="hidden" name="TerminalModel" value="pc"/><input type="hidden" name="time" value=""/><input type="hidden" name="zp_channel_id" value="105_yc0004a"/><input type="hidden" name="contentKey" value="CYC"/><input type="hidden" name="full_name" value="あ"/><input type="hidden" name="birthday" value="1976-08-17"/><input type="hidden" name="gender" value="F"/>  <div class="mosaic_text_background">
    <button type="button" class="charge_transition_screen_button" name="paymentAppraisalButtonOfAjax">
      <img loading="lazy" alt="続きを見る(有料)" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/charge_transition_screen_button.png" onmouseover="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/charge_transition_screen_button_over.png'" onmouseout="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/charge_transition_screen_button.png'">
    </button>
  </div>
</form>
<script>
  window.onload = () => {
    var processing = false;
    $('button[name=paymentAppraisalButtonOfAjax]').on('click', function() {
      if (processing) {
        return;
      }
      processing = true;
      var paymentSystemName = 'cocoloni';
      var form = $(this).parents("form");
      var itemcd = form.find('input:hidden[name=itemcd]').val()
      var channel = form.find('input:hidden[name=zp_channel_id]').val()
      var fullName = form.find("input:hidden[name='full_name']").val()
      var birthday = form.find('input:hidden[name=birthday]').val()
      var gender = form.find("input:hidden[name=gender]").val()
      var targetFullName = form.find("input:hidden[name='target_full_name']").val()
      var targetBirthday = form.find('input:hidden[name=target_birthday]').val()
      var targetGender = form.find('input:hidden[name=target_gender]').val()

      if (paymentSystemName == "minori") {
        var url = location.href;
        var env = url.match("dev") ? 'https://dev.rensa.jp.net' : 'https://rensa.jp.net';
        $.ajax({
          type: "POST",
          url: env + "https://honkaku-uranai.jp/cp_rsa/yumecakra_rsa/result/life001", //本番環境用
          //url: "http://localhost/maki/minori/result/life001",//テスト用
          data: {
            "isNomalPayment": true,
            "itemcd": itemcd,
            "howToBuy": "partlyAppraisalButton",
            "full_name": fullName,
            "birthday": birthday,
            "gender": gender,
            "target_full_name": targetFullName,
            "target_birthday": targetBirthday,
            "target_gender": targetGender,
            "TerminalModel": "pc"
          },
          dataType: "html"
        }).done(function(data) {
          console.log(data);
          var dom_parser = new DOMParser();
          var retensionResultDataId = dom_parser.parseFromString(data, "text/html").getElementById("retensionResultData").innerHTML
          $("[name=retensionResultDataId]").val(retensionResultDataId.split("__rid__")[1])
          form.attr("method", "post")
          form.attr("action", "https://zap-happyfortune.rensa.jp.net/cocoloni/yumecakra_rsa/result/").submit();
          processing = false;
        }).fail(function() {
          alert("通信に失敗しました");
          processing = false;
        });
      } else if (paymentSystemName == "cocoloni" || paymentSystemName == "cp_rsa") {
        let postUrl = "";
        let locationUri = location.hostname;
        switch (locationUri) {
            case "honkaku-uranai.jp":
                postUrl = "https://honkaku-uranai.jp/cp_rsa/yumecakra_rsa/result";
                break;
            case "test-honkaku.cocoloni.jp":
                postUrl = "https://test-honkaku.cocoloni.jp/cp_rsa/yumecakra_rsa/result";
                break;
            default:
                postUrl = "http://localhost/cocoloni/yumecakra_rsa/result/life001";
        };
        let time = form.find("input[name='time']").val();
        $.ajax({
          type: "POST",
          url: postUrl,
          data: {
            "ajaxParameter": true,
            "itemcd": itemcd,
            "zp_channel_id": channel,
            "time": time,
            "full_name": fullName,
            "birthday": birthday,
            "gender": gender,
            "target_full_name": targetFullName,
            "target_birthday": targetBirthday,
            "target_gender": targetGender,
            "TerminalModel": "pc",
            "howToBuy": "paymentAppraisalButton",
          }
        }).done(function(data) {
          var dataValue = JSON.parse(data)
          var zp_channel_id = dataValue.zp_channel_id
          var zp_sid = dataValue.zp_sid
          var zp_sig = dataValue.zp_sig
          processing = false;
          if (location.hostname.includes("test-honkaku.cocoloni.jp") !== false) {
            window.location.href = "https://test-honkaku.cocoloni.jp/portal/charge/?zp_cp_name=cp_rsa&zp_channel_id=" + zp_channel_id + "&zp_sid=" + zp_sid + "&zp_sig=" + zp_sig
          } else {
            window.location.href = "https://honkaku-uranai.jp/portal/charge/?zp_cp_name=cp_rsa&zp_channel_id=" + zp_channel_id + "&zp_sid=" + zp_sid + "&zp_sig=" + zp_sig
          }
        }).fail(function() {
          alert("通信に失敗しました");
          processing = false;
        });
      }
    })
  };
</script>          </div>
  </div>
</section>                  </div>
        <!---------------------------->
        <!-- small menu section end -->
        <!---------------------------->
                            <!--------------------------------------------->
          <!-- party applaisal paid menu section start -->
          <!--------------------------------------------->
          <div>
            <div class="line_background">
              <img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/top/line.png" style="vertical-align: bottom; width: 100%;">
            </div>
            <div class="paid_menu">
              
<style>
    .result_paid_menu {
        color: #ffffff;
    }
    .see_more_button {
        color: #FF9494;
    }
    .paid_price {
        color: #FF9494;
    }
    .paid_premium_price {
        color: #8ede77;
    }
</style>
<div class="result_paid_menu">
            <p><span class="see_more_button">「続きを見る（有料）」</span>をクリックすると、鑑定結果の続きがご覧になれます。</p>
        <p>ご利用には<span class="paid_price">価格3,740円（税込）</span>が必要です。</p>
        <p>占う前に内容のご確認をお願いします。</p>
        <p>ご購入いただくと、サービス・コンテンツの利用料金が発生します。</p>
    </div>              <div class="paid-button" style="margin-top: 10px;">
                <style>
  .charge_transition_screen_button {
    width: 308px;
    height: 104px;
    padding: 0;
    border: none;
    outline: none;
    cursor: pointer;
  }

  .charge_transition_screen_button img {
    width: 100%;
    height: 100%;
    border: none;
  }

  .mosaic_text_background {
    background: url("https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/result_mosaic_text.png") no-repeat;
    background-size: 115% 100%;
    background-position: center;
    width: 100%;
    height: 180px;
    text-align: center;
    padding-top: 10%;
  }

  .graph_charge_transition_screen_button {
    height: 125px;
    width: 375px;
    padding: 0;
    border: none;
    outline: none;
    cursor: pointer;
  }

  .graph_charge_transition_screen_button img {
    width: 100%;
  }
</style>

<form method="post" accept-charset="euc-jp" id="buyMoreProfileForm" action="https://zap-happyfortune.rensa.jp.net/cocoloni/yumecakra_rsa/result/"><div style="display:none;"><input type="hidden" name="_method" value="POST"/></div><input type="hidden" name="itemcd" value="life001"/><input type="hidden" name="howToBuy" value="paymentAppraisalButton"/><input type="hidden" name="TerminalModel" value="pc"/><input type="hidden" name="time" value=""/><input type="hidden" name="zp_channel_id" value="105_yc0004a"/><input type="hidden" name="contentKey" value="CYC"/><input type="hidden" name="full_name" value="あ"/><input type="hidden" name="birthday" value="1976-08-17"/><input type="hidden" name="gender" value="F"/>  <div style="text-align: center; min-height: 102px;">
    <button type="button" class="charge_transition_screen_button" name="paymentAppraisalButtonOfAjax">
      <img loading="lazy" alt="続きを見る(有料)" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/charge_transition_screen_button.png" onmouseover="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/charge_transition_screen_button_over.png'" onmouseout="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/charge_transition_screen_button.png'">
    </button>
  </div>
</form>
<script>
  window.onload = () => {
    var processing = false;
    $('button[name=paymentAppraisalButtonOfAjax]').on('click', function() {
      if (processing) {
        return;
      }
      processing = true;
      var paymentSystemName = 'cocoloni';
      var form = $(this).parents("form");
      var itemcd = form.find('input:hidden[name=itemcd]').val()
      var channel = form.find('input:hidden[name=zp_channel_id]').val()
      var fullName = form.find("input:hidden[name='full_name']").val()
      var birthday = form.find('input:hidden[name=birthday]').val()
      var gender = form.find("input:hidden[name=gender]").val()
      var targetFullName = form.find("input:hidden[name='target_full_name']").val()
      var targetBirthday = form.find('input:hidden[name=target_birthday]').val()
      var targetGender = form.find('input:hidden[name=target_gender]').val()

      if (paymentSystemName == "minori") {
        var url = location.href;
        var env = url.match("dev") ? 'https://dev.rensa.jp.net' : 'https://rensa.jp.net';
        $.ajax({
          type: "POST",
          url: env + "https://honkaku-uranai.jp/cp_rsa/yumecakra_rsa/result/life001", //本番環境用
          //url: "http://localhost/maki/minori/result/life001",//テスト用
          data: {
            "isNomalPayment": true,
            "itemcd": itemcd,
            "howToBuy": "partlyAppraisalButton",
            "full_name": fullName,
            "birthday": birthday,
            "gender": gender,
            "target_full_name": targetFullName,
            "target_birthday": targetBirthday,
            "target_gender": targetGender,
            "TerminalModel": "pc"
          },
          dataType: "html"
        }).done(function(data) {
          console.log(data);
          var dom_parser = new DOMParser();
          var retensionResultDataId = dom_parser.parseFromString(data, "text/html").getElementById("retensionResultData").innerHTML
          $("[name=retensionResultDataId]").val(retensionResultDataId.split("__rid__")[1])
          form.attr("method", "post")
          form.attr("action", "https://zap-happyfortune.rensa.jp.net/cocoloni/yumecakra_rsa/result/").submit();
          processing = false;
        }).fail(function() {
          alert("通信に失敗しました");
          processing = false;
        });
      } else if (paymentSystemName == "cocoloni" || paymentSystemName == "cp_rsa") {
        let postUrl = "";
        let locationUri = location.hostname;
        switch (locationUri) {
            case "honkaku-uranai.jp":
                postUrl = "https://honkaku-uranai.jp/cp_rsa/yumecakra_rsa/result";
                break;
            case "test-honkaku.cocoloni.jp":
                postUrl = "https://test-honkaku.cocoloni.jp/cp_rsa/yumecakra_rsa/result";
                break;
            default:
                postUrl = "http://localhost/cocoloni/yumecakra_rsa/result/life001";
        };
        let time = form.find("input[name='time']").val();
        $.ajax({
          type: "POST",
          url: postUrl,
          data: {
            "ajaxParameter": true,
            "itemcd": itemcd,
            "zp_channel_id": channel,
            "time": time,
            "full_name": fullName,
            "birthday": birthday,
            "gender": gender,
            "target_full_name": targetFullName,
            "target_birthday": targetBirthday,
            "target_gender": targetGender,
            "TerminalModel": "pc",
            "howToBuy": "paymentAppraisalButton",
          }
        }).done(function(data) {
          var dataValue = JSON.parse(data)
          var zp_channel_id = dataValue.zp_channel_id
          var zp_sid = dataValue.zp_sid
          var zp_sig = dataValue.zp_sig
          processing = false;
          if (location.hostname.includes("test-honkaku.cocoloni.jp") !== false) {
            window.location.href = "https://test-honkaku.cocoloni.jp/portal/charge/?zp_cp_name=cp_rsa&zp_channel_id=" + zp_channel_id + "&zp_sid=" + zp_sid + "&zp_sig=" + zp_sig
          } else {
            window.location.href = "https://honkaku-uranai.jp/portal/charge/?zp_cp_name=cp_rsa&zp_channel_id=" + zp_channel_id + "&zp_sid=" + zp_sid + "&zp_sig=" + zp_sig
          }
        }).fail(function() {
          alert("通信に失敗しました");
          processing = false;
        });
      }
    })
  };
</script>              </div>
            </div>
            <img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/result_description_bottom.jpg" style="vertical-align: top; width: 100%;">
          </div>
          <!--------------------------------------------->
          <!-- party applaisal paid menu section start -->
          <!--------------------------------------------->
                      </div>
      <section id="footer" style="margin: 0 33px;"><style>
    .footer {
        clear: both;
        background: black;
        color: white;
        padding: 35px 90px 30px;    }
    .footer a {
        text-decoration: underline;
        color: yellow;
    }
    .footer a:hover {
        color: #ff6b00;
        text-decoration: none;
    }
    .attention-line {
        width: 100%;
        height: 2px; /* 要sp対応 */
        line-height: 0;
        margin: 10px auto; /* 要sp対応 */
        border-top: 1px dashed #542; /* 要sp対応 */
    }
    .text-center {
        text-align: center;
    }
</style>

<div class="footer">
    <style>
    .footer-text-section h3 {
        text-align: center;
    }
    .precautions-list {
        padding: 12px 0;
    }
    .copyright_text {
        text-align: center;
    }
    .teller-telling-footer-section {
        text-align: center;
    }
    .pre-footer-section ul {
        margin: 3px;
        list-style-type: circle;
    }
</style>
    <div class="teller-telling-footer-section">
        <!-- @: link/ --><a href="/cp_rsa/yumecakra_rsa/" class="color-e8ca22">トップページに戻る</a><br/><br/>
        <!-- @: link/ --><a href="/cp_rsa/tokusyo/" class="link_attention" target="yumecakra_rsa_isp">特定商取引法に基づく表記</a>
    </div>
<p class="copyright_text">Copyright Rensa Co., Ltd.<br />このページの無断転用・転記を禁じます。</p>
<br/><br/>
<div class="footer_img"></div>
</div></section>
    </section>
  </div>
</main>

<!-- charge_transition_screen.ctpでjQueryを使用してるため -->
<!-- JS -->
<script src="https://web-img.rensa.jp.net/rensa/images/web/Cocoloni/common/js/jquery.js"></script><!-- -->    </div>
                <script>
        var userAgent = window.navigator.userAgent.toLowerCase();
        var isSmoothScrollDisableBrowser = false;
        var smoothScrollEnabled = true;

        if (userAgent.indexOf('msie') != -1 || userAgent.indexOf('trident') != -1) {
            isSmoothScrollDisableBrowser = true;
        } else if (userAgent.indexOf('edge') != -1) {
            isSmoothScrollDisableBrowser = true;
        } else if (userAgent.indexOf('safari') != -1) {
            isSmoothScrollDisableBrowser = true;
        }


        document.addEventListener('mousewheel', function(e) {
            if (smoothScrollEnabled) {
                e.preventDefault();
                var wd = e.wheelDelta;
                var csp = window.pageYOffset;
                window.scrollTo(0, csp - wd / 2);
            }
        }, {
            passive: false
        });

        function smoothScrollEnable() {
            smoothScrollEnabled = true;
        }

        function smoothScrollDisable() {
            smoothScrollEnabled = false;
        }

        if (isSmoothScrollDisableBrowser) {
            smoothScrollEnable()

            $("select").change(function() {
                smoothScrollEnable();
                $(this).blur()
            });
            $("select")
                .focusin(function(e) {
                    smoothScrollDisable()
                })
                .focusout(function(e) {
                    smoothScrollEnable();
                });
        }
    </script>
    </body>

</html>"""

# %%
result_df = result_html_to_df_rsa(result_html_str)

# %%
result_df
# Out:
#     index_result                    sub_title_result
# 0              1     第2チャクラから視る、あなたは人生で何に幸福と喜びを感じるのか
# 1              2            第3チャクラで分かる、あなたの人を引き付ける魅力
# 2              3         第5チャクラで知る、あなたらしく生きる人生の引き寄せ方
# 3              4       第7チャクラが教える、生まれた時から持っている人生の可能性
# 4              5                運勢が良い時、あなたに起こりやすい出来事
# 5              6                  あなたが望みを叶えるための決断と選択
# 6              7             あなたが日常で抱えやすい問題と、その乗り越え方
# 7              8            あなたが感じやすいストレスと、それに対する解消法
# 8              9          今のあなたが、日々の生活の中で力を注ぐべきものは何？
# 9             10             あなたに気を付けてほしい生活習慣と健康について
# 10            11                あなたに与えられた仕事運と将来に得るもの
# 11            12                 あなたを見ている周囲の人たちからの評価
# 12            13              あなたに与えられた恋愛運命と引き寄せやすい縁
# 13            14              この先、あなたを良き方へ導いてくれる重要人物
# 14            15              あなたをトラブルに巻き込んでしまう要注意人物
# 15            16                 今、あなたの愛に訪れようとしている運命
# 16            17         その運命は、あなたの愛に大きな影響を与えることになる？
# ...

# %%
compare_inputpage(input_df, result_df)
# Out:
# [{'index_input': 1,
#   'sub_title_input': 'あなたを巡るエネルギーの中核を視る◆チャクラ占い',
#   'check_order': 'Item Missing or Created with Image',
#   'check_text': False},
#  {'index_input': 2,
#   'sub_title_input': '第2チャクラから視る、あなたは人生で何に幸福と喜びを感じるのか',
#   'check_order': '',
#   'check_text': True},
#  {'index_input': 3,
#   'sub_title_input': '第3チャクラで分かる、あなたの人を引き付ける魅力',
#   'check_order': '',
#   'check_text': True},
#  {'index_input': 4,
#   'sub_title_input': '第5チャクラで知る、あなたらしく生きる人生の引き寄せ方',
#   'check_order': '',
#   'check_text': True},
#  {'index_input': 5,
#   'sub_title_input': '第7チャクラが教える、生まれた時から持っている人生の可能性',
#   'check_order': '',
#   'check_text': True},
#  {'index_input': 6,
#   'sub_title_input': '運勢が良い時、あなたに起こりやすい出来事',
#   'check_order': '',
#   'check_text': True},
#  {'index_input': 7,
#   'sub_title_input': 'あなたが望みを叶えるための決断と選択',
#   'check_order': '',
#   'check_text': True},
#  {'index_input': 8,
#   'sub_title_input': 'あなたが日常で抱えやすい問題と、その乗り越え方',
#   'check_order': '',
# ...

# %%
input_df
# Out:
#     index_input                     sub_title_input  \
# 0             1            あなたを巡るエネルギーの中核を視る◆チャクラ占い
# 1             2     第2チャクラから視る、あなたは人生で何に幸福と喜びを感じるのか
# 2             3            第3チャクラで分かる、あなたの人を引き付ける魅力
# 3             4         第5チャクラで知る、あなたらしく生きる人生の引き寄せ方
# 4             5       第7チャクラが教える、生まれた時から持っている人生の可能性
# 5             6                運勢が良い時、あなたに起こりやすい出来事
# 6             7                  あなたが望みを叶えるための決断と選択
# 7             8             あなたが日常で抱えやすい問題と、その乗り越え方
# 8             9            あなたが感じやすいストレスと、それに対する解消法
# 9            10          今のあなたが、日々の生活の中で力を注ぐべきものは何？
# 10           11             あなたに気を付けてほしい生活習慣と健康について
# 11           12          エネルギーの流れから視えた運命◆チャクラ・ヴィジョン
# 12           13                あなたに与えられた仕事運と将来に得るもの
# 13           14                 あなたを見ている周囲の人たちからの評価
# 14           15              あなたに与えられた恋愛運命と引き寄せやすい縁
# 15           16              この先、あなたを良き方へ導いてくれる重要人物
# 16           17              あなたをトラブルに巻き込んでしまう要注意人物
# ...
