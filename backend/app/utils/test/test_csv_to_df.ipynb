# %%
import sys
sys.path.append('../')
from csv_to_df import csv_to_df

# %%
import io
import pandas as pd


# 使用例
csv_path = 'csv/test_rsa.csv'
with open(csv_path, 'r') as csv_file:
    df = csv_to_df(csv_file)

# %%
df
# Out:
#                                menu_csv  \
# 0      あなたの内面をつつぬけにする【無料のチャクラ占い】本性/伸びしろ
# 1      隠しごと一切ナシ【あの人の本性暴くチャクラ占い】恋愛観＆欲｜無料
# 2      『どんな恋人同士になれる？』あの人との恋愛相性を霊視◆絆/相性率
# 3    人生掌握【ゆめの心々渾身】あなたの全運命を霊視◆1年⇒10年後/晩年
# 4     現状から昇進/昇給【霊視でわかる◆あなたの仕事運】才能/評価/成功
# 5      何が起こる？どんな影響ある？【霊視で暴くあなたの人生】転機＆時期
# 6     婚姻待ったナシ【成婚へ導く霊視占】あなたの結婚縁/相手特徴/入籍後
# 7     まるで目の前にいるかのよう【あなたの生涯伴侶/全特徴】出会い/入籍
# 8   2人の恋心/強制成就【ゆめの心々◆宿縁霊視30項】本心/転機/関係最後
# 9    本気の不倫愛を救済【2人の関係導く21項】あの人の覚悟/行動/愛結末
# 10    考えも想いもマルわかり【あの人の全てを知る霊視】存在 /恋心/決断
# 11   愛熱高まる夜【2人の想い重ね確かめ合う◆濃密官能占】体相性/欲/H後
# 12    どんな別れ方でも修復【諦めきれない恋心を救済鑑定】現状/未練/結末
# 13    あの人の本命は誰？【2人の恋運命を全解明】恋愛相性/本命/最終関係
# 14     進展皆無の恋【距離感じるあの人の態度理由を霊視】2人の誤解⇒解消
# 15     この人しかいない『運命感じるのは私だけ？』霊視で視抜く◆本心/答
# 16    『あの人と交際できる？』片想いの結末まで解明◆2人の絆/本音/変化
# 17     抱き続けてる恋心【あの人は気づいてる？】恋霊視◆恋愛対象/次行動
# 18     どうしても知りたい【あの人のあなたに対する恋心有無】存在/恋告白
# 19    なかなか距離縮まらないあの人『想い続けて叶う？』本音/転機/恋決着
# 20     チャクラ占い｜結婚霊視【手に取るようにわかる】あなたの運命の相手
#
#                                           caption_csv  price_csv
# ...
