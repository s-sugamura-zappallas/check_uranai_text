# %%
import sys
sys.path.append('../')
from html_to_df import html_to_df_rsa

# %%
html_str = """
<!DOCTYPE html>
<html>

<head>
    <script src="https://rensa.jp.net/premium_fortune/portal_proxy_js?method=get&url=https://happyfortune.rensa.jp.net/js/Build/Yumecakra/js/result_telling.js-8fac2cf9.js" type="module"></script>        <link rel="stylesheet" href="https://happyfortune.rensa.jp.net/js/Build/assets/result_telling-99941372.css"/><link rel="stylesheet" href="https://happyfortune.rensa.jp.net/js/Build/assets/result-cde74db8.css"/>            <script src="/js/jquery.js?1580433509"></script>    
    <title>
        本州南端の生き神様【ゆめの心々】運命霊視/隠し事暴くチャクラ占い | cocoloni占い館 Moon    </title>
            <meta name="viewport" content="width=device-width, initial-scale=1.0">
    
            <!-- Google Tag Manager -->
        <script>
            (function(w, d, s, l, i) {
                w[l] = w[l] || [];
                w[l].push({
                    'gtm.start': new Date().getTime(),
                    event: 'gtm.js'
                });
                var f = d.getElementsByTagName(s)[0],
                    j = d.createElement(s),
                    dl = l != 'dataLayer' ? '&l=' + l : '';
                j.async = true;
                j.src = 'https://www.googletagmanager.com/gtm.js?id=' + i + dl;
                f.parentNode.insertBefore(j, f);
            })(window, document, 'script', 'dataLayer', 'GTM-MV3KXWG');
        </script>
        <!-- End Google Tag Manager -->
            
    
    <meta charset="utf-8"/>
            <meta name="description" content="【無料あり】チャクラ占い｜現実を視透かす本州南端の生き神様『ゆめの心々』。滞ったエネルギーや上手く巡らない運勢を霊視し体内チャクラを調律。バランスを整え本来の流れへ矯正します。救い求め全国から次々来訪のチャクラ霊視。あなたの願いや恋焦がれる想いも満願成就へ誘います。" />            <meta name="Keywords" content="チャクラ占い, ゆめの心々, 霊視, スピリチュアル, 調律, 巡り, 循環" />                        <meta property="og:type" content="article" />                    <meta property="og:image" content="https://web-img.rensa.jp.net/rensa/images/web/Cocoloni/Yumecakra/1200_630.jpg" />                    <meta property="og:title" content="本州南端の生き神様【ゆめの心々】運命霊視/隠し事暴くチャクラ占い | cocoloni占い館 Moon" />                    <meta property="og:description" content="【無料あり】チャクラ占い｜現実を視透かす本州南端の生き神様『ゆめの心々』。滞ったエネルギーや上手く巡らない運勢を霊視し体内チャクラを調律。バランスを整え本来の流れへ矯正します。救い求め全国から次々来訪のチャクラ霊視。あなたの願いや恋焦がれる想いも満願成就へ誘います。" />                    <meta property="og:url" content="https://honkaku-uranai.jp/cp_rsa/yumecakra_rsa/">        <meta property="og:locale" content="ja_JP" />
                
        </head>

<body>
    
            <!-- Google Tag Manager (noscript) -->
        <noscript><iframe src="https://www.googletagmanager.com/ns.html?id=GTM-MV3KXWG" height="0" width="0" style="display:none;visibility:hidden"></iframe></noscript>
        <!-- End Google Tag Manager (noscript) -->
                                    <!-- <script><//?php echo mb_convert_encoding( file_get_contents('https://630hso4ag2.user-space.cdn.idcfcloud.net/js/'.$cocoloniJsFailName ) , 'utf-8', 'euc-jp') ?></script> -->
                <script type="text/javascript" src="https://630hso4ag2.user-space.cdn.idcfcloud.net/js/honkaku_common.js" charset="EUC-JP" ;></script>
                            <!-- cocoloni header tag start -->
        <div id="honkaku_header" style="display:none;">
                            <input type="hidden" name="contents_name" value="yumecakra_rsa">
                                    </div>
        <!-- cocoloni header tag start -->
        <!-- contents_headerCopy start -->
        <p class="contents_headerCopy">
                            本州南端の生き神様【ゆめの心々】運命霊視/隠し事暴くチャクラ占い                    </p>
        <!-- contents_headerCopy end -->
        <noscript>
            <!-- cocoloni sp javascript not working -->
            <style>
                .js-error-section {
                    margin: 1vw;
                    padding: 1vw;
                    background: #fff;
                    border: 2px solid #dc0000;
                    text-align: center;
                    font-size: 2vw;
                }
            </style>
            <div class="js-error-section">
                <p>お客様が現在お使いのブラウザでは、JavaScriptの設定が無効となっています。<br />
                    当サイトはJavaScriptを使用致しますので、設定をオンにご変更下さい。</p>
            </div>
        </noscript>
        <div id="cocoloniAttention"></div>
        <!-- cocoloniAttention -->
    
    
        
        <div class="container clearfix">

        <!-- vue を使用できるようにする -->

<!-- CSS -->
<style>
@import url('https://fonts.googleapis.com/css2?family=Noto+Sans+JP&display=swap');
body , main , h1 , h2 , h3 , h4 , h5 , p , img , div {
  margin: 0px;
  font-family: 'Noto Sans JP', sans-serif;
}
html {
  font-size: 16px;
}
a {
  transition: all 0.25s 0s ease;
  text-underline-offset: 0.25em;
}
a:hover {
  text-decoration: none;
}
button {
  cursor: pointer;
  background-color: transparent;
  border: none;
}

/********************************************************************/
/* use common background and common font size and color adjustment */
/******************************************************************/
.content_main {
  background: url("https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/common/main_background.jpg") no-repeat center top;
  background-size: 1800px 1600px;
  min-width: 990px;
  background-color: #131120;
  background-attachment: fixed;
  color: white;
  display: block;
  overflow: hidden;
}

.main_shadow {
  max-width: 1800px;
  margin: 0 auto;
  box-shadow: 100px 0 50px -50px #131120 inset, -100px 0px 50px -50px #131120 inset;
}

/**********************************/
/* use common  section adjustment */
/*********************************/
.section_container {
  width: 990px;
  margin: 0 auto;
}
.section_background {
  background: url('https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/common/section_background.jpg') repeat-y;
  background-size: 100%;
}

/* cocoloniのおすすめリンク先のスタイル */
  .content-main {
    background: url("https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/common/main_background.jpg") no-repeat center top;
    background-size: 1800px 1600px;
    min-width: 990px;
    background-color: #131120;
    background-attachment: fixed;
    color: white;
    display: block;
    overflow: hidden;
  }
  .section-container {
    width: 990px;
    margin: 0 auto;
  }
  .section-background {
    background: url('https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/common/section_background.jpg') repeat-y;
    background-size: 100%;
  }

/* つなぎ込み部分 */
.balloon_connect_background {
  background: url('https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/result_background.jpg') repeat-y;
  background-position: center;
  background-size: 100%;
  min-height: 100px;
  padding: 3% 5% 2%;
}
.balloon_connect {
  background-color: #00000080;
  width: 100%;
  min-height: 100px;
  text-align: left;
  margin-bottom: 3%;
  padding: 2% 5%;
  box-sizing: border-box;
  border-radius: 22px;
  box-shadow: 0 0 10px #f9fbbdb3, 0 0 10px #f9fbbdb3;
}
.balloon_connect p {
  font-family: "ヒラギノ明朝 ProN W6", "HiraMinProN-W6", "HG明朝E", "ＭＳ Ｐ明朝", "MS PMincho", "MS 明朝", serif;
  font-size: 1.3rem;
  line-height: 140%;
  color: #ffffff;
  letter-spacing: 0.05rem;
}

/*************************************/
/* use free menu buttons adjustment */
/***********************************/
.top_free_menu_buttons {
  text-align: center;
}
.top_free_menu_buttons button {
  width: 700px;
  height: 280px;
  padding: 0;
  border: none;
  outline: none;
  cursor: pointer;
  background-size: 100% 100%;
}
.top_free_menu_buttons img {
  width: 100%;
  height: 100%;
  border: none;
  outline: none;
}

/**********************/
/* use text menu link */
/**********************/
.appraisal_menu {
  display: flex;
  flex-flow: column;
  text-align: left;
}
.appraisal_menu img {
  width: 11%;
  float: left;
  margin-right: 2%;
}

.appraisal_menu a {
  color: #ffcf3a;
}
.appraisal_menu a:hover {
  color: #c29c27;
}
.appraisal_menu.light a {
  color: #4901a6;
}
.appraisal_menu.light a:hover {
  color: #7203ff;
}
.appraisal_menu a p {
  font-family: "ヒラギノ明朝 ProN W6", "HiraMinProN-W6", "HG明朝E", "ＭＳ Ｐ明朝", "MS PMincho", "MS 明朝", serif;
  letter-spacing: 0.05rem;
  font-size: 30px;
  font-weight: bold;
  display: inline;
  line-height: 140%;
}

.appraisal_menu .description {
  font-size: 18px;
  font-weight: normal;
  color: #ffffff;
  padding: 1%;
}
.appraisal_menu.light .description {
  color: #000000;
}

.menu_info {
  text-align: right;
  font-size: 16px;
}
.add_day {
  color: red;
}
.price {
  font-weight: bold;
}
.appraisal_menu.light .premium_price {
  color: #236310;
}
.appraisal_menu.light .common_price {
  color: #983030;
}
.premium_price {
  color: #8ede77;
}
.common_price {
  color: #FF9494;
}
/* 説明文言強調 */
.telling_background {
  width: 100%;
  background: url("https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/top/telling_introduction_sample_background.jpg") repeat-y;
  background-position: center;
  background-size: 100%;
}
.telling_description {
  font-family: "ヒラギノ明朝 ProN W6", "HiraMinProN-W6", "HG明朝E", "ＭＳ Ｐ明朝", "MS PMincho", "MS 明朝", serif;
  letter-spacing: 0.05rem;
  color: #ffffff;
  width: 95%;
  font-size: 1.3rem;
  text-align: left;
  margin: 0 auto 2%;
  line-height: 140%;
}

.telling_link_head {
  color: #fc97fd;
  font-family: "ヒラギノ明朝 ProN W6", "HiraMinProN-W6", "HG明朝E", "ＭＳ Ｐ明朝", "MS PMincho", "MS 明朝", serif;
  letter-spacing: 0.05rem;
  font-weight: bold;
  text-shadow: 0 0 10px #686860;
  width: 100%;
  font-size: 1.3rem;
  text-align: center;
  margin: 10px auto;
}

.strong-text {
  text-align: left;
  color: #FFFFFF;
}
.blue {
  text-shadow: 0 0 5px #0066CC, 0 0 5px #0066CC, 0 0 5px #0066CC, 0 0 5px #0066CC, 0 0 5px #0066CC;
}
.green {
  text-shadow: 0 0 5px #009966, 0 0 5px #009966, 0 0 5px #009966, 0 0 5px #009966, 0 0 5px #009966;
}
</style><style>
  .index_text_link {
    color: #73c2f4;
    font-size: 1.3rem;
    text-decoration: underline;
    font-weight: bold;
    font-family: "ヒラギノ明朝 ProN W6", "HiraMinProN-W6", "HG明朝E", "ＭＳ Ｐ明朝", "MS PMincho", "MS 明朝", serif;
    letter-spacing: 0.05rem;
    display: inline;
    line-height: 140%;
  }
  .index_text_link:not(:last-child) {
    margin-bottom: 7px;
  }
  .index_text_link:hover {
    color: #5b5ff1;
    text-decoration: none;
  }
  .index_text_link.link1 {
    color: #CCFFFF;
  }
  .index_text_link.link1:hover {
    color: #5b5ff1;
  }
  .index_text_link.link2 {
    color: #CC99FF;
  }
  .index_text_link.link2:hover {
    color: #e55eff;
  }
  .index_text_link.link3 {
    color: #FF99CC;
  }
  .index_text_link.link3:hover {
    color: #fb3397;
  }


  /******************************+***/
  /* use top category menu section */
  /*********************************/
  .top_menu_link_background_center {
    width: 100%;
    background: url('https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/top/top_menu_list_background.jpg') repeat-y;
    background-position: center;
    background-size: 100%;
    padding: 20px 90px 0;
    box-sizing: border-box;
  }
  .content_menu_link_background_center {
    width: 100%;
    padding: 2% 9%;
    box-sizing: border-box;
    font-size: 1.3rem;
  }
  .category_transition_link {
    font-size: 1.3rem;
    color: #ffffff;
    margin: 1% 3%;
    float: right;
  }
  .category_transition_link:hover {
    color: #73c2f4;
  }
  .content_menu_transition_buttons {
    display: flex;
    height: 110px;
  }
  .content_menu_transition_buttons a {
    width: 33.33%;
  }
  .content_menu_transition_buttons img {
    width: 100%;
    height: 106px;
  }
  .content_menu_transition_buttons div {
    background-size: 100%;
    height: 110px;
  }
  .content_menu_transition_buttons div:hover{
    background-size: 100%;
    height: 110px;
  }

  /******************************+***/
  /* use top free tarot ancker text */
  /*********************************/

  /* worries section */
  .worries-container {
    width: 100%;
    height: 100%;
    position: relative;
  }

  .worries-container img {
    width: 100%;
    height: auto;
  }

  .worries-container a {
    width: 100%;
    font-size: 1.5rem;
    color: #ffffff;
    padding: 10px;
    border-radius: 5px;
    box-shadow: rgba(0,0,0,1) 0 1px 0;
    text-shadow: rgba(0,0,0,.4) 0 1px 0;
    letter-spacing: inherit;
    cursor: pointer;
    text-decoration: underline;
  }

  .worries-container a:hover {
    color: #ffffa4;
    text-decoration: none;
  }

  .worries-container_menus {
    position: absolute;
    top: 56%;
    left: 9%;
    width: 62%;
    text-align: left;
  }

  .worries-container_menus div {
    margin-bottom: 8%;
  }

  .worries-container a.onayami-show-next {
    background-color: #6E6657;
  }
  .worries-container a.onayami-show-next:hover {
    color: #ffffa4;
    text-decoration: none;
  }

  /* Free Tarot */
  .free_tarot_background {
    width: 100%;
    min-height: 390px;
    background: url('https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/top/tarot_free_appraisal_menu_background.jpg') repeat-y;
    background-size: 100%;
    position: relative;
  }
  .free_tarot_background_inner {
    position: absolute;
    top: 0;
    left: 0;
    width: 100%;
    min-height: 390px;
  }
  .free_tarot_background_over {
    width: 100%;
    box-sizing: border-box;
    background: url('https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/top/tarot_free_appraisal_menu_background.jpg') no-repeat;
    background-size: 100% 100%;
    display: none;
  }
  .top_free_tarot_result_text_box {
    padding: 0 5% 2%;
    text-align: left;
  }
  #top_free_tarot_result_menu_link {
    margin: 2% 0;
  }
  .top_free_tarot_link_text {
    color: #e0ff80;
    font-size: 1.3rem;
    line-height: 140%;
  }
  .top_free_tarot_link_text:hover {
    color: #c1ff00;
    text-decoration: none;
  }
  .top_free_tarot_appraisal_menu_box {
    padding: 0 7%;
  }

  .free_tarot_display {
    position: absolute;
    top: 0%;
    left: 0%;
    width: 100%;
    height: 390px;
    z-index: 10;
  }
  .free_tarot_question {
    width: 100%;
    text-align: center;
    margin: 1% 0 2%;
  }
  .free_tarot_question p {
    font-family: "ヒラギノ明朝 ProN W6", "HiraMinProN-W6", "HG明朝E", "ＭＳ Ｐ明朝", "MS PMincho", "MS 明朝", serif;
    color: #ffffff;
    font-size: 2.4rem;
    letter-spacing: 0.05rem;
  }
  /* 生年月日入力欄 */
  .birthday_select_box.free_tarot_birthday_select_box {
      margin-left: 17%;
      display: flex;
      align-items: end;
      gap: 2%;
  }
  .birthday_select_box.free_tarot_birthday_select_box select {
    font-family:  "ヒラギノ明朝 ProN W6", "HiraMinProN-W6", "HG明朝E", "ＭＳ Ｐ明朝", "MS PMincho", "MS 明朝", serif;
    letter-spacing: 0.05rem;
    font-size: 2.5rem;
    line-height: 140%;
  }
  .birthday_select_box.free_tarot_birthday_select_box p {
    font-family:  "ヒラギノ明朝 ProN W6", "HiraMinProN-W6", "HG明朝E", "ＭＳ Ｐ明朝", "MS PMincho", "MS 明朝", serif;
    letter-spacing: 0.05rem;
  }

  #free_tarot_button {
    width: 464px;
    height: 196px;
    margin: 6% auto 0;
    cursor: pointer;
  }
  #free_tarot_button img {
    width: 100%;
  }

  .loading_text_box {
    position: absolute;
    top: 0%;
    left: 0%;
    width: 100%;
    height: 390px;
    text-align: left;
    display: none;
  }
  #loading_text {
    font-family: "ヒラギノ明朝 ProN W6", "HiraMinProN-W6", "HG明朝E", "ＭＳ Ｐ明朝", "MS PMincho", "MS 明朝", serif;
    font-weight: bold;
    font-size: 5rem;
    color: #ffffff;
    margin-top: 15%;
    margin-left: 25%;
    letter-spacing: 0.05rem;
  }

  .free_tarot_box {
    position: absolute;
    top: 0%;
    left: 0%;
    width: 100%;
    height: 390px;
  }
  #free_tarot_teller_box,
  #free_tarot_chakra_image,
  #free_tarot_result_box {
    display: none;
  }

  .free_tarot_teller_image {
    background: url(https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/result/res_type_yumeno2.jpg) no-repeat;
    background-position: center;
    background-size: 100%;
    width: 100%;
    height: 357px;
  }

  .free_tarot_teller_comment_box {
    position: absolute;
    top: 50%;
    right: 1%;
    transform: translateY(-50%);
    width: 60%;
  }
  .free_tarot_teller_comment_box p {
    font-family: "ヒラギノ明朝 ProN W6", "HiraMinProN-W6", "HG明朝E", "ＭＳ Ｐ明朝", "MS PMincho", "MS 明朝", serif;
    font-weight: bold;
    font-size: 2.8rem;
    color: #CC99FF;
    text-shadow: 0 0 4px #000000, 0 0 8px #000000, 0 0 8px #ae00ff;
    line-height: 140%;
    letter-spacing: 0.05rem;
  }
  .chakra_image_box {
    position: absolute;
    top: 50%;
    left: 66%;
    transform: translate(-50%, -50%);
    width: 300px;
    height: 300px;
  }
  .chakra_image_box img {
    width: 100%;
  }

  .free_tarot_result_text {
    width: 100%;
    text-align: left;
    font-size: 1.3rem;
    color: #ffffff;
    line-height: 140%;
  }

  /* show_text_link */
  .show-text-link a {
    font-size: 1.32rem;
  }
  .show-text-link_flex {
    display: flex;
    justify-content: space-between;
    align-items: center;
    width: 90%;
    margin: 0 auto;
  }
  .show-text-link_flex_left {
    width: 12%;
  }
  .show-text-link_flex_right {
    width: 85%;
    text-align: left;
  }
  .show-text-link_flex_right div {
    text-align: right;
  }

  .show-text-link_flex_right_new {
    font-size: 1.1rem;
    color: red;
    text-align: right;
  }

  .show-text-link_ballon {
    background: linear-gradient(to right, #ffb1aa 1%,#f16a60 10%, #f16a60 90%,#ffb1aa 99%);
    padding: 5px;
    margin-bottom: 25px;
    font-size: 1.5rem;
  }
</style><style>
.pre_teller_background {
  background: url('https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/telling/telling_introduction_background.jpg') repeat-y;
  background-position: center;
  background-size: 100%;
}
#preTellerComment p {
  line-height: 140%;
  font-size: 1.3rem;
  text-align: left;
  padding: 0 10% 2%;
  color: #ffffff;
}
.telling_bottom_link {
  color: #76ead6;
  font-size: 1.32rem;
  font-weight: bold;
  font-family: "ヒラギノ明朝 ProN W6", "HiraMinProN-W6", "HG明朝E", "ＭＳ Ｐ明朝", "MS PMincho", "MS 明朝", serif;
  display: inline-block;
  line-height: 160%;
}
.telling_bottom_link.bottom_space {
  margin-bottom: 3%;
}
.telling_bottom_link:hover {
  color: #248662;
}

.telling_subheading_background_center {
  font-size: 1.6rem;
  padding: 0 80px;
  font-weight: bold;
}
.telling_subheading_background_center p {
  color: #fff;
  font-family: "ヒラギノ明朝 ProN W6", "HiraMinProN-W6", "HG明朝E", "ＭＳ Ｐ明朝", "MS PMincho", "MS 明朝", serif;
  letter-spacing: 0.05rem;
  font-weight: bold;
  line-height: 140%;
}
.telling_description_background_center p {
  color: #fff;
  font-size: 1.3rem;
  line-height: 140%;
  text-align: left;
  padding: 0 10% 2%;
}
</style><!-- -->

<!-- TOP無料鑑定時の生年月日の選択で必要 -->

<main class="content_main">
    <div class="main_shadow">
        <section id="header">
            <style>
            .header_background_index {
            max-width: 1000px;
            margin: 0 auto;
            background: url('https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/header/header_background.png');
            background-repeat: no-repeat;
            background-size: 100%;
            position: relative;
        }

        .header_background {
            max-width: 1000px;
            margin: 0 auto;
            background: url('https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/header/header_background_harf.png');
            background-repeat: no-repeat;
            background-size: 100%;
            position: relative;
        }
    
    /*************************************************/
    /* use free items transition navigation section */
    /***********************************************/
    .navigation_background a div {
        width: 100%;
        height: 172px;
    }

    .navigation_background .navigation_menu_links {
        width: 990px;
        height: 180px;
        display: flex;
        justify-content: space-around;
        flex-wrap: wrap;
    }

    .navigation_background .navigation_menu_links a {
        width: 330px;
        height: 176px;
        background-size: 100% 100%;
    }

    .navigation_background .navigation_menu_links img {
        width: 100%;
        height: 100%;
    }

    .navigation_background .navigation_menu_links_minori {
        width: 990px;
        height: 190px;
        display: flex;
        justify-content: space-around;
        flex-wrap: wrap;
    }

    .navigation_background .navigation_menu_links_minori a {
        width: 240px;
        height: 190px;
        background-size: 100% 100%;
    }

    .navigation_background .navigation_menu_links_minori img {
        width: 100%;
        height: 100%;
    }

    /*************************************************/
    /* use each pages tarnsition navigation section */
    /***********************************************/
    .navigation_background .navigation_menu_pages {
        width: 990px;
        height: 110px;
        box-sizing: border-box;
        background: url('https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/header/navigation_background.png') no-repeat;
        display: flex;
        justify-content: center;
        align-items: end;
        flex-wrap: wrap;
    }

    .navigation_background .navigation_menu_pages a {
        width: 270px;
        height: 90px;
        background-size: 100% 100%;
    }

    .navigation_background .navigation_menu_pages img {
        width: 100%;
        height: 100%;
    }

    /******************/
    /* use addcrumbs */
    /****************/
    .addcrumbs_text_section {
        text-align: left;
        color: #ffffff;
        font-size: 1.3rem;
        background-size: 100% 100%;
        background: url('https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/common/section_background.jpg');
        padding: 10px 50px;
    }

    .addcrumbs_text_section a {
        color: #24aaff;
    }

    .addcrumbs_text_section a:hover {
        color: #5b5ff1;
    }
</style>

<!DOCTYPE html>


<header>
    <!-- KV image -->
            <div class="header_background_index">
            <div style="height:415px;"></div>
                    <section id="header" class="section_container">
                <div class="navigation_background">
                    <!-- KV image link range -->
                                                                                    <!---------------------------------------------------->
                        <!-- top free menu transition buttons section start -->
                        <!---------------------------------------------------->
                                                    <div id="free_menu_transition_navigation_minori" class="navigation_menu_links_minori">
                                <a class="navigation_menu_link_button_minori_1" href="/cp_rsa/yumecakra_rsa/pre/free002/"><img loading="lazy" alt='無料恋愛鑑定 あの人の恋愛観＆欲' src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/common/navigation_menu_link_button_minori1.png" onmouseover="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/common/navigation_menu_link_button_minori1_over.png'" onmouseout="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/common/navigation_menu_link_button_minori1.png'"></a>
                                <a class="navigation_menu_link_button_minori_2" href="/cp_rsa/yumecakra_rsa/pre/free005/"><img loading="lazy" alt='無料結婚鑑定 あなたの運命の相手' src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/common/navigation_menu_link_button_minori2.png" onmouseover="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/common/navigation_menu_link_button_minori2_over.png'" onmouseout="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/common/navigation_menu_link_button_minori2.png'"></a>
                                <a class="navigation_menu_link_button_minori_3" href="/cp_rsa/yumecakra_rsa/pre/free003/"><img loading="lazy" alt='無料相性鑑定 2人の絆相性率' src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/common/navigation_menu_link_button_minori3.png" onmouseover="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/common/navigation_menu_link_button_minori3_over.png'" onmouseout="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/common/navigation_menu_link_button_minori3.png'"></a>
                                <a class="navigation_menu_link_button_minori_4" href="/cp_rsa/yumecakra_rsa/pre/free001/"><img loading="lazy" alt='無料人生鑑定 あなたの本性伸びしろ' src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/common/navigation_menu_link_button_minori4.png" onmouseover="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/common/navigation_menu_link_button_minori4_over.png'" onmouseout="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/common/navigation_menu_link_button_minori4.png'"></a>
                            </div>
                        
                        <!-------------------------------------------------->
                        <!-- top free menu transition buttons section end -->
                        <!-------------------------------------------------->
                                        <section id="pageTransitionNavigation">
                        <!------------------------------------------->
                        <!-- page transition buttons section start -->
                        <!------------------------------------------->
                        <div class="navigation_menu_pages">
                                                            <a class="navigation_menu_page_button_left" href="/cp_rsa/yumecakra_rsa/teller/"><img loading="lazy" alt='監修者紹介' src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/header/navigation_button1.png" onmouseover="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/header/navigation_button1_over.png'" onmouseout="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/header/navigation_button1.png'"></a>
                                                                                        <a class="navigation_menu_page_button_center" href="/cp_rsa/yumecakra_rsa/telling/"><img loading="lazy" alt='占術紹介' src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/header/navigation_button2.png" onmouseover="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/header/navigation_button2_over.png'" onmouseout="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/header/navigation_button2.png'"></a>
                                                                                        <a target="_new" class="navigation_menu_page_button_right" href="/cp_rsa/yumecakra_rsa/recommend/"><img loading="lazy" alt='おすすめリンク' src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/header/navigation_button3.png" onmouseover="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/header/navigation_button3_over.png'" onmouseout="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/header/navigation_button3.png'"></a>
                                                    </div>
                        <!----------------------------------------->
                        <!-- page transition buttons section end -->
                        <!----------------------------------------->
                        <!------------------------------>
                        <!-- topic path section start -->
                        <!------------------------------>

                                                    <div id="topicpath" class="addcrumbs_text_section">
                                <p>
                                                                            <a href="/moon/">cocoloni占い館 Moon Top</a>&nbsp;&gt;&nbsp;本州南端の生き神様【ゆめの心々】運命霊視/隠し事暴くチャクラ占い                                                                    </p>
                            </div>
                                                <!------------------------------>
                        <!-- topic path section start -->
                        <!------------------------------>
                    </section>
                </div>
            </section>
            </div><!-- KV image div -->
</header>        </section>
        <section class="section_container section_background">
            <div style="margin: 0px 50px; text-align: center;">
                <!-- text_links 1st -->
                <div style="padding: 2%;">
                    <a href="/cp_rsa/yumecakra_rsa/pre/life001" class="index_text_link link1">あなたの人生に巡りくる運命をチャクラによって視抜きます</a><br>
                    <a href="/cp_rsa/yumecakra_rsa/pre/love001" class="index_text_link link2">あの人が抱く想いも恋心も全て暴きお伝えします</a><br>
                    <a href="/cp_rsa/yumecakra_rsa#topFreeTarotFortuneAnimation" class="index_text_link link3">“今”あの人があなたとの関係に感じている想いをお確かめください</a>
                </div>

                <img loading="lazy" alt="『気持ちが1つにならない』『想いが伝わらない』『思い通りにいかない』それはチャクラのエネルギーがうまく流れていないから。チャクラを霊視で調律し、バランスを整えエネルギーを流せばどんな願いも満願成就します。チャクラ調律師ゆめの心々のチャクラ占い" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/top/top_billboard.jpg" style="width: 100%; height: auto;">
                <img loading="lazy" style="width: 100%;" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/top/line.png">

                <!-- 新着・厳選メニュー -->
                                    <section id="newMenuLinks">
                        <img loading="lazy" alt="『不思議なくらいスラスラ当てる』動画配信で17万いいね獲得※想いを繋げ、気持ちを1つにする※2023年10月時点　株式会社レンサ調べ　TikTok「《癒しの言霊》ゆめの心々」総いいね数より チャクラ調律師ゆめの心々 新着メニュー" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/top/top_menu_list_new_head.jpg" style="width: 100%; vertical-align: bottom;">
                        <div class="top_menu_link_background_center">
                                                            
  <div class="appraisal_menu light">
  <div>
    <img src="https://img.rensa.jp.net/web/RYC/menu/icon_off/icon6.png" class="icon" alt="片想い"/>    <a class="" href="/cp_rsa/yumecakra_rsa/pre/love012/">
      <p>    なかなか距離縮まらないあの人『想い続けて叶う？』本音/転機/恋決着
</p>
    </a>
  </div>
      <p class="description">あなたとあの人の恋には既に「答え」が出ています。ですから、なかなか進展しない関係に悩み続ける必要はありません。恋の成就を叶えるために、あの人への片想いをここで昇華させ、2人の恋の現実を受け止めてください。</p>
    <div class="menu_info">
          <p class="add_day">
        2024年4月11日 公開
      </p>
        <p class="price">
              <span class="common_price">価格 1,650円(税込)</span>
          </p>
  </div>
</div>                                                                                    </div>
                        <img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/top/top_menu_list_bottom.jpg" style="width: 100%; vertical-align: top;">
                    </section>
                                <!-- -->

                <!-- 占術紹介 -->
                <section id="tellingIntroduction">
                    <!-- 占術紹介(TOP,tellingで使用) -->
<img loading="lazy" alt='チャクラ占いは体に存在する7つのチャクラの性質やバランスからその人が歩む運命を視抜くための占術。エネルギーの流れを司るチャクラだからこそ内に秘めた想いも、隠した本性も、分からなくなってしまった本質も、全ての答えを明確に特定しお伝えします。' src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/top/top_telling_billboard.jpg" style="width: 100%;">

<div class="telling_background">
  <!-- telling animation 1st -->
  <img loading="lazy" alt="1.あなた/あの人から視えたチャクラ" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/top/telling_introduction_sample_title1.jpg" style="width: 100%;">
  <p class="telling_description">&emsp;人によって、時期によって異なるチャクラ。それぞれのチャクラを読み解くことで、生まれ持った性格や、周囲に求められていること、心の底にある本質的な願いを明らかにします。</p>

  <!-- vue start -->
  <div id="chakra_telling">
    <chakra-telling />
  </div>
  <!-- vue end -->

  <p class="telling_link_head">↓↓“あなたのチャクラ”からこんなことが分かります↓↓</p>
  <a href="/cp_rsa/yumecakra_rsa/pre/life002" class="telling_bottom_link">あなたの持つ力を存分に活かせる天職</a><br>
  <a href="/cp_rsa/yumecakra_rsa/pre/marriage001" class="telling_bottom_link bottom_space">結婚をすることによって、あなたが得るもの</a>

  <!-- telling animation 2nd -->
  <img loading="lazy" alt="2.あなたとあの人を繫ぐチャクラ" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/top/telling_introduction_sample_title2.jpg" style="width: 100%;">
  <p class="telling_description">&emsp;あなたと「気になるあの人」のチャクラを並べ視ることで、2人の相性はもちろん、今の心の繋がりや、この先の関係性まで知ることができます。あの人との恋の行く先を暴きます。</p>

  <!-- vue start -->
  <div id="chakra_connections">
    <chakra-connections />
  </div>
  <!-- vue end -->

  <p class="telling_link_head">↓↓“2人のチャクラ”からこんなことが分かります↓↓</p>
  <a href="/cp_rsa/yumecakra_rsa/pre/love001" class="telling_bottom_link">あなたとあの人を繫ぐ宿縁</a><br>
  <a href="/cp_rsa/yumecakra_rsa/pre/love006" class="telling_bottom_link bottom_space">2人が恋愛から受ける日々への影響</a>

  <!-- telling animation 3rd -->
  <img loading="lazy" alt="3.チャクラから視えたヴィジョン" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/top/telling_introduction_sample_title3.jpg" style="width: 100%;">
  <p class="telling_description">&emsp;チャクラから巡るエネルギーによって視えた情景や言葉から、あなたに伝えるべきメッセージについてお話しします。チャクラが導く真実をお確かめ下さい。</p>

  <!-- vue start -->
  <div id="chakra_vision">
    <chakra-vision />
  </div>
  <!-- vue end -->

  <p class="telling_link_head">↓↓“チャクラのヴィジョン”からこんなことが分かります↓↓</p>
  <a href="/cp_rsa/yumecakra_rsa/pre/life001" class="telling_bottom_link">この先、あなたを良き方へ導いてくれる重要人物</a><br>
  <a href="/cp_rsa/yumecakra_rsa/pre/love001" class="telling_bottom_link">今、あの人はあなたにとってどんな存在でありたいと考えている？</a>
  <!-- -->
</div>

<img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/top/telling_introduction_sample_bottom.jpg" style="width: 100%;">                </section>
                <!-- -->

                <!-- TOP無料鑑定 -->
                <section id="topFreeTarotFortuneAnimation">
                    <img loading="lazy" alt='ゆめの心々　無料占い 言葉にしない気持ち 表情に出さない感情 そんな内に秘めたあの人の想いも チャクラを霊視することで全て手に取るようにわかります' src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/top/tarot_free_appraisal_menu_head.jpg" style="width: 100%; vertical-align: bottom;">
                    <div class="free_tarot_background">
                        <div class="free_tarot_background_inner">
                            <div class="free_tarot_display">
                                <!-- あの人の誕生日を聞く部分 -->
                                <div class="free_tarot_question">
                                    <p>あの人の生年月日を教えて下さい</p>
                                </div>
                                <!-- あの人の誕生日の入力 -->

                                <form method="post" accept-charset="euc-jp" id="profileForm" name="profileForm" action="/cocoloni/yumecakra_rsa/"><div style="display:none;"><input type="hidden" name="_method" value="POST"/></div>
                                <div class="birthday_select_box free_tarot_birthday_select_box profile-input-background-center" name="birthday">
                                    <div>
                                        <div class="input select"><select name="target_birthday_year" class="year" id="target-birthday-year"><option value="1940">1940</option><option value="1941">1941</option><option value="1942">1942</option><option value="1943">1943</option><option value="1944">1944</option><option value="1945">1945</option><option value="1946">1946</option><option value="1947">1947</option><option value="1948">1948</option><option value="1949">1949</option><option value="1950">1950</option><option value="1951">1951</option><option value="1952">1952</option><option value="1953">1953</option><option value="1954">1954</option><option value="1955">1955</option><option value="1956">1956</option><option value="1957">1957</option><option value="1958">1958</option><option value="1959">1959</option><option value="1960">1960</option><option value="1961">1961</option><option value="1962">1962</option><option value="1963">1963</option><option value="1964">1964</option><option value="1965">1965</option><option value="1966">1966</option><option value="1967">1967</option><option value="1968">1968</option><option value="1969">1969</option><option value="1970">1970</option><option value="1971">1971</option><option value="1972">1972</option><option value="1973">1973</option><option value="1974">1974</option><option value="" selected="selected">--</option><option value="1975">1975</option><option value="1976">1976</option><option value="1977">1977</option><option value="1978">1978</option><option value="1979">1979</option><option value="1980">1980</option><option value="1981">1981</option><option value="1982">1982</option><option value="1983">1983</option><option value="1984">1984</option><option value="1985">1985</option><option value="1986">1986</option><option value="1987">1987</option><option value="1988">1988</option><option value="1989">1989</option><option value="1990">1990</option><option value="1991">1991</option><option value="1992">1992</option><option value="1993">1993</option><option value="1994">1994</option><option value="1995">1995</option><option value="1996">1996</option><option value="1997">1997</option><option value="1998">1998</option><option value="1999">1999</option><option value="2000">2000</option><option value="2001">2001</option><option value="2002">2002</option><option value="2003">2003</option><option value="2004">2004</option><option value="2005">2005</option><option value="2006">2006</option><option value="2007">2007</option><option value="2008">2008</option><option value="2009">2009</option><option value="2010">2010</option><option value="2011">2011</option><option value="2012">2012</option><option value="2013">2013</option><option value="2014">2014</option><option value="2015">2015</option><option value="2016">2016</option><option value="2017">2017</option><option value="2018">2018</option><option value="2019">2019</option><option value="2020">2020</option></select></div>                                        <p class="label">年</p>
                                    </div>
                                    <div>
                                        <div class="input select"><select name="target_birthday_month" class="month" id="target-birthday-month"><option value="1">1</option><option value="2">2</option><option value="3">3</option><option value="4">4</option><option value="5">5</option><option value="6">6</option><option value="" selected="selected">--</option><option value="7">7</option><option value="8">8</option><option value="9">9</option><option value="10">10</option><option value="11">11</option><option value="12">12</option></select></div>                                        <p class="label">月</p>
                                    </div>
                                    <div>
                                        <div class="input select"><select name="target_birthday_day" class="day" id="target-birthday-day"><option value="1">1</option><option value="2">2</option><option value="3">3</option><option value="4">4</option><option value="5">5</option><option value="6">6</option><option value="7">7</option><option value="8">8</option><option value="9">9</option><option value="10">10</option><option value="11">11</option><option value="12">12</option><option value="13">13</option><option value="14">14</option><option value="15">15</option><option value="" selected="selected">--</option><option value="16">16</option><option value="17">17</option><option value="18">18</option><option value="19">19</option><option value="20">20</option><option value="21">21</option><option value="22">22</option><option value="23">23</option><option value="24">24</option><option value="25">25</option><option value="26">26</option><option value="27">27</option><option value="28">28</option><option value="29">29</option><option value="30">30</option><option value="31">31</option></select></div>                                        <p class="label">日</p>
                                    </div>
                                </div>

                                                                    <div class="cookie_info" style="display: none;">
                                        <p>入力した情報を記録しますか？</p>
                                        <div class="cookie_check">
                                            <label><input class="cookie-input" id="checkbox" name="cwflg" value="ok" type="checkbox" checked=""><span class="cookie-label">記録する</span></label>

                                            <div class="input button"><label for="ji-luwo-xue-chusuru"></label><button type="button" onclick="resetCookie()" id="ji-luwo-xue-chusuru">記録を削除する</button></div>                                        </div>
                                    </div>
                                                                </form>
                                <!-- 鑑定ボタン -->
                                <div id="free_tarot_button">
                                    <img loading="lazy" alt='今、あの人が抱いている想いを視抜きます（無料で鑑定頂けます）' src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/form/select_item_appraisal_part_free_button_second.png" onmouseover="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/form/select_item_appraisal_part_free_button_second_over.png'" onmouseout="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/form/select_item_appraisal_part_free_button_second.png'">
                                </div>
                            </div>

                            <!-- 鑑定中テキスト start -->
                            <div class="loading_text_box">
                                <p id="loading_text">鑑定中</p>
                            </div>

                            <!-- アニメーション部分 -->
                            <div id="free_tarot_teller_box" class="free_tarot_box">
                                <!-- 占い師の画像 -->
                                <div class="free_tarot_teller_image">
                                    <!-- 占い師のコメント -->
                                    <div id="free_tarot_teller_comment" class="free_tarot_teller_comment_box">
                                        <p>
                                            第7チャクラから<br>
                                            あの人の内なる想いを<br>
                                            視抜きます
                                        </p>
                                    </div>

                                    <!-- チャクラの画像 -->
                                    <div id="free_tarot_chakra_image" class="chakra_image_box">
                                        <img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/motif/type1/res_type1_701.png">
                                    </div>
                                </div>
                            </div>
                            <!-- アニメーション部分 end -->
                        </div>
                    </div>

                    <!-- スライドダウン後に表示 -->
                    <div id="top_free_tarot_animation_text" class="free_tarot_background_over" name="free_tarot_background_over">
                        <div class="top_free_tarot_result_text_box">
                            <!-- 結果原稿は jQuery で操作 -->
                            <div id="free_tarot_result_text_box" class="free_tarot_result_text"></div>
                            <!-- リンクのテキストや path は jQuery で操作 -->
                            <div id="top_free_tarot_result_menu_link"></div>
                        </div>
                        <img loading="lazy" alt='ここまで、あの人があなたに感じている気持ちをお伝えしました。 あなたとあの人を結ぶ縁の正体 あの人と想いは1つになるのか この恋は成就するのか…… 霊的エネルギーをチャクラ調律すれば確実に恋成就へと進みます。' src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/top/tarot_free_appraisal_menu_teller_background.jpg" style="width: 100%">
                        <div class="top_free_tarot_appraisal_menu_box">
                                                            
  <div class="appraisal_menu">
  <div>
    <img src="https://img.rensa.jp.net/web/RYC/menu/icon_off/icon1.png" class="icon" alt="宿縁"/>    <a class="" href="/cp_rsa/yumecakra_rsa/pre/love001/">
      <p>    2人の恋心/強制成就【ゆめの心々◆宿縁霊視30項】本心/転機/関係最後
</p>
    </a>
  </div>
      <p class="description">恋愛占い｜あなたとあの人のチャクラから、2人の繋がりと関係性を知ることができます。お互いのチャクラがどれだけ惹かれ合い結ばれているのか、この先どこまで愛を深めることができるのか……2人だけが持つ宿縁を、余すところなくお伝えしていきます。</p>
    <div class="menu_info">
        <p class="price">
              <span class="common_price">価格 3,740円(税込)</span>
          </p>
  </div>
</div>                                <img loading="lazy" style="width: 100%; margin: 2% 0;" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/top/line.png">                                                            
  <div class="appraisal_menu">
  <div>
    <img src="https://img.rensa.jp.net/web/RYC/menu/icon_off/icon7.png" class="icon" alt="あの人の気持ち"/>    <a class="" href="/cp_rsa/yumecakra_rsa/pre/love003/">
      <p>    考えも想いもマルわかり【あの人の全てを知る霊視】存在 /恋心/決断
</p>
    </a>
  </div>
      <p class="description">恋愛チャクラ占い｜恋は盲目というように、恋をすると「その人」しか目に映らなくなることがあります。あの人があなたに向けている願望や、心の奥底に秘めた想い、この先の関係への望み……あの人が持つチャクラから胸の内を明らかにしましょう。その全てを知って受け止めて下さい。</p>
    <div class="menu_info">
        <p class="price">
              <span class="common_price">価格 2,750円(税込)</span>
          </p>
  </div>
</div>                                <img loading="lazy" style="width: 100%; margin: 2% 0;" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/top/line.png">                                                            
  <div class="appraisal_menu">
  <div>
    <img src="https://img.rensa.jp.net/web/RYC/menu/icon_off/icon4.png" class="icon" alt="復縁"/>    <a class="" href="/cp_rsa/yumecakra_rsa/pre/love005/">
      <p>    どんな別れ方でも修復【諦めきれない恋心を救済鑑定】現状/未練/結末
</p>
    </a>
  </div>
      <p class="description">復縁占い｜一度は違う道を進むと決めたあなたとあの人。しかし、どうしても忘れられない相手というのは、運命的な縁で結ばれているのです。2人が再接近する日も遠くありません。あなたがお別れをしたあの人と縁を結び直し、2人の関係を修復していきます。</p>
    <div class="menu_info">
        <p class="price">
              <span class="common_price">価格 1,980円(税込)</span>
          </p>
  </div>
</div>                                <img loading="lazy" style="width: 100%; margin: 2% 0;" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/top/line.png">                                                            
  <div class="appraisal_menu">
  <div>
    <img src="https://img.rensa.jp.net/web/RYC/menu/icon_off/icon3.png" class="icon" alt="苦しい恋"/>    <a class="" href="/cp_rsa/yumecakra_rsa/pre/love007/">
      <p>    進展皆無の恋【距離感じるあの人の態度理由を霊視】2人の誤解⇒解消
</p>
    </a>
  </div>
      <p class="description">会話や仕草の節々から心の距離を感じるあの人。それはあなたが恋愛対象外ということの意志表示なのでしょうか。あの人が言葉にしない想いをチャクラから読み取ります。普段のあなたに対する態度には、2人の関係に対する感情が視えてきました。</p>
    <div class="menu_info">
        <p class="price">
              <span class="common_price">価格 1,320円(税込)</span>
          </p>
  </div>
</div>                                <img loading="lazy" style="width: 100%; margin: 2% 0;" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/top/line.png">                                                            
  <div class="appraisal_menu">
  <div>
    <img src="https://img.rensa.jp.net/web/RYC/menu/icon_off/icon6.png" class="icon" alt="片想い"/>    <a class="" href="/cp_rsa/yumecakra_rsa/pre/love009/">
      <p>    『あの人と交際できる？』片想いの結末まで解明◆2人の絆/本音/変化
</p>
    </a>
  </div>
      <p class="description">あの人から何らかのアクションがあれば、あなたもこんなにヤキモキすることはないでしょう。もしあなたから想いを伝えたら……あの人はどんな反応を見せてくれるのか。2人の関係を進めるために、今のあなただからできることをお伝えしましょう。</p>
    <div class="menu_info">
        <p class="price">
              <span class="common_price">価格 1,100円(税込)</span>
          </p>
  </div>
</div>                                                                                    </div>
                    </div>
                    <img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/top/tarot_free_appraisal_menu_bottom.jpg" style="width: 100%; vertical-align: top;">
                </section>

                <script>
                    function topFreeTarotAnimation(resultText, linkText, linkItemcd, resetLoop) {
                        // 「鑑定中のループを抜ける処理」
                        clearTimeout(resetLoop);

                                                // 結果原稿の挿入
                        $(".free_tarot_result_text").html(resultText);

                        // 誘導リンク（楽天・みのり・うらなえる・cocoloni　の設定のみ完了）
                                                                                    $("#top_free_tarot_result_menu_link").append(
                                    $("<a>")
                                    .attr({
                                        class: "top_free_tarot_link_text",
                                        href: "https://honkaku-uranai.jp/cp_rsa/yumecakra_rsa/pre/" + linkItemcd
                                    })
                                    .html(linkText)
                                );
                                                    
                        // アニメーション
                        $(".loading_text_box").css("display", "none");
                        setTimeout(() => {
                            $("#free_tarot_teller_box").fadeIn(500);
                            setTimeout(() => {
                                $("#free_tarot_teller_comment").fadeOut(500);
                                setTimeout(() => {
                                    $("#free_tarot_chakra_image").fadeIn(500);
                                    $("#free_tarot_result_text_box").slideDown(500);
                                    setTimeout(() => {
                                        $("*[name=free_tarot_background_over]").slideDown(500);
                                    }, 500);
                                }, 500);
                            }, 1500);
                        }, 300);
                    }

                    // アニメーションの発火
                    $("#free_tarot_button").on("click", function() {
                        let paymentSystemName = "cocoloni";
                        let freeTarotPostUrl = "";
                        let inputBirthday = $("select[name='target_birthday_year']").val() + "-" + ("00" + $("select[name='target_birthday_month']").val()).slice(-2) + "-" + ("00" + $("select[name='target_birthday_day']").val()).slice(-2);

                        let t_year = $("select[name='target_birthday_year']").val();
                        let t_month = $("select[name='target_birthday_month']").val();
                        let t_day = $("select[name='target_birthday_day']").val();

                        //値が空の時
                        if (t_year === "" || t_month === "" || t_day === "") {
                            alert("あの人の生年月日を正しく入力してください。");
                        } else {
                            // 鑑定ボタン等の非表示
                            $(".free_tarot_question, .free_tarot_birthday_select_box, #free_tarot_button").css("display", "none");
                            // 「鑑定中」のテキスト
                            $(".loading_text_box").fadeIn(500);
                            const addText = "・・・";
                            let counter = 1;
                            let loadingText = "";
                            let resetLoop = "";

                            function loading() {
                                letter = addText.slice(0, counter++);
                                $("#loading_text").text("鑑定中" + letter);
                                if (letter.length === addText.length) {
                                    counter = 0;
                                }
                                resetLoop = setTimeout(loading, 500);
                            }
                            loading();

                            if (paymentSystemName !== "minori") {
                                // 入力補助
                                actSubmit($(this).siblings("form"));
                            }

                            // 楽天
                            if (location.hostname.includes("happyfortune") !== false || (location.hostname.includes("localhost") !== false && location.href.includes("rakuten") !== false)) {
                                freeTarotPostUrl = location.protocol + "/yumecakra/rakuten/result/love900";
                                $.ajax({
                                    type: "post",
                                    url: freeTarotPostUrl,
                                    data: {
                                        "isFreeTarot": true,
                                        "itemcd": "love900",
                                        "full_name": "あ",
                                        "birthday": "1980-04-01",
                                        "gender": "F",
                                        "target_full_name": "あ",
                                        "target_birthday": inputBirthday,
                                        "target_gender": "M",
                                        "TerminalModel": "pc",
                                    },
                                    dataType: "html"
                                }).done(function(data) {
                                    const domParser = new DOMParser();
                                    const parseHtml = domParser.parseFromString(data, "text/html");

                                    // 結果のテキスト
                                    const topFreeTarotResultText = parseHtml.getElementById("free_result_text").innerHTML;
                                    // 誘導リンクのテキスト
                                    const topFreeTarotLinkText = parseHtml.getElementById("free_result_link_text").innerHTML;
                                    // 誘導リンクの itemcd
                                    const topFreeTarotLinkItemcd = parseHtml.getElementById("free_result_link_itemcd").innerHTML;

                                    topFreeTarotAnimation(topFreeTarotResultText, topFreeTarotLinkText, topFreeTarotLinkItemcd, resetLoop);
                                }).fail(function() {
                                    alert("通信に失敗しました");
                                });
                                // みのり
                            } else if (paymentSystemName == "minori") {
                                if (location.href.match("localhost")) {
                                    freeTarotPostUrl = "http://localhost/yumecakra/minori/result/love900";
                                } else if (location.href.match("dev")) {
                                    freeTarotPostUrl = "https://dev.rensa.jp.net/premium_fortune/portal/cp_ren/174/yumecakra/result/love900";
                                } else {
                                    freeTarotPostUrl = "https://rensa.jp.net/premium_fortune/portal/cp_ren/174/yumecakra/result/love900";
                                }
                                $.ajax({
                                    type: "post",
                                    url: freeTarotPostUrl,
                                    data: {
                                        "isFreeTarot": true,
                                        "itemcd": "love900",
                                        "full_name": "あ",
                                        "birthday": "1980-04-01",
                                        "gender": "F",
                                        "target_full_name": "あ",
                                        "target_birthday": inputBirthday,
                                        "target_gender": "M",
                                        "TerminalModel": "pc",
                                        "isNomalPayment": true,
                                        "howToBuy": "partlyAppraisalButton",
                                        "channel": "love900",
                                    },
                                    dataType: "html"
                                }).done(function(data) {
                                    const domParser = new DOMParser();
                                    const parseHtml = domParser.parseFromString(data, "text/html");

                                    // 結果のテキスト
                                    const topFreeTarotResultText = parseHtml.getElementById("free_result_text").innerHTML;
                                    // 誘導リンクのテキスト
                                    const topFreeTarotLinkText = parseHtml.getElementById("free_result_link_text").innerHTML;
                                    // 誘導リンクの itemcd
                                    const topFreeTarotLinkItemcd = parseHtml.getElementById("free_result_link_itemcd").innerHTML;

                                    topFreeTarotAnimation(topFreeTarotResultText, topFreeTarotLinkText, topFreeTarotLinkItemcd, resetLoop);
                                }).fail(function() {
                                    alert("通信に失敗しました");
                                });
                                // うらなえる
                            } else if (paymentSystemName == "fortune-premium") {
                                freeTarotPostUrl = location.href.replace("#topFreeTarotFortuneAnimation", "") + '/result/love900';
                                $.ajax({
                                    type: "post",
                                    url: freeTarotPostUrl,
                                    data: {
                                        "itemcd": "love900",
                                        "full_name": "あ",
                                        "birthday": "1980-04-01",
                                        "gender": "F",
                                        "target_full_name": "あ",
                                        "target_birthday": inputBirthday,
                                        "target_gender": "M",
                                        "TerminalModel": "pc",
                                        "isNomalPayment": true,
                                        "howToBuy": "partlyAppraisalButton",
                                        "channel": "love900",
                                    },
                                    dataType: "html"
                                }).done(function(data) {
                                    const domParser = new DOMParser();
                                    const parseHtml = domParser.parseFromString(data, "text/html");

                                    // 結果のテキスト
                                    const topFreeTarotResultText = parseHtml.getElementById("free_result_text").innerHTML;
                                    // 誘導リンクのテキスト
                                    const topFreeTarotLinkText = parseHtml.getElementById("free_result_link_text").innerHTML;
                                    // 誘導リンクの itemcd
                                    const topFreeTarotLinkItemcd = parseHtml.getElementById("free_result_link_itemcd").innerHTML;

                                    topFreeTarotAnimation(topFreeTarotResultText, topFreeTarotLinkText, topFreeTarotLinkItemcd, resetLoop);
                                }).fail(function() {
                                    alert("通信に失敗しました");
                                });
                                // それ以外
                            } else {
                                if (location.href.match("localhost")) {
                                    freeTarotPostUrl = "http://localhost/cocoloni/yumecakra_rsa/result/love900";
                                } else if (location.href.match("test-honkaku")) {
                                    freeTarotPostUrl = "https://test-honkaku.cocoloni.jp/cp_rsa/yumecakra_rsa/result/love900";
                                } else {
                                    freeTarotPostUrl = "https://honkaku-uranai.jp/cp_rsa/yumecakra_rsa/result/love900";
                                }
                                $.ajax({
                                    type: "post",
                                    url: freeTarotPostUrl,
                                    data: {
                                        "itemcd": "love900",
                                        "full_name": "あ",
                                        "birthday": "1980-04-01",
                                        "gender": "F",
                                        "target_full_name": "あ",
                                        "target_birthday": inputBirthday,
                                        "target_gender": "M",
                                        "TerminalModel": "pc",
                                        "isNomalPayment": true,
                                        "howToBuy": "partlyAppraisalButton",
                                        "channel": "love900",
                                    },
                                    dataType: "html"
                                }).done(function(data) {
                                    const domParser = new DOMParser();
                                    const parseHtml = domParser.parseFromString(data, "text/html");

                                    // 結果のテキスト
                                    const topFreeTarotResultText = parseHtml.getElementById("free_result_text").innerHTML;
                                    // 誘導リンクのテキスト
                                    const topFreeTarotLinkText = parseHtml.getElementById("free_result_link_text").innerHTML;
                                    // 誘導リンクの itemcd
                                    const topFreeTarotLinkItemcd = parseHtml.getElementById("free_result_link_itemcd").innerHTML;

                                    topFreeTarotAnimation(topFreeTarotResultText, topFreeTarotLinkText, topFreeTarotLinkItemcd, resetLoop);
                                }).fail(function() {
                                    alert("通信に失敗しました");
                                });
                            }
                        }
                    });
                </script>
                <!-- -->

                <!-- 人生鑑定フォーム -->
                <section id="lifePartialAppraisalFreeForm">
                    <img loading="lazy" alt='答えはあなたの中にあります 体に宿るチャクラの巡りを視抜き今迎えている運勢、周囲からの影響、この先の成功まで特定 あなたが歩むべき運命の詳細をお伝えします。' src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/top/top_appraisal_form_billboard.jpg" style="margin-left: -1.9%; vertical-align: bottom;">
                        <script src="https://web-img.rensa.jp.net/rensa/images/web/common_files/js/cookie-retention.js"></script>
<!-- form入力の警告をするためのjs -->
    <script src="https://web-img.rensa.jp.net/rensa/images/web/Cocoloni/common/js/formValidate.js"></script><!-- -->

<style>
    .profile-input-background-center.for-style {
        background: url("https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/form/content_menu_list_background.jpg") repeat-y;
        background-position: center;
        font-weight: bold;
        color: #000000;
    }

    /***********************************/
    /* use input font size Adjustment */
    /*********************************/
    .profile-input-background-center.for-style select {
        font-family: "ヒラギノ明朝 ProN W6", "HiraMinProN-W6", "HG明朝E", "ＭＳ Ｐ明朝", "MS PMincho", "MS 明朝", serif;
        font-weight: bold;
        letter-spacing: 0.05rem;
        font-size: 1.8rem;
        line-height: 140%;
        height: 45px;
    }

    .profile-input-background-center.for-style input {
        font-size: 1.8rem;
        line-height: 140%;
    }

    .profile-input-background-center.for-style input:-webkit-autofill {
        box-shadow: 0 0 0 100px #ffffff inset;
        -webkit-text-fill-color: #000000;
    }

    /***************************/
    /* use input name section */
    /**************************/
    .profile_input_area {
        padding: 0 8%;
        display: flex;
        flex-flow: column;
    }

    .profile_input_area p {
        font-family: "ヒラギノ明朝 ProN W6", "HiraMinProN-W6", "HG明朝E", "ＭＳ Ｐ明朝", "MS PMincho", "MS 明朝", serif;
        letter-spacing: 0.05rem;
    }

    .label {
        font-size: 1.8rem;
        line-height: 140%;
    }

    .note {
        font-size: 1.3rem;
        width: 90%;
        margin: 2% auto 2% 17%;
        text-align: left;
        line-height: 140%;
    }

    .note span {
        color: #983030;
    }

    /* 名前入力欄 */
    .full_name_input_box {
        display: flex;
        gap: 1%;
        margin-left: 3.5%;
        align-items: center;
    }

    #full-name,
    #target-full-name {
        font-family: "ヒラギノ明朝 ProN W6", "HiraMinProN-W6", "HG明朝E", "ＭＳ Ｐ明朝", "MS PMincho", "MS 明朝", serif;
        letter-spacing: 0.05rem;
        width: 300px;
        font-weight: bold;
    }

    /* 生年月日入力欄 */
    .birthday_select_box,
    .birthday_select_box div {
        display: flex;
        align-items: center;
        gap: 1%;
    }

    .birthday_select_box select {
        width: 160px;
    }

    /* 性別選択欄 */
    .sex_input_box {
        display: flex;
        align-items: center;
        margin-left: 7.3%;
        gap: 2%;
    }

    .sex_input_box>div {
        display: flex;
        align-items: flex-end;
        width: 17%;
    }

    #gender,
    #target-gender {
        width: 120px;
    }

    /* formボタン共通 */
    .form_branch_btn_area {
        display: flex;
        justify-content: center;
        max-height: 150px;
        margin-top: 2%;
    }

    .form_branch_btn_area button {
        width: 390px;
        height: 130px;
        padding: 0;
        border: none;
        outline: none;
        cursor: pointer;
    }

    .form_branch_btn_area button img {
        width: 100%;
        height: 100%;
        border: none;
    }

    /* anokimo button */
    .submit_branch_button_second {
        background-size: 100% 100%;
    }

    /* payment button */
    .submit_pay_image {
        background-size: 100% 100%;
    }

    /* partry free button */
    .submit_part_free_image {
        background-size: 100% 100%;
    }

    /* free button */
    .submit_free_image {
        background-size: 100% 100%;
    }


    /* checkbox */
    .cookie_check label,
    .cookie_info p,
    .cookie_check button {
        color: #000000;
        font-family: "ヒラギノ明朝 ProN W6", "HiraMinProN-W6", "HG明朝E", "MS P明朝", "MS PMincho", "MS 明朝", serif;
    }

    .cookie_check label {
        padding-right: 5px;
        font-size: 1rem;
    }

    .cookie_check button {
        background-color: #efefef;
        border: solid 1px #767676;
        border-radius: 2px;
    }

    .cookie_check button:hover {
        background-color: #d6d6d6;
    }

    .cookie_check {
        display: flex;
    }

    .cookie_check {
        align-items: center;
    }

    .cookie_info {
        font-size: 1rem;
    }

    .cookie_check {
        justify-content: center;
        gap: 30px;
    }

    .cookie-input {
        min-width: auto;
    }

    .cookie-label {
        padding-left: 10px;
        color: #000;
    }

    /* ----- */
</style>

<form method="post" accept-charset="euc-jp" id="profileForm" name="profileForm" action="/cocoloni/yumecakra_rsa/"><div style="display:none;"><input type="hidden" name="_method" value="POST"/></div><input type="hidden" name="itemcd" value="life001"/><input type="hidden" name="contentKey" value="CYC"/><input type="hidden" name="howToBuy" value="freeAppraisalButton"/><input type="hidden" name="TerminalModel" value="pc"/><input type="hidden" name="retensionResultDataId" value=""/><input type="hidden" name="time" value=""/><input type="hidden" name="zp_channel_id" value="105_yc0004a"/><div class="profile-input-background-center for-style" id="profileSection">
            <!-- appraisal item information display start -->
        <div style="padding: 20px 65px 0;">
            
  <div class="appraisal_menu light">
  <div>
    <img src="https://img.rensa.jp.net/web/RYC/menu/icon_off/icon12.png" class="icon" alt="人生"/>    <a class="" href="/cp_rsa/yumecakra_rsa/pre/life001/">
      <p>    人生掌握【ゆめの心々渾身】あなたの全運命を霊視◆1年⇒10年後/晩年
</p>
    </a>
  </div>
      <p class="description">チャクラ占い｜目には見えない人の運命。しかし、人の体にあるチャクラとそこから流れるエネルギーを視れば、その詳細を知ることができるのです。あなたのチャクラのエネルギーから、あなただけに与えられた運命、歩んでいく人生の詳細を明らかにしていきましょう。</p>
    <div class="menu_info">
        <p class="price">
              <span class="common_price">価格 3,740円(税込)</span>
          </p>
  </div>
</div>        </div>
        <!-- appraisal item information display end -->
        <img loading="lazy" alt="あなたについて教えてください" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/form/input_form_my_head.png" style="width: 100%; margin: 0 auto;">
    <div class="profile_input_area">

        <!-------------------------->
        <!-- あなたの名前入力ここから -->
        <!-------------------------->
                    <div class="full_name_input_box">
                <p class="label">お名前</p>
                <div class="input text"><input type="text" name="full_name" maxlength="8" id="full-name"/></div>            </div>
            <p class="note">※「お名前」は、全角8文字以内の「ひらがな」「カタカナ」<br>「漢字」で入力ください。</p>
                <!-------------------------->
        <!-- あなたの名前入力ここまで -->
        <!-------------------------->

        <!---------------------------->
        <!-- あなたの誕生日入力ここから -->
        <!---------------------------->
                            <div class="birthday_select_box" id="birthday" name="birthday">
                <p class="label">生年月日</p>
                <div>
                    <div>
                        <div class="input select"><select name="birthday_year" class="year" id="birthday-year"><option value="1940">1940</option><option value="1941">1941</option><option value="1942">1942</option><option value="1943">1943</option><option value="1944">1944</option><option value="1945">1945</option><option value="1946">1946</option><option value="1947">1947</option><option value="1948">1948</option><option value="1949">1949</option><option value="1950">1950</option><option value="1951">1951</option><option value="1952">1952</option><option value="1953">1953</option><option value="1954">1954</option><option value="1955">1955</option><option value="1956">1956</option><option value="1957">1957</option><option value="1958">1958</option><option value="1959">1959</option><option value="1960">1960</option><option value="1961">1961</option><option value="1962">1962</option><option value="1963">1963</option><option value="1964">1964</option><option value="1965">1965</option><option value="1966">1966</option><option value="1967">1967</option><option value="1968">1968</option><option value="1969">1969</option><option value="1970">1970</option><option value="1971">1971</option><option value="1972">1972</option><option value="1973">1973</option><option value="1974">1974</option><option value="" selected="selected">--</option><option value="1975">1975</option><option value="1976">1976</option><option value="1977">1977</option><option value="1978">1978</option><option value="1979">1979</option><option value="1980">1980</option><option value="1981">1981</option><option value="1982">1982</option><option value="1983">1983</option><option value="1984">1984</option><option value="1985">1985</option><option value="1986">1986</option><option value="1987">1987</option><option value="1988">1988</option><option value="1989">1989</option><option value="1990">1990</option><option value="1991">1991</option><option value="1992">1992</option><option value="1993">1993</option><option value="1994">1994</option><option value="1995">1995</option><option value="1996">1996</option><option value="1997">1997</option><option value="1998">1998</option><option value="1999">1999</option><option value="2000">2000</option><option value="2001">2001</option><option value="2002">2002</option><option value="2003">2003</option><option value="2004">2004</option><option value="2005">2005</option><option value="2006">2006</option><option value="2007">2007</option><option value="2008">2008</option><option value="2009">2009</option><option value="2010">2010</option><option value="2011">2011</option><option value="2012">2012</option><option value="2013">2013</option><option value="2014">2014</option><option value="2015">2015</option><option value="2016">2016</option><option value="2017">2017</option><option value="2018">2018</option><option value="2019">2019</option><option value="2020">2020</option></select></div>                        <p class="label">年</p>
                    </div>
                    <div>
                        <div class="input select"><select name="birthday_month" class="month" id="birthday-month"><option value="1">1</option><option value="2">2</option><option value="3">3</option><option value="4">4</option><option value="5">5</option><option value="6">6</option><option value="" selected="selected">--</option><option value="7">7</option><option value="8">8</option><option value="9">9</option><option value="10">10</option><option value="11">11</option><option value="12">12</option></select></div>                        <p class="label">月</p>
                    </div>
                    <div>
                        <div class="input select"><select name="birthday_day" class="day" id="birthday-day"><option value="1">1</option><option value="2">2</option><option value="3">3</option><option value="4">4</option><option value="5">5</option><option value="6">6</option><option value="7">7</option><option value="8">8</option><option value="9">9</option><option value="10">10</option><option value="11">11</option><option value="12">12</option><option value="13">13</option><option value="14">14</option><option value="15">15</option><option value="" selected="selected">--</option><option value="16">16</option><option value="17">17</option><option value="18">18</option><option value="19">19</option><option value="20">20</option><option value="21">21</option><option value="22">22</option><option value="23">23</option><option value="24">24</option><option value="25">25</option><option value="26">26</option><option value="27">27</option><option value="28">28</option><option value="29">29</option><option value="30">30</option><option value="31">31</option></select></div>                        <p class="label">日</p>
                    </div>
                </div>
            </div>
            <p class="note"><span>※必須</span></p>
                <!---------------------------->
        <!-- あなたの誕生日入力ここまで -->
        <!---------------------------->

        <!-------------------------->
        <!-- あなたの性別入力ここから -->
        <!-------------------------->
                    <div class="sex_input_box">
                <p class="label">性別</p>
                                    <div class="input select"><select name="gender" id="gender"><option value="F" selected="selected">女性</option><option value="M">男性</option></select></div>                    <p class="label">で占う</p>
                            </div>
                            <p class="note"><span>※必須</span></p>
                            <!-------------------------->
        <!-- あなたの性別入力ここまで -->
        <!-------------------------->
    </div>

        <!------------------------------>
    <!-- Cookie入力情報の削除ここから -->
    <!------------------------------>
            <div class="cookie_info">
            <p>入力した情報を記録しますか？</p>
            <div class="cookie_check">
                <label><input class="cookie-input" id="checkbox" name="cwflg" value="ok" type="checkbox" checked=""><span class="cookie-label">記録する</span></label>

                <div class="input button"><label for="ji-luwo-xue-chusuru"></label><button type="button" onclick="resetCookie()" id="ji-luwo-xue-chusuru">記録を削除する</button></div>            </div>
        </div>
        <!------------------------------>
    <!-- Cookie入力情報の削除ここから -->
    <!------------------------------>
    <!--------------------->
    <!-- 遷移ボタンここから -->
    <!--------------------->
    <div class="form_branch_btn_area">
                    <!-- 引数で $branchTransitionMenu が渡されていない場合の処理 itemcd に対応して遷移する。-->
                            <!-- 一部無料ボタン -->
                <button type="button" class="submit_part_free_image" name="partlyAppraisalButton1" id="" value="life001and105_yc0004a" onclick="formButtonPrecess($(this));">
                    <img loading="lazy" alt="一部無料で鑑定" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/form/appraisal_part_free_button.png" onmouseover="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/form/appraisal_part_free_button_over.png'" onmouseout="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/form/appraisal_part_free_button.png'">
                </button>
                <!-- 有料ボタン -->
                <button type="button" class="submit_pay_image" name="paymentAppraisalButton1" id="" value="life001and105_yc0004a">
                    <img loading="lazy" alt="鑑定する（有料）" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/form/appraisal_pay_button.png" onmouseover="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/form/appraisal_pay_button_over.png'" onmouseout="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/form/appraisal_pay_button.png'">
                </button>
                        </div>
    <script>
        $("form").keydown(function(e) {
            if ((e.which && e.which === 13) || (e.keyCode && e.keyCode === 13)) {
                return false;
            } else {
                return true;
            }
        });

        var paymentSystemName = 'cocoloni';
        var paymentMetaData = [{"count":1,"method":"post","parameterName":"zp_channel_id","paymentUrl":"https:\/\/zap-happyfortune.rensa.jp.net\/cocoloni\/yumecakra_rsa\/result\/","partlyUrl":"https:\/\/honkaku-uranai.jp\/cp_rsa\/yumecakra_rsa\/result\/","freeUrl":"https:\/\/honkaku-uranai.jp\/cp_rsa\/yumecakra_rsa\/result\/life001","ids":"105_yc0004a","itemcd":"life001","price":3740,"premium_price":2700,"addCrumbPreUrl":"\/cocoloni\/yumecakra_rsa\/pre\/life001"}];

        function formButtonPrecess(button) {
            let settlementCodeDatas = button.attr("value").split("and")
            let howToBuy = button.attr("name")
            let buttonName = button.context.name;
            if (paymentSystemName == "minori") {
                var formId = button.attr("name").slice(-1);
                var partlyUrl = document.getElementsByName("partlyUrl" + formId)[0].innerHTML;
            }

            if (formValidate(button.parents("form"), 8, false)) {
                $("[name=itemcd]").val(settlementCodeDatas[0])
                buttonName.indexOf("anokimoPartlyAppraisalButton") !== -1 ? $("[name=howToBuy]").val('partlyAppraisalButton') : $("[name=howToBuy]").val(howToBuy);
                if (paymentSystemName !== "minori") {
                    actSubmit(button.parents("form"));
                }
                if (paymentSystemName == "cocoloni" || paymentSystemName == "cp_rsa" || paymentSystemName == "fortune-premium") {
                    $("[name=zp_channel_id]").val(settlementCodeDatas[1])
                    document.charset = 'euc-jp'
                }
                button.parents("form").attr("method", "post")
                if (buttonName.indexOf("freeAppraisalButton") !== -1) {
                    button.parents("form").attr("action", "https://honkaku-uranai.jp/cp_rsa/yumecakra_rsa/result/life001/").submit();
                } else if (paymentSystemName == "minori") {
                    button.parents("form").attr("action", partlyUrl).submit();
                } else {
                    button.parents("form").attr("action", "https://honkaku-uranai.jp/cp_rsa/yumecakra_rsa/result/" + settlementCodeDatas[0] + "/").submit();
                }
            }
        };

        // payment appraisal button js
        var isProcessing = false;
        var btnCount = $(".form_branch_btn_area").length;
        window.onpageshow = function() {
            for (let i = 1; i <= btnCount; i++) {
                $('button[name=paymentAppraisalButton' + i + ']').prop("disabled", false);
            }
        }
        $('button[name=paymentAppraisalButton1]').on('click', function() {
            if (formValidate($(this).parents("form"), 8, false)) {
                var btn = $('button[name=paymentAppraisalButton1]')
                btn.prop("disabled", true);
                if (paymentSystemName == "minori") {
                    // みのり 用に遷移元を ローカルストレージへ保存
                    localStorage.setItem('backUrl', location.href);
                }
                if (paymentSystemName !== "minori") {
                    actSubmit($(this).parents("form"));
                }
                if (paymentSystemName == "cocoloni" || paymentSystemName == "cp_rsa" || paymentSystemName == "fortune-premium") {
                    document.charset = 'euc-jp'
                }
                var settlementCodeDatas = $(this).attr("value").split("and")
                var howToBuy = $(this).attr("name")
                var parameterName = "zp_channel_id";
                                    var $JudgmentGender = $(this).parents("form").find("select[name='gender']").val()
                                var gender = $JudgmentGender
                var fullName = $(this).parents("form").find("input[name='full_name']").val()
                var targetGender = $(this).parents("form").find('select[name=target_gender]').val()
                var targetFullName = $(this).parents("form").find("input[name='target_full_name']").val()
                var birthday = $(this).parents("form").find("select[name='birthday_year']").val() + "-" + ('00' + $(this).parents("form").find("select[name='birthday_month']").val()).slice(-2) + "-" + ('00' + $(this).parents("form").find("select[name='birthday_day']").val()).slice(-2)
                var targetBirthday = $(this).parents("form").find("select[name='target_birthday_year']").val() + "-" + ('00' + $(this).parents("form").find("select[name='target_birthday_month']").val()).slice(-2) + "-" + ('00' + $(this).parents("form").find("select[name='target_birthday_day']").val()).slice(-2)
                $("[name=itemcd]").val(settlementCodeDatas[0])
                $("[name=howToBuy]").val(howToBuy)

                if (paymentSystemName == "minori") {
                    // みのり 用に遷移元を ローカルストレージへ保存
                    localStorage.setItem('backUrl', location.href);
                    var url = location.href;
                    var env = url.match("dev") ? 'https://dev.rensa.jp.net' : 'https://rensa.jp.net'
                    $.ajax({
                        type: "POST",
                        url: env + "https://honkaku-uranai.jp/cp_rsa/yumecakra_rsa/result/life001", //本番環境用
                        // url: "http://localhost/yumecakra/minori/result/love001",//テスト用
                        data: {
                            "isNomalPayment": true,
                            "itemcd": settlementCodeDatas[0],
                            "howToBuy": "partlyAppraisalButton",
                            "channel": settlementCodeDatas[1],
                            "full_name": fullName,
                            "birthday": birthday,
                            "gender": gender,
                            "target_full_name": targetFullName,
                            "target_birthday": targetBirthday,
                            "target_gender": targetGender,
                            "TerminalModel": "pc"
                        },
                        dataType: "html"
                    }).done(function(data) {
                        console.log(data);
                        var dom_parser = new DOMParser();
                        var retensionResultDataId = dom_parser.parseFromString(data, "text/html").getElementById("retensionResultData").innerHTML
                        $("[name=zp_channel_id]").val(settlementCodeDatas[1])
                        $("[name=retensionResultDataId]").val(retensionResultDataId.split("__rid__")[1])
                        btn.parents("form").attr("method", "post")
                        btn.parents("form").attr("action", "https://zap-happyfortune.rensa.jp.net/cocoloni/yumecakra_rsa/result/").submit();
                    }).fail(function() {
                        alert("通信に失敗しました");
                        btn.prop("disabled", false);
                    });
                } else if (paymentSystemName == "cocoloni" || paymentSystemName == "cp_rsa") {
                    let postUrl = "";
                    let locationUri = location.hostname;
                    switch (locationUri) {
                        case "honkaku-uranai.jp":
                            postUrl = "https://honkaku-uranai.jp/cp_rsa/yumecakra_rsa/result";
                            break;
                        case "test-honkaku.cocoloni.jp":
                            postUrl = "https://test-honkaku.cocoloni.jp/cp_rsa/yumecakra_rsa/result";
                            break;
                        default:
                            postUrl = "http://localhost/cocoloni/yumecakra_rsa/result/life001";
                    };
                    let time = $(this).parents("form").find("input[name='time']").val();
                    document.charset = 'euc-jp'
                    $.ajax({
                        type: "post",
                        url: postUrl,
                        data: {
                            "ajaxParameter": true,
                            "itemcd": settlementCodeDatas[0],
                            "zp_channel_id": settlementCodeDatas[1],
                            "time": time,
                            "full_name": fullName,
                            "birthday": birthday,
                            "gender": gender,
                            "target_full_name": targetFullName,
                            "target_birthday": targetBirthday,
                            "target_gender": targetGender,
                            "TerminalModel": "pc",
                            "howToBuy": "paymentAppraisalButton",
                        },
                        dataType: "html"
                    }).done(function(data) {
                        var dataValue = JSON.parse(data)
                        var zp_channel_id = dataValue.zp_channel_id
                        var zp_sid = dataValue.zp_sid
                        var zp_sig = dataValue.zp_sig
                        if (location.hostname.indexOf("test-honkaku.cocoloni.jp") >= 0) {
                            window.location.href = "https://test-honkaku.cocoloni.jp/portal/charge/?zp_cp_name=cp_rsa&zp_channel_id=" + zp_channel_id + "&zp_sid=" + zp_sid + "&zp_sig=" + zp_sig
                        } else {
                            window.location.href = "https://honkaku-uranai.jp/portal/charge/?zp_cp_name=cp_rsa&zp_channel_id=" + zp_channel_id + "&zp_sid=" + zp_sid + "&zp_sig=" + zp_sig
                        }
                    }).fail(function() {
                        alert("通信に失敗しました");
                        btn.prop("disabled", false);
                    });
                } else {
                    if (paymentSystemName == "fortune-premium") {
                        $("[name=zp_channel_id]").val(settlementCodeDatas[1])
                    }
                    btn.parents("form").attr("method", "post")
                    btn.parents("form").attr("action", "https://zap-happyfortune.rensa.jp.net/cocoloni/yumecakra_rsa/result/").submit();
                }
            }
        })
    </script>
    <!--------------------->
    <!-- 遷移ボタンここまで -->
    <!--------------------->
    </form>    <div style="text-align: center; padding: 20px 75px; clear: both; font-size: 1.1rem;">
        <style>
    .form_purchase_description,
    .privacy-policy-section a {
        color: #000;
    }

    .anokimo_button_message_color {
        color: #983030;
    }

    .strong_text_color {
        color: #983030;
    }

    .price_color {
        color: #983030;
    }

    .premium_price_color {
        color: #236310;
    }

    .free_guid_text_color {
        color: #008000;
    }

    .privacy-policy-section {
        border: 1px solid #0000005c;
        margin-top: 10px;
        padding: 7px;
        text-align: left;
    }

    .privacy-policy-section a:hover {
        color: #983030;
    }
</style>

<div class="form_purchase_description">
            <p>
            <span class="strong_text_color">「一部無料で鑑定する」</span>をクリックすると、鑑定結果の一部を無料でご覧になれます。
                    </p>
        <br>
                    <p>
                ご利用には<span class="price_color">3,740円（税込）/1回</span>が必要となります。
                <br>
                （定額制ではございません。入力項目が同じでも占う度に料金が発生いたします。）
                <br>
                <br>
                占う前に占断する内容や入力情報をご確認の上、購入お願いいたします。
                <br>
                ご購入いただくと、サービス・コンテンツの利用料金が発生します。
            </p>
            
    <div class="privacy-policy-section">
        <p>
                            株式会社レンサは、ご入力いただいた情報を、占いサービスを提供するためにのみ使用し、情報の蓄積を行ったり、他の目的で使用することはありません。                <a href='https://rensa.co.jp/privacy-policy' target="_new">個人情報保護方針（外部サイト）</a>をご確認の上、必要情報をご入力ください。また、ご購入に関しては、cocoloni占い館の<a href="/agreement/" target="_link">利用規約</a>に 同意の上、必要情報をご入力ください。
                    </p>
    </div>
</div>    </div>
</div>
<img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/form/content_menu_list_bottom.jpg" style="margin-left: -1.9%; vertical-align: top;">

<script>
    var birthdayYearSelectOptions;
    if (typeof isBirthdayYearOptionDefined === "undefined") {
        birthdayYearSelectOptions = "";
        for (var i = 1930; i <= new Date().getFullYear(); i++) {
            birthdayYearSelectOptions = birthdayYearSelectOptions + "<option value='" + i + "'>" + i + "</option>"
            if (i == 1975) {
                birthdayYearSelectOptions = birthdayYearSelectOptions + "<option value='' selected >--</option>"
            }
        }
    }
    var isBirthdayYearOptionDefined = true
    $("*[name=birthday_year]").html(birthdayYearSelectOptions);
    $("*[name=target_birthday_year]").html(birthdayYearSelectOptions);

    var birthdayInputForm = $('div[name=birthday]')

    birthdayInputForm.change(function() {
        var yearElem = $(this).find(".year")
        var monthElem = $(this).find(".month")
        var dayElem = $(this).find(".day")

        var year = yearElem.val()
        var month = monthElem.val()
        var day = dayElem.val()

        if (year == "" || month == "" || day == "") {
            return
        }

        // 閏年か否か判定
        var isLeapYear = year % 4 == 0;
        if (year % 100 == 0) {
            if (year % 400 == 0) {
                isLeapYear = true;
            }
        }

        // 該当月の最大日数を取得
        var mEndOfDay = [31, 28, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31]
        if (isLeapYear) {
            mEndOfDay[1] = 29;
        }

        if (day > mEndOfDay[parseInt(month) - 1]) {
            dayElem.val(mEndOfDay[parseInt(month) - 1]);
        }

        var today = new Date();
        if (year >= today.getFullYear()) {
            if (month >= today.getMonth() + 1) {
                monthElem.val(today.getMonth() + 1)
                if (day > today.getDate()) {
                    dayElem.val(today.getDate())
                }
                if (month > today.getMonth() + 1) {
                    dayElem.val(today.getDate())
                }
            }
        }
    });

    if (paymentSystemName !== "minori") {
        setLoad($("form"))
    }
</script>                </section>
                <!-- -->

                <!-- お悩みセクション -->
                <section id="worriesMenuLinks">
                    <script>
                        let onayami_titles = ["\u3010\u5bbf\u7e01\u3011\u3053\u306e\u60f3\u3044\u306f\u3042\u306e\u4eba\u306b\u5c4a\u304f\uff1f ","\u3053\u306e\u5148\u3001\u3042\u306a\u305f\u306e\u3010\u4eba\u751f\u3011\u4f55\u304c\u8d77\u3053\u308b\uff1f","\u4eca\u306e\u3010\u4ed5\u4e8b\u3011\u7d9a\u3051\u308b\u3079\u304d\uff1f\u3000\u5909\u3048\u308b\u3079\u304d\uff1f ","\u3042\u306a\u305f\u306e\u201c\u7d50\u5a5a\u201c\u76f8\u624b\u306f\u3069\u3093\u306a\u4eba\uff1f","\u904b\u547d\u306e\u76f8\u624b\u3068\u306e\u201c\u51fa\u4f1a\u3044\u201d\u306f\u3069\u3053\u3067\uff1f ","\u3010\u4e0d\u502b\u3011\u672c\u6c17\u306e\u95a2\u4fc2\u3002\u3042\u306e\u4eba\u3082\u540c\u3058\uff1f","\u3042\u306e\u4eba\u306e\u60f3\u3044\u25c6\u3042\u306a\u305f\u3078\u306e\u604b\u611b\u610f\u8b58","\u3010\u5b98\u80fd\u5360\u3011\u3042\u306a\u305f\u304c\u77e5\u3089\u306a\u3044\u591c\u306e\u3042\u306e\u4eba","\u3010\u5fa9\u7e01\u3011\u3042\u306a\u305f\u3068\u3001\u3042\u306e\u4eba\u306e\u518d\u71c3\u78ba\u7387"];
                        let onayami_itemcds = ["love001","life001","life002","marriage001","marriage002","love002","love003","love004","love005"];
                        let onayami_item_menu = [{"background":"#660099","border":"1px solid #330066"},{"background":"#006666","border":"1px solid #003333"},{"background":"#006666","border":"1px solid #003333"},{"background":" #990033","border":"1px solid #330000"},{"background":" #990033","border":"1px solid #330000"},{"background":"#660099","border":"1px solid #330066"},{"background":"#660099","border":"1px solid #330066"},{"background":"#660099","border":"1px solid #330066"},{"background":"#660099","border":"1px solid #330066"}];
                        let platform = 'cocoloni';
                        let urlkey = 'yumecakra_rsa';
                        let controllerName = 'yumecakra';
                    </script>
                    <div class="worries-container">
                        <img loading="lazy" alt='「この先、願いは叶う？」「想いは結ばれる？」チャクラから巡るエネルギーを視て運命の流れまでをズバリ特定 この霊視はあたなにとってあらゆる場面の行く先を指し示します' src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/top/top_onayami_background.jpg">
                        <div class="worries-container_menus">
                            <div><a id="onayamiButton1" class="worries-menu-text-ie">《人生》この先、あなたに起こる出来事</a></div>
                            <div><a id="onayamiButton2" class="worries-menu-text-ie">【現職or転職】成功を掴めるのはどっち？</a></div>
                            <div><a id="onayamiButton3" class="worries-menu-text-ie">結婚◆あなたの未来の伴侶は誰？</a></div>
                            <div><a id="onayamiShowNext" class="onayami-show-next">この中にはない</a></div>
                        </div>
                    </div>
                </section>
                <script>
                    let ob1 = document.getElementById("onayamiButton1");
                    let ob2 = document.getElementById("onayamiButton2");
                    let ob3 = document.getElementById("onayamiButton3");

                    if (window.navigator.userAgent.indexOf('Trident') != -1) {
                        ob1.style.background = "linear-gradient(#099064,#01362c)";
                        ob2.style.background = "linear-gradient(#099064,#01362c)";
                        ob3.style.background = "linear-gradient(#099064,#01362c)";
                        ob1.style.border = "1px solid #524f50";
                        ob2.style.border = "1px solid #524f50";
                        ob3.style.border = "1px solid #524f50";
                    } else {
                        ob1.style.background = "rgba(10, 77, 227, 0.85)";
                        ob2.style.background = "rgba(10, 77, 227, 0.85)";
                        ob3.style.background = "rgba(169, 26, 67, 0.97)";
                        ob1.style.border = "1px solid rgba(10, 77, 227, 0.85)";
                        ob2.style.border = "1px solid rgba(10, 77, 227, 0.85)";
                        ob3.style.border = "1px solid rgba(169, 26, 67, 0.97)";
                    }
                </script>
                <!-- -->

                <!-- あの人の気持ち鑑定フォーム -->
                <section id="anokimoPartialAppraisalFreeForm">
                    <img loading="lazy" alt='お互いのチャクラから伝わる本音や欲求、心の奥に抱いている想い その1つ1つを紐解き、2人の気持ちを1つにしていきましょう' src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/top/top_appraisal_form_anokimo_billboard.jpg" style="margin-left: -1.8%; vertical-align: bottom;">
                        
<!-- form入力の警告をするためのjs -->
    <!-- -->

<style>
    .profile-input-background-center.for-style {
        background: url("https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/form/content_menu_list_background.jpg") repeat-y;
        background-position: center;
        font-weight: bold;
        color: #000000;
    }

    /***********************************/
    /* use input font size Adjustment */
    /*********************************/
    .profile-input-background-center.for-style select {
        font-family: "ヒラギノ明朝 ProN W6", "HiraMinProN-W6", "HG明朝E", "ＭＳ Ｐ明朝", "MS PMincho", "MS 明朝", serif;
        font-weight: bold;
        letter-spacing: 0.05rem;
        font-size: 1.8rem;
        line-height: 140%;
        height: 45px;
    }

    .profile-input-background-center.for-style input {
        font-size: 1.8rem;
        line-height: 140%;
    }

    .profile-input-background-center.for-style input:-webkit-autofill {
        box-shadow: 0 0 0 100px #ffffff inset;
        -webkit-text-fill-color: #000000;
    }

    /***************************/
    /* use input name section */
    /**************************/
    .profile_input_area {
        padding: 0 8%;
        display: flex;
        flex-flow: column;
    }

    .profile_input_area p {
        font-family: "ヒラギノ明朝 ProN W6", "HiraMinProN-W6", "HG明朝E", "ＭＳ Ｐ明朝", "MS PMincho", "MS 明朝", serif;
        letter-spacing: 0.05rem;
    }

    .label {
        font-size: 1.8rem;
        line-height: 140%;
    }

    .note {
        font-size: 1.3rem;
        width: 90%;
        margin: 2% auto 2% 17%;
        text-align: left;
        line-height: 140%;
    }

    .note span {
        color: #983030;
    }

    /* 名前入力欄 */
    .full_name_input_box {
        display: flex;
        gap: 1%;
        margin-left: 3.5%;
        align-items: center;
    }

    #full-name,
    #target-full-name {
        font-family: "ヒラギノ明朝 ProN W6", "HiraMinProN-W6", "HG明朝E", "ＭＳ Ｐ明朝", "MS PMincho", "MS 明朝", serif;
        letter-spacing: 0.05rem;
        width: 300px;
        font-weight: bold;
    }

    /* 生年月日入力欄 */
    .birthday_select_box,
    .birthday_select_box div {
        display: flex;
        align-items: center;
        gap: 1%;
    }

    .birthday_select_box select {
        width: 160px;
    }

    /* 性別選択欄 */
    .sex_input_box {
        display: flex;
        align-items: center;
        margin-left: 7.3%;
        gap: 2%;
    }

    .sex_input_box>div {
        display: flex;
        align-items: flex-end;
        width: 17%;
    }

    #gender,
    #target-gender {
        width: 120px;
    }

    /* formボタン共通 */
    .form_branch_btn_area {
        display: flex;
        justify-content: center;
        max-height: 150px;
        margin-top: 2%;
    }

    .form_branch_btn_area button {
        width: 390px;
        height: 130px;
        padding: 0;
        border: none;
        outline: none;
        cursor: pointer;
    }

    .form_branch_btn_area button img {
        width: 100%;
        height: 100%;
        border: none;
    }

    /* anokimo button */
    .submit_branch_button_second {
        background-size: 100% 100%;
    }

    /* payment button */
    .submit_pay_image {
        background-size: 100% 100%;
    }

    /* partry free button */
    .submit_part_free_image {
        background-size: 100% 100%;
    }

    /* free button */
    .submit_free_image {
        background-size: 100% 100%;
    }


    /* checkbox */
    .cookie_check label,
    .cookie_info p,
    .cookie_check button {
        color: #000000;
        font-family: "ヒラギノ明朝 ProN W6", "HiraMinProN-W6", "HG明朝E", "MS P明朝", "MS PMincho", "MS 明朝", serif;
    }

    .cookie_check label {
        padding-right: 5px;
        font-size: 1rem;
    }

    .cookie_check button {
        background-color: #efefef;
        border: solid 1px #767676;
        border-radius: 2px;
    }

    .cookie_check button:hover {
        background-color: #d6d6d6;
    }

    .cookie_check {
        display: flex;
    }

    .cookie_check {
        align-items: center;
    }

    .cookie_info {
        font-size: 1rem;
    }

    .cookie_check {
        justify-content: center;
        gap: 30px;
    }

    .cookie-input {
        min-width: auto;
    }

    .cookie-label {
        padding-left: 10px;
        color: #000;
    }

    /* ----- */
</style>

<form method="post" accept-charset="euc-jp" id="profileForm" name="profileForm" action="/cocoloni/yumecakra_rsa/"><div style="display:none;"><input type="hidden" name="_method" value="POST"/></div><input type="hidden" name="itemcd" value="love003"/><input type="hidden" name="contentKey" value="CYC"/><input type="hidden" name="howToBuy" value="freeAppraisalButton"/><input type="hidden" name="TerminalModel" value="pc"/><input type="hidden" name="retensionResultDataId" value=""/><input type="hidden" name="time" value=""/><input type="hidden" name="zp_channel_id" value="105_yc0011a"/><div class="profile-input-background-center for-style" id="profileSection">
            <!-- appraisal item information display start -->
        <div style="padding: 20px 65px 0;">
            
  <div class="appraisal_menu light">
  <div>
    <img src="https://img.rensa.jp.net/web/RYC/menu/icon_off/icon7.png" class="icon" alt="あの人の気持ち"/>    <a class="" href="/cp_rsa/yumecakra_rsa/pre/love003/">
      <p>    考えも想いもマルわかり【あの人の全てを知る霊視】存在 /恋心/決断
</p>
    </a>
  </div>
      <p class="description">恋愛チャクラ占い｜恋は盲目というように、恋をすると「その人」しか目に映らなくなることがあります。あの人があなたに向けている願望や、心の奥底に秘めた想い、この先の関係への望み……あの人が持つチャクラから胸の内を明らかにしましょう。その全てを知って受け止めて下さい。</p>
    <div class="menu_info">
        <p class="price">
              <span class="common_price">価格 2,750円(税込)</span>
          </p>
  </div>
</div>        </div>
        <!-- appraisal item information display end -->
        <img loading="lazy" alt="あなたについて教えてください" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/form/input_form_my_head.png" style="width: 100%; margin: 0 auto;">
    <div class="profile_input_area">

        <!-------------------------->
        <!-- あなたの名前入力ここから -->
        <!-------------------------->
                    <div class="full_name_input_box">
                <p class="label">お名前</p>
                <div class="input text"><input type="text" name="full_name" maxlength="8" id="full-name"/></div>            </div>
            <p class="note">※「お名前」は、全角8文字以内の「ひらがな」「カタカナ」<br>「漢字」で入力ください。</p>
                <!-------------------------->
        <!-- あなたの名前入力ここまで -->
        <!-------------------------->

        <!---------------------------->
        <!-- あなたの誕生日入力ここから -->
        <!---------------------------->
                            <div class="birthday_select_box" id="birthday" name="birthday">
                <p class="label">生年月日</p>
                <div>
                    <div>
                        <div class="input select"><select name="birthday_year" class="year" id="birthday-year"><option value="1940">1940</option><option value="1941">1941</option><option value="1942">1942</option><option value="1943">1943</option><option value="1944">1944</option><option value="1945">1945</option><option value="1946">1946</option><option value="1947">1947</option><option value="1948">1948</option><option value="1949">1949</option><option value="1950">1950</option><option value="1951">1951</option><option value="1952">1952</option><option value="1953">1953</option><option value="1954">1954</option><option value="1955">1955</option><option value="1956">1956</option><option value="1957">1957</option><option value="1958">1958</option><option value="1959">1959</option><option value="1960">1960</option><option value="1961">1961</option><option value="1962">1962</option><option value="1963">1963</option><option value="1964">1964</option><option value="1965">1965</option><option value="1966">1966</option><option value="1967">1967</option><option value="1968">1968</option><option value="1969">1969</option><option value="1970">1970</option><option value="1971">1971</option><option value="1972">1972</option><option value="1973">1973</option><option value="1974">1974</option><option value="" selected="selected">--</option><option value="1975">1975</option><option value="1976">1976</option><option value="1977">1977</option><option value="1978">1978</option><option value="1979">1979</option><option value="1980">1980</option><option value="1981">1981</option><option value="1982">1982</option><option value="1983">1983</option><option value="1984">1984</option><option value="1985">1985</option><option value="1986">1986</option><option value="1987">1987</option><option value="1988">1988</option><option value="1989">1989</option><option value="1990">1990</option><option value="1991">1991</option><option value="1992">1992</option><option value="1993">1993</option><option value="1994">1994</option><option value="1995">1995</option><option value="1996">1996</option><option value="1997">1997</option><option value="1998">1998</option><option value="1999">1999</option><option value="2000">2000</option><option value="2001">2001</option><option value="2002">2002</option><option value="2003">2003</option><option value="2004">2004</option><option value="2005">2005</option><option value="2006">2006</option><option value="2007">2007</option><option value="2008">2008</option><option value="2009">2009</option><option value="2010">2010</option><option value="2011">2011</option><option value="2012">2012</option><option value="2013">2013</option><option value="2014">2014</option><option value="2015">2015</option><option value="2016">2016</option><option value="2017">2017</option><option value="2018">2018</option><option value="2019">2019</option><option value="2020">2020</option></select></div>                        <p class="label">年</p>
                    </div>
                    <div>
                        <div class="input select"><select name="birthday_month" class="month" id="birthday-month"><option value="1">1</option><option value="2">2</option><option value="3">3</option><option value="4">4</option><option value="5">5</option><option value="6">6</option><option value="" selected="selected">--</option><option value="7">7</option><option value="8">8</option><option value="9">9</option><option value="10">10</option><option value="11">11</option><option value="12">12</option></select></div>                        <p class="label">月</p>
                    </div>
                    <div>
                        <div class="input select"><select name="birthday_day" class="day" id="birthday-day"><option value="1">1</option><option value="2">2</option><option value="3">3</option><option value="4">4</option><option value="5">5</option><option value="6">6</option><option value="7">7</option><option value="8">8</option><option value="9">9</option><option value="10">10</option><option value="11">11</option><option value="12">12</option><option value="13">13</option><option value="14">14</option><option value="15">15</option><option value="" selected="selected">--</option><option value="16">16</option><option value="17">17</option><option value="18">18</option><option value="19">19</option><option value="20">20</option><option value="21">21</option><option value="22">22</option><option value="23">23</option><option value="24">24</option><option value="25">25</option><option value="26">26</option><option value="27">27</option><option value="28">28</option><option value="29">29</option><option value="30">30</option><option value="31">31</option></select></div>                        <p class="label">日</p>
                    </div>
                </div>
            </div>
            <p class="note"><span>※必須</span></p>
                <!---------------------------->
        <!-- あなたの誕生日入力ここまで -->
        <!---------------------------->

        <!-------------------------->
        <!-- あなたの性別入力ここから -->
        <!-------------------------->
                    <div class="sex_input_box">
                <p class="label">性別</p>
                                    <div class="input select"><select name="gender" id="gender"><option value="F" selected="selected">女性</option><option value="M">男性</option></select></div>                    <p class="label">で占う</p>
                            </div>
                            <p class="note"><span>※必須</span></p>
                            <!-------------------------->
        <!-- あなたの性別入力ここまで -->
        <!-------------------------->
    </div>

            <img loading="lazy" alt="あの人について教えてください" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/form/input_form_you_head.png" style="width: 100%; margin: 0 auto;">
        <div class="profile_input_area">
            <!-------------------------->
            <!-- あの人の名前入力ここから -->
            <!-------------------------->
                            <div class="full_name_input_box">
                    <p class="label">お名前</p>
                    <div class="input text"><input type="text" name="target_full_name" maxlength="8" id="target-full-name"/></div>                </div>
                <p class="note">※「お名前」は、全角8文字以内の「ひらがな」「カタカナ」<br>「漢字」で入力ください。</p>
                        <!-------------------------->
            <!-- あの人の名前入力ここまで -->
            <!-------------------------->

            <!---------------------------->
            <!-- あの人の誕生日入力ここから -->
            <!---------------------------->
                            <div class="birthday_select_box" name="birthday">
                    <p class="label">生年月日</p>
                    <div>
                        <div>
                            <div class="input select"><select name="target_birthday_year" class="year" id="target-birthday-year"><option value="1940">1940</option><option value="1941">1941</option><option value="1942">1942</option><option value="1943">1943</option><option value="1944">1944</option><option value="1945">1945</option><option value="1946">1946</option><option value="1947">1947</option><option value="1948">1948</option><option value="1949">1949</option><option value="1950">1950</option><option value="1951">1951</option><option value="1952">1952</option><option value="1953">1953</option><option value="1954">1954</option><option value="1955">1955</option><option value="1956">1956</option><option value="1957">1957</option><option value="1958">1958</option><option value="1959">1959</option><option value="1960">1960</option><option value="1961">1961</option><option value="1962">1962</option><option value="1963">1963</option><option value="1964">1964</option><option value="1965">1965</option><option value="1966">1966</option><option value="1967">1967</option><option value="1968">1968</option><option value="1969">1969</option><option value="1970">1970</option><option value="1971">1971</option><option value="1972">1972</option><option value="1973">1973</option><option value="1974">1974</option><option value="" selected="selected">--</option><option value="1975">1975</option><option value="1976">1976</option><option value="1977">1977</option><option value="1978">1978</option><option value="1979">1979</option><option value="1980">1980</option><option value="1981">1981</option><option value="1982">1982</option><option value="1983">1983</option><option value="1984">1984</option><option value="1985">1985</option><option value="1986">1986</option><option value="1987">1987</option><option value="1988">1988</option><option value="1989">1989</option><option value="1990">1990</option><option value="1991">1991</option><option value="1992">1992</option><option value="1993">1993</option><option value="1994">1994</option><option value="1995">1995</option><option value="1996">1996</option><option value="1997">1997</option><option value="1998">1998</option><option value="1999">1999</option><option value="2000">2000</option><option value="2001">2001</option><option value="2002">2002</option><option value="2003">2003</option><option value="2004">2004</option><option value="2005">2005</option><option value="2006">2006</option><option value="2007">2007</option><option value="2008">2008</option><option value="2009">2009</option><option value="2010">2010</option><option value="2011">2011</option><option value="2012">2012</option><option value="2013">2013</option><option value="2014">2014</option><option value="2015">2015</option><option value="2016">2016</option><option value="2017">2017</option><option value="2018">2018</option><option value="2019">2019</option><option value="2020">2020</option></select></div>                            <p class="label">年</p>
                        </div>
                        <div>
                            <div class="input select"><select name="target_birthday_month" class="month" id="target-birthday-month"><option value="1">1</option><option value="2">2</option><option value="3">3</option><option value="4">4</option><option value="5">5</option><option value="6">6</option><option value="" selected="selected">--</option><option value="7">7</option><option value="8">8</option><option value="9">9</option><option value="10">10</option><option value="11">11</option><option value="12">12</option></select></div>                            <p class="label">月</p>
                        </div>
                        <div>
                            <div class="input select"><select name="target_birthday_day" class="day" id="target-birthday-day"><option value="1">1</option><option value="2">2</option><option value="3">3</option><option value="4">4</option><option value="5">5</option><option value="6">6</option><option value="7">7</option><option value="8">8</option><option value="9">9</option><option value="10">10</option><option value="11">11</option><option value="12">12</option><option value="13">13</option><option value="14">14</option><option value="15">15</option><option value="" selected="selected">--</option><option value="16">16</option><option value="17">17</option><option value="18">18</option><option value="19">19</option><option value="20">20</option><option value="21">21</option><option value="22">22</option><option value="23">23</option><option value="24">24</option><option value="25">25</option><option value="26">26</option><option value="27">27</option><option value="28">28</option><option value="29">29</option><option value="30">30</option><option value="31">31</option></select></div>                            <p class="label">日</p>
                        </div>
                    </div>
                </div>
                <p class="note"><span>※必須</span></p>
                        <!---------------------------->
            <!-- あの人の誕生日入力ここまで -->
            <!---------------------------->

            <!-------------------------->
            <!-- あの人の性別入力ここから -->
            <!-------------------------->
                            <div class="sex_input_box">
                    <p class="label">性別</p>
                    <div class="input select"><select name="target_gender" id="target-gender"><option value="F">女性</option><option value="M" selected="selected">男性</option></select></div>                    <p class="label">で占う</p>
                </div>
                <p class="note"><span>※必須</span></p>
                        <!-------------------------->
            <!-- あの人の性別入力ここまで -->
            <!-------------------------->

        </div>
        <!------------------------------>
    <!-- Cookie入力情報の削除ここから -->
    <!------------------------------>
            <div class="cookie_info">
            <p>入力した情報を記録しますか？</p>
            <div class="cookie_check">
                <label><input class="cookie-input" id="checkbox" name="cwflg" value="ok" type="checkbox" checked=""><span class="cookie-label">記録する</span></label>

                <div class="input button"><label for="ji-luwo-xue-chusuru"></label><button type="button" onclick="resetCookie()" id="ji-luwo-xue-chusuru">記録を削除する</button></div>            </div>
        </div>
        <!------------------------------>
    <!-- Cookie入力情報の削除ここから -->
    <!------------------------------>
    <!--------------------->
    <!-- 遷移ボタンここから -->
    <!--------------------->
    <div class="form_branch_btn_area">
                    <!-- あのきもボタン -->
            <button type="button" class="submit_branch_button_second" name="anokimoPartlyAppraisalButton2" id="" value="love003and105_yc0011a" onclick="formButtonPrecess($(this));">
                <img loading="lazy" alt="あの人が内に秘めた想いを視抜く" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/form/top_input_profile_button.png" onmouseover="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/form/top_input_profile_button_over.png'" onmouseout="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/form/top_input_profile_button.png'">
            </button>
            </div>
    <script>
        $("form").keydown(function(e) {
            if ((e.which && e.which === 13) || (e.keyCode && e.keyCode === 13)) {
                return false;
            } else {
                return true;
            }
        });

        var paymentSystemName = 'cocoloni';
        var paymentMetaData = [{"count":1,"method":"post","parameterName":"zp_channel_id","paymentUrl":"https:\/\/zap-happyfortune.rensa.jp.net\/cocoloni\/yumecakra_rsa\/result\/","partlyUrl":"https:\/\/honkaku-uranai.jp\/cp_rsa\/yumecakra_rsa\/result\/","freeUrl":"https:\/\/honkaku-uranai.jp\/cp_rsa\/yumecakra_rsa\/result\/love003","ids":"105_yc0011a","itemcd":"love003","price":2750,"premium_price":2000,"addCrumbPreUrl":"\/cocoloni\/yumecakra_rsa\/pre\/love003"}];

        function formButtonPrecess(button) {
            let settlementCodeDatas = button.attr("value").split("and")
            let howToBuy = button.attr("name")
            let buttonName = button.context.name;
            if (paymentSystemName == "minori") {
                var formId = button.attr("name").slice(-1);
                var partlyUrl = document.getElementsByName("partlyUrl" + formId)[0].innerHTML;
            }

            if (formValidate(button.parents("form"), 8, false)) {
                $("[name=itemcd]").val(settlementCodeDatas[0])
                buttonName.indexOf("anokimoPartlyAppraisalButton") !== -1 ? $("[name=howToBuy]").val('partlyAppraisalButton') : $("[name=howToBuy]").val(howToBuy);
                if (paymentSystemName !== "minori") {
                    actSubmit(button.parents("form"));
                }
                if (paymentSystemName == "cocoloni" || paymentSystemName == "cp_rsa" || paymentSystemName == "fortune-premium") {
                    $("[name=zp_channel_id]").val(settlementCodeDatas[1])
                    document.charset = 'euc-jp'
                }
                button.parents("form").attr("method", "post")
                if (buttonName.indexOf("freeAppraisalButton") !== -1) {
                    button.parents("form").attr("action", "https://honkaku-uranai.jp/cp_rsa/yumecakra_rsa/result/love003/").submit();
                } else if (paymentSystemName == "minori") {
                    button.parents("form").attr("action", partlyUrl).submit();
                } else {
                    button.parents("form").attr("action", "https://honkaku-uranai.jp/cp_rsa/yumecakra_rsa/result/" + settlementCodeDatas[0] + "/").submit();
                }
            }
        };

        // payment appraisal button js
        var isProcessing = false;
        var btnCount = $(".form_branch_btn_area").length;
        window.onpageshow = function() {
            for (let i = 1; i <= btnCount; i++) {
                $('button[name=paymentAppraisalButton' + i + ']').prop("disabled", false);
            }
        }
        $('button[name=paymentAppraisalButton2]').on('click', function() {
            if (formValidate($(this).parents("form"), 8, false)) {
                var btn = $('button[name=paymentAppraisalButton2]')
                btn.prop("disabled", true);
                if (paymentSystemName == "minori") {
                    // みのり 用に遷移元を ローカルストレージへ保存
                    localStorage.setItem('backUrl', location.href);
                }
                if (paymentSystemName !== "minori") {
                    actSubmit($(this).parents("form"));
                }
                if (paymentSystemName == "cocoloni" || paymentSystemName == "cp_rsa" || paymentSystemName == "fortune-premium") {
                    document.charset = 'euc-jp'
                }
                var settlementCodeDatas = $(this).attr("value").split("and")
                var howToBuy = $(this).attr("name")
                var parameterName = "zp_channel_id";
                                    var $JudgmentGender = $(this).parents("form").find("select[name='gender']").val()
                                var gender = $JudgmentGender
                var fullName = $(this).parents("form").find("input[name='full_name']").val()
                var targetGender = $(this).parents("form").find('select[name=target_gender]').val()
                var targetFullName = $(this).parents("form").find("input[name='target_full_name']").val()
                var birthday = $(this).parents("form").find("select[name='birthday_year']").val() + "-" + ('00' + $(this).parents("form").find("select[name='birthday_month']").val()).slice(-2) + "-" + ('00' + $(this).parents("form").find("select[name='birthday_day']").val()).slice(-2)
                var targetBirthday = $(this).parents("form").find("select[name='target_birthday_year']").val() + "-" + ('00' + $(this).parents("form").find("select[name='target_birthday_month']").val()).slice(-2) + "-" + ('00' + $(this).parents("form").find("select[name='target_birthday_day']").val()).slice(-2)
                $("[name=itemcd]").val(settlementCodeDatas[0])
                $("[name=howToBuy]").val(howToBuy)

                if (paymentSystemName == "minori") {
                    // みのり 用に遷移元を ローカルストレージへ保存
                    localStorage.setItem('backUrl', location.href);
                    var url = location.href;
                    var env = url.match("dev") ? 'https://dev.rensa.jp.net' : 'https://rensa.jp.net'
                    $.ajax({
                        type: "POST",
                        url: env + "https://honkaku-uranai.jp/cp_rsa/yumecakra_rsa/result/love003", //本番環境用
                        // url: "http://localhost/yumecakra/minori/result/love001",//テスト用
                        data: {
                            "isNomalPayment": true,
                            "itemcd": settlementCodeDatas[0],
                            "howToBuy": "partlyAppraisalButton",
                            "channel": settlementCodeDatas[1],
                            "full_name": fullName,
                            "birthday": birthday,
                            "gender": gender,
                            "target_full_name": targetFullName,
                            "target_birthday": targetBirthday,
                            "target_gender": targetGender,
                            "TerminalModel": "pc"
                        },
                        dataType: "html"
                    }).done(function(data) {
                        console.log(data);
                        var dom_parser = new DOMParser();
                        var retensionResultDataId = dom_parser.parseFromString(data, "text/html").getElementById("retensionResultData").innerHTML
                        $("[name=zp_channel_id]").val(settlementCodeDatas[1])
                        $("[name=retensionResultDataId]").val(retensionResultDataId.split("__rid__")[1])
                        btn.parents("form").attr("method", "post")
                        btn.parents("form").attr("action", "https://zap-happyfortune.rensa.jp.net/cocoloni/yumecakra_rsa/result/").submit();
                    }).fail(function() {
                        alert("通信に失敗しました");
                        btn.prop("disabled", false);
                    });
                } else if (paymentSystemName == "cocoloni" || paymentSystemName == "cp_rsa") {
                    let postUrl = "";
                    let locationUri = location.hostname;
                    switch (locationUri) {
                        case "honkaku-uranai.jp":
                            postUrl = "https://honkaku-uranai.jp/cp_rsa/yumecakra_rsa/result";
                            break;
                        case "test-honkaku.cocoloni.jp":
                            postUrl = "https://test-honkaku.cocoloni.jp/cp_rsa/yumecakra_rsa/result";
                            break;
                        default:
                            postUrl = "http://localhost/cocoloni/yumecakra_rsa/result/life001";
                    };
                    let time = $(this).parents("form").find("input[name='time']").val();
                    document.charset = 'euc-jp'
                    $.ajax({
                        type: "post",
                        url: postUrl,
                        data: {
                            "ajaxParameter": true,
                            "itemcd": settlementCodeDatas[0],
                            "zp_channel_id": settlementCodeDatas[1],
                            "time": time,
                            "full_name": fullName,
                            "birthday": birthday,
                            "gender": gender,
                            "target_full_name": targetFullName,
                            "target_birthday": targetBirthday,
                            "target_gender": targetGender,
                            "TerminalModel": "pc",
                            "howToBuy": "paymentAppraisalButton",
                        },
                        dataType: "html"
                    }).done(function(data) {
                        var dataValue = JSON.parse(data)
                        var zp_channel_id = dataValue.zp_channel_id
                        var zp_sid = dataValue.zp_sid
                        var zp_sig = dataValue.zp_sig
                        if (location.hostname.indexOf("test-honkaku.cocoloni.jp") >= 0) {
                            window.location.href = "https://test-honkaku.cocoloni.jp/portal/charge/?zp_cp_name=cp_rsa&zp_channel_id=" + zp_channel_id + "&zp_sid=" + zp_sid + "&zp_sig=" + zp_sig
                        } else {
                            window.location.href = "https://honkaku-uranai.jp/portal/charge/?zp_cp_name=cp_rsa&zp_channel_id=" + zp_channel_id + "&zp_sid=" + zp_sid + "&zp_sig=" + zp_sig
                        }
                    }).fail(function() {
                        alert("通信に失敗しました");
                        btn.prop("disabled", false);
                    });
                } else {
                    if (paymentSystemName == "fortune-premium") {
                        $("[name=zp_channel_id]").val(settlementCodeDatas[1])
                    }
                    btn.parents("form").attr("method", "post")
                    btn.parents("form").attr("action", "https://zap-happyfortune.rensa.jp.net/cocoloni/yumecakra_rsa/result/").submit();
                }
            }
        })
    </script>
    <!--------------------->
    <!-- 遷移ボタンここまで -->
    <!--------------------->
    </form>    <div style="text-align: center; padding: 20px 75px; clear: both; font-size: 1.1rem;">
        <style>
    .form_purchase_description,
    .privacy-policy-section a {
        color: #000;
    }

    .anokimo_button_message_color {
        color: #983030;
    }

    .strong_text_color {
        color: #983030;
    }

    .price_color {
        color: #983030;
    }

    .premium_price_color {
        color: #236310;
    }

    .free_guid_text_color {
        color: #008000;
    }

    .privacy-policy-section {
        border: 1px solid #0000005c;
        margin-top: 10px;
        padding: 7px;
        text-align: left;
    }

    .privacy-policy-section a:hover {
        color: #983030;
    }
</style>

<div class="form_purchase_description">
            <p>
            <span class="anokimo_button_message_color">「あの人が内に秘めた想いを視抜く」</span>をクリックすると、<br>鑑定結果の一部を無料でご覧になれます。
        </p>
        <br>
    
    <div class="privacy-policy-section">
        <p>
                            株式会社レンサは、ご入力いただいた情報を、占いサービスを提供するためにのみ使用し、情報の蓄積を行ったり、他の目的で使用することはありません。                <a href='https://rensa.co.jp/privacy-policy' target="_new">個人情報保護方針（外部サイト）</a>をご確認の上、必要情報をご入力ください。また、ご購入に関しては、cocoloni占い館の<a href="/agreement/" target="_link">利用規約</a>に 同意の上、必要情報をご入力ください。
                    </p>
    </div>
</div>    </div>
</div>
<img loading="lazy" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/form/content_menu_list_bottom.jpg" style="margin-left: -1.9%; vertical-align: top;">

<script>
    var birthdayYearSelectOptions;
    if (typeof isBirthdayYearOptionDefined === "undefined") {
        birthdayYearSelectOptions = "";
        for (var i = 1930; i <= new Date().getFullYear(); i++) {
            birthdayYearSelectOptions = birthdayYearSelectOptions + "<option value='" + i + "'>" + i + "</option>"
            if (i == 1975) {
                birthdayYearSelectOptions = birthdayYearSelectOptions + "<option value='' selected >--</option>"
            }
        }
    }
    var isBirthdayYearOptionDefined = true
    $("*[name=birthday_year]").html(birthdayYearSelectOptions);
    $("*[name=target_birthday_year]").html(birthdayYearSelectOptions);

    var birthdayInputForm = $('div[name=birthday]')

    birthdayInputForm.change(function() {
        var yearElem = $(this).find(".year")
        var monthElem = $(this).find(".month")
        var dayElem = $(this).find(".day")

        var year = yearElem.val()
        var month = monthElem.val()
        var day = dayElem.val()

        if (year == "" || month == "" || day == "") {
            return
        }

        // 閏年か否か判定
        var isLeapYear = year % 4 == 0;
        if (year % 100 == 0) {
            if (year % 400 == 0) {
                isLeapYear = true;
            }
        }

        // 該当月の最大日数を取得
        var mEndOfDay = [31, 28, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31]
        if (isLeapYear) {
            mEndOfDay[1] = 29;
        }

        if (day > mEndOfDay[parseInt(month) - 1]) {
            dayElem.val(mEndOfDay[parseInt(month) - 1]);
        }

        var today = new Date();
        if (year >= today.getFullYear()) {
            if (month >= today.getMonth() + 1) {
                monthElem.val(today.getMonth() + 1)
                if (day > today.getDate()) {
                    dayElem.val(today.getDate())
                }
                if (month > today.getMonth() + 1) {
                    dayElem.val(today.getDate())
                }
            }
        }
    });

    if (paymentSystemName !== "minori") {
        setLoad($("form"))
    }
</script>                </section>

                <!-- TOP下 freeメニュー遷移ボタン -->
                <section id="triple_free_buttons">
                    <div class="top_free_menu_buttons">
                                                    <a href="/cp_rsa/yumecakra_rsa/pre/free002/"><button><img loading="lazy" alt='無料恋愛鑑定 あの人の【ありのまま】教えます 恋愛観＆欲' src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/telling/triple_appraisal_transition_button_top_minori.jpg" onmouseover="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/telling/triple_appraisal_transition_button_top_minori_over.jpg'" onmouseout="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/telling/triple_appraisal_transition_button_top_minori.jpg'"></button></a>
                            <a href="/cp_rsa/yumecakra_rsa/pre/free005/"><button><img loading="lazy" alt='無料結婚鑑定 【手に取るようにわかる】あなたの運命の相手' src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/telling/triple_appraisal_transition_button_middle2_minori.jpg" onmouseover="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/telling/triple_appraisal_transition_button_middle2_minori_over.jpg'" onmouseout="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/telling/triple_appraisal_transition_button_middle2_minori.jpg'"></button></a>
                            <a href="/cp_rsa/yumecakra_rsa/pre/free003/"><button><img loading="lazy" alt='無料相性鑑定 『2人はどれくらい特別になれる？』恋愛相性◆絆/相性率' src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/telling/triple_appraisal_transition_button_middle_minori.jpg" onmouseover="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/telling/triple_appraisal_transition_button_middle_minori_over.jpg'" onmouseout="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/telling/triple_appraisal_transition_button_middle_minori.jpg'"></button></a>
                            <a href="/cp_rsa/yumecakra_rsa/pre/free001/"><button><img loading="lazy" alt='無料人生鑑定 あなたの内面マルわかり 本性/伸びしろ' src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/telling/triple_appraisal_transition_button_bottom_minori.jpg" onmouseover="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/telling/triple_appraisal_transition_button_bottom_minori_over.jpg'" onmouseout="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/telling/triple_appraisal_transition_button_bottom_minori.jpg'"></button></a>
                                            </div>
                </section>
                <!-- -->

                <!-- TOP下 カテゴリ別遷移ボタン -->
                <section id="category_menu_transition_buttons">
                    <div class="content_menu_transition_buttons">
                        <a href="#loveMenuLinks">
                            <div class="content_menu_button_left"><img loading="lazy" alt='恋愛鑑定' src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/top/love_menu_transition_button.png" onmouseover="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/top/love_menu_transition_button_over.png'" onmouseout="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/top/love_menu_transition_button.png'"></div>
                        </a>
                        <a href="#marriageMenuLinks">
                            <div class="content_menu_button_center"><img loading="lazy" alt='結婚鑑定' src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/top/marriage_menu_transition_button.png" onmouseover="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/top/marriage_menu_transition_button_over.png'" onmouseout="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/top/marriage_menu_transition_button.png'"></div>
                        </a>
                        <a href="#lifeMenuLinks">
                            <div class="content_menu_button_right"><img loading="lazy" alt='人生鑑定' src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/top/life_menu_transition_button.png" onmouseover="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/top/life_menu_transition_button_over.png'" onmouseout="this.src='https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/top/life_menu_transition_button.png'"></div>
                        </a>
                    </div>
                </section>
                <!-- -->

                <!-- 恋愛(love)カテゴリメニュー -->
                <section id="loveMenuLinks">
                    <img loading="lazy" alt='2人の縁を結ぶ【恋愛】鑑定' src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/top/love_menu_billboard_head.jpg" style="width: 100%; vertical-align: bottom;">
                    <div class="content_menu_link_background_center">
                                                                                    
  <div class="appraisal_menu">
  <div>
    <img src="https://img.rensa.jp.net/web/RYC/menu/icon_off/icon1.png" class="icon" alt="宿縁"/>    <a class="" href="/cp_rsa/yumecakra_rsa/pre/love001/">
      <p>    2人の恋心/強制成就【ゆめの心々◆宿縁霊視30項】本心/転機/関係最後
</p>
    </a>
  </div>
      <p class="description">恋愛占い｜あなたとあの人のチャクラから、2人の繋がりと関係性を知ることができます。お互いのチャクラがどれだけ惹かれ合い結ばれているのか、この先どこまで愛を深めることができるのか……2人だけが持つ宿縁を、余すところなくお伝えしていきます。</p>
    <div class="menu_info">
        <p class="price">
              <span class="common_price">価格 3,740円(税込)</span>
          </p>
  </div>
</div>                                                                                        <img loading="lazy" style="width: 100%;" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/top/line.png">
                                                                                                                
  <div class="appraisal_menu">
  <div>
    <img src="https://img.rensa.jp.net/web/RYC/menu/icon_off/icon2.png" class="icon" alt="不倫"/>    <a class="" href="/cp_rsa/yumecakra_rsa/pre/love002/">
      <p>    本気の不倫愛を救済【2人の関係導く21項】あの人の覚悟/行動/愛結末
</p>
    </a>
  </div>
      <p class="description">「2人の愛は望んだ関係へと続いていますか？」既にパートナーがいるあの人との関係は、この先どうなっていくのか……お互いのチャクラから示された答えについて、“視えたまま”の全てをお伝えします。あの人が固める覚悟と、2人の関係が迎える結末をお確かめ下さい。</p>
    <div class="menu_info">
        <p class="price">
              <span class="common_price">価格 2,860円(税込)</span>
          </p>
  </div>
</div>                                                                                        <img loading="lazy" style="width: 100%;" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/top/line.png">
                                                                                                                
  <div class="appraisal_menu">
  <div>
    <img src="https://img.rensa.jp.net/web/RYC/menu/icon_off/icon7.png" class="icon" alt="あの人の気持ち"/>    <a class="" href="/cp_rsa/yumecakra_rsa/pre/love003/">
      <p>    考えも想いもマルわかり【あの人の全てを知る霊視】存在 /恋心/決断
</p>
    </a>
  </div>
      <p class="description">恋愛チャクラ占い｜恋は盲目というように、恋をすると「その人」しか目に映らなくなることがあります。あの人があなたに向けている願望や、心の奥底に秘めた想い、この先の関係への望み……あの人が持つチャクラから胸の内を明らかにしましょう。その全てを知って受け止めて下さい。</p>
    <div class="menu_info">
        <p class="price">
              <span class="common_price">価格 2,750円(税込)</span>
          </p>
  </div>
</div>                                                                                        <img loading="lazy" style="width: 100%;" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/top/line.png">
                                                                                                                
  <div class="appraisal_menu">
  <div>
    <img src="https://img.rensa.jp.net/web/RYC/menu/icon_off/icon9.png" class="icon" alt="夜の相性"/>    <a class="" href="/cp_rsa/yumecakra_rsa/pre/love004/">
      <p>    愛熱高まる夜【2人の想い重ね確かめ合う◆濃密官能占】体相性/欲/H後
</p>
    </a>
  </div>
      <p class="description">「色欲」とも呼ばれる性的な願望。そういった欲もチャクラの状態によって反映されます。あの人が表には出さないようにしている、夜だけの素顔を赤裸々に暴いていきましょう。少々刺激の強い内容になりますので、周りに誰もいない時にコッソリ読むことをおすすめします。</p>
    <div class="menu_info">
        <p class="price">
              <span class="common_price">価格 2,420円(税込)</span>
          </p>
  </div>
</div>                                                                                        <img loading="lazy" style="width: 100%;" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/top/line.png">
                                                                                                                
  <div class="appraisal_menu">
  <div>
    <img src="https://img.rensa.jp.net/web/RYC/menu/icon_off/icon4.png" class="icon" alt="復縁"/>    <a class="" href="/cp_rsa/yumecakra_rsa/pre/love005/">
      <p>    どんな別れ方でも修復【諦めきれない恋心を救済鑑定】現状/未練/結末
</p>
    </a>
  </div>
      <p class="description">復縁占い｜一度は違う道を進むと決めたあなたとあの人。しかし、どうしても忘れられない相手というのは、運命的な縁で結ばれているのです。2人が再接近する日も遠くありません。あなたがお別れをしたあの人と縁を結び直し、2人の関係を修復していきます。</p>
    <div class="menu_info">
        <p class="price">
              <span class="common_price">価格 1,980円(税込)</span>
          </p>
  </div>
</div>                                                                                        <img loading="lazy" style="width: 100%;" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/top/line.png">
                                                                                                                
  <div class="appraisal_menu">
  <div>
    <img src="https://img.rensa.jp.net/web/RYC/menu/icon_off/icon5.png" class="icon" alt="恋の行方"/>    <a class="" href="/cp_rsa/yumecakra_rsa/pre/love006/">
      <p>    あの人の本命は誰？【2人の恋運命を全解明】恋愛相性/本命/最終関係
</p>
    </a>
  </div>
      <p class="description">人の気持ちは目には視えないもの。だからこそ、想いを正確に理解できないことや、想いが届かないことが起こってしまうのです。今、あなたが進めている恋にも同じことが言えそうです。目に視えているものからは一度目をそらして、チャクラから読み解いたあの人の本音だけに目を向けていきましょう。</p>
    <div class="menu_info">
        <p class="price">
              <span class="common_price">価格 1,650円(税込)</span>
          </p>
  </div>
</div>                                                                                        <img loading="lazy" style="width: 100%;" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/top/line.png">
                                                                                                                
  <div class="appraisal_menu">
  <div>
    <img src="https://img.rensa.jp.net/web/RYC/menu/icon_off/icon3.png" class="icon" alt="苦しい恋"/>    <a class="" href="/cp_rsa/yumecakra_rsa/pre/love007/">
      <p>    進展皆無の恋【距離感じるあの人の態度理由を霊視】2人の誤解⇒解消
</p>
    </a>
  </div>
      <p class="description">会話や仕草の節々から心の距離を感じるあの人。それはあなたが恋愛対象外ということの意志表示なのでしょうか。あの人が言葉にしない想いをチャクラから読み取ります。普段のあなたに対する態度には、2人の関係に対する感情が視えてきました。</p>
    <div class="menu_info">
        <p class="price">
              <span class="common_price">価格 1,320円(税込)</span>
          </p>
  </div>
</div>                                                                                        <img loading="lazy" style="width: 100%;" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/top/line.png">
                                                                                                                
  <div class="appraisal_menu">
  <div>
    <img src="https://img.rensa.jp.net/web/RYC/menu/icon_off/icon5.png" class="icon" alt="恋の行方"/>    <a class="" href="/cp_rsa/yumecakra_rsa/pre/love008/">
      <p>    この人しかいない『運命感じるのは私だけ？』霊視で視抜く◆本心/答
</p>
    </a>
  </div>
      <p class="description">一生に一度のご縁の「運命の相手」。あなた自身が「運命」を感じる相手に出会えたのなら……決して諦めてはいけません。あなたが想いを寄せるあの人との現状をチャクラから読み解き、2人の交際がスタートできるよう恋の行方までをお伝えします。</p>
    <div class="menu_info">
        <p class="price">
              <span class="common_price">価格 1,320円(税込)</span>
          </p>
  </div>
</div>                                                                                        <img loading="lazy" style="width: 100%;" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/top/line.png">
                                                                                                                
  <div class="appraisal_menu">
  <div>
    <img src="https://img.rensa.jp.net/web/RYC/menu/icon_off/icon6.png" class="icon" alt="片想い"/>    <a class="" href="/cp_rsa/yumecakra_rsa/pre/love009/">
      <p>    『あの人と交際できる？』片想いの結末まで解明◆2人の絆/本音/変化
</p>
    </a>
  </div>
      <p class="description">あの人から何らかのアクションがあれば、あなたもこんなにヤキモキすることはないでしょう。もしあなたから想いを伝えたら……あの人はどんな反応を見せてくれるのか。2人の関係を進めるために、今のあなただからできることをお伝えしましょう。</p>
    <div class="menu_info">
        <p class="price">
              <span class="common_price">価格 1,100円(税込)</span>
          </p>
  </div>
</div>                                                                                        <img loading="lazy" style="width: 100%;" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/top/line.png">
                                                                                                                
  <div class="appraisal_menu">
  <div>
    <img src="https://img.rensa.jp.net/web/RYC/menu/icon_off/icon7.png" class="icon" alt="あの人の気持ち"/>    <a class="" href="/cp_rsa/yumecakra_rsa/pre/love010/">
      <p>    抱き続けてる恋心【あの人は気づいてる？】恋霊視◆恋愛対象/次行動
</p>
    </a>
  </div>
      <p class="description">相手への恋心が大きくなれば、同じくらい相手からの好意が欲しいと願うのは、誰もが同じでしょう。あの人にとってあなたはどんな存在なのか、あなたとの関係に何を望んでいるのか。直接聞くことのできない、あなたへの明確な感情を読み解いていきましょう。</p>
    <div class="menu_info">
        <p class="price">
              <span class="common_price">価格 880円(税込)</span>
          </p>
  </div>
</div>                                                                                        <img loading="lazy" style="width: 100%;" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/top/line.png">
                                                                                                                
  <div class="appraisal_menu">
  <div>
    <img src="https://img.rensa.jp.net/web/RYC/menu/icon_off/icon7.png" class="icon" alt="あの人の気持ち"/>    <a class="" href="/cp_rsa/yumecakra_rsa/pre/love011/">
      <p>    どうしても知りたい【あの人のあなたに対する恋心有無】存在/恋告白
</p>
    </a>
  </div>
      <p class="description">想い続けた先で、相思相愛の未来は訪れるのでしょうか。チャクラの現状を視ることで、あの人の胸中を紐解いていきましょう。そこにはあなたに対する想い、そしてあなた同様今後に対する期待が込められています。</p>
    <div class="menu_info">
        <p class="price">
              <span class="common_price">価格 1,100円(税込)</span>
          </p>
  </div>
</div>                                                                                        <img loading="lazy" style="width: 100%;" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/top/line.png">
                                                                                                                
  <div class="appraisal_menu">
  <div>
    <img src="https://img.rensa.jp.net/web/RYC/menu/icon_off/icon6.png" class="icon" alt="片想い"/>    <a class="" href="/cp_rsa/yumecakra_rsa/pre/love012/">
      <p>    なかなか距離縮まらないあの人『想い続けて叶う？』本音/転機/恋決着
</p>
    </a>
  </div>
      <p class="description">あなたとあの人の恋には既に「答え」が出ています。ですから、なかなか進展しない関係に悩み続ける必要はありません。恋の成就を叶えるために、あの人への片想いをここで昇華させ、2人の恋の現実を受け止めてください。</p>
    <div class="menu_info">
          <p class="add_day">
        2024年4月11日 公開
      </p>
        <p class="price">
              <span class="common_price">価格 1,650円(税込)</span>
          </p>
  </div>
</div>                                                                                                                                                                                    </div>
                </section>
                <a href="#loveMenuLinks" class="category_transition_link">▲カテゴリーTOPへ</a>
                <!-- -->

                <!-- 結婚(marriage)カテゴリメニュー -->
                <section id="marriageMenuLinks">
                    <img loading="lazy" alt='幸せな成婚叶える【結婚】鑑定' src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/top/marriage_menu_billboard_head.jpg" style="width: 100%; vertical-align: bottom;">
                    <div class="content_menu_link_background_center">
                                                    
  <div class="appraisal_menu">
  <div>
    <img src="https://img.rensa.jp.net/web/RYC/menu/icon_off/icon11.png" class="icon" alt="結婚"/>    <a class="" href="/cp_rsa/yumecakra_rsa/pre/marriage001/">
      <p>    婚姻待ったナシ【成婚へ導く霊視占】あなたの結婚縁/相手特徴/入籍後
</p>
    </a>
  </div>
      <p class="description">結婚占い｜運命的な縁で繋がることを「運命の赤い糸」と言いますが、チャクラもまた「人」と「人」を繋ぐものです。あなたのチャクラと結ばれた運命の相手はどのような人物なのでしょうか。見た目や性格だけでなく、出会いから婚姻までの詳細をお伝えいたします。</p>
    <div class="menu_info">
        <p class="price">
              <span class="common_price">価格 2,860円(税込)</span>
          </p>
  </div>
</div>                                                            <img loading="lazy" style="width: 100%;" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/top/line.png">
                                                                                
  <div class="appraisal_menu">
  <div>
    <img src="https://img.rensa.jp.net/web/RYC/menu/icon_off/icon10.png" class="icon" alt="出会い"/>    <a class="" href="/cp_rsa/yumecakra_rsa/pre/marriage002/">
      <p>    まるで目の前にいるかのよう【あなたの生涯伴侶/全特徴】出会い/入籍
</p>
    </a>
  </div>
      <p class="description">「この人が運命の相手です！」と言われてもピンと来ないかもしれませんが、読み進めるごとにその人物像がハッキリと浮かんできます……。その相手との出会いから交際模様、入籍後のことまで事細かにお伝えします。いつまでも仲睦まじい関係でいられるように、結婚後の2人までをも具体的にお教えしましょう。</p>
    <div class="menu_info">
        <p class="price">
              <span class="common_price">価格 1,980円(税込)</span>
          </p>
  </div>
</div>                                                                        </div>
                </section>
                <a href="#marriageMenuLinks" class="category_transition_link">▲カテゴリーTOPへ</a>
                <!-- -->

                <!-- 人生(life)カテゴリメニュー -->
                <section id="lifeMenuLinks">
                    <img loading="lazy" alt='あなたを成功へ導く【人生】鑑定' src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/top/life_menu_billboard_head.jpg" style="width: 100%; vertical-align: bottom;">
                    <div class="content_menu_link_background_center">
                                                    
  <div class="appraisal_menu">
  <div>
    <img src="https://img.rensa.jp.net/web/RYC/menu/icon_off/icon12.png" class="icon" alt="人生"/>    <a class="" href="/cp_rsa/yumecakra_rsa/pre/life001/">
      <p>    人生掌握【ゆめの心々渾身】あなたの全運命を霊視◆1年⇒10年後/晩年
</p>
    </a>
  </div>
      <p class="description">チャクラ占い｜目には見えない人の運命。しかし、人の体にあるチャクラとそこから流れるエネルギーを視れば、その詳細を知ることができるのです。あなたのチャクラのエネルギーから、あなただけに与えられた運命、歩んでいく人生の詳細を明らかにしていきましょう。</p>
    <div class="menu_info">
        <p class="price">
              <span class="common_price">価格 3,740円(税込)</span>
          </p>
  </div>
</div>                                                            <img loading="lazy" style="width: 100%;" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/top/line.png">
                                                                                
  <div class="appraisal_menu">
  <div>
    <img src="https://img.rensa.jp.net/web/RYC/menu/icon_off/icon13.png" class="icon" alt="仕事"/>    <a class="" href="/cp_rsa/yumecakra_rsa/pre/life002/">
      <p>    現状から昇進/昇給【霊視でわかる◆あなたの仕事運】才能/評価/成功
</p>
    </a>
  </div>
      <p class="description">人には誰しも向き不向きがあるものです。その中で自分自身は何に向いているのかを正確に理解することは至難の業と言えるでしょう。才能や仕事運という目に見えないものを、チャクラを視ることで明らかにしていきます。あなたの仕事における運命をお確かめ下さい。</p>
    <div class="menu_info">
        <p class="price">
              <span class="common_price">価格 1,980円(税込)</span>
          </p>
  </div>
</div>                                                            <img loading="lazy" style="width: 100%;" src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/pc/top/line.png">
                                                                                
  <div class="appraisal_menu">
  <div>
    <img src="https://img.rensa.jp.net/web/RYC/menu/icon_off/icon12.png" class="icon" alt="人生"/>    <a class="" href="/cp_rsa/yumecakra_rsa/pre/life003/">
      <p>    何が起こる？どんな影響ある？【霊視で暴くあなたの人生】転機＆時期
</p>
    </a>
  </div>
      <p class="description">あなたが持つチャクラから、今後のあなたの人生を巡る運命について具体的に暴いていきます。どんな環境の中に身を置き、何を得ることになるのか……。これから先で訪れる運気が好転するタイミングを逃さないよう、しっかりと現実を受け止めて下さい。</p>
    <div class="menu_info">
        <p class="price">
              <span class="common_price">価格 880円(税込)</span>
          </p>
  </div>
</div>                                                                        </div>
                </section>
                <a href="#lifeMenuLinks" class="category_transition_link">▲カテゴリーTOPへ</a>
                <!-- -->
            </div>
            <section id="footer" style="margin: 0 33px;"><style>
    .footer {
        clear: both;
        background: black;
        color: white;
        padding: 35px 90px 30px;    }
    .footer a {
        text-decoration: underline;
        color: yellow;
    }
    .footer a:hover {
        color: #ff6b00;
        text-decoration: none;
    }
    .attention-line {
        width: 100%;
        height: 2px; /* 要sp対応 */
        line-height: 0;
        margin: 10px auto; /* 要sp対応 */
        border-top: 1px dashed #542; /* 要sp対応 */
    }
    .text-center {
        text-align: center;
    }
</style>

<div class="footer">
    <style>
    .footer-text-section h3 {
        text-align: center;
    }
    .precautions-list {
        padding: 12px 0;
    }
    .copyright_text {
        text-align: center;
    }
    .teller-telling-footer-section {
        text-align: center;
    }
    .pre-footer-section ul {
        margin: 3px;
        list-style-type: circle;
    }
</style>
<div class="footer-text-section">
    <h3>注意事項</h3>
    <ol class="precautions-lists-section">
        <li class="precautions-list">ご利用料金について<br/>
            「本州南端の生き神様【ゆめの心々】運命霊視/隠し事暴くチャクラ占い」は有料コンテンツです。占いをご購入の都度、表示料金のお支払いが必要となります。同じ占いメニューを同じ内容で占う場合でも、その都度料金が発生しますのでご注意ください。
            <div class="separator"></div>
        </li>
        <li class="precautions-list">占い結果について<br/>
            一度ご購入いただいた占い結果は、最初に購入された日を含め10日間閲覧が可能です。ご購入した際に送信されます注文受付自動配信メールをご確認いただき、そちらに記載されておりますURLより閲覧することが可能です。ご購入した占い結果をデータとして保存しておくことはできませんので、10日間を超えて保存されたい場合は別途プリントアウト等されることを推奨いたします。
            <div class="separator"></div>
        </li>

        <li class="precautions-list">利用推奨環境<br/>
            この占い番組は、次の環境でご利用ください。<br/>
            ＜OS＞<br/>
            <ul>
                <li>Windows：Windows 10以降</li>
                <li>Mac(Macintosh)：macOS 10.15 (Catalina)以降</li>
            </ul>
            ＜ブラウザ＞<br/>
            <ul>
                <li>Windows：Google Chrome最新版、Microsoft Edge最新版、Firefox最新版、またはそれに相当するブラウザ。</li>
                <li>Mac(Macintosh)：Safari最新版、またはそれに相当するブラウザ。</li>
            </ul>
            ※JavaScriptの設定をONにしてご利用ください。<br>
            ※Cookieの設定をONにしてご利用ください。<br>
            ※NetscapeはWindows、Macintosh共に非対応です。
            <br/>
            <div class="separator"></div>
        </li>

        <li class="precautions-list">決済方法について<br />
            <ul>
                <li>当コンテンツお支払いには、クレジットカード・WebMoney(ウェブマネー)・携帯キャリア決済・Amazon Payをご利用いただけます。</li>
                <li>他者による不正利用防止のため、クレジットカード情報のほかに、セキュリティコード、お電話番号、メールアドレスをご入力いただく方式を採用しております。お客様に安心してご利用いただけるよう、入力いただいた情報は、SSLで暗号化され、送信されます。</li>
            </ul>
            <div class="separator"></div>
        </li>

        <li class="precautions-list">特定商取引法に基づく表記<br />
            <ul>
                <li><!-- @: link/ --><a href="/cp_rsa/tokusyo/" class="link_attention" target="yumecakra_rsa_isp">特定商取引法に基づく表記</a></li>
                                    <li><a href="https://honkaku-uranai.jp/agreement/" class="link_attention" target="yumecakra_rsa_isp">利用規約</a></li>
                            </ul>
            <div class="separator"></div>
        </li>
            <li class="precautions-list">このサービスのお問い合わせは<a id="inquiry_link" href="/inquiry/?cont_id=345" class="link_attention" target="_new">こちら</a>をご覧ください。</li>
    </ol>
</div>
<p class="copyright_text">Copyright Rensa Co., Ltd.<br />このページの無断転用・転記を禁じます。</p>
<br/><br/>
<div class="footer_img"></div>
</div></section>
        </section>
        <div id="#scroll_bottom"></div>
    </div>
</main>

<!-- JS -->
    <script src="https://web-img.rensa.jp.net/rensa/images/web/Yumecakra/js/pc/top.js"></script><!-- -->    </div>
                <script>
        var userAgent = window.navigator.userAgent.toLowerCase();
        var isSmoothScrollDisableBrowser = false;
        var smoothScrollEnabled = true;

        if (userAgent.indexOf('msie') != -1 || userAgent.indexOf('trident') != -1) {
            isSmoothScrollDisableBrowser = true;
        } else if (userAgent.indexOf('edge') != -1) {
            isSmoothScrollDisableBrowser = true;
        } else if (userAgent.indexOf('safari') != -1) {
            isSmoothScrollDisableBrowser = true;
        }


        document.addEventListener('mousewheel', function(e) {
            if (smoothScrollEnabled) {
                e.preventDefault();
                var wd = e.wheelDelta;
                var csp = window.pageYOffset;
                window.scrollTo(0, csp - wd / 2);
            }
        }, {
            passive: false
        });

        function smoothScrollEnable() {
            smoothScrollEnabled = true;
        }

        function smoothScrollDisable() {
            smoothScrollEnabled = false;
        }

        if (isSmoothScrollDisableBrowser) {
            smoothScrollEnable()

            $("select").change(function() {
                smoothScrollEnable();
                $(this).blur()
            });
            $("select")
                .focusin(function(e) {
                    smoothScrollDisable()
                })
                .focusout(function(e) {
                    smoothScrollEnable();
                });
        }
    </script>
    </body>

</html>"""

# %%
df = html_to_df_rsa(html_str)

# %%
df
# Out:
#                               menu_html  \
# 0     なかなか距離縮まらないあの人『想い続けて叶う？』本音/転機/恋決着
# 1   2人の恋心/強制成就【ゆめの心々◆宿縁霊視30項】本心/転機/関係最後
# 2     考えも想いもマルわかり【あの人の全てを知る霊視】存在 /恋心/決断
# 3     どんな別れ方でも修復【諦めきれない恋心を救済鑑定】現状/未練/結末
# 4      進展皆無の恋【距離感じるあの人の態度理由を霊視】2人の誤解⇒解消
# 5     『あの人と交際できる？』片想いの結末まで解明◆2人の絆/本音/変化
# 6    人生掌握【ゆめの心々渾身】あなたの全運命を霊視◆1年⇒10年後/晩年
# 7     考えも想いもマルわかり【あの人の全てを知る霊視】存在 /恋心/決断
# 8   2人の恋心/強制成就【ゆめの心々◆宿縁霊視30項】本心/転機/関係最後
# 9    本気の不倫愛を救済【2人の関係導く21項】あの人の覚悟/行動/愛結末
# 10    考えも想いもマルわかり【あの人の全てを知る霊視】存在 /恋心/決断
# 11   愛熱高まる夜【2人の想い重ね確かめ合う◆濃密官能占】体相性/欲/H後
# 12    どんな別れ方でも修復【諦めきれない恋心を救済鑑定】現状/未練/結末
# 13    あの人の本命は誰？【2人の恋運命を全解明】恋愛相性/本命/最終関係
# 14     進展皆無の恋【距離感じるあの人の態度理由を霊視】2人の誤解⇒解消
# 15     この人しかいない『運命感じるのは私だけ？』霊視で視抜く◆本心/答
# 16    『あの人と交際できる？』片想いの結末まで解明◆2人の絆/本音/変化
# 17     抱き続けてる恋心【あの人は気づいてる？】恋霊視◆恋愛対象/次行動
# 18     どうしても知りたい【あの人のあなたに対する恋心有無】存在/恋告白
# 19    なかなか距離縮まらないあの人『想い続けて叶う？』本音/転機/恋決着
# 20    婚姻待ったナシ【成婚へ導く霊視占】あなたの結婚縁/相手特徴/入籍後
# 21    まるで目の前にいるかのよう【あなたの生涯伴侶/全特徴】出会い/入籍
# ...
