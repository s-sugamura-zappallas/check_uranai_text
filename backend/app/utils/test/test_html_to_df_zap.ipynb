# %%
import sys
sys.path.append('../')
from html_to_df import html_to_df_zap

# %%
html_str = """
<!DOCTYPE html>
<html lang="ja">
<!-- Release Date : 2024-05-21 cp_zap -->
  <head>

<script type="text/javascript">
<!---
if (!(navigator.userAgent.indexOf('iPhone') > 0 || navigator.userAgent.indexOf('iPad') > 0 || navigator.userAgent.indexOf('Android') > 0 || navigator.userAgent.indexOf('Mobile') > 0 ) || !(window.screen.width < 640 || window.screen.height < 640))  {
  document.getElementsByTagName("html")[0].setAttribute("class","disp_pc");
  document.write('<meta name="viewport" content="width=device-width,initial-scale=1.0,minimum-scale=1.0,maximum-scale=1.0,user-scalable=no">');
}else{
  document.getElementsByTagName("html")[0].setAttribute("class","disp_sp");
  document.write('<meta name="viewport" content="width=375,user-scalable=no">');
}
//--->
</script>

    <meta http-equiv="Content-Type" content="text/html; charset=UTF-8">
    <meta name="copyright" content="(C)cocoloni,Inc">
    <meta http-equiv="X-UA-Compatible" content="IE=edge">
    <meta name="Content-Language" content="ja">
    <meta http-equiv="Content-Script-Type" content="text/javascript">
    <meta http-equiv="Content-Style-Type" content="text/css">
    <meta name="Keywords" content="天稀三輪,霊視,龍神,守護霊,当たる">
    <meta name="Description" content="類まれなる霊力に全国から依頼殺到！　守護霊や龍神の言葉を降ろす【憑依ユタ・天稀三輪】の霊視鑑定が登場。あなたに訪れる現実や恋する相手の想い、秘め事も……脅威の“神霊対話”で全てを暴き尽くす！">
    <meta property="og:title" content="『私も視てほしい！』脅威の神霊対話で心奥暴く◆憑依ユタ◆天稀三輪 | cocoloni占い館 Moon">
    <meta property="og:description" content="類まれなる霊力に全国から依頼殺到！　守護霊や龍神の言葉を降ろす【憑依ユタ・天稀三輪】の霊視鑑定が登場。あなたに訪れる現実や恋する相手の想い、秘め事も……脅威の“神霊対話”で全てを暴き尽くす！">
    <meta property="og:url" content="https://honkaku-uranai.jp/cp_zap/amaki_zap/">
    <meta property="og:type" content="article"/>
    <meta property="og:image" content="https://honkaku-uranai.jp/cp_zap/amaki_zap/image/contents/amaki_zap.jpg" />
    <meta property="og:locale" content="ja_JP">
    <title>『私も視てほしい！』脅威の神霊対話で心奥暴く◆憑依ユタ◆天稀三輪 | cocoloni占い館 Moon</title>
    <script language="JavaScript" type="text/javascript" >
          var contents_title = '『私も視てほしい！』脅威の神霊対話で心奥暴く◆憑依ユタ◆天稀三輪';
    </script>
        <script type="text/javascript" src="https://lw6nr4oyej.user-space.cdn.idcfcloud.net/amaki_zap/source/js/jquery.js"></script>
    <script type="text/javascript" src="https://lw6nr4oyej.user-space.cdn.idcfcloud.net/amaki_zap/source/js/effect.js"></script>
    <!-- for input form -->
    <script type="text/javascript" src="https://lw6nr4oyej.user-space.cdn.idcfcloud.net/amaki_zap/source/js/ecl.js"></script>
    <script type="text/javascript" src="https://lw6nr4oyej.user-space.cdn.idcfcloud.net/common/source/js/input_common_sp.js"></script>
    <script type="text/javascript" src="./source/js/input/common.js"></script>
    <script type="text/javascript">
    <!--
    window.onunload = function () {}
    menuPerson = 2;
    var free_id = "am9400af";
    //-->
    </script>
    <script type="text/javascript" src="https://lw6nr4oyej.user-space.cdn.idcfcloud.net/amaki_zap/source/js/contents_index.js"></script>
    <!-- //for input form -->

<script type="text/javascript">
  const script_hdr = document.createElement('script');
  script_hdr.src = "https://lw6nr4oyej.user-space.cdn.idcfcloud.net/cp_zap/common/source/js/gtm_hdr.js";
  document.head.appendChild(script_hdr);
</script>
    <noscript>
      <meta http-equiv="refresh" content="0;url=/cp_zap/amaki_zap/browser_error.html">
    </noscript>
    <script type="text/javascript" src="./source/js/script.js"></script>
    <script type="text/javascript" src="https://lw6nr4oyej.user-space.cdn.idcfcloud.net/cp_zap/common/source/js/purl.js"></script>
    <script type="text/javascript">
    <!---
    // Check the clients browser
    var isNavi  = checkNavigator ( );
    if ( ! isNavi )
      location.href = "/cp_zap/amaki_zap/browser_error.html";
    //--->
    </script>
    <link rel="stylesheet" type="text/css" href="https://lw6nr4oyej.user-space.cdn.idcfcloud.net/amaki_zap/source/css/contents.css">
    <link rel="stylesheet" type="text/css" href="https://lw6nr4oyej.user-space.cdn.idcfcloud.net/amaki_zap/source/css/index.css">
    <link rel="stylesheet preload" type="text/css" href="https://lw6nr4oyej.user-space.cdn.idcfcloud.net/amaki_zap/source/css/isp/cp_zap/index_attention.css">
    <link rel="stylesheet" type="text/css" href="https://lw6nr4oyej.user-space.cdn.idcfcloud.net/amaki_zap/source/css/isp/cp_zap/cp_zap_common.css">
    <link rel="canonical" href="https://honkaku-uranai.jp/cp_zap/amaki_zap/">
  </head>
<body>

<!-- Google Tag Manager (noscript) -->
<noscript><iframe src="https://www.googletagmanager.com/ns.html?id=GTM-MV3KXWG"
height="0" width="0" style="display:none;visibility:hidden"></iframe></noscript>
<!-- End Google Tag Manager (noscript) -->

<script type="text/javascript">

<!---
if ((navigator.userAgent.indexOf('iPhone') > 0 && navigator.userAgent.indexOf('iPad') == -1) || navigator.userAgent.indexOf('iPod') > 0 || navigator.userAgent.indexOf('Android') > 0) {
    var script = document.createElement('script'); 
    script.src = "https://lw6nr4oyej.user-space.cdn.idcfcloud.net/cp_zap/common/source/js/cp_zap_sp.js";
    document.head.appendChild(script);
} else {
    var css=document.createElement("link");
    css.setAttribute("rel","stylesheet");
    css.setAttribute("type","text/css");
    css.setAttribute("href","https://lw6nr4oyej.user-space.cdn.idcfcloud.net/cp_zap/common/source/css/merchant_header.css");
    document.getElementsByTagName("head")[0].appendChild(css);

    var script = document.createElement('script'); 
    //script.src = "/cp_zap/common/source/js/cp_zap_utf8.js";
    script.src = "https://lw6nr4oyej.user-space.cdn.idcfcloud.net/cp_zap/common/source/js/cp_zap.js";
    script.setAttribute("charset","euc-jp");
    document.head.appendChild(script);
}

//--->
</script>
  <div id="isp_header" style="display:none;"></div>
  <h1 class="contents_headerCopy">『私も視てほしい！』脅威の神霊対話で心奥暴く◆憑依ユタ◆天稀三輪</h1>

  <div id="base">
    <div id="header_index">
      <div id="header">
        <div class="h_wrap">
          <h2><img width="640" height="auto" src="https://lw6nr4oyej.user-space.cdn.idcfcloud.net/amaki_zap/image/contents/header_index.jpg" alt="『私も視てほしい！』脅威の神霊対話で心奥暴く◆憑依ユタ◆天稀三輪" class="header_img"></h2>
        </div>
      </div>
    </div>
    <div class="contents_wrap">
      <div id="index">
        <div id="header_nav">
          <ul>
            <li><a href="/cp_zap/amaki_zap/input/am0200a.html" ><img width="210" height="148" style="width:100%;height:auto;" src="https://lw6nr4oyej.user-space.cdn.idcfcloud.net/amaki_zap/image/index/header_btn1.png" alt="無料で占うあの人の心の声　今の状況" class="swapImage"></a></li>
            <li><a href="/cp_zap/amaki_zap/input/am0100a.html" ><img width="210" height="148" style="width:100%;height:auto;" src="https://lw6nr4oyej.user-space.cdn.idcfcloud.net/amaki_zap/image/index/header_btn2.png" alt="無料で占うあなたの結婚縁　異性の評判" class="swapImage"></a></li>
            <li><a href="/cp_zap/amaki_zap/input/am0101a.html" ><img width="210" height="148" style="width:100%;height:auto;" src="https://lw6nr4oyej.user-space.cdn.idcfcloud.net/amaki_zap/image/index/header_btn3.png" alt="無料で占う　あなたの特別な力　この世での使命" class="swapImage"></a></li>
          </ul>
          <div class="clear"></div>
        </div>
        <div id="top_bg">
          <div id="nav">
            <ul>
              <li class="profile"><a href="./profile.html"><img src="https://lw6nr4oyej.user-space.cdn.idcfcloud.net/amaki_zap/image/contents/navi/profile.png" alt="監修者・占術紹介" width="302" height="52" style="width:100%;height:auto;" class="swapImage"></a></li>
              <li class="explain"><a href="#input_group"><img src="https://lw6nr4oyej.user-space.cdn.idcfcloud.net/amaki_zap/image/contents/navi/extra.png" alt="厳選恋愛メニュー" width="302" height="52" style="width:100%;height:auto;" class="swapImage"></a></li>
            </ul>
            <div class="clear"></div>
          </div>
        </div>
        <div id="topicpath" class="is_pc">
          <p><span class="def"></span><input type="hidden" name="contents_name" value="amaki_zap">&nbsp;&gt;&nbsp;『私も視てほしい！』脅威の神霊対話で心奥暴く◆憑依ユタ◆天稀三輪</p>
        </div>

        <div id="maintenance" style="display:none;"></div>
        <div class="text_img">
          <h2><img width="640" height="956" style="width:100%;height:auto;" src="https://lw6nr4oyej.user-space.cdn.idcfcloud.net/amaki_zap/image/contents/text.jpg" alt="言うことが次々的中!!　守護霊や龍神と繋がれば言葉が降りる！　未来が視える！　彼の性格もよく当たっていて、ホント凄い。。なかなか予約のできない先生ですが、また視て頂きたいです!!　連絡がきた！　演者＆スタッフも鑑定に行列！！　劇団○○　私も占ってほしい〜！　噂を聞きつけ電話・対面鑑定　全国各地から依頼続々！　人智超えの救済霊視"></h2>
          <div class="mark_1">※1</div>
          <div class="mark_2">※2</div>
          <div class="note_1">※1　電話占い 「ロバミミ」口コミ　2024年2月時点 cocoloni調べ<br>
          ※2　天稀三輪体験談　2024年2月時点 cocoloni調べ</div>
        </div>



        <div id="new_group">
          <div class="section_bdy">
            <h2><img width="640" height="172" style="width:100%;height:auto;" src="https://lw6nr4oyej.user-space.cdn.idcfcloud.net/amaki_zap/image/index/new_group/section_title.jpg" alt="新着メニュー"></h2>
            <div class="section_ftr">
              <div class="section_hdr">
                <div class="latest">
                  <div class="severalmenu">
                    <div class="icon">
                      <span title="あの人の気持ち" class="icon_category_5"></span>
                    </div>
                    <div class="menu_info">
                    
                            <h3><a href="/cp_zap/amaki_zap/input/am6800a.html">最後二人は【結ばれるorお別れ】相手が隠す本音/位置づけ/最終関係</a></h3>
                          </div>
                          <div class="clear"></div>
                          <p class="caption">あの人に、あなたが感じている「予感」。今、あの人の様子に何か引っかかるものがあるみたいね。あなたの前であの人がそんな風になってしまうのは、きっと“ある気持ち”をあなたに悟られたくないからよ。覚悟があるなら、煮え切らないこの恋の真相を暴いていくわ。</p>
                          <div class="price_info">1,980円（税込）</div>
                  </div>


                </div>
                <div class="clear"></div>
              </div>
            </div>
          </div>
        </div>
        <hr>
<hr>


            <div id="feature">
              <div class="balloon_group">
                <img width="640" height="1116" style="width:100%;height:auto;" src="https://lw6nr4oyej.user-space.cdn.idcfcloud.net/amaki_zap/image/index/feature/text.jpg" alt="どんなに離れていても……私には隠し事はできません　連絡はまだ……　誘ってもいい？　本当は触れたい　あなたが知りたいこと全て教えるわ">
                <div class="balloon">
                 <div class="detail_txt">
                   <p>私には目には見えない存在が、小さい頃からなんでも教えてくれたの。この“力”は隠せても、無くすことはできなかった。それなら､人のために使いたいって思ったのよ。だから……</p>
                 </div>
                </div>
              </div>
              <div class="section_bdy">
                <div class="section_bdy">
                  <div class="section_bdy">

                      <img width="100%" height="auto" src="https://lw6nr4oyej.user-space.cdn.idcfcloud.net/amaki_zap/image/index/feature/text1.jpg" alt="1 状況も潜在能力も筒抜け！　深層視抜く守護霊対話">
                    <img width="100%" height="auto" src="https://lw6nr4oyej.user-space.cdn.idcfcloud.net/amaki_zap/image/index/feature/img1.jpg" alt="今置かれている現状や相手の嘘偽りない本音について、個人を見守る守護霊に尋ね、最も強く伝わってきた言葉を受け取りお伝えします。">

                      <div class="severalmenu">
                      <div class="icon">
                        <span title="あの人の気持ち" class="icon_category_5"></span>
                      </div>
                      <div class="menu_info">
                        <h3><a href="/cp_zap/amaki_zap/input/am9400a.html">覚悟※神霊対話で心奥暴く！【あの人のリアルすぎる15の本音】全暴露</a></h3>
                      </div>
                      <div class="clear"></div>
                            <p class="price_info">3,190円（税込）</p>
                    </div>
                      <div class="severalmenu">
                      <div class="icon">
                        <span title="あの人の本性" class="icon_category_8"></span>
                      </div>
                      <div class="menu_info">
                        <h3><a href="/cp_zap/amaki_zap/input/am8000a.html">繋がりたいのは本望よ。【極秘官能占】あの人の欲望/衝動/誘惑サイン</a></h3>
                      </div>
                      <div class="clear"></div>
                            <p class="price_info">2,200円（税込）</p>
                    </div>
                      <div class="severalmenu">
                      <div class="icon">
                        <span title="片想い" class="icon_category_3"></span>
                      </div>
                      <div class="menu_info">
                        <h3><a href="/cp_zap/amaki_zap/input/am4200a.html">苦しい恋はもう終わり◆あなたはあの人を【想い続ける⇔諦める】べき</a></h3>
                      </div>
                      <div class="clear"></div>
                            <p class="price_info">1,320円（税込）</p>
                    </div>
                      <img width="100%" height="auto" src="https://lw6nr4oyej.user-space.cdn.idcfcloud.net/amaki_zap/image/index/feature/text2.jpg" alt="2 時の知らせが救いをもたらす！　運命の成長へ導く龍神のお告げ">
                    <img width="100%" height="auto" src="https://lw6nr4oyej.user-space.cdn.idcfcloud.net/amaki_zap/image/index/feature/img2.jpg" alt="あなたが良い方向へ向かう重要なアドバイス、恋の相手との進展に向けた転機について、龍神かのらメッセージを受け取りお伝えします。">

                      <div class="severalmenu">
                      <div class="icon">
                        <span title="仕事" class="icon_category_22"></span>
                      </div>
                      <div class="menu_info">
                        <h3 class="second"><a href="/cp_zap/amaki_zap/input/am7000a.html">知れば変わるわ。働くあなたの【本当の評価×BIGチャンス】得る成功</a></h3>
                      </div>
                      <div class="clear"></div>
                            <p class="price_info">2,200円（税込）</p>
                    </div>
                      <div class="severalmenu">
                      <div class="icon">
                        <span title="運命の相手" class="icon_category_15"></span>
                      </div>
                      <div class="menu_info">
                        <h3 class="second"><a href="/cp_zap/amaki_zap/input/am7001a.html">緊急霊視※周りはあなたをどう見てる？　もう運命の人と出会ってる？</a></h3>
                      </div>
                      <div class="clear"></div>
                            <p class="price_info">2,200円（税込）</p>
                    </div>
                      <div class="severalmenu">
                      <div class="icon">
                        <span title="人生" class="icon_category_21"></span>
                      </div>
                      <div class="menu_info">
                        <h3 class="second"><a href="/cp_zap/amaki_zap/input/am1800a.html">当てすぎ“神霊対話”にゾッ！『あなたの人生、次●●が起こるわよ』</a></h3>
                      </div>
                      <div class="clear"></div>
                            <p class="price_info">880円（税込）</p>
                    </div>
                      <img width="100%" height="auto" src="https://lw6nr4oyej.user-space.cdn.idcfcloud.net/amaki_zap/image/index/feature/text3.jpg" alt="3 隠れた本音、未来の場面……真実を特定し核心断言！">
                    <img width="100%" height="auto" src="https://lw6nr4oyej.user-space.cdn.idcfcloud.net/amaki_zap/image/index/feature/img3.jpg" alt="守護霊を通して視える二人の未来の恋模様、将来の出来事など今後起こる場面を特定し、視えた真実を具体的にお伝えします。">

                      <div class="severalmenu">
                      <div class="icon">
                        <span title="あの人の気持ち" class="icon_category_5"></span>
                      </div>
                      <div class="menu_info">
                        <h3 class="third"><a href="/cp_zap/amaki_zap/input/am6000a.html">迷惑or期待している◆相手の今の心境⇒あなたへの執着度/願望/恋未来</a></h3>
                      </div>
                      <div class="clear"></div>
                            <p class="price_info">1,650円（税込）</p>
                    </div>
                      <div class="severalmenu">
                      <div class="icon">
                        <span title="あの人の気持ち" class="icon_category_5"></span>
                      </div>
                      <div class="menu_info">
                        <h3 class="third"><a href="/cp_zap/amaki_zap/input/am6001a.html">これが現実よ。曖昧なあの人、実はあなたを【手に入れたいor無関心】</a></h3>
                      </div>
                      <div class="clear"></div>
                            <p class="price_info">1,650円（税込）</p>
                    </div>
                      <div class="severalmenu">
                      <div class="icon">
                        <span title="恋の行方" class="icon_category_4"></span>
                      </div>
                      <div class="menu_info">
                        <h3 class="third"><a href="/cp_zap/amaki_zap/input/am6002a.html">この恋叶う？【年の差/既婚/職場etc】相手の本音/好みのタイプ/結論</a></h3>
                      </div>
                      <div class="clear"></div>
                            <p class="price_info">1,650円（税込）</p>
                    </div>
                  </div>
                </div>
              </div>
            </div>
            <hr>

            <div id="input_group">
              <h2>
                <img width="640" height="662" style="width:100%;height:auto;" src="https://lw6nr4oyej.user-space.cdn.idcfcloud.net/amaki_zap/image/index/input_group/section_title.jpg" alt="本心がわかれば怖くない　“本音”も“恋の運命”も守護霊に直接尋ねれば答えをくれるわ　早速だけど……あなたへの嘘偽りない本心を聴いてみましょうか？">
              </h2>
              <div class="section_bdy">
                <div class="section_ftr">
                  <div class="section_hdr">
                    <div class="article_bdy">
                      <div class="article_ftr">
                        <div class="article_hdr">
<form name="frmMain2" method="get" action="/cp_zap/common/cgi-bin/charge.cgi" onSubmit="return false" accept-charset="euc-jp">
<input type="hidden" name="contents_name" value="amaki_zap">
<input type="hidden" name="isp" value="11">
<input type="hidden" name="menu_id" value="am9400a">
<input type="hidden" name="t" value="result/normal_free">
<input type="hidden" name="l" value="result_amaki_zap">
                    <div id="frmInput" style="display:block;">
                      <!--- input_self --->
                      <div class="input_self">
                        <h3><img width="596" height="70" style="width:100%;height:auto;" src="https://lw6nr4oyej.user-space.cdn.idcfcloud.net/amaki_zap/image/index/input_group/section_hdr_self.jpg" alt="あなたについて教えてください"></h3>
                        <table class="input_tbl" cellspacing="0">
                          <tbody>
                            <tr class="tr_name">
                              <th><label for="name_last_self">せい</label><span class="hissu">（必須）</label></th>
                            </tr>
                            <tr class="tr_name">
                              <td><input type="text" id="name_last_self" name="name_last_self" size="8" maxlength="8" class="input_name"></td>
                            </tr>
                            <tr class="tr_name">
                              <th><label for="name_first_self">めい</label><span class="hissu">（必須）</label></th>
                            </tr>
                            <tr class="tr_name">
                              <td><input type="text" id="name_first_self" name="name_first_self" size="8" maxlength="8" class="input_name"></td>
                            </tr>
                            <tr class="tr_caution">
                              <td>
                                <p>※ひらがなで入力（各8文字まで）</p>
                              </td>
                            </tr>
                          </tbody>
                        </table>
                      </div>

                      <div class="input_other">
                        <h3><img width="596" height="70" style="width:100%;height:auto;" src="https://lw6nr4oyej.user-space.cdn.idcfcloud.net/amaki_zap/image/index/input_group/section_hdr_other.jpg" alt="あの人について教えてください"></h3>
                        <table class="input_tbl" cellspacing="0">
                          <tbody>
                            <tr class="tr_name">
                              <th><label for="name_last_other">せい</label><span class="hissu">（必須）</label></th>
                            </tr>
                            <tr class="tr_name">
                              <td><input type="text" id="name_last_other" name="name_last_other" size="8" maxlength="8" class="input_name"></td>
                            </tr>
                            <tr class="tr_name">
                              <th><label for="name_first_other">めい</label><span class="hissu">（必須）</label></th>
                            </tr>
                            <tr class="tr_name">
                              <td><input type="text" id="name_first_other" name="name_first_other" size="8" maxlength="8" class="input_name"></td>
                            </tr>
                            <tr class="tr_caution">
                              <td>
                                <p>※ひらがなで入力（各8文字まで）</p>
                              </td>
                            </tr>
                          </tbody>
                        </table>
                      </div>
                      <!--- //input_other  --->
                      <div class="price_info_btn">
                            <div class="cookie_check">入力した情報を記録しますか？<br>
                        <label><input name="cwflg" value="ok" type="checkbox" checked>&nbsp;記録する</label>　　　
                        <input type="button" value="記録を削除する" onclick="resetCookie()"></div>
                            <input width="100%" height="auto" type="image" src="https://lw6nr4oyej.user-space.cdn.idcfcloud.net/amaki_zap/image/index/input_group/btn_trial.png" alt="あの人の本音を知る" id="btn_trial" onclick="checkParamsFree( null, true );" class="swapImage" name="btn_trial">
                      </div>
                      <div class="clear"></div>
                      <p class="btn_exp"><span>「あの人の本音を知る」</span>ボタンを<span class="is_pc">クリック</span><span class="is_sp">タップ</span>すると、鑑定結果の一部を無料でご覧になれます。</p>
                      <div id="privacy">
                                              <p>株式会社cocoloniは、ご入力いただいた情報を、占いサービスを提供するためにのみ使用し、情報の蓄積を行ったり、他の目的で使用することはありません。<br><a href="https://cocoloni.com/privacypolicy" target="_blank">当社個人情報保護方針</a>（外部サイト）に同意の上、必要情報をご入力ください。<br>また、ご購入に関しては、cocoloni占い館の<a href="/agreement/" target="_privacy">利用規約</a>に同意の上、必要情報をご入力ください。</p>
                                            </div>
                      <div class="clear"></div>
                    </div>
                    </form>
                        </div>
                      </div>
                    </div>
                  </div>
                </div>
              </div>
            </div>

       <div id="extra_group">
         <h2><img width="640" height="698" style="width:100%;height:auto;" src="https://lw6nr4oyej.user-space.cdn.idcfcloud.net/amaki_zap/image/index/extra_group/section_title.jpg" alt="“龍神”は運を上昇させ、運命の成長を促してくれる存在　恋や運命に訪れる最高のタイミングを示してくれるわ　↓この日だけは絶対に忘れないで↓"></h2>
         <div class="section_bdy">
           <div class="section_ftr">
             <div class="section_hdr">
                            <p class="menu_theme">【恋愛】あの人との恋に変化が訪れる日</p>
                 <div class="menu_bdy">
                 <div class="menu_ftr">
                   <div class="menu_hdr">
                     <div class="severalmenu">
                       <div class="icon">
                         <span width="120" height="120" title="恋愛特別鑑定" class="icon_category_1"></span>
                       </div>
                       <div class="menu_info">
                         <h3><a href="/cp_zap/amaki_zap/input/am9600a.html">両想い∞強力縁結び【二人の宿縁/あの人の想い/結婚縁】恋愛成就霊視</a></h3>
                       </div>
                       <div class="clear"></div>
                          <p class="caption">『あの人に一生愛され続ける』二人の愛と縁を結ぶ恋愛成就霊視◆この恋を叶えるため、あの人の想いや二人の間にある特別な絆、そして約束された未来をこれからお見せするわね。あなたとあの人の“出会いは必然だった”……それが本物だって証を形にするわ。</p>
                       <p class="price_info">3,740円（税込）</p>
                     </div>
                   </div>
                 </div>
               </div>
               <div class="horizon"></div>
                            <p class="menu_theme">【結婚】運命の相手と結婚を決意する日</p>
                 <div class="menu_bdy">
                 <div class="menu_ftr">
                   <div class="menu_hdr">
                     <div class="severalmenu">
                       <div class="icon">
                         <span width="120" height="120" title="結婚特別鑑定" class="icon_category_26"></span>
                       </div>
                       <div class="menu_info">
                         <h3><a href="/cp_zap/amaki_zap/input/am9000a.html">縁結びSP霊視【あなたの結婚相手は誰？】相手の特徴/出会う場面/婚期</a></h3>
                       </div>
                       <div class="clear"></div>
                          <p class="caption">大切なのは早く結婚することではなく、“どんな人と結婚すればあなたが幸せになれるのか”なのよ。神霊はその全てをわかっているわ。だから、あなたの結婚相手がどんな人なのかここで全て明かすわ。その人物の顔や性格、そして出会いの場面から婚期まで……お伝えするわね。</p>
                       <p class="price_info">2,750円（税込）</p>
                     </div>
                   </div>
                 </div>
               </div>
               <div class="horizon"></div>
                            <p class="menu_theme">【人生】あなたに大きな転機が訪れる日</p>
                 <div class="menu_bdy">
                 <div class="menu_ftr">
                   <div class="menu_hdr">
                     <div class="severalmenu">
                       <div class="icon">
                         <span width="120" height="120" title="人生特別鑑定" class="icon_category_19"></span>
                       </div>
                       <div class="menu_info">
                         <h3><a href="/cp_zap/amaki_zap/input/am9700a.html">神霊が語る宿命【あなたの使命/可能性/財/転機】晩年まで⇒完全網羅</a></h3>
                       </div>
                       <div class="clear"></div>
                          <p class="caption">【この鑑定が転機になる】あなたの幸せを願う神霊が今あなたに伝えたいこと……そこには目の前にある人生の見方が変わるようなたくさんの“ヒント”が隠されているの。これから訪れる人生の可能性や転機、人との関わりや晩年の生活まで、私に視えるもの全てお伝えするわ。</p>
                       <p class="price_info">3,740円（税込）</p>
                     </div>
                   </div>
                 </div>
               </div>
               <div class="horizon"></div>
                            <p class="menu_theme">【官能】二人が身も心も結ばれやすい日</p>
                 <div class="menu_bdy">
                 <div class="menu_ftr">
                   <div class="menu_hdr">
                     <div class="severalmenu">
                       <div class="icon">
                         <span width="120" height="120" title="あの人の本性" class="icon_category_8"></span>
                       </div>
                       <div class="menu_info">
                         <h3><a href="/cp_zap/amaki_zap/input/am8000a.html">繋がりたいのは本望よ。【極秘官能占】あの人の欲望/衝動/誘惑サイン</a></h3>
                       </div>
                       <div class="clear"></div>
                          <p class="caption">恥ずかしがる必要なんてないのよ。あの人との愛を確かめ合いたい、ベッドの上で交じり合うときあの人がどんな顔を見せるのか、どんな欲望にかられるのか。ちょっと覗いて見てみましょうか……淫らな想いも、隠したい欲求も……あの人の欲望の全てを受け入れてね。</p>
                       <p class="price_info">2,200円（税込）</p>
                     </div>
                   </div>
                 </div>
               </div>
               <div class="horizon"></div>
                            <p class="menu_theme">【不倫】今の関係に決着がつく日</p>
                 <div class="menu_bdy">
                 <div class="menu_ftr">
                   <div class="menu_hdr">
                     <div class="severalmenu">
                       <div class="icon">
                         <span width="120" height="120" title="不倫愛" class="icon_category_10"></span>
                       </div>
                       <div class="menu_info">
                         <h3><a href="/cp_zap/amaki_zap/input/am9401a.html">不倫占【あの人との愛確かめる20章】あなたへの本音/覚悟/愛の終着点</a></h3>
                       </div>
                       <div class="clear"></div>
                          <p class="caption">あの人との関係はずっとこのまま？　この愛は本物？――あなたが不安に思うその問いに、私がハッキリと答えを出すわ。あの人のあなたへの覚悟や愛情、この関係に対する本音、そしてあなたたちがどんな結末を選ぶのか……綺麗事ナシで真実に迫るわね。</p>
                       <p class="price_info">3,190円（税込）</p>
                     </div>
                   </div>
                 </div>
               </div>
               <div class="horizon"></div>
                            <p class="menu_theme">【仕事】働くあなたにとっての最大転機</p>
                 <div class="menu_bdy">
                 <div class="menu_ftr">
                   <div class="menu_hdr">
                     <div class="severalmenu">
                       <div class="icon">
                         <span width="120" height="120" title="仕事" class="icon_category_22"></span>
                       </div>
                       <div class="menu_info">
                         <h3><a href="/cp_zap/amaki_zap/input/am7000a.html">知れば変わるわ。働くあなたの【本当の評価×BIGチャンス】得る成功</a></h3>
                       </div>
                       <div class="clear"></div>
                          <p class="caption">仕事というのは生活の大部分を占めるもの。『上手くいってない……』もしそう思っているなら、それはあなたが、“本当の自分”を生きていないからかもしれないわ。だから、あなたは自身が持つ素晴らしい才能を知り、それを活かすべき。あなたの価値はもっと輝くはずよ。</p>
                       <p class="price_info">2,200円（税込）</p>
                     </div>
                   </div>
                 </div>
               </div>
               <div class="horizon"></div>
                            <p class="menu_theme">【出会い】運命の人と関係を深める日</p>
                 <div class="menu_bdy">
                 <div class="menu_ftr">
                   <div class="menu_hdr">
                     <div class="severalmenu">
                       <div class="icon">
                         <span width="120" height="120" title="運命の相手" class="icon_category_15"></span>
                       </div>
                       <div class="menu_info">
                         <h3><a href="/cp_zap/amaki_zap/input/am7001a.html">緊急霊視※周りはあなたをどう見てる？　もう運命の人と出会ってる？</a></h3>
                       </div>
                       <div class="clear"></div>
                          <p class="caption">【神霊対話でピタリと的中！】もしかしたらあなたは今、ご自分に出会いの気配を感じていないのかもしれません。でも、“特別な縁”っていうのは必ず巡ってくるものよ。そのときを見逃さないよう、あなたの周りの目線や出会いについて視えたものを、ズバリお伝えするわね。</p>
                       <p class="price_info">2,200円（税込）</p>
                     </div>
                   </div>
                 </div>
               </div>
             </div>
           </div>
         </div>
       </div>
       <hr>


       <div id="extra_group2">
         <div class="balloon_group">
           <img width="640" height="543" style="width:100%;height:auto;" src="https://lw6nr4oyej.user-space.cdn.idcfcloud.net/amaki_zap/image/index/extra_group2/section_title.jpg" alt="あなたがこれから先手に入れる幸せ、進むべき道、人生の目的地は……？">
           <div class="balloon">
            <div class="detail_txt">
              <p>あなたの身の回りに起きることに偶然はなく、全てに意味があり必然です。今、絶望しそうな未来しか見えなくても必ず好機はやってきます。だから、私に降りてくる神霊たちの言葉をあなたにもお伝えさせて。</p>
            </div>
           </div>
         </div>
         <h2><img width="640" height="165" style="width:100%;height:auto;" src="https://lw6nr4oyej.user-space.cdn.idcfcloud.net/amaki_zap/image/index/extra_group2/section_hdr.jpg" alt="お悩み別メニュー"></h2>
         <div class="section_bdy">
           <div class="section_ftr">
             <div class="section_hdr">
               <div class="menu_bdy">
                 <div class="menu_ftr">
                   <div class="menu_hdr">
                     <div class="severalmenu">
                       <div class="icon">
                         <span width="120" height="120" title="人生特別鑑定" class="icon_category_19"></span>
                       </div>
                       <div class="menu_info">
                         <h3><a href="/cp_zap/amaki_zap/input/am9700a.html">神霊が語る宿命【あなたの使命/可能性/財/転機】晩年まで⇒完全網羅</a></h3>
                       </div>
                       <div class="clear"></div>
                          <p class="caption">【この鑑定が転機になる】あなたの幸せを願う神霊が今あなたに伝えたいこと……そこには目の前にある人生の見方が変わるようなたくさんの“ヒント”が隠されているの。これから訪れる人生の可能性や転機、人との関わりや晩年の生活まで、私に視えるもの全てお伝えするわ。</p>
                       <p class="price_info">3,740円（税込）</p>
                     </div>
                   </div>
                 </div>
               </div>
               <div class="horizon"></div>
               <div class="menu_bdy">
                 <div class="menu_ftr">
                   <div class="menu_hdr">
                     <div class="severalmenu">
                       <div class="icon">
                         <span width="120" height="120" title="復縁" class="icon_category_9"></span>
                       </div>
                       <div class="menu_info">
                         <h3><a href="/cp_zap/amaki_zap/input/am8001a.html">復縁できる？【元サヤ救済霊視】相手の未練/今の望み/今後の可能性</a></h3>
                       </div>
                       <div class="clear"></div>
                          <p class="caption">『今も忘れられない……』本気で復縁したい相手がいるなら、無理にあの人を忘れる必要はないわ。それと同時に、やみくもに動いてもいけません。今あの人はあなたをどう想っているのか、動く意思はあるのか、二人が迎える本当の結末が何か、ここで明らかにしていきましょう。</p>
                       <p class="price_info">2,200円（税込）</p>
                     </div>
                   </div>
                 </div>
               </div>
               <div class="horizon"></div>
               <div class="menu_bdy">
                 <div class="menu_ftr">
                   <div class="menu_hdr">
                     <div class="severalmenu">
                       <div class="icon">
                         <span width="120" height="120" title="恋の行方" class="icon_category_4"></span>
                       </div>
                       <div class="menu_info">
                         <h3><a href="/cp_zap/amaki_zap/input/am6002a.html">この恋叶う？【年の差/既婚/職場etc】相手の本音/好みのタイプ/結論</a></h3>
                       </div>
                       <div class="clear"></div>
                          <p class="caption">相手のほうから告白される。そんな瞬間を、一度でも想像したことがあるかしら？　その前に、あの人があなたを恋愛対象としてみているか、それともただ人として好きなのか、あなたに対する「真っ正直」な本音をお伝えするわ。この恋が叶うかどうか、最後まで教えるわね。</p>
                       <p class="price_info">1,650円（税込）</p>
                     </div>
                   </div>
                 </div>
               </div>
               <div class="horizon"></div>
               <div class="menu_bdy">
                 <div class="menu_ftr">
                   <div class="menu_hdr">
                     <div class="severalmenu">
                       <div class="icon">
                         <span width="120" height="120" title="片想い" class="icon_category_3"></span>
                       </div>
                       <div class="menu_info">
                         <h3><a href="/cp_zap/amaki_zap/input/am4200a.html">苦しい恋はもう終わり◆あなたはあの人を【想い続ける⇔諦める】べき</a></h3>
                       </div>
                       <div class="clear"></div>
                          <p class="caption">『本心がわからない！』普段のあの人の振る舞いや発言に惑わされてはいけません。そう、甘い考えは危険よ。苦しい恋の現状をどうにかしたいのなら、あの人の状況と今後の展開、そしてあなたはどうすべきか、知ってちょうだい。少しは楽になるんじゃないかしら？</p>
                       <p class="price_info">1,320円（税込）</p>
                     </div>
                   </div>
                 </div>
               </div>
               <div class="horizon"></div>
               <div class="menu_bdy">
                 <div class="menu_ftr">
                   <div class="menu_hdr">
                     <div class="severalmenu">
                       <div class="icon">
                         <span width="120" height="120" title="人生" class="icon_category_21"></span>
                       </div>
                       <div class="menu_info">
                         <h3><a href="/cp_zap/amaki_zap/input/am1800a.html">当てすぎ“神霊対話”にゾッ！『あなたの人生、次●●が起こるわよ』</a></h3>
                       </div>
                       <div class="clear"></div>
                          <p class="caption">『あなたの運命視えたわ……』脅威の未来予知で奇跡体験！◆間近に迫る未来であなたの人生に訪れる出来事と、その後の変わっていく状況をこれから教えるわね。この訪れは、これまでのあなたが、今より●●になるものよ。</p>
                       <p class="price_info">880円（税込）</p>
                     </div>
                   </div>
                 </div>
               </div>
             </div>
           </div>
         </div>
       </div>
       <hr>
    
    
             <div id="free_group">
               <h2><img width="100%" height="auto" src="https://lw6nr4oyej.user-space.cdn.idcfcloud.net/amaki_zap/image/index/free_group/section_title.jpg" alt="完全無料メニュー"></h2>
               <div class="section_bdy">
                 <div class="section_ftr">
                   <div class="section_hdr">
                     <div class="menu_bdy">
                       <div class="severalmenu">
                         <div class="icon">
                           <span title="無料結婚" width="120" height="120" class="icon_category_29"></span>
                         </div>
                         <div class="menu_info">
                           <h3 class="color_category_29"><a href="/cp_zap/amaki_zap/input/am0100a.html">【リアル神霊対話で判明】あなたの結婚運×異性を惹きつける今の魅力</a></h3>
                         </div>
                         <div class="clear"></div>
                         <p class="caption">結婚はあなたにとって、ベストなタイミングで訪れるものよ。だから今、結婚していなくても不安に思うことはないわ。今日はあなたが持つ『結婚運』と、異性を惹きつける『魅力』について、その現実を視ていくわね。</p>
                       </div>
                     </div>
                     <div class="horizon"></div>
                     <div class="menu_bdy">
                       <div class="severalmenu">
                         <div class="icon">
                           <span title="無料人生" width="120" height="120" class="icon_category_24"></span>
                         </div>
                         <div class="menu_info">
                           <h3 class="color_category_24"><a href="/cp_zap/amaki_zap/input/am0101a.html">自己覚醒◆神霊対話で明かされる【あなたに宿る力×この世の使命】</a></h3>
                         </div>
                         <div class="clear"></div>
                         <p class="caption">驚くかも知れないけど、あなたがここに来たのは神霊たちの導きがあったからよ。あなたの身の回りに起きることに偶然はなく、全てに意味があり必然。だから、私がここで伝えるべきあなたの人生に今、必要なメッセージを届けるわ。どうか自分を信じ、自分を愛し、慈しんで。</p>
                       </div>
                     </div>
                     <div class="horizon"></div>
                     <div class="menu_bdy">
                       <div class="severalmenu">
                         <div class="icon">
                           <span title="無料恋愛" width="120" height="120" class="icon_category_13"></span>
                         </div>
                         <div class="menu_info">
                           <h3 class="color_category_13"><a href="/cp_zap/amaki_zap/input/am0200a.html">心の声、降ろすわね……◇あの人が最近伝えられなかった言葉は●●よ</a></h3>
                         </div>
                         <div class="clear"></div>
                         <p class="caption">あの人が何を考えているのかわからない……直接聞けないあの人の“心の奥”にある想いを、今日はこっそり明かすわ。あの人があなたに伝えられていないこと、今この瞬間、抱えている“ある想い”まで、降りてきた言葉をそのまま届けるわね。</p>
                       </div>
                     </div>
                   </div>
                 </div>
               </div>
             </div>
            <hr>


            <div id="allmenus">
              <div id="group1">
                <h2><img width="640" height="180" style="width:100%;height:auto;" src="https://lw6nr4oyej.user-space.cdn.idcfcloud.net/amaki_zap/image/index/allmenu/group1/section_title.jpg" alt="あの人との恋・片想い"></h2>
                <div class="section_bdy">
                  <div class="section_ftr">
                    <div class="section_hdr">
                      <div class="menu_bdy">
                        <div class="menu_ftr">
                          <div class="menu_hdr">
                            <a href="/cp_zap/amaki_zap/input/am9600a.html">
                            <div class="severalmenu">
                              <div class="icon">
                                <span title="恋愛特別鑑定" class="icon_category_1"></span>
                              </div>
                              <div class="menu_info">
                                <div class="menu_ttl">
                                  <h3>両想い∞強力縁結び【二人の宿縁/あの人の想い/結婚縁】恋愛成就霊視</h3>
                                </div>
                              </div>
                              <div class="clear"></div>
                            <p class="caption">『あの人に一生愛され続ける』二人の愛と縁を結ぶ恋愛成就霊視◆この恋を叶えるため、あの人の想いや二人の間にある特別な絆、そして約束された未来をこれからお見せするわね。あなたとあの人の“出会いは必然だった”……それが本物だって証を形にするわ。</p>
                            <div class="price_info">
                                <p class="price_normal">3,740円（税込）</p>
                              </div>
                            </div>
                            </a>
                          </div>
                        </div>
                      </div>
                      <div class="horizon"></div>
                      <div class="menu_bdy">
                        <div class="menu_ftr">
                          <div class="menu_hdr">
                            <a href="/cp_zap/amaki_zap/input/am9400a.html">
                            <div class="severalmenu">
                              <div class="icon">
                                <span title="あの人の気持ち" class="icon_category_5"></span>
                              </div>
                              <div class="menu_info">
                                <div class="menu_ttl">
                                  <h3>覚悟※神霊対話で心奥暴く！【あの人のリアルすぎる15の本音】全暴露</h3>
                                </div>
                              </div>
                              <div class="clear"></div>
                            <p class="caption">申し訳ないけれど、どんなに上手く隠していても私の前ではそれは無意味よ。だってあの人の守護霊に尋ねれば、心の声……そう“本音”が全てわかってしまうから。今日は、あの人が隠し持つあなたへの数々の想いを、一つ残らずここで明かしていくわね。さぁ、心の準備はいい？</p>
                            <div class="price_info">
                                <p class="price_normal">3,190円（税込）</p>
                              </div>
                            </div>
                            </a>
                          </div>
                        </div>
                      </div>
                      <div class="horizon"></div>
                      <div class="menu_bdy">
                        <div class="menu_ftr">
                          <div class="menu_hdr">
                            <a href="/cp_zap/amaki_zap/input/am9401a.html">
                            <div class="severalmenu">
                              <div class="icon">
                                <span title="不倫愛" class="icon_category_10"></span>
                              </div>
                              <div class="menu_info">
                                <div class="menu_ttl">
                                  <h3>不倫占【あの人との愛確かめる20章】あなたへの本音/覚悟/愛の終着点</h3>
                                </div>
                              </div>
                              <div class="clear"></div>
                            <p class="caption">あの人との関係はずっとこのまま？　この愛は本物？――あなたが不安に思うその問いに、私がハッキリと答えを出すわ。あの人のあなたへの覚悟や愛情、この関係に対する本音、そしてあなたたちがどんな結末を選ぶのか……綺麗事ナシで真実に迫るわね。</p>
                            <div class="price_info">
                                <p class="price_normal">3,190円（税込）</p>
                              </div>
                            </div>
                            </a>
                          </div>
                        </div>
                      </div>
                      <div class="horizon"></div>
                      <div class="menu_bdy">
                        <div class="menu_ftr">
                          <div class="menu_hdr">
                            <a href="/cp_zap/amaki_zap/input/am8000a.html">
                            <div class="severalmenu">
                              <div class="icon">
                                <span title="あの人の本性" class="icon_category_8"></span>
                              </div>
                              <div class="menu_info">
                                <div class="menu_ttl">
                                  <h3>繋がりたいのは本望よ。【極秘官能占】あの人の欲望/衝動/誘惑サイン</h3>
                                </div>
                              </div>
                              <div class="clear"></div>
                            <p class="caption">恥ずかしがる必要なんてないのよ。あの人との愛を確かめ合いたい、ベッドの上で交じり合うときあの人がどんな顔を見せるのか、どんな欲望にかられるのか。ちょっと覗いて見てみましょうか……淫らな想いも、隠したい欲求も……あの人の欲望の全てを受け入れてね。</p>
                            <div class="price_info">
                                <p class="price_normal">2,200円（税込）</p>
                              </div>
                            </div>
                            </a>
                          </div>
                        </div>
                      </div>
                      <div class="horizon"></div>
                      <div class="menu_bdy">
                        <div class="menu_ftr">
                          <div class="menu_hdr">
                            <a href="/cp_zap/amaki_zap/input/am8001a.html">
                            <div class="severalmenu">
                              <div class="icon">
                                <span title="復縁" class="icon_category_9"></span>
                              </div>
                              <div class="menu_info">
                                <div class="menu_ttl">
                                  <h3>復縁できる？【元サヤ救済霊視】相手の未練/今の望み/今後の可能性</h3>
                                </div>
                              </div>
                              <div class="clear"></div>
                            <p class="caption">『今も忘れられない……』本気で復縁したい相手がいるなら、無理にあの人を忘れる必要はないわ。それと同時に、やみくもに動いてもいけません。今あの人はあなたをどう想っているのか、動く意思はあるのか、二人が迎える本当の結末が何か、ここで明らかにしていきましょう。</p>
                            <div class="price_info">
                                <p class="price_normal">2,200円（税込）</p>
                              </div>
                            </div>
                            </a>
                          </div>
                        </div>
                      </div>
                      <div class="horizon"></div>
                      <div class="menu_bdy">
                        <div class="menu_ftr">
                          <div class="menu_hdr">
                            <a href="/cp_zap/amaki_zap/input/am6000a.html">
                            <div class="severalmenu">
                              <div class="icon">
                                <span title="あの人の気持ち" class="icon_category_5"></span>
                              </div>
                              <div class="menu_info">
                                <div class="menu_ttl">
                                  <h3>迷惑or期待している◆相手の今の心境⇒あなたへの執着度/願望/恋未来</h3>
                                </div>
                              </div>
                              <div class="clear"></div>
                            <p class="caption">人は不思議なもので、好意を抱くと途端に臆病になってしまうもの。誰だって傷つきたくなんかないもの、あなたもそうよね？　きっとあの人にも何か事情があるはずだから、今の想いやあなたに望むこと、そしてこの関係をどうしたいのか……その真実を明らかにするわ。</p>
                            <div class="price_info">
                                <p class="price_normal">1,650円（税込）</p>
                              </div>
                            </div>
                            </a>
                          </div>
                        </div>
                      </div>
                      <div class="horizon"></div>
                      <div class="menu_bdy">
                        <div class="menu_ftr">
                          <div class="menu_hdr">
                            <a href="/cp_zap/amaki_zap/input/am6001a.html">
                            <div class="severalmenu">
                              <div class="icon">
                                <span title="あの人の気持ち" class="icon_category_5"></span>
                              </div>
                              <div class="menu_info">
                                <div class="menu_ttl">
                                  <h3>これが現実よ。曖昧なあの人、実はあなたを【手に入れたいor無関心】</h3>
                                </div>
                              </div>
                              <div class="clear"></div>
                            <p class="caption">思うように進まない状況にやきもきしているようね。「あの人は一体何を考えてる？」……可能性として理由は二つよ。あの人があなたのことを真剣に考えているから、軽はずみに動けない。そしてもう一つは、興味がない。あの人の心の中にある想い……知る勇気、ある？</p>
                            <div class="price_info">
                                <p class="price_normal">1,650円（税込）</p>
                              </div>
                            </div>
                            </a>
                          </div>
                        </div>
                      </div>
                      <div class="horizon"></div>
                      <div class="menu_bdy">
                        <div class="menu_ftr">
                          <div class="menu_hdr">
                            <a href="/cp_zap/amaki_zap/input/am6002a.html">
                            <div class="severalmenu">
                              <div class="icon">
                                <span title="恋の行方" class="icon_category_4"></span>
                              </div>
                              <div class="menu_info">
                                <div class="menu_ttl">
                                  <h3>この恋叶う？【年の差/既婚/職場etc】相手の本音/好みのタイプ/結論</h3>
                                </div>
                              </div>
                              <div class="clear"></div>
                            <p class="caption">相手のほうから告白される。そんな瞬間を、一度でも想像したことがあるかしら？　その前に、あの人があなたを恋愛対象としてみているか、それともただ人として好きなのか、あなたに対する「真っ正直」な本音をお伝えするわ。この恋が叶うかどうか、最後まで教えるわね。</p>
                            <div class="price_info">
                                <p class="price_normal">1,650円（税込）</p>
                              </div>
                            </div>
                            </a>
                          </div>
                        </div>
                      </div>
                      <div class="horizon"></div>
                      <div class="menu_bdy">
                        <div class="menu_ftr">
                          <div class="menu_hdr">
                            <a href="/cp_zap/amaki_zap/input/am4200a.html">
                            <div class="severalmenu">
                              <div class="icon">
                                <span title="片想い" class="icon_category_3"></span>
                              </div>
                              <div class="menu_info">
                                <div class="menu_ttl">
                                  <h3>苦しい恋はもう終わり◆あなたはあの人を【想い続ける⇔諦める】べき</h3>
                                </div>
                              </div>
                              <div class="clear"></div>
                            <p class="caption">『本心がわからない！』普段のあの人の振る舞いや発言に惑わされてはいけません。そう、甘い考えは危険よ。苦しい恋の現状をどうにかしたいのなら、あの人の状況と今後の展開、そしてあなたはどうすべきか、知ってちょうだい。少しは楽になるんじゃないかしら？</p>
                            <div class="price_info">
                                <p class="price_normal">1,320円（税込）</p>
                              </div>
                            </div>
                            </a>
                          </div>
                        </div>
                      </div>
                      <div class="horizon"></div>
                      <div class="menu_bdy">
                        <div class="menu_ftr">
                          <div class="menu_hdr">
                            <a href="/cp_zap/amaki_zap/input/am6800a.html">
                            <div class="severalmenu">
                              <div class="icon">
                                <span title="あの人の気持ち" class="icon_category_5"></span>
                              </div>
                              <div class="menu_info">
                                
                                <div class="menu_ttl">
                                  <h3>最後二人は【結ばれるorお別れ】相手が隠す本音/位置づけ/最終関係</h3>
                                </div>
                              </div>
                              <div class="clear"></div>
                            <p class="caption">あの人に、あなたが感じている「予感」。今、あの人の様子に何か引っかかるものがあるみたいね。あなたの前であの人がそんな風になってしまうのは、きっと“ある気持ち”をあなたに悟られたくないからよ。覚悟があるなら、煮え切らないこの恋の真相を暴いていくわ。</p>
                            <span title="新着" class="icon_new"></span>
                            <div class="price_info">
                                <p class="price_normal">1,980円（税込）</p>
                              </div>
                            </div>
                            </a>
                          </div>
                        </div>
                      </div>
                    </div>
                  </div>
                </div>
              </div>
              <div id="group2">
                <h2><img width="640" height="180" style="width:100%;height:auto;" src="https://lw6nr4oyej.user-space.cdn.idcfcloud.net/amaki_zap/image/index/allmenu/group2/section_title.jpg" alt="あなたの結婚・出会い"></h2>
                <div class="section_bdy">
                  <div class="section_ftr">
                    <div class="section_hdr">
                      <div class="menu_bdy">
                        <div class="menu_ftr">
                          <div class="menu_hdr">
                            <a href="/cp_zap/amaki_zap/input/am9000a.html">
                            <div class="severalmenu">
                              <div class="icon">
                                <span title="結婚特別鑑定" class="icon_category_26"></span>
                              </div>
                              <div class="menu_info">
                                <div class="menu_ttl">
                                  <h3>縁結びSP霊視【あなたの結婚相手は誰？】相手の特徴/出会う場面/婚期</h3>
                                </div>
                              </div>
                              <div class="clear"></div>
                            <p class="caption">大切なのは早く結婚することではなく、“どんな人と結婚すればあなたが幸せになれるのか”なのよ。神霊はその全てをわかっているわ。だから、あなたの結婚相手がどんな人なのかここで全て明かすわ。その人物の顔や性格、そして出会いの場面から婚期まで……お伝えするわね。</p>
                            <div class="price_info">
                                <p class="price_normal">2,750円（税込）</p>
                              </div>
                            </div>
                            </a>
                          </div>
                        </div>
                      </div>
                      <div class="horizon"></div>
                      <div class="menu_bdy">
                        <div class="menu_ftr">
                          <div class="menu_hdr">
                            <a href="/cp_zap/amaki_zap/input/am7001a.html">
                            <div class="severalmenu">
                              <div class="icon">
                                <span title="運命の相手" class="icon_category_15"></span>
                              </div>
                              <div class="menu_info">
                                <div class="menu_ttl">
                                  <h3>緊急霊視※周りはあなたをどう見てる？　もう運命の人と出会ってる？</h3>
                                </div>
                              </div>
                              <div class="clear"></div>
                            <p class="caption">【神霊対話でピタリと的中！】もしかしたらあなたは今、ご自分に出会いの気配を感じていないのかもしれません。でも、“特別な縁”っていうのは必ず巡ってくるものよ。そのときを見逃さないよう、あなたの周りの目線や出会いについて視えたものを、ズバリお伝えするわね。</p>
                            <div class="price_info">
                                <p class="price_normal">2,200円（税込）</p>
                              </div>
                            </div>
                            </a>
                          </div>
                        </div>
                      </div>
                    </div>
                  </div>
                </div>
              </div>
              <div id="group3">
                <h2><img width="640" height="180" style="width:100%;height:auto;" src="https://lw6nr4oyej.user-space.cdn.idcfcloud.net/amaki_zap/image/index/allmenu/group3/section_title.jpg" alt="あなたの人生・仕事"></h2>
                <div class="section_bdy">
                  <div class="section_ftr">
                    <div class="section_hdr">
                      <div class="menu_bdy">
                        <div class="menu_ftr">
                          <div class="menu_hdr">
                            <a href="/cp_zap/amaki_zap/input/am9700a.html">
                            <div class="severalmenu">
                              <div class="icon">
                                <span title="人生特別鑑定" class="icon_category_19"></span>
                              </div>
                              <div class="menu_info">
                                <div class="menu_ttl">
                                  <h3>神霊が語る宿命【あなたの使命/可能性/財/転機】晩年まで⇒完全網羅</h3>
                                </div>
                              </div>
                              <div class="clear"></div>
                            <p class="caption">【この鑑定が転機になる】あなたの幸せを願う神霊が今あなたに伝えたいこと……そこには目の前にある人生の見方が変わるようなたくさんの“ヒント”が隠されているの。これから訪れる人生の可能性や転機、人との関わりや晩年の生活まで、私に視えるもの全てお伝えするわ。</p>
                            <div class="price_info">
                                <p class="price_normal">3,740円（税込）</p>
                              </div>
                            </div>
                            </a>
                          </div>
                        </div>
                      </div>
                      <div class="horizon"></div>
                      <div class="menu_bdy">
                        <div class="menu_ftr">
                          <div class="menu_hdr">
                            <a href="/cp_zap/amaki_zap/input/am7000a.html">
                            <div class="severalmenu">
                              <div class="icon">
                                <span title="仕事" class="icon_category_22"></span>
                              </div>
                              <div class="menu_info">
                                <div class="menu_ttl">
                                  <h3>知れば変わるわ。働くあなたの【本当の評価×BIGチャンス】得る成功</h3>
                                </div>
                              </div>
                              <div class="clear"></div>
                            <p class="caption">仕事というのは生活の大部分を占めるもの。『上手くいってない……』もしそう思っているなら、それはあなたが、“本当の自分”を生きていないからかもしれないわ。だから、あなたは自身が持つ素晴らしい才能を知り、それを活かすべき。あなたの価値はもっと輝くはずよ。</p>
                            <div class="price_info">
                                <p class="price_normal">2,200円（税込）</p>
                              </div>
                            </div>
                            </a>
                          </div>
                        </div>
                      </div>
                      <div class="horizon"></div>
                      <div class="menu_bdy">
                        <div class="menu_ftr">
                          <div class="menu_hdr">
                            <a href="/cp_zap/amaki_zap/input/am1800a.html">
                            <div class="severalmenu">
                              <div class="icon">
                                <span title="人生" class="icon_category_21"></span>
                              </div>
                              <div class="menu_info">
                                <div class="menu_ttl">
                                  <h3>当てすぎ“神霊対話”にゾッ！『あなたの人生、次●●が起こるわよ』</h3>
                                </div>
                              </div>
                              <div class="clear"></div>
                            <p class="caption">『あなたの運命視えたわ……』脅威の未来予知で奇跡体験！◆間近に迫る未来であなたの人生に訪れる出来事と、その後の変わっていく状況をこれから教えるわね。この訪れは、これまでのあなたが、今より●●になるものよ。</p>
                            <div class="price_info">
                                <p class="price_normal">880円（税込）</p>
                              </div>
                            </div>
                            </a>
                          </div>
                        </div>
                      </div>
                    </div>
                  </div>
                </div>
              </div>
            </div>

      
      <div id="attention">
      <h3 title="注意事項">注意事項</h3>
      <div id="attentionBody">
        <ol>
          <li>ご利用料金について<br />
          <p>「『私も視てほしい！』脅威の神霊対話で心奥暴く◆憑依ユタ◆天稀三輪」は有料コンテンツです。占いをご購入の都度、表示料金のお支払いが必要となります。同じ占いメニューを同じ内容で占う場合でも、その都度料金が発生しますのでご注意ください。</p><div class="attentionLine"></div></li>
          <li>占い結果について<br />
          <p>一度ご購入いただいた占い結果は、最初に購入された日を含め10日間閲覧が可能です。ご購入した際に送信されます注文受付自動配信メールをご確認いただき、そちらに記載されておりますURLより閲覧することが可能です。ご購入した占い結果をデータとして保存しておくことはできませんので、10日間を超えて保存されたい場合は別途プリントアウト等されることを推奨いたします。</p><div class="attentionLine"></div></li>
          <li>利用推奨環境<br />
            この占い番組は、次の環境でご利用ください。<br />
            ▼パソコン<br />
            ＜OS＞<br />
            <ul>
            <li>Windows：Windows 7 以上</li>
            <li>Macintosh：Mac OS X 10.11（El Capitan）以上</li>
            </ul>
            ＜ブラウザ＞ <br />
            <ul>
            <li>Windows：Microsoft Edge最新版、Firefox最新版、Google Chrome最新版、またはそれに相当するブラウザ。</li>
            <li>Macintosh：Safari 9.0以降、またはそれに相当するブラウザ。</li>
            <li class="noMark">※JavaScriptの設定をONにしてご利用ください。</li>
            <li class="noMark">※Cookieの設定をONにしてご利用ください。</li>
            <li class="noMark">※NetscapeはWindows、Macintosh共に非対応です。</li>
            </ul><br />
            ▼スマートフォン<br />
            ＜OS＞<br />
            <ul>
            <li>Android 5.0以降</li>
            <li>iOS 10.0以降</li>
            </ul>
            ＜ブラウザ＞ <br />
            <ul>
            <li><p>OSに標準搭載されているブラウザ。</p></li>
            <li class="noMark">※JavaScriptの設定をONにしてご利用ください。</li>
            </ul>
          <div class="attentionLine"></div></li>
          <li>決済方法について
            <ul>
            <li><p>当コンテンツお支払いには、クレジットカード・WebMoney（ウェブマネー）・携帯キャリア決済・Amazon Payをご利用いただけます。</p></li>
            <li><p>他者による不正利用防止のため、クレジットカード情報のほかに、セキュリティコード、お電話番号、メールアドレスをご入力いただく方式を採用しております。お客様に安心してご利用いただけるよう、入力いただいた情報は、SSLで暗号化され、送信されます。</p></li>
            </ul>
          <div class="attentionLine"></div></li>
          <li>特定商取引法に基づく表記
            <ul>
              <li><a href="/notice/" onClick="targetPage(this); return false;" target="_217_isp">特定商取引法に基づく表記</a></li>
              <li><a href="/agreement/" onClick="targetPage(this); return false;" target="_217_isp">利用規約</a></li>
            </ul>
          </li>
        </ol>
        <ul class="attentionLink">
        <li><p>このサービスのお問い合わせは<a href="/inquiry/?cont_id=352" target="_217_form">こちら</a>をご覧ください。</p></li>
        </ul>
      </div>
    </div>
      </div>
          
          <div id="footer">
            <div id="footernavi">
              <ul><li>|&nbsp;<a href="/moon/">cocoloni占い館 Moon&nbsp;Top</a>&nbsp;</li><li>|&nbsp;<a href="/sitemap/">サイトマップ</a>&nbsp;|</li></ul>
            </div>
            <div class="clear"></div>
        <p class="contents_footerCopy">人気の占いを集めた占いポータルサイトcocoloni占い館 Moon｜<span class="cp_zap_short_title">神霊対話◆天稀三輪</span></p>
      <div id="footerCopy">

    <div id="footer_campaign">
      <p style="text-align:center;margin-bottom:5px;"><a href="/cp_hon/ishiiyukari_hon/" target="_contents">石井ゆかりの月間占い</a></p>
      <p style="text-align:center;margin-bottom:5px;"><a href="/cp_zap/special/2021/01a/" target="_contents">TV出演で大人気の占い師特集-星ひとみ・シウマ・木下レオン-</a></p>
      <p style="text-align:center;margin-bottom:5px;"><a href="/cp_zap/special/2020/07a/" target="_contents">運命を変える数意学◆シウマ特集</a></p>
      <p style="text-align:center;margin-bottom:5px;"><a href="/cp_zap/special/2019/03b/" target="_contents">レオン・サリラ大特集!!</a></p>
      <p style="text-align:center;margin-bottom:5px;"><a href="/cp_zap/special/2017/10b/" target="_contents">島田秀平＆原宿の母★開運占い特集</a></p>
      <p style="text-align:center;margin-bottom:5px;"><a href="/cp_zap/special/2017/10a/" target="_contents">鏡リュウジ特集</a></p>
      <p style="text-align:center;margin-bottom:5px;"><a href="/cp_zap/special/2017/04a/" target="_contents">川井春水「氣札運開術＆荘厳契密法」特集</a></p>
      <p style="text-align:center;margin-bottom:5px;"><a href="/cp_zap/special/2016/11b/" target="_contents">水晶玉子特集</a></p>
    </div>

      </div>      </div>
        <div id="topicpath" class="is_sp">
          <p><span class="def"></span><input type="hidden" name="contents_name" value="amaki_zap">&nbsp;&gt;&nbsp;『私も視てほしい！』脅威の神霊対話で心奥暴く◆憑依ユタ◆天稀三輪</p>
        </div>

    </div>
  </div>
  <hr>
  
        <link rel="stylesheet" type="text/css" href="https://lw6nr4oyej.user-space.cdn.idcfcloud.net/cp_zap/common/source/css/topicpath.css">
        <div id="breadcrumblist">
          <div class="linkbox">
            <div class="linkbox_inner">
              <span class="def"></span><input type="hidden" name="contents_name" value="amaki_zap">
            </div>
          </div>
        </div>
        <div id="isp_footer" style="display:none;"></div>  
<!-- marketing -->
</body>
</html>"""

# %%
df = html_to_df_zap(html_str)
# Out:
# start html_to_df_zap
# Pattern 2: 1,980円（税込）
# Pattern 1: 3,190円（税込）
# Pattern 1: 2,200円（税込）
# Pattern 1: 1,320円（税込）
# Pattern 1: 2,200円（税込）
# Pattern 1: 2,200円（税込）
# Pattern 1: 880円（税込）
# Pattern 1: 1,650円（税込）
# Pattern 1: 1,650円（税込）
# Pattern 1: 1,650円（税込）
# Pattern 1: 3,740円（税込）
# Pattern 1: 2,750円（税込）
# Pattern 1: 3,740円（税込）
# Pattern 1: 2,200円（税込）
# Pattern 1: 3,190円（税込）
# Pattern 1: 2,200円（税込）
# Pattern 1: 2,200円（税込）
# Pattern 1: 3,740円（税込）
# Pattern 1: 2,200円（税込）
# Pattern 1: 1,650円（税込）
# Pattern 1: 1,320円（税込）
# Pattern 1: 880円（税込）
# No price found
# No price found
# No price found
# Pattern 2: 3,740円（税込）
# Pattern 2: 3,190円（税込）
# Pattern 2: 3,190円（税込）
# Pattern 2: 2,200円（税込）
# Pattern 2: 2,200円（税込）
# Pattern 2: 1,650円（税込）
# Pattern 2: 1,650円（税込）
# Pattern 2: 1,650円（税込）
# Pattern 2: 1,320円（税込）
# Pattern 2: 1,980円（税込）
# Pattern 2: 2,750円（税込）
# Pattern 2: 2,200円（税込）
# Pattern 2: 3,740円（税込）
# Pattern 2: 2,200円（税込）
# Pattern 2: 880円（税込）

# %%
df
# Out:
#                               menu_html  \
# 0     最後二人は【結ばれるorお別れ】相手が隠す本音/位置づけ/最終関係
# 1     覚悟※神霊対話で心奥暴く！【あの人のリアルすぎる15の本音】全暴露
# 2     繋がりたいのは本望よ。【極秘官能占】あの人の欲望/衝動/誘惑サイン
# 3      苦しい恋はもう終わり◆あなたはあの人を【想い続ける⇔諦める】べき
# 4     知れば変わるわ。働くあなたの【本当の評価×BIGチャンス】得る成功
# 5      緊急霊視※周りはあなたをどう見てる？　もう運命の人と出会ってる？
# 6      当てすぎ“神霊対話”にゾッ！『あなたの人生、次●●が起こるわよ』
# 7    迷惑or期待している◆相手の今の心境⇒あなたへの執着度/願望/恋未来
# 8     これが現実よ。曖昧なあの人、実はあなたを【手に入れたいor無関心】
# 9   この恋叶う？【年の差/既婚/職場etc】相手の本音/好みのタイプ/結論
# 10    両想い∞強力縁結び【二人の宿縁/あの人の想い/結婚縁】恋愛成就霊視
# 11   縁結びSP霊視【あなたの結婚相手は誰？】相手の特徴/出会う場面/婚期
# 12    神霊が語る宿命【あなたの使命/可能性/財/転機】晩年まで⇒完全網羅
# 13    繋がりたいのは本望よ。【極秘官能占】あの人の欲望/衝動/誘惑サイン
# 14   不倫占【あの人との愛確かめる20章】あなたへの本音/覚悟/愛の終着点
# 15    知れば変わるわ。働くあなたの【本当の評価×BIGチャンス】得る成功
# 16     緊急霊視※周りはあなたをどう見てる？　もう運命の人と出会ってる？
# 17    神霊が語る宿命【あなたの使命/可能性/財/転機】晩年まで⇒完全網羅
# 18     復縁できる？【元サヤ救済霊視】相手の未練/今の望み/今後の可能性
# 19  この恋叶う？【年の差/既婚/職場etc】相手の本音/好みのタイプ/結論
# 20     苦しい恋はもう終わり◆あなたはあの人を【想い続ける⇔諦める】べき
# 21     当てすぎ“神霊対話”にゾッ！『あなたの人生、次●●が起こるわよ』
# ...
